# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from graphviz import Digraph
import scipy.spatial.distance
from scipy.cluster.hierarchy import dendrogram
#Clustering birch
from freediscovery.cluster import birch_hierarchy_wrapper
from freediscovery.cluster import Birch,BirchSubcluster
#Sklearn
from sklearn.metrics.pairwise import pairwise_distances
from sklearn.model_selection import train_test_split
from sklearn import metrics
#Learners
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import OneClassSVM
#Distance measure
from scipy.spatial.distance import euclidean

import warnings

import matplotlib.pyplot as plt

# %%
warnings.filterwarnings("ignore")

# %%
class bcluster(object):
    
    def __init__(self):
        self.parent = None
        self.parent_id = None
        self.depth = None
        self.size = None
        self.cluster_id = None
        self.data_points = []
        self.test_points = []
        self.test_labels = []
        self.predicted = []
        self.centroid = None
        self.classifier = None
        self.outlier_model = None
        self.cluster_obj = None
        self.outlier_points = []
        self.score = []
        self.d1 = None
        self.d2 = None
        self.threshold = None
    
    def set_parent(self,parent_node=None):
        if parent_node == None:
            self.parent = None
            self.parent_id = None
        else:
            self.parent = parent_node
            self.parent_id = parent_node.cluster_id
    
    def set_depth(self,depth):
        self.depth = depth
    
    def set_size(self,size):
        self.size = size
        
    def set_cluster_id(self,cluster_id):
        self.cluster_id = cluster_id
        
    def set_data_points(self,data_points):
        self.data_points = data_points
    
    def set_test_labels(self,test_labels):
        self.test_labels = test_labels
        
    def add_test_points(self,test_point):
        self.test_points.append(test_point)
        
    def add_predicted(self,predicted):
        self.predicted.append(predicted)
    
    def set_centroid(self,centroid):
        self.centroid = centroid
        
    def set_classifier(self,classifier):
        self.classifier = classifier
        
    def set_outlier_model(self,outlier_model):
        self.outlier_model = outlier_model
        
    def set_cluster_obj(self,cluster_obj):
        self.cluster_obj = cluster_obj
        
    def add_outlier_points(self,outlier_points):
        self.outlier_points.append(outlier_points)
        
    def set_score(self,score):
        self.score = score
        
    def add_d1(self,d1):
        self.d1 = d1
        
    def add_d2(self,d2):
        self.d2 = d2
        
    def calculate_threshold(self,outlier_threshold):
        self.threshold = max(self.d1,self.d2)*outlier_threshold
        
    def check_outlier(self,distance):
        if self.threshold < distance:
            result = True
        else:
            result = False
        return result
    
    def check_OCS_outlier(self,test_data):
        if self.outlier_model.predict([test_data]) == -1:
            result = True
        else:
            result = False
        return result

# %%
class birch(object):

    def __init__(self,threshold=0.7,branching_factor=40,n_clusters=None,outlier_threshold=0.7):
        self.threshold = threshold
        self.branching_factor = branching_factor
        self.n_clusters = n_clusters
        self.outlier_threshold = outlier_threshold
        self.Birch_clusterer = Birch(threshold=self.threshold, branching_factor=self.branching_factor,
                                     n_clusters=self.n_clusters,compute_sample_indices=True)
    # Fitting the model with train_X
    def fit(self,data,y):
        self.data = data
        self.y = y
        #self.data.drop(self.data.columns[len(self.data.columns)-1], axis=1, inplace=True)
        self.Birch_clusterer.fit(self.data)

    #Defines and builds the Cluster Feature Tree
    def get_cluster_tree(self):
        self.htree, n_clusters = birch_hierarchy_wrapper(self.Birch_clusterer)
        clusters = {}
        max_depth = 0
        for i in range(n_clusters):
            #print('cluster:', i)
            node = bcluster()
            sub_cluster = self.htree.flatten()[i]
            node.set_cluster_id(sub_cluster['cluster_id'])
            depth = sub_cluster.current_depth
            node.set_depth(depth)
            if depth > max_depth:
                max_depth = depth
            if i not in clusters.keys():
                clusters[i] = {}
            if sub_cluster.current_depth == 0:
                node.set_parent()
            else:
                node.set_parent(clusters[sub_cluster.parent['cluster_id']])
            cluster_size = sub_cluster['cluster_size']
            node.set_size(cluster_size)
            data_points = sub_cluster['document_id_accumulated']
            node.set_data_points(data_points)
            centroid = self.data.iloc[sub_cluster['document_id_accumulated'], :].mean(axis=0).values
            node.set_centroid(centroid)
            d1,d1_v = self.calculate_d1(centroid,data_points)
            d2 = self.calculate_d2(centroid,data_points,d1_v)
            node.add_d1(d1)
            node.add_d2(d2)
            node.calculate_threshold(self.outlier_threshold)
            clusters[i] = node
        return clusters,max_depth
    
    #Calculate the d1 distance(point farthest away from centroid)
    def calculate_d1(self,centroid,data_points):
        d1 = 0
        u = centroid
        d1_v = None
        for point in data_points:
            v = point
            distance = euclidean(u,v)
            if distance>d1:
                d1 = distance
                d1_v = v
        return d1,d1_v
    
    #Calculate the d2 distance(point farthest away from d1 and its distance from centroid)
    def calculate_d2(self,centroid,data_points,d1_v):
        d2_d1 = 0
        u = d1_v
        d2_v = None
        for point in data_points:
            v = point
            distance = euclidean(u,v)
            if distance>d2_d1:
                d2_d1 = distance
                d2_v = v
        d2 = euclidean(centroid,v)
        return d2
    
    # Display's the tree
    def show_clutser_tree(self):
        self.htree.display_tree()
        
    # Add classification model at each node and leaf
    def model_adder(self,cluster_tree):
        for cluster_id in cluster_tree:
            clf = DecisionTreeClassifier(criterion='entropy')
            sample_points = cluster_tree[cluster_id].data_points
            train_X_sub = self.data.iloc[sample_points,:]
            train_y_sub = self.y.iloc[sample_points]
            clf.fit(train_X_sub,train_y_sub)
            cluster_tree[cluster_id].set_classifier(clf)
        return cluster_tree
    
    def outlier_model_adder(self,cluster_tree):
        for cluster_id in cluster_tree:
            clf = OneClassSVM(nu=0.1)
            sample_points = cluster_tree[cluster_id].data_points
            train_X_sub = self.data.iloc[sample_points,:]
            clf.fit(train_X_sub)
            cluster_tree[cluster_id].set_outlier_model(clf)
        return cluster_tree
        
    # Prediction Function with height based prediction with outlier detection
    def predict(self,test_X,depth,do_predict=True):
        predicted = []
        for test_instance in test_X.iterrows():
            test_sample = test_instance[1].values
            min_distance = float('inf')
            selected_cluster = None
            for cluster_id in cluster_tree:
                if cluster_tree[cluster_id].depth != depth:
                    continue
                u = cluster_tree[cluster_id].centroid
                v = np.asarray(test_sample,dtype='float64')
                distance = euclidean(u,v)
                if distance < min_distance:
                    min_distance = distance
                    selected_cluster = cluster_id
            cluster_tree[selected_cluster].add_test_points(test_instance[0])
            # Outlier identifier
            if cluster_tree[selected_cluster].check_outlier(min_distance):
                cluster_tree[selected_cluster].add_outlier_points(test_instance[0])
            if do_predict:
                _predicted_label = cluster_tree[selected_cluster].classifier.predict([test_sample])
                cluster_tree[selected_cluster].add_predicted(_predicted_label)
                predicted.append(_predicted_label)
        return predicted
    
    def distance(self,x,y):
        dist = (list(x[:,1]) - y)**2
        dist = np.sum(dist, axis=1)
        dist = np.sqrt(dist)
        ind = np.unravel_index(np.argmin(dist, axis=None), dist.shape)
        min_distance = dist[np.argmin(dist, axis=None)]
        return list(x[ind])[0],min_distance
    
    # New Predict
    def predict_new(self,test_X,depth,do_predict=True):
        predicted = []
        cluster_centroids = []
        for cluster_id in cluster_tree:
            if cluster_tree[cluster_id].depth != depth:
                continue
            cluster_centroids.append([cluster_id,cluster_tree[cluster_id].centroid])
        cluster_centroids = np.array(cluster_centroids)
        for test_instance in test_X.iterrows():
            test_sample = np.array(test_instance[1].values)
            selected_cluster,min_distance = self.distance(cluster_centroids,test_sample)
            cluster_tree[selected_cluster].add_test_points(test_instance[0])
            # Outlier identifier
            #if cluster_tree[selected_cluster].check_outlier(min_distance):
            #    cluster_tree[selected_cluster].add_outlier_points(test_instance[0])
            if cluster_tree[selected_cluster].check_OCS_outlier(test_sample):
                cluster_tree[selected_cluster].add_outlier_points(test_instance[0])
            if do_predict:
                _predicted_label = cluster_tree[selected_cluster].classifier.predict([test_sample])
                cluster_tree[selected_cluster].add_predicted(_predicted_label)
                predicted.append(_predicted_label)
        return predicted
    
    # Model certification creator
    def certify_model(self,cluster_tree,test_y):
        for cluster_id in cluster_tree:
            if len(cluster_tree[cluster_id].test_points) == 0:
                continue
            cluster_tree[cluster_id].set_test_labels(test_y[cluster_tree[cluster_id].test_points].values)
            precision = metrics.precision_score(cluster_tree[cluster_id].test_labels, 
                                                cluster_tree[cluster_id].predicted,average='weighted')
            recall = metrics.recall_score(cluster_tree[cluster_id].test_labels, 
                                          cluster_tree[cluster_id].predicted,average='weighted')
            f1_Score = metrics.f1_score(cluster_tree[cluster_id].test_labels, 
                                        cluster_tree[cluster_id].predicted,average='weighted')
            score = {'precision': precision,'recall': recall,'f1_Score': f1_Score}
            cluster_tree[cluster_id].set_score(score)

# %%
def load_data(path,target):
    df = pd.read_csv(path)
    print(df.shape)
    #df_change = df[['protocol_type', 'service','flag']]
    #df = df.drop(labels = ['protocol_type', 'service','flag'], axis = 1)
    #df_change = pd.get_dummies(df_change, prefix=['protocol_type', 'service','flag'])
    #df = df.merge(df_change,left_index=True, right_index=True)
    y = df[target]
    X = df.drop(labels = target, axis = 1)
    X = X.apply(pd.to_numeric)
    train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.10, random_state=42)
    return train_X, test_X, train_y, test_y

def load_mutated_data(path,target):
    df = pd.read_csv(path)
    y = df[target]
    X = df.drop(labels = target, axis = 1)
    X = X.apply(pd.to_numeric)
    return X,y

# %%
# Cluster Driver
def cluster_driver(file,print_tree = True):
    train_X, test_X, train_y, test_y = load_data(file,'defects')
    cluster = birch(branching_factor=20)
    cluster.fit(train_X,train_y)
    cluster_tree,max_depth = cluster.get_cluster_tree()
    #cluster_tree = cluster.model_adder(cluster_tree)
    cluster_tree = cluster.outlier_model_adder(cluster_tree)
    if print_tree:
        cluster.show_clutser_tree()
    return cluster,cluster_tree,max_depth,test_X

# %%
# getting the cluster tree
file = 'Data/KDD/modified/train.csv'

cluster,cluster_tree,max_depth,test_X_1 = cluster_driver(file)
# Out:
# (97278, 11)
# [cluster_id=0] N_children: 11 N_samples: 9727
# > [cluster_id=1] N_children: 8 N_samples: 123
# > > [cluster_id=2] N_children: 0 N_samples: 13
# > > [cluster_id=3] N_children: 0 N_samples: 18
# > > [cluster_id=4] N_children: 0 N_samples: 20
# > > [cluster_id=5] N_children: 0 N_samples: 19
# > > [cluster_id=6] N_children: 0 N_samples: 16
# > > [cluster_id=7] N_children: 0 N_samples: 14
# > > [cluster_id=8] N_children: 0 N_samples: 18
# > > [cluster_id=9] N_children: 0 N_samples: 5
# > [cluster_id=10] N_children: 0 N_samples: 13
# > [cluster_id=11] N_children: 3 N_samples: 652
# > > [cluster_id=12] N_children: 15 N_samples: 201
# > > > [cluster_id=13] N_children: 0 N_samples: 15
# > > > [cluster_id=14] N_children: 0 N_samples: 7
# > > > [cluster_id=15] N_children: 0 N_samples: 18
# > > > [cluster_id=16] N_children: 0 N_samples: 10
# > > > [cluster_id=17] N_children: 0 N_samples: 13
# > > > [cluster_id=18] N_children: 0 N_samples: 20
# > > > [cluster_id=19] N_children: 0 N_samples: 13
# > > > [cluster_id=20] N_children: 0 N_samples: 12
# > > > [cluster_id=21] N_children: 0 N_samples: 13
# > > > [cluster_id=22] N_children: 0 N_samples: 9
# > > > [cluster_id=23] N_children: 0 N_samples: 7
# > > > [cluster_id=24] N_children: 0 N_samples: 16
# > > > [cluster_id=25] N_children: 0 N_samples: 14
# > > > [cluster_id=26] N_children: 0 N_samples: 18
# > > > [cluster_id=27] N_children: 0 N_samples: 16
# > > [cluster_id=28] N_children: 18 N_samples: 246
# > > > [cluster_id=29] N_children: 0 N_samples: 15
# > > > [cluster_id=30] N_children: 0 N_samples: 13
# > > > [cluster_id=31] N_children: 0 N_samples: 16
# > > > [cluster_id=32] N_children: 0 N_samples: 17
# > > > [cluster_id=33] N_children: 0 N_samples: 12
# > > > [cluster_id=34] N_children: 0 N_samples: 17
# > > > [cluster_id=35] N_children: 0 N_samples: 19
# > > > [cluster_id=36] N_children: 0 N_samples: 19
# > > > [cluster_id=37] N_children: 0 N_samples: 14
# > > > [cluster_id=38] N_children: 0 N_samples: 16
# > > > [cluster_id=39] N_children: 0 N_samples: 9
# > > > [cluster_id=40] N_children: 0 N_samples: 20
# > > > [cluster_id=41] N_children: 0 N_samples: 3
# > > > [cluster_id=42] N_children: 0 N_samples: 17
# > > > [cluster_id=43] N_children: 0 N_samples: 7
# > > > [cluster_id=44] N_children: 0 N_samples: 11
# > > > [cluster_id=45] N_children: 0 N_samples: 14
# > > > [cluster_id=46] N_children: 0 N_samples: 7
# > > [cluster_id=47] N_children: 18 N_samples: 205
# > > > [cluster_id=48] N_children: 0 N_samples: 16
# > > > [cluster_id=49] N_children: 0 N_samples: 13
# > > > [cluster_id=50] N_children: 0 N_samples: 16
# > > > [cluster_id=51] N_children: 0 N_samples: 6
# > > > [cluster_id=52] N_children: 0 N_samples: 17
# > > > [cluster_id=53] N_children: 0 N_samples: 15
# > > > [cluster_id=54] N_children: 0 N_samples: 10
# > > > [cluster_id=55] N_children: 0 N_samples: 12
# > > > [cluster_id=56] N_children: 0 N_samples: 1
# > > > [cluster_id=57] N_children: 0 N_samples: 17
# > > > [cluster_id=58] N_children: 0 N_samples: 9
# > > > [cluster_id=59] N_children: 0 N_samples: 14
# > > > [cluster_id=60] N_children: 0 N_samples: 11
# > > > [cluster_id=61] N_children: 0 N_samples: 12
# > > > [cluster_id=62] N_children: 0 N_samples: 12
# > > > [cluster_id=63] N_children: 0 N_samples: 5
# > > > [cluster_id=64] N_children: 0 N_samples: 8
# > > > [cluster_id=65] N_children: 0 N_samples: 11
# > [cluster_id=66] N_children: 2 N_samples: 274
# > > [cluster_id=67] N_children: 14 N_samples: 178
# > > > [cluster_id=68] N_children: 0 N_samples: 19
# > > > [cluster_id=69] N_children: 0 N_samples: 5
# > > > [cluster_id=70] N_children: 0 N_samples: 13
# > > > [cluster_id=71] N_children: 0 N_samples: 6
# > > > [cluster_id=72] N_children: 0 N_samples: 7
# > > > [cluster_id=73] N_children: 0 N_samples: 7
# > > > [cluster_id=74] N_children: 0 N_samples: 12
# > > > [cluster_id=75] N_children: 0 N_samples: 14
# > > > [cluster_id=76] N_children: 0 N_samples: 19
# > > > [cluster_id=77] N_children: 0 N_samples: 19
# > > > [cluster_id=78] N_children: 0 N_samples: 17
# > > > [cluster_id=79] N_children: 0 N_samples: 10
# > > > [cluster_id=80] N_children: 0 N_samples: 18
# > > > [cluster_id=81] N_children: 0 N_samples: 12
# > > [cluster_id=82] N_children: 8 N_samples: 96
# > > > [cluster_id=83] N_children: 0 N_samples: 15
# > > > [cluster_id=84] N_children: 0 N_samples: 10
# > > > [cluster_id=85] N_children: 0 N_samples: 7
# > > > [cluster_id=86] N_children: 0 N_samples: 19
# > > > [cluster_id=87] N_children: 0 N_samples: 3
# > > > [cluster_id=88] N_children: 0 N_samples: 12
# > > > [cluster_id=89] N_children: 0 N_samples: 12
# > > > [cluster_id=90] N_children: 0 N_samples: 18
# > [cluster_id=91] N_children: 2 N_samples: 308
# > > [cluster_id=92] N_children: 8 N_samples: 116
# > > > [cluster_id=93] N_children: 0 N_samples: 10
# > > > [cluster_id=94] N_children: 0 N_samples: 17
# > > > [cluster_id=95] N_children: 0 N_samples: 13
# > > > [cluster_id=96] N_children: 0 N_samples: 17
# > > > [cluster_id=97] N_children: 0 N_samples: 18
# > > > [cluster_id=98] N_children: 0 N_samples: 6
# > > > [cluster_id=99] N_children: 0 N_samples: 17
# > > > [cluster_id=100] N_children: 0 N_samples: 18
# > > [cluster_id=101] N_children: 13 N_samples: 192
# > > > [cluster_id=102] N_children: 0 N_samples: 13
# > > > [cluster_id=103] N_children: 0 N_samples: 19
# > > > [cluster_id=104] N_children: 0 N_samples: 6
# > > > [cluster_id=105] N_children: 0 N_samples: 7
# > > > [cluster_id=106] N_children: 0 N_samples: 22
# > > > [cluster_id=107] N_children: 0 N_samples: 8
# > > > [cluster_id=108] N_children: 0 N_samples: 5
# > > > [cluster_id=109] N_children: 0 N_samples: 51
# > > > [cluster_id=110] N_children: 0 N_samples: 22
# > > > [cluster_id=111] N_children: 0 N_samples: 5
# > > > [cluster_id=112] N_children: 0 N_samples: 8
# > > > [cluster_id=113] N_children: 0 N_samples: 17
# > > > [cluster_id=114] N_children: 0 N_samples: 9
# > [cluster_id=115] N_children: 10 N_samples: 150
# > > [cluster_id=116] N_children: 0 N_samples: 20
# > > [cluster_id=117] N_children: 0 N_samples: 17
# > > [cluster_id=118] N_children: 0 N_samples: 9
# > > [cluster_id=119] N_children: 0 N_samples: 5
# > > [cluster_id=120] N_children: 0 N_samples: 7
# > > [cluster_id=121] N_children: 0 N_samples: 31
# > > [cluster_id=122] N_children: 0 N_samples: 3
# > > [cluster_id=123] N_children: 0 N_samples: 7
# > > [cluster_id=124] N_children: 0 N_samples: 11
# > > [cluster_id=125] N_children: 0 N_samples: 40
# > [cluster_id=126] N_children: 6 N_samples: 1116
# > > [cluster_id=127] N_children: 5 N_samples: 58
# > > > [cluster_id=128] N_children: 0 N_samples: 11
# > > > [cluster_id=129] N_children: 0 N_samples: 17
# > > > [cluster_id=130] N_children: 0 N_samples: 16
# > > > [cluster_id=131] N_children: 0 N_samples: 2
# > > > [cluster_id=132] N_children: 0 N_samples: 12
# > > [cluster_id=133] N_children: 14 N_samples: 147
# > > > [cluster_id=134] N_children: 0 N_samples: 20
# > > > [cluster_id=135] N_children: 0 N_samples: 7
# > > > [cluster_id=136] N_children: 0 N_samples: 13
# > > > [cluster_id=137] N_children: 0 N_samples: 11
# > > > [cluster_id=138] N_children: 0 N_samples: 1
# > > > [cluster_id=139] N_children: 0 N_samples: 6
# > > > [cluster_id=140] N_children: 0 N_samples: 6
# > > > [cluster_id=141] N_children: 0 N_samples: 19
# > > > [cluster_id=142] N_children: 0 N_samples: 15
# > > > [cluster_id=143] N_children: 0 N_samples: 20
# > > > [cluster_id=144] N_children: 0 N_samples: 10
# > > > [cluster_id=145] N_children: 0 N_samples: 5
# > > > [cluster_id=146] N_children: 0 N_samples: 13
# > > > [cluster_id=147] N_children: 0 N_samples: 1
# > > [cluster_id=148] N_children: 17 N_samples: 206
# > > > [cluster_id=149] N_children: 0 N_samples: 7
# > > > [cluster_id=150] N_children: 0 N_samples: 7
# > > > [cluster_id=151] N_children: 0 N_samples: 14
# > > > [cluster_id=152] N_children: 0 N_samples: 14
# > > > [cluster_id=153] N_children: 0 N_samples: 7
# > > > [cluster_id=154] N_children: 0 N_samples: 18
# > > > [cluster_id=155] N_children: 0 N_samples: 15
# > > > [cluster_id=156] N_children: 0 N_samples: 12
# > > > [cluster_id=157] N_children: 0 N_samples: 17
# > > > [cluster_id=158] N_children: 0 N_samples: 13
# > > > [cluster_id=159] N_children: 0 N_samples: 1
# > > > [cluster_id=160] N_children: 0 N_samples: 19
# > > > [cluster_id=161] N_children: 0 N_samples: 9
# > > > [cluster_id=162] N_children: 0 N_samples: 16
# > > > [cluster_id=163] N_children: 0 N_samples: 12
# > > > [cluster_id=164] N_children: 0 N_samples: 16
# > > > [cluster_id=165] N_children: 0 N_samples: 9
# > > [cluster_id=166] N_children: 20 N_samples: 243
# > > > [cluster_id=167] N_children: 0 N_samples: 7
# > > > [cluster_id=168] N_children: 0 N_samples: 19
# > > > [cluster_id=169] N_children: 0 N_samples: 16
# > > > [cluster_id=170] N_children: 0 N_samples: 13
# > > > [cluster_id=171] N_children: 0 N_samples: 8
# > > > [cluster_id=172] N_children: 0 N_samples: 19
# > > > [cluster_id=173] N_children: 0 N_samples: 17
# > > > [cluster_id=174] N_children: 0 N_samples: 17
# > > > [cluster_id=175] N_children: 0 N_samples: 6
# > > > [cluster_id=176] N_children: 0 N_samples: 11
# > > > [cluster_id=177] N_children: 0 N_samples: 13
# > > > [cluster_id=178] N_children: 0 N_samples: 1
# > > > [cluster_id=179] N_children: 0 N_samples: 15
# > > > [cluster_id=180] N_children: 0 N_samples: 7
# > > > [cluster_id=181] N_children: 0 N_samples: 11
# > > > [cluster_id=182] N_children: 0 N_samples: 10
# > > > [cluster_id=183] N_children: 0 N_samples: 16
# > > > [cluster_id=184] N_children: 0 N_samples: 13
# > > > [cluster_id=185] N_children: 0 N_samples: 11
# > > > [cluster_id=186] N_children: 0 N_samples: 13
# > > [cluster_id=187] N_children: 16 N_samples: 206
# > > > [cluster_id=188] N_children: 0 N_samples: 1
# > > > [cluster_id=189] N_children: 0 N_samples: 7
# > > > [cluster_id=190] N_children: 0 N_samples: 14
# > > > [cluster_id=191] N_children: 0 N_samples: 10
# > > > [cluster_id=192] N_children: 0 N_samples: 10
# > > > [cluster_id=193] N_children: 0 N_samples: 11
# > > > [cluster_id=194] N_children: 0 N_samples: 18
# > > > [cluster_id=195] N_children: 0 N_samples: 14
# > > > [cluster_id=196] N_children: 0 N_samples: 11
# > > > [cluster_id=197] N_children: 0 N_samples: 16
# > > > [cluster_id=198] N_children: 0 N_samples: 18
# > > > [cluster_id=199] N_children: 0 N_samples: 20
# > > > [cluster_id=200] N_children: 0 N_samples: 14
# > > > [cluster_id=201] N_children: 0 N_samples: 20
# > > > [cluster_id=202] N_children: 0 N_samples: 11
# > > > [cluster_id=203] N_children: 0 N_samples: 11
# > > [cluster_id=204] N_children: 19 N_samples: 256
# > > > [cluster_id=205] N_children: 0 N_samples: 8
# > > > [cluster_id=206] N_children: 0 N_samples: 16
# > > > [cluster_id=207] N_children: 0 N_samples: 15
# > > > [cluster_id=208] N_children: 0 N_samples: 17
# > > > [cluster_id=209] N_children: 0 N_samples: 9
# > > > [cluster_id=210] N_children: 0 N_samples: 19
# > > > [cluster_id=211] N_children: 0 N_samples: 14
# > > > [cluster_id=212] N_children: 0 N_samples: 13
# > > > [cluster_id=213] N_children: 0 N_samples: 18
# > > > [cluster_id=214] N_children: 0 N_samples: 14
# > > > [cluster_id=215] N_children: 0 N_samples: 16
# > > > [cluster_id=216] N_children: 0 N_samples: 20
# > > > [cluster_id=217] N_children: 0 N_samples: 3
# > > > [cluster_id=218] N_children: 0 N_samples: 17
# > > > [cluster_id=219] N_children: 0 N_samples: 18
# > > > [cluster_id=220] N_children: 0 N_samples: 14
# > > > [cluster_id=221] N_children: 0 N_samples: 15
# > > > [cluster_id=222] N_children: 0 N_samples: 7
# > > > [cluster_id=223] N_children: 0 N_samples: 3
# > [cluster_id=224] N_children: 12 N_samples: 1912
# > > [cluster_id=225] N_children: 17 N_samples: 194
# > > > [cluster_id=226] N_children: 0 N_samples: 5
# > > > [cluster_id=227] N_children: 0 N_samples: 9
# > > > [cluster_id=228] N_children: 0 N_samples: 12
# > > > [cluster_id=229] N_children: 0 N_samples: 13
# > > > [cluster_id=230] N_children: 0 N_samples: 14
# > > > [cluster_id=231] N_children: 0 N_samples: 20
# > > > [cluster_id=232] N_children: 0 N_samples: 19
# > > > [cluster_id=233] N_children: 0 N_samples: 8
# > > > [cluster_id=234] N_children: 0 N_samples: 6
# > > > [cluster_id=235] N_children: 0 N_samples: 10
# > > > [cluster_id=236] N_children: 0 N_samples: 11
# > > > [cluster_id=237] N_children: 0 N_samples: 7
# > > > [cluster_id=238] N_children: 0 N_samples: 15
# > > > [cluster_id=239] N_children: 0 N_samples: 13
# > > > [cluster_id=240] N_children: 0 N_samples: 12
# > > > [cluster_id=241] N_children: 0 N_samples: 8
# > > > [cluster_id=242] N_children: 0 N_samples: 12
# > > [cluster_id=243] N_children: 8 N_samples: 101
# > > > [cluster_id=244] N_children: 0 N_samples: 19
# > > > [cluster_id=245] N_children: 0 N_samples: 3
# > > > [cluster_id=246] N_children: 0 N_samples: 6
# > > > [cluster_id=247] N_children: 0 N_samples: 15
# > > > [cluster_id=248] N_children: 0 N_samples: 16
# > > > [cluster_id=249] N_children: 0 N_samples: 12
# > > > [cluster_id=250] N_children: 0 N_samples: 20
# > > > [cluster_id=251] N_children: 0 N_samples: 10
# > > [cluster_id=252] N_children: 13 N_samples: 194
# > > > [cluster_id=253] N_children: 0 N_samples: 12
# > > > [cluster_id=254] N_children: 0 N_samples: 16
# > > > [cluster_id=255] N_children: 0 N_samples: 20
# > > > [cluster_id=256] N_children: 0 N_samples: 20
# > > > [cluster_id=257] N_children: 0 N_samples: 19
# > > > [cluster_id=258] N_children: 0 N_samples: 8
# > > > [cluster_id=259] N_children: 0 N_samples: 15
# > > > [cluster_id=260] N_children: 0 N_samples: 18
# > > > [cluster_id=261] N_children: 0 N_samples: 13
# > > > [cluster_id=262] N_children: 0 N_samples: 8
# > > > [cluster_id=263] N_children: 0 N_samples: 18
# > > > [cluster_id=264] N_children: 0 N_samples: 13
# > > > [cluster_id=265] N_children: 0 N_samples: 14
# > > [cluster_id=266] N_children: 17 N_samples: 241
# > > > [cluster_id=267] N_children: 0 N_samples: 19
# > > > [cluster_id=268] N_children: 0 N_samples: 18
# > > > [cluster_id=269] N_children: 0 N_samples: 9
# > > > [cluster_id=270] N_children: 0 N_samples: 15
# > > > [cluster_id=271] N_children: 0 N_samples: 12
# > > > [cluster_id=272] N_children: 0 N_samples: 15
# > > > [cluster_id=273] N_children: 0 N_samples: 19
# > > > [cluster_id=274] N_children: 0 N_samples: 19
# > > > [cluster_id=275] N_children: 0 N_samples: 20
# > > > [cluster_id=276] N_children: 0 N_samples: 12
# > > > [cluster_id=277] N_children: 0 N_samples: 11
# > > > [cluster_id=278] N_children: 0 N_samples: 19
# > > > [cluster_id=279] N_children: 0 N_samples: 16
# > > > [cluster_id=280] N_children: 0 N_samples: 12
# > > > [cluster_id=281] N_children: 0 N_samples: 15
# > > > [cluster_id=282] N_children: 0 N_samples: 7
# > > > [cluster_id=283] N_children: 0 N_samples: 3
# > > [cluster_id=284] N_children: 17 N_samples: 225
# > > > [cluster_id=285] N_children: 0 N_samples: 3
# > > > [cluster_id=286] N_children: 0 N_samples: 2
# > > > [cluster_id=287] N_children: 0 N_samples: 17
# > > > [cluster_id=288] N_children: 0 N_samples: 9
# > > > [cluster_id=289] N_children: 0 N_samples: 14
# > > > [cluster_id=290] N_children: 0 N_samples: 19
# > > > [cluster_id=291] N_children: 0 N_samples: 16
# > > > [cluster_id=292] N_children: 0 N_samples: 17
# > > > [cluster_id=293] N_children: 0 N_samples: 20
# > > > [cluster_id=294] N_children: 0 N_samples: 20
# > > > [cluster_id=295] N_children: 0 N_samples: 11
# > > > [cluster_id=296] N_children: 0 N_samples: 20
# > > > [cluster_id=297] N_children: 0 N_samples: 15
# > > > [cluster_id=298] N_children: 0 N_samples: 11
# > > > [cluster_id=299] N_children: 0 N_samples: 16
# > > > [cluster_id=300] N_children: 0 N_samples: 9
# > > > [cluster_id=301] N_children: 0 N_samples: 6
# > > [cluster_id=302] N_children: 17 N_samples: 215
# > > > [cluster_id=303] N_children: 0 N_samples: 15
# > > > [cluster_id=304] N_children: 0 N_samples: 19
# > > > [cluster_id=305] N_children: 0 N_samples: 18
# > > > [cluster_id=306] N_children: 0 N_samples: 17
# > > > [cluster_id=307] N_children: 0 N_samples: 6
# > > > [cluster_id=308] N_children: 0 N_samples: 14
# > > > [cluster_id=309] N_children: 0 N_samples: 8
# > > > [cluster_id=310] N_children: 0 N_samples: 13
# > > > [cluster_id=311] N_children: 0 N_samples: 12
# > > > [cluster_id=312] N_children: 0 N_samples: 8
# > > > [cluster_id=313] N_children: 0 N_samples: 19
# > > > [cluster_id=314] N_children: 0 N_samples: 19
# > > > [cluster_id=315] N_children: 0 N_samples: 15
# > > > [cluster_id=316] N_children: 0 N_samples: 9
# > > > [cluster_id=317] N_children: 0 N_samples: 6
# > > > [cluster_id=318] N_children: 0 N_samples: 14
# > > > [cluster_id=319] N_children: 0 N_samples: 3
# > > [cluster_id=320] N_children: 16 N_samples: 207
# > > > [cluster_id=321] N_children: 0 N_samples: 16
# > > > [cluster_id=322] N_children: 0 N_samples: 12
# > > > [cluster_id=323] N_children: 0 N_samples: 14
# > > > [cluster_id=324] N_children: 0 N_samples: 17
# > > > [cluster_id=325] N_children: 0 N_samples: 19
# > > > [cluster_id=326] N_children: 0 N_samples: 17
# > > > [cluster_id=327] N_children: 0 N_samples: 9
# > > > [cluster_id=328] N_children: 0 N_samples: 17
# > > > [cluster_id=329] N_children: 0 N_samples: 18
# > > > [cluster_id=330] N_children: 0 N_samples: 13
# > > > [cluster_id=331] N_children: 0 N_samples: 11
# > > > [cluster_id=332] N_children: 0 N_samples: 11
# > > > [cluster_id=333] N_children: 0 N_samples: 10
# > > > [cluster_id=334] N_children: 0 N_samples: 13
# > > > [cluster_id=335] N_children: 0 N_samples: 1
# > > > [cluster_id=336] N_children: 0 N_samples: 9
# > > [cluster_id=337] N_children: 2 N_samples: 24
# > > > [cluster_id=338] N_children: 0 N_samples: 4
# > > > [cluster_id=339] N_children: 0 N_samples: 20
# > > [cluster_id=340] N_children: 9 N_samples: 100
# > > > [cluster_id=341] N_children: 0 N_samples: 15
# > > > [cluster_id=342] N_children: 0 N_samples: 2
# > > > [cluster_id=343] N_children: 0 N_samples: 20
# > > > [cluster_id=344] N_children: 0 N_samples: 19
# > > > [cluster_id=345] N_children: 0 N_samples: 5
# > > > [cluster_id=346] N_children: 0 N_samples: 10
# > > > [cluster_id=347] N_children: 0 N_samples: 6
# > > > [cluster_id=348] N_children: 0 N_samples: 18
# > > > [cluster_id=349] N_children: 0 N_samples: 5
# > > [cluster_id=350] N_children: 19 N_samples: 223
# > > > [cluster_id=351] N_children: 0 N_samples: 17
# > > > [cluster_id=352] N_children: 0 N_samples: 8
# > > > [cluster_id=353] N_children: 0 N_samples: 8
# > > > [cluster_id=354] N_children: 0 N_samples: 12
# > > > [cluster_id=355] N_children: 0 N_samples: 16
# > > > [cluster_id=356] N_children: 0 N_samples: 7
# > > > [cluster_id=357] N_children: 0 N_samples: 5
# > > > [cluster_id=358] N_children: 0 N_samples: 8
# > > > [cluster_id=359] N_children: 0 N_samples: 20
# > > > [cluster_id=360] N_children: 0 N_samples: 11
# > > > [cluster_id=361] N_children: 0 N_samples: 10
# > > > [cluster_id=362] N_children: 0 N_samples: 18
# > > > [cluster_id=363] N_children: 0 N_samples: 9
# > > > [cluster_id=364] N_children: 0 N_samples: 20
# > > > [cluster_id=365] N_children: 0 N_samples: 17
# > > > [cluster_id=366] N_children: 0 N_samples: 8
# > > > [cluster_id=367] N_children: 0 N_samples: 15
# > > > [cluster_id=368] N_children: 0 N_samples: 9
# > > > [cluster_id=369] N_children: 0 N_samples: 5
# > > [cluster_id=370] N_children: 10 N_samples: 97
# > > > [cluster_id=371] N_children: 0 N_samples: 10
# > > > [cluster_id=372] N_children: 0 N_samples: 5
# > > > [cluster_id=373] N_children: 0 N_samples: 19
# > > > [cluster_id=374] N_children: 0 N_samples: 1
# > > > [cluster_id=375] N_children: 0 N_samples: 7
# > > > [cluster_id=376] N_children: 0 N_samples: 6
# > > > [cluster_id=377] N_children: 0 N_samples: 16
# > > > [cluster_id=378] N_children: 0 N_samples: 19
# > > > [cluster_id=379] N_children: 0 N_samples: 9
# > > > [cluster_id=380] N_children: 0 N_samples: 5
# > > [cluster_id=381] N_children: 9 N_samples: 91
# > > > [cluster_id=382] N_children: 0 N_samples: 5
# > > > [cluster_id=383] N_children: 0 N_samples: 1
# > > > [cluster_id=384] N_children: 0 N_samples: 5
# > > > [cluster_id=385] N_children: 0 N_samples: 3
# > > > [cluster_id=386] N_children: 0 N_samples: 20
# > > > [cluster_id=387] N_children: 0 N_samples: 13
# > > > [cluster_id=388] N_children: 0 N_samples: 14
# > > > [cluster_id=389] N_children: 0 N_samples: 12
# > > > [cluster_id=390] N_children: 0 N_samples: 18
# > [cluster_id=391] N_children: 8 N_samples: 1217
# > > [cluster_id=392] N_children: 5 N_samples: 71
# > > > [cluster_id=393] N_children: 0 N_samples: 12
# > > > [cluster_id=394] N_children: 0 N_samples: 14
# > > > [cluster_id=395] N_children: 0 N_samples: 19
# > > > [cluster_id=396] N_children: 0 N_samples: 16
# > > > [cluster_id=397] N_children: 0 N_samples: 10
# > > [cluster_id=398] N_children: 9 N_samples: 87
# > > > [cluster_id=399] N_children: 0 N_samples: 2
# > > > [cluster_id=400] N_children: 0 N_samples: 5
# > > > [cluster_id=401] N_children: 0 N_samples: 19
# > > > [cluster_id=402] N_children: 0 N_samples: 20
# > > > [cluster_id=403] N_children: 0 N_samples: 7
# > > > [cluster_id=404] N_children: 0 N_samples: 8
# > > > [cluster_id=405] N_children: 0 N_samples: 9
# > > > [cluster_id=406] N_children: 0 N_samples: 1
# > > > [cluster_id=407] N_children: 0 N_samples: 16
# > > [cluster_id=408] N_children: 20 N_samples: 257
# > > > [cluster_id=409] N_children: 0 N_samples: 16
# > > > [cluster_id=410] N_children: 0 N_samples: 1
# > > > [cluster_id=411] N_children: 0 N_samples: 12
# > > > [cluster_id=412] N_children: 0 N_samples: 13
# > > > [cluster_id=413] N_children: 0 N_samples: 13
# > > > [cluster_id=414] N_children: 0 N_samples: 14
# > > > [cluster_id=415] N_children: 0 N_samples: 20
# > > > [cluster_id=416] N_children: 0 N_samples: 13
# > > > [cluster_id=417] N_children: 0 N_samples: 4
# > > > [cluster_id=418] N_children: 0 N_samples: 13
# > > > [cluster_id=419] N_children: 0 N_samples: 17
# > > > [cluster_id=420] N_children: 0 N_samples: 18
# > > > [cluster_id=421] N_children: 0 N_samples: 16
# > > > [cluster_id=422] N_children: 0 N_samples: 20
# > > > [cluster_id=423] N_children: 0 N_samples: 4
# > > > [cluster_id=424] N_children: 0 N_samples: 13
# > > > [cluster_id=425] N_children: 0 N_samples: 12
# > > > [cluster_id=426] N_children: 0 N_samples: 15
# > > > [cluster_id=427] N_children: 0 N_samples: 6
# > > > [cluster_id=428] N_children: 0 N_samples: 17
# > > [cluster_id=429] N_children: 20 N_samples: 212
# > > > [cluster_id=430] N_children: 0 N_samples: 1
# > > > [cluster_id=431] N_children: 0 N_samples: 15
# > > > [cluster_id=432] N_children: 0 N_samples: 6
# > > > [cluster_id=433] N_children: 0 N_samples: 7
# > > > [cluster_id=434] N_children: 0 N_samples: 15
# > > > [cluster_id=435] N_children: 0 N_samples: 11
# > > > [cluster_id=436] N_children: 0 N_samples: 18
# > > > [cluster_id=437] N_children: 0 N_samples: 9
# > > > [cluster_id=438] N_children: 0 N_samples: 18
# > > > [cluster_id=439] N_children: 0 N_samples: 11
# > > > [cluster_id=440] N_children: 0 N_samples: 9
# > > > [cluster_id=441] N_children: 0 N_samples: 15
# > > > [cluster_id=442] N_children: 0 N_samples: 6
# > > > [cluster_id=443] N_children: 0 N_samples: 11
# > > > [cluster_id=444] N_children: 0 N_samples: 2
# > > > [cluster_id=445] N_children: 0 N_samples: 16
# > > > [cluster_id=446] N_children: 0 N_samples: 10
# > > > [cluster_id=447] N_children: 0 N_samples: 11
# > > > [cluster_id=448] N_children: 0 N_samples: 13
# > > > [cluster_id=449] N_children: 0 N_samples: 8
# > > [cluster_id=450] N_children: 16 N_samples: 218
# > > > [cluster_id=451] N_children: 0 N_samples: 13
# > > > [cluster_id=452] N_children: 0 N_samples: 20
# > > > [cluster_id=453] N_children: 0 N_samples: 15
# > > > [cluster_id=454] N_children: 0 N_samples: 6
# > > > [cluster_id=455] N_children: 0 N_samples: 8
# > > > [cluster_id=456] N_children: 0 N_samples: 15
# > > > [cluster_id=457] N_children: 0 N_samples: 17
# > > > [cluster_id=458] N_children: 0 N_samples: 15
# > > > [cluster_id=459] N_children: 0 N_samples: 8
# > > > [cluster_id=460] N_children: 0 N_samples: 14
# > > > [cluster_id=461] N_children: 0 N_samples: 16
# > > > [cluster_id=462] N_children: 0 N_samples: 18
# > > > [cluster_id=463] N_children: 0 N_samples: 19
# > > > [cluster_id=464] N_children: 0 N_samples: 10
# > > > [cluster_id=465] N_children: 0 N_samples: 11
# > > > [cluster_id=466] N_children: 0 N_samples: 13
# > > [cluster_id=467] N_children: 9 N_samples: 131
# > > > [cluster_id=468] N_children: 0 N_samples: 20
# > > > [cluster_id=469] N_children: 0 N_samples: 19
# > > > [cluster_id=470] N_children: 0 N_samples: 5
# > > > [cluster_id=471] N_children: 0 N_samples: 19
# > > > [cluster_id=472] N_children: 0 N_samples: 7
# > > > [cluster_id=473] N_children: 0 N_samples: 19
# > > > [cluster_id=474] N_children: 0 N_samples: 17
# > > > [cluster_id=475] N_children: 0 N_samples: 11
# > > > [cluster_id=476] N_children: 0 N_samples: 14
# > > [cluster_id=477] N_children: 6 N_samples: 48
# > > > [cluster_id=478] N_children: 0 N_samples: 12
# > > > [cluster_id=479] N_children: 0 N_samples: 12
# > > > [cluster_id=480] N_children: 0 N_samples: 1
# > > > [cluster_id=481] N_children: 0 N_samples: 2
# > > > [cluster_id=482] N_children: 0 N_samples: 6
# > > > [cluster_id=483] N_children: 0 N_samples: 15
# > > [cluster_id=484] N_children: 16 N_samples: 193
# > > > [cluster_id=485] N_children: 0 N_samples: 9
# > > > [cluster_id=486] N_children: 0 N_samples: 12
# > > > [cluster_id=487] N_children: 0 N_samples: 10
# > > > [cluster_id=488] N_children: 0 N_samples: 19
# > > > [cluster_id=489] N_children: 0 N_samples: 20
# > > > [cluster_id=490] N_children: 0 N_samples: 19
# > > > [cluster_id=491] N_children: 0 N_samples: 14
# > > > [cluster_id=492] N_children: 0 N_samples: 18
# > > > [cluster_id=493] N_children: 0 N_samples: 6
# > > > [cluster_id=494] N_children: 0 N_samples: 4
# > > > [cluster_id=495] N_children: 0 N_samples: 8
# > > > [cluster_id=496] N_children: 0 N_samples: 13
# > > > [cluster_id=497] N_children: 0 N_samples: 14
# > > > [cluster_id=498] N_children: 0 N_samples: 9
# > > > [cluster_id=499] N_children: 0 N_samples: 3
# > > > [cluster_id=500] N_children: 0 N_samples: 15
# > [cluster_id=501] N_children: 4 N_samples: 726
# > > [cluster_id=502] N_children: 19 N_samples: 225
# > > > [cluster_id=503] N_children: 0 N_samples: 11
# > > > [cluster_id=504] N_children: 0 N_samples: 13
# > > > [cluster_id=505] N_children: 0 N_samples: 8
# > > > [cluster_id=506] N_children: 0 N_samples: 9
# > > > [cluster_id=507] N_children: 0 N_samples: 7
# > > > [cluster_id=508] N_children: 0 N_samples: 8
# > > > [cluster_id=509] N_children: 0 N_samples: 13
# > > > [cluster_id=510] N_children: 0 N_samples: 12
# > > > [cluster_id=511] N_children: 0 N_samples: 16
# > > > [cluster_id=512] N_children: 0 N_samples: 6
# > > > [cluster_id=513] N_children: 0 N_samples: 14
# > > > [cluster_id=514] N_children: 0 N_samples: 15
# > > > [cluster_id=515] N_children: 0 N_samples: 11
# > > > [cluster_id=516] N_children: 0 N_samples: 19
# > > > [cluster_id=517] N_children: 0 N_samples: 18
# > > > [cluster_id=518] N_children: 0 N_samples: 20
# > > > [cluster_id=519] N_children: 0 N_samples: 7
# > > > [cluster_id=520] N_children: 0 N_samples: 8
# > > > [cluster_id=521] N_children: 0 N_samples: 10
# > > [cluster_id=522] N_children: 18 N_samples: 234
# > > > [cluster_id=523] N_children: 0 N_samples: 11
# > > > [cluster_id=524] N_children: 0 N_samples: 14
# > > > [cluster_id=525] N_children: 0 N_samples: 19
# > > > [cluster_id=526] N_children: 0 N_samples: 13
# > > > [cluster_id=527] N_children: 0 N_samples: 19
# > > > [cluster_id=528] N_children: 0 N_samples: 19
# > > > [cluster_id=529] N_children: 0 N_samples: 17
# > > > [cluster_id=530] N_children: 0 N_samples: 12
# > > > [cluster_id=531] N_children: 0 N_samples: 4
# > > > [cluster_id=532] N_children: 0 N_samples: 10
# > > > [cluster_id=533] N_children: 0 N_samples: 20
# > > > [cluster_id=534] N_children: 0 N_samples: 14
# > > > [cluster_id=535] N_children: 0 N_samples: 11
# > > > [cluster_id=536] N_children: 0 N_samples: 5
# > > > [cluster_id=537] N_children: 0 N_samples: 13
# > > > [cluster_id=538] N_children: 0 N_samples: 7
# > > > [cluster_id=539] N_children: 0 N_samples: 18
# > > > [cluster_id=540] N_children: 0 N_samples: 8
# > > [cluster_id=541] N_children: 17 N_samples: 207
# > > > [cluster_id=542] N_children: 0 N_samples: 18
# > > > [cluster_id=543] N_children: 0 N_samples: 9
# > > > [cluster_id=544] N_children: 0 N_samples: 15
# > > > [cluster_id=545] N_children: 0 N_samples: 18
# > > > [cluster_id=546] N_children: 0 N_samples: 12
# > > > [cluster_id=547] N_children: 0 N_samples: 5
# > > > [cluster_id=548] N_children: 0 N_samples: 18
# > > > [cluster_id=549] N_children: 0 N_samples: 20
# > > > [cluster_id=550] N_children: 0 N_samples: 12
# > > > [cluster_id=551] N_children: 0 N_samples: 7
# > > > [cluster_id=552] N_children: 0 N_samples: 11
# > > > [cluster_id=553] N_children: 0 N_samples: 20
# > > > [cluster_id=554] N_children: 0 N_samples: 9
# > > > [cluster_id=555] N_children: 0 N_samples: 8
# > > > [cluster_id=556] N_children: 0 N_samples: 6
# > > > [cluster_id=557] N_children: 0 N_samples: 10
# > > > [cluster_id=558] N_children: 0 N_samples: 9
# > > [cluster_id=559] N_children: 4 N_samples: 60
# > > > [cluster_id=560] N_children: 0 N_samples: 20
# > > > [cluster_id=561] N_children: 0 N_samples: 20
# > > > [cluster_id=562] N_children: 0 N_samples: 11
# > > > [cluster_id=563] N_children: 0 N_samples: 9
# > [cluster_id=564] N_children: 14 N_samples: 3236
# > > [cluster_id=565] N_children: 12 N_samples: 157
# > > > [cluster_id=566] N_children: 0 N_samples: 9
# > > > [cluster_id=567] N_children: 0 N_samples: 11
# > > > [cluster_id=568] N_children: 0 N_samples: 23
# > > > [cluster_id=569] N_children: 0 N_samples: 12
# > > > [cluster_id=570] N_children: 0 N_samples: 18
# > > > [cluster_id=571] N_children: 0 N_samples: 22
# > > > [cluster_id=572] N_children: 0 N_samples: 9
# > > > [cluster_id=573] N_children: 0 N_samples: 5
# > > > [cluster_id=574] N_children: 0 N_samples: 4
# > > > [cluster_id=575] N_children: 0 N_samples: 17
# > > > [cluster_id=576] N_children: 0 N_samples: 21
# > > > [cluster_id=577] N_children: 0 N_samples: 6
# > > [cluster_id=578] N_children: 15 N_samples: 181
# > > > [cluster_id=579] N_children: 0 N_samples: 4
# > > > [cluster_id=580] N_children: 0 N_samples: 1
# > > > [cluster_id=581] N_children: 0 N_samples: 20
# > > > [cluster_id=582] N_children: 0 N_samples: 1
# > > > [cluster_id=583] N_children: 0 N_samples: 12
# > > > [cluster_id=584] N_children: 0 N_samples: 10
# > > > [cluster_id=585] N_children: 0 N_samples: 16
# > > > [cluster_id=586] N_children: 0 N_samples: 18
# > > > [cluster_id=587] N_children: 0 N_samples: 13
# > > > [cluster_id=588] N_children: 0 N_samples: 37
# > > > [cluster_id=589] N_children: 0 N_samples: 13
# > > > [cluster_id=590] N_children: 0 N_samples: 3
# > > > [cluster_id=591] N_children: 0 N_samples: 9
# > > > [cluster_id=592] N_children: 0 N_samples: 15
# > > > [cluster_id=593] N_children: 0 N_samples: 9
# > > [cluster_id=594] N_children: 16 N_samples: 201
# > > > [cluster_id=595] N_children: 0 N_samples: 9
# > > > [cluster_id=596] N_children: 0 N_samples: 10
# > > > [cluster_id=597] N_children: 0 N_samples: 16
# > > > [cluster_id=598] N_children: 0 N_samples: 19
# > > > [cluster_id=599] N_children: 0 N_samples: 15
# > > > [cluster_id=600] N_children: 0 N_samples: 18
# > > > [cluster_id=601] N_children: 0 N_samples: 18
# > > > [cluster_id=602] N_children: 0 N_samples: 17
# > > > [cluster_id=603] N_children: 0 N_samples: 18
# > > > [cluster_id=604] N_children: 0 N_samples: 13
# > > > [cluster_id=605] N_children: 0 N_samples: 4
# > > > [cluster_id=606] N_children: 0 N_samples: 12
# > > > [cluster_id=607] N_children: 0 N_samples: 14
# > > > [cluster_id=608] N_children: 0 N_samples: 4
# > > > [cluster_id=609] N_children: 0 N_samples: 2
# > > > [cluster_id=610] N_children: 0 N_samples: 12
# > > [cluster_id=611] N_children: 16 N_samples: 575
# > > > [cluster_id=612] N_children: 0 N_samples: 155
# > > > [cluster_id=613] N_children: 0 N_samples: 4
# > > > [cluster_id=614] N_children: 0 N_samples: 20
# > > > [cluster_id=615] N_children: 0 N_samples: 14
# > > > [cluster_id=616] N_children: 0 N_samples: 112
# > > > [cluster_id=617] N_children: 0 N_samples: 3
# > > > [cluster_id=618] N_children: 0 N_samples: 9
# > > > [cluster_id=619] N_children: 0 N_samples: 85
# > > > [cluster_id=620] N_children: 0 N_samples: 14
# > > > [cluster_id=621] N_children: 0 N_samples: 70
# > > > [cluster_id=622] N_children: 0 N_samples: 41
# > > > [cluster_id=623] N_children: 0 N_samples: 1
# > > > [cluster_id=624] N_children: 0 N_samples: 17
# > > > [cluster_id=625] N_children: 0 N_samples: 1
# > > > [cluster_id=626] N_children: 0 N_samples: 18
# > > > [cluster_id=627] N_children: 0 N_samples: 11
# > > [cluster_id=628] N_children: 19 N_samples: 314
# > > > [cluster_id=629] N_children: 0 N_samples: 5
# > > > [cluster_id=630] N_children: 0 N_samples: 3
# > > > [cluster_id=631] N_children: 0 N_samples: 21
# > > > [cluster_id=632] N_children: 0 N_samples: 19
# > > > [cluster_id=633] N_children: 0 N_samples: 19
# > > > [cluster_id=634] N_children: 0 N_samples: 11
# > > > [cluster_id=635] N_children: 0 N_samples: 17
# > > > [cluster_id=636] N_children: 0 N_samples: 16
# > > > [cluster_id=637] N_children: 0 N_samples: 11
# > > > [cluster_id=638] N_children: 0 N_samples: 71
# > > > [cluster_id=639] N_children: 0 N_samples: 22
# > > > [cluster_id=640] N_children: 0 N_samples: 13
# > > > [cluster_id=641] N_children: 0 N_samples: 13
# > > > [cluster_id=642] N_children: 0 N_samples: 8
# > > > [cluster_id=643] N_children: 0 N_samples: 14
# > > > [cluster_id=644] N_children: 0 N_samples: 18
# > > > [cluster_id=645] N_children: 0 N_samples: 9
# > > > [cluster_id=646] N_children: 0 N_samples: 11
# > > > [cluster_id=647] N_children: 0 N_samples: 13
# > > [cluster_id=648] N_children: 13 N_samples: 151
# > > > [cluster_id=649] N_children: 0 N_samples: 14
# > > > [cluster_id=650] N_children: 0 N_samples: 18
# > > > [cluster_id=651] N_children: 0 N_samples: 14
# > > > [cluster_id=652] N_children: 0 N_samples: 13
# > > > [cluster_id=653] N_children: 0 N_samples: 20
# > > > [cluster_id=654] N_children: 0 N_samples: 13
# > > > [cluster_id=655] N_children: 0 N_samples: 10
# > > > [cluster_id=656] N_children: 0 N_samples: 10
# > > > [cluster_id=657] N_children: 0 N_samples: 14
# > > > [cluster_id=658] N_children: 0 N_samples: 4
# > > > [cluster_id=659] N_children: 0 N_samples: 2
# > > > [cluster_id=660] N_children: 0 N_samples: 9
# > > > [cluster_id=661] N_children: 0 N_samples: 10
# > > [cluster_id=662] N_children: 17 N_samples: 189
# > > > [cluster_id=663] N_children: 0 N_samples: 6
# > > > [cluster_id=664] N_children: 0 N_samples: 1
# > > > [cluster_id=665] N_children: 0 N_samples: 16
# > > > [cluster_id=666] N_children: 0 N_samples: 9
# > > > [cluster_id=667] N_children: 0 N_samples: 20
# > > > [cluster_id=668] N_children: 0 N_samples: 19
# > > > [cluster_id=669] N_children: 0 N_samples: 1
# > > > [cluster_id=670] N_children: 0 N_samples: 20
# > > > [cluster_id=671] N_children: 0 N_samples: 11
# > > > [cluster_id=672] N_children: 0 N_samples: 15
# > > > [cluster_id=673] N_children: 0 N_samples: 10
# > > > [cluster_id=674] N_children: 0 N_samples: 2
# > > > [cluster_id=675] N_children: 0 N_samples: 18
# > > > [cluster_id=676] N_children: 0 N_samples: 17
# > > > [cluster_id=677] N_children: 0 N_samples: 13
# > > > [cluster_id=678] N_children: 0 N_samples: 6
# > > > [cluster_id=679] N_children: 0 N_samples: 5
# > > [cluster_id=680] N_children: 7 N_samples: 94
# > > > [cluster_id=681] N_children: 0 N_samples: 3
# > > > [cluster_id=682] N_children: 0 N_samples: 17
# > > > [cluster_id=683] N_children: 0 N_samples: 11
# > > > [cluster_id=684] N_children: 0 N_samples: 14
# > > > [cluster_id=685] N_children: 0 N_samples: 20
# > > > [cluster_id=686] N_children: 0 N_samples: 20
# > > > [cluster_id=687] N_children: 0 N_samples: 9
# > > [cluster_id=688] N_children: 11 N_samples: 108
# > > > [cluster_id=689] N_children: 0 N_samples: 10
# > > > [cluster_id=690] N_children: 0 N_samples: 12
# > > > [cluster_id=691] N_children: 0 N_samples: 14
# > > > [cluster_id=692] N_children: 0 N_samples: 1
# > > > [cluster_id=693] N_children: 0 N_samples: 6
# > > > [cluster_id=694] N_children: 0 N_samples: 12
# > > > [cluster_id=695] N_children: 0 N_samples: 4
# > > > [cluster_id=696] N_children: 0 N_samples: 4
# > > > [cluster_id=697] N_children: 0 N_samples: 13
# > > > [cluster_id=698] N_children: 0 N_samples: 20
# > > > [cluster_id=699] N_children: 0 N_samples: 12
# > > [cluster_id=700] N_children: 20 N_samples: 195
# > > > [cluster_id=701] N_children: 0 N_samples: 8
# > > > [cluster_id=702] N_children: 0 N_samples: 5
# > > > [cluster_id=703] N_children: 0 N_samples: 6
# > > > [cluster_id=704] N_children: 0 N_samples: 11
# > > > [cluster_id=705] N_children: 0 N_samples: 16
# > > > [cluster_id=706] N_children: 0 N_samples: 3
# > > > [cluster_id=707] N_children: 0 N_samples: 6
# > > > [cluster_id=708] N_children: 0 N_samples: 4
# > > > [cluster_id=709] N_children: 0 N_samples: 5
# > > > [cluster_id=710] N_children: 0 N_samples: 17
# > > > [cluster_id=711] N_children: 0 N_samples: 20
# > > > [cluster_id=712] N_children: 0 N_samples: 12
# > > > [cluster_id=713] N_children: 0 N_samples: 2
# > > > [cluster_id=714] N_children: 0 N_samples: 12
# > > > [cluster_id=715] N_children: 0 N_samples: 17
# > > > [cluster_id=716] N_children: 0 N_samples: 5
# > > > [cluster_id=717] N_children: 0 N_samples: 19
# > > > [cluster_id=718] N_children: 0 N_samples: 2
# > > > [cluster_id=719] N_children: 0 N_samples: 10
# > > > [cluster_id=720] N_children: 0 N_samples: 15
# > > [cluster_id=721] N_children: 11 N_samples: 139
# > > > [cluster_id=722] N_children: 0 N_samples: 15
# > > > [cluster_id=723] N_children: 0 N_samples: 18
# > > > [cluster_id=724] N_children: 0 N_samples: 7
# > > > [cluster_id=725] N_children: 0 N_samples: 15
# > > > [cluster_id=726] N_children: 0 N_samples: 14
# > > > [cluster_id=727] N_children: 0 N_samples: 12
# > > > [cluster_id=728] N_children: 0 N_samples: 19
# > > > [cluster_id=729] N_children: 0 N_samples: 13
# > > > [cluster_id=730] N_children: 0 N_samples: 11
# > > > [cluster_id=731] N_children: 0 N_samples: 2
# > > > [cluster_id=732] N_children: 0 N_samples: 13
# > > [cluster_id=733] N_children: 16 N_samples: 220
# > > > [cluster_id=734] N_children: 0 N_samples: 11
# > > > [cluster_id=735] N_children: 0 N_samples: 2
# > > > [cluster_id=736] N_children: 0 N_samples: 14
# > > > [cluster_id=737] N_children: 0 N_samples: 15
# > > > [cluster_id=738] N_children: 0 N_samples: 11
# > > > [cluster_id=739] N_children: 0 N_samples: 15
# > > > [cluster_id=740] N_children: 0 N_samples: 15
# > > > [cluster_id=741] N_children: 0 N_samples: 15
# > > > [cluster_id=742] N_children: 0 N_samples: 13
# > > > [cluster_id=743] N_children: 0 N_samples: 12
# > > > [cluster_id=744] N_children: 0 N_samples: 20
# > > > [cluster_id=745] N_children: 0 N_samples: 18
# > > > [cluster_id=746] N_children: 0 N_samples: 14
# > > > [cluster_id=747] N_children: 0 N_samples: 16
# > > > [cluster_id=748] N_children: 0 N_samples: 10
# > > > [cluster_id=749] N_children: 0 N_samples: 19
# > > [cluster_id=750] N_children: 19 N_samples: 422
# > > > [cluster_id=751] N_children: 0 N_samples: 20
# > > > [cluster_id=752] N_children: 0 N_samples: 30
# > > > [cluster_id=753] N_children: 0 N_samples: 17
# > > > [cluster_id=754] N_children: 0 N_samples: 21
# > > > [cluster_id=755] N_children: 0 N_samples: 3
# > > > [cluster_id=756] N_children: 0 N_samples: 11
# > > > [cluster_id=757] N_children: 0 N_samples: 103
# > > > [cluster_id=758] N_children: 0 N_samples: 1
# > > > [cluster_id=759] N_children: 0 N_samples: 74
# > > > [cluster_id=760] N_children: 0 N_samples: 16
# > > > [cluster_id=761] N_children: 0 N_samples: 19
# > > > [cluster_id=762] N_children: 0 N_samples: 14
# > > > [cluster_id=763] N_children: 0 N_samples: 8
# > > > [cluster_id=764] N_children: 0 N_samples: 10
# > > > [cluster_id=765] N_children: 0 N_samples: 17
# > > > [cluster_id=766] N_children: 0 N_samples: 10
# > > > [cluster_id=767] N_children: 0 N_samples: 23
# > > > [cluster_id=768] N_children: 0 N_samples: 12
# > > > [cluster_id=769] N_children: 0 N_samples: 13
# > > [cluster_id=770] N_children: 15 N_samples: 290
# > > > [cluster_id=771] N_children: 0 N_samples: 18
# > > > [cluster_id=772] N_children: 0 N_samples: 58
# > > > [cluster_id=773] N_children: 0 N_samples: 20
# > > > [cluster_id=774] N_children: 0 N_samples: 11
# > > > [cluster_id=775] N_children: 0 N_samples: 24
# > > > [cluster_id=776] N_children: 0 N_samples: 2
# > > > [cluster_id=777] N_children: 0 N_samples: 64
# > > > [cluster_id=778] N_children: 0 N_samples: 21
# > > > [cluster_id=779] N_children: 0 N_samples: 2
# > > > [cluster_id=780] N_children: 0 N_samples: 14
# > > > [cluster_id=781] N_children: 0 N_samples: 19
# > > > [cluster_id=782] N_children: 0 N_samples: 7
# > > > [cluster_id=783] N_children: 0 N_samples: 8
# > > > [cluster_id=784] N_children: 0 N_samples: 17
# > > > [cluster_id=785] N_children: 0 N_samples: 5

# %%
# Base performance score
#file = 'Data/KDD/modified/train.csv'
#clf = DecisionTreeClassifier(criterion='gini')
#train_X, test_X, train_y, test_y = load_data(file,'defects')
#clf.fit(train_X, train_y)
#predicted = clf.predict(test_X)
#print(metrics.classification_report(test_y, predicted))

# %%
file = 'Data/KDD/modified/test.csv'
test_X,test_y = load_mutated_data(file,'defects')
#train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.10, random_state=42)

# %%
# Birch classifier score(mention depth)
print(max_depth)
depth = max_depth
predicted = cluster.predict_new(test_X_1,depth,False)
#print(metrics.classification_report(test_y, predicted,False))
#cluster.certify_model(cluster_tree,test_y)
# Out:
# 3

# %%
test_X_1.shape
# Out:
# (87551, 10)

# %%
# Get all the scores
for i in cluster_tree:
    if len(cluster_tree[i].test_points) == 0:
        continue
    print(cluster_tree[i].score)

# %%
# Check for outlies detected
total = 0
j = 0
for i in cluster_tree:
    if len(cluster_tree[i].test_points) == 0:
        continue
    print("Percentage Identified",len(cluster_tree[i].data_points),len(cluster_tree[i].test_points),len(cluster_tree[i].outlier_points)/len(cluster_tree[i].test_points))
    j += 1
    total += len(cluster_tree[i].outlier_points)
print(j,total)
# Out:
# Percentage Identified 15 125 1.0
# Percentage Identified 7 74 1.0
# Percentage Identified 18 89 1.0
# Percentage Identified 10 64 1.0
# Percentage Identified 13 53 1.0
# Percentage Identified 20 92 1.0
# Percentage Identified 13 101 1.0
# Percentage Identified 12 63 1.0
# Percentage Identified 13 171 1.0
# Percentage Identified 9 21 1.0
# Percentage Identified 7 146 1.0
# Percentage Identified 16 90 1.0
# Percentage Identified 14 118 1.0
# Percentage Identified 18 174 1.0
# Percentage Identified 16 152 1.0
# Percentage Identified 15 145 0.993103448275862
# Percentage Identified 13 74 1.0
# Percentage Identified 16 90 1.0
# Percentage Identified 17 217 1.0
# Percentage Identified 12 95 1.0
# Percentage Identified 17 94 1.0
# Percentage Identified 19 161 0.9937888198757764
# Percentage Identified 19 176 1.0
# Percentage Identified 14 102 0.9901960784313726
# Percentage Identified 16 145 1.0
# Percentage Identified 9 94 1.0
# Percentage Identified 20 140 1.0
# Percentage Identified 3 153 1.0
# Percentage Identified 17 141 1.0
# Percentage Identified 7 262 1.0
# Percentage Identified 11 128 0.9921875
# Percentage Identified 14 137 1.0
# Percentage Identified 7 130 0.9923076923076923
# Percentage Identified 16 206 1.0
# Percentage Identified 13 207 1.0
# Percentage Identified 16 144 1.0
# Percentage Identified 6 87 1.0
# Percentage Identified 17 151 1.0
# Percentage Identified 15 99 1.0
# Percentage Identified 10 80 1.0
# Percentage Identified 12 105 1.0
# Percentage Identified 1 6 1.0
# Percentage Identified 17 252 1.0
# Percentage Identified 9 128 1.0
# Percentage Identified 14 100 1.0
# Percentage Identified 11 105 1.0
# Percentage Identified 12 57 1.0
# Percentage Identified 12 94 1.0
# Percentage Identified 5 58 1.0
# Percentage Identified 8 142 1.0
# Percentage Identified 11 212 1.0
# Percentage Identified 19 67 1.0
# Percentage Identified 5 53 1.0
# Percentage Identified 13 170 1.0
# Percentage Identified 6 207 1.0
# Percentage Identified 7 117 1.0
# Percentage Identified 7 99 1.0
# Percentage Identified 12 149 1.0
# Percentage Identified 14 88 1.0
# Percentage Identified 19 124 1.0
# Percentage Identified 19 167 1.0
# Percentage Identified 17 97 1.0
# Percentage Identified 10 59 1.0
# Percentage Identified 18 159 1.0
# Percentage Identified 12 87 1.0
# Percentage Identified 15 108 1.0
# Percentage Identified 10 110 1.0
# Percentage Identified 7 148 1.0
# Percentage Identified 19 136 1.0
# Percentage Identified 3 111 1.0
# Percentage Identified 12 129 1.0
# Percentage Identified 12 151 1.0
# Percentage Identified 18 32 1.0
# Percentage Identified 10 191 1.0
# Percentage Identified 17 157 0.9490445859872612
# Percentage Identified 13 136 1.0
# Percentage Identified 17 208 0.8701923076923077
# Percentage Identified 18 116 0.8879310344827587
# Percentage Identified 6 56 0.9642857142857143
# Percentage Identified 17 170 1.0
# Percentage Identified 18 175 0.8857142857142857
# Percentage Identified 13 218 0.9770642201834863
# Percentage Identified 19 231 0.5454545454545454
# Percentage Identified 6 83 0.9879518072289156
# Percentage Identified 7 193 0.9948186528497409
# Percentage Identified 22 313 0.8274760383386581
# Percentage Identified 8 83 1.0
# Percentage Identified 5 50 1.0
# Percentage Identified 51 762 0.421259842519685
# Percentage Identified 22 105 0.8857142857142857
# Percentage Identified 5 199 0.507537688442211
# Percentage Identified 8 114 0.9912280701754386
# Percentage Identified 17 102 0.9411764705882353
# Percentage Identified 9 122 0.8688524590163934
# Percentage Identified 11 56 1.0
# Percentage Identified 17 52 1.0
# Percentage Identified 16 15 1.0
# Percentage Identified 2 38 1.0
# Percentage Identified 12 109 1.0
# Percentage Identified 20 31 1.0
# Percentage Identified 7 67 1.0
# Percentage Identified 13 64 1.0
# Percentage Identified 11 105 1.0
# Percentage Identified 1 39 1.0
# Percentage Identified 6 121 1.0
# Percentage Identified 6 129 1.0
# Percentage Identified 19 109 1.0
# Percentage Identified 15 24 1.0
# Percentage Identified 20 260 0.9846153846153847
# Percentage Identified 10 73 1.0
# Percentage Identified 5 48 1.0
# Percentage Identified 13 91 1.0
# Percentage Identified 1 2 1.0
# Percentage Identified 7 68 1.0
# Percentage Identified 7 88 1.0
# Percentage Identified 14 143 1.0
# Percentage Identified 14 161 1.0
# Percentage Identified 7 85 1.0
# Percentage Identified 18 110 1.0
# Percentage Identified 15 130 1.0
# Percentage Identified 12 69 1.0
# Percentage Identified 17 156 1.0
# Percentage Identified 13 135 1.0
# Percentage Identified 1 14 1.0
# Percentage Identified 19 120 0.9916666666666667
# Percentage Identified 9 44 1.0
# Percentage Identified 16 221 1.0
# Percentage Identified 12 122 1.0
# Percentage Identified 16 144 1.0
# Percentage Identified 9 88 1.0
# Percentage Identified 7 124 1.0
# Percentage Identified 19 160 1.0
# Percentage Identified 16 176 1.0
# Percentage Identified 13 113 1.0
# Percentage Identified 8 118 1.0
# Percentage Identified 19 174 0.9942528735632183
# Percentage Identified 17 137 1.0
# Percentage Identified 17 93 1.0
# Percentage Identified 6 95 1.0
# Percentage Identified 11 82 1.0
# Percentage Identified 13 137 1.0
# Percentage Identified 15 170 1.0
# Percentage Identified 7 78 1.0
# Percentage Identified 11 100 1.0
# Percentage Identified 10 111 1.0
# Percentage Identified 16 173 1.0
# Percentage Identified 13 107 1.0
# Percentage Identified 11 113 1.0
# Percentage Identified 13 114 1.0
# Percentage Identified 1 21 1.0
# Percentage Identified 7 88 1.0
# Percentage Identified 14 140 1.0
# Percentage Identified 10 151 1.0
# Percentage Identified 10 75 1.0
# Percentage Identified 11 83 1.0
# Percentage Identified 18 119 1.0
# Percentage Identified 14 111 1.0
# Percentage Identified 11 47 1.0
# Percentage Identified 16 141 1.0
# Percentage Identified 18 151 1.0
# Percentage Identified 20 118 1.0
# Percentage Identified 14 103 1.0
# Percentage Identified 20 201 1.0
# Percentage Identified 11 87 1.0
# Percentage Identified 11 190 1.0
# Percentage Identified 8 25 1.0
# Percentage Identified 16 176 1.0
# Percentage Identified 15 78 1.0
# Percentage Identified 17 130 1.0
# Percentage Identified 9 45 1.0
# Percentage Identified 19 244 1.0
# Percentage Identified 14 127 0.9921259842519685
# Percentage Identified 13 148 1.0
# Percentage Identified 18 136 1.0
# Percentage Identified 14 90 1.0
# Percentage Identified 16 126 1.0
# Percentage Identified 20 207 1.0
# Percentage Identified 3 52 1.0
# Percentage Identified 17 210 1.0
# Percentage Identified 18 149 1.0
# Percentage Identified 14 123 1.0
# Percentage Identified 15 159 1.0
# Percentage Identified 7 129 1.0
# Percentage Identified 3 23 1.0
# Percentage Identified 5 67 1.0
# Percentage Identified 9 20 1.0
# Percentage Identified 12 79 1.0
# Percentage Identified 13 80 1.0
# Percentage Identified 14 74 1.0
# Percentage Identified 20 211 1.0
# Percentage Identified 19 129 1.0
# Percentage Identified 8 94 1.0
# Percentage Identified 6 78 1.0
# Percentage Identified 10 123 0.991869918699187
# Percentage Identified 11 169 1.0
# Percentage Identified 7 72 1.0
# Percentage Identified 15 60 1.0
# Percentage Identified 13 93 1.0
# Percentage Identified 12 190 0.9947368421052631
# Percentage Identified 8 148 0.972972972972973
# Percentage Identified 12 97 1.0
# Percentage Identified 19 69 1.0
# Percentage Identified 3 72 1.0
# Percentage Identified 6 57 1.0
# Percentage Identified 15 135 1.0
# Percentage Identified 16 111 1.0
# Percentage Identified 12 151 1.0
# Percentage Identified 20 61 1.0
# Percentage Identified 10 170 1.0
# Percentage Identified 12 38 1.0
# Percentage Identified 16 68 1.0
# Percentage Identified 20 150 1.0
# Percentage Identified 20 131 1.0
# Percentage Identified 19 133 1.0
# Percentage Identified 8 77 1.0
# Percentage Identified 15 113 1.0
# Percentage Identified 18 75 1.0
# Percentage Identified 13 123 1.0
# Percentage Identified 8 61 1.0
# Percentage Identified 18 119 1.0
# Percentage Identified 13 136 1.0
# Percentage Identified 14 134 1.0
# Percentage Identified 19 116 1.0
# Percentage Identified 18 183 1.0
# Percentage Identified 9 78 1.0
# Percentage Identified 15 131 1.0
# Percentage Identified 12 46 1.0
# Percentage Identified 15 172 1.0
# Percentage Identified 19 196 1.0
# Percentage Identified 19 93 0.989247311827957
# Percentage Identified 20 183 1.0
# Percentage Identified 12 117 1.0
# Percentage Identified 11 81 1.0
# Percentage Identified 19 186 1.0
# Percentage Identified 16 242 1.0
# Percentage Identified 12 110 1.0
# Percentage Identified 15 117 1.0
# Percentage Identified 7 109 1.0
# Percentage Identified 3 96 1.0
# Percentage Identified 3 39 1.0
# Percentage Identified 2 55 1.0
# Percentage Identified 17 135 1.0
# Percentage Identified 9 100 1.0
# Percentage Identified 14 115 1.0
# Percentage Identified 19 130 0.9923076923076923
# Percentage Identified 16 181 1.0
# Percentage Identified 17 150 1.0
# Percentage Identified 20 226 1.0
# Percentage Identified 20 157 1.0
# Percentage Identified 11 104 1.0
# Percentage Identified 20 126 1.0
# Percentage Identified 15 65 1.0
# Percentage Identified 11 77 1.0
# Percentage Identified 16 189 0.9947089947089947
# Percentage Identified 9 96 1.0
# Percentage Identified 6 66 1.0
# Percentage Identified 15 62 1.0
# Percentage Identified 19 217 1.0
# Percentage Identified 18 141 1.0
# Percentage Identified 17 225 1.0
# Percentage Identified 6 100 1.0
# Percentage Identified 14 142 1.0
# Percentage Identified 8 170 1.0
# Percentage Identified 13 117 1.0
# Percentage Identified 12 149 1.0
# Percentage Identified 8 105 1.0
# Percentage Identified 19 224 1.0
# Percentage Identified 19 193 1.0
# Percentage Identified 15 79 1.0
# Percentage Identified 9 158 1.0
# Percentage Identified 6 87 1.0
# Percentage Identified 14 151 1.0
# Percentage Identified 3 51 1.0
# Percentage Identified 16 107 1.0
# Percentage Identified 12 60 1.0
# Percentage Identified 14 129 1.0
# Percentage Identified 17 148 1.0
# Percentage Identified 19 89 1.0
# Percentage Identified 17 184 1.0
# Percentage Identified 9 117 1.0
# Percentage Identified 17 152 0.993421052631579
# Percentage Identified 18 117 1.0
# Percentage Identified 13 130 1.0
# Percentage Identified 11 138 1.0
# Percentage Identified 11 66 1.0
# Percentage Identified 10 85 1.0
# Percentage Identified 13 200 0.995
# Percentage Identified 1 58 1.0
# Percentage Identified 9 111 1.0
# Percentage Identified 4 66 1.0
# Percentage Identified 20 55 1.0
# Percentage Identified 15 171 1.0
# Percentage Identified 2 46 1.0
# Percentage Identified 20 186 1.0
# Percentage Identified 19 120 1.0
# Percentage Identified 5 73 1.0
# Percentage Identified 10 81 1.0
# Percentage Identified 6 68 1.0
# Percentage Identified 18 73 1.0
# Percentage Identified 5 82 1.0
# Percentage Identified 17 114 0.9824561403508771
# Percentage Identified 8 63 1.0
# Percentage Identified 8 75 1.0
# Percentage Identified 12 92 1.0
# Percentage Identified 16 175 1.0
# Percentage Identified 7 86 1.0
# Percentage Identified 5 92 1.0
# Percentage Identified 8 33 1.0
# Percentage Identified 20 192 1.0
# Percentage Identified 11 57 1.0
# Percentage Identified 10 91 1.0
# Percentage Identified 18 122 0.9918032786885246
# Percentage Identified 9 81 1.0
# Percentage Identified 20 108 0.9907407407407407
# Percentage Identified 17 155 0.9935483870967742
# Percentage Identified 8 112 1.0
# Percentage Identified 15 143 1.0
# Percentage Identified 9 71 1.0
# Percentage Identified 5 40 1.0
# Percentage Identified 10 109 1.0
# Percentage Identified 5 36 1.0
# Percentage Identified 19 132 1.0
# Percentage Identified 1 3 1.0
# Percentage Identified 7 37 1.0
# Percentage Identified 6 48 1.0
# Percentage Identified 16 128 1.0
# Percentage Identified 19 94 1.0
# Percentage Identified 9 124 1.0
# Percentage Identified 5 95 1.0
# Percentage Identified 5 102 1.0
# Percentage Identified 1 7 1.0
# Percentage Identified 5 42 1.0
# Percentage Identified 3 51 1.0
# Percentage Identified 20 148 1.0
# Percentage Identified 13 99 1.0
# Percentage Identified 14 139 1.0
# Percentage Identified 12 122 1.0
# Percentage Identified 18 182 1.0
# Percentage Identified 12 73 1.0
# Percentage Identified 14 143 1.0
# Percentage Identified 19 52 1.0
# Percentage Identified 16 129 1.0
# Percentage Identified 10 29 1.0
# Percentage Identified 2 6 1.0
# Percentage Identified 5 49 1.0
# Percentage Identified 19 208 0.9951923076923077
# Percentage Identified 20 122 1.0
# Percentage Identified 7 96 1.0
# Percentage Identified 8 79 1.0
# Percentage Identified 9 104 1.0
# Percentage Identified 1 40 1.0
# Percentage Identified 16 198 1.0
# Percentage Identified 16 158 1.0
# Percentage Identified 1 18 1.0
# Percentage Identified 12 160 1.0
# Percentage Identified 13 96 1.0
# Percentage Identified 13 159 1.0
# Percentage Identified 14 84 1.0
# Percentage Identified 20 96 1.0
# Percentage Identified 13 127 1.0
# Percentage Identified 4 83 1.0
# Percentage Identified 13 129 1.0
# Percentage Identified 17 129 1.0
# Percentage Identified 18 234 1.0
# Percentage Identified 16 148 1.0
# Percentage Identified 20 151 1.0
# Percentage Identified 4 105 1.0
# Percentage Identified 13 110 1.0
# Percentage Identified 12 80 1.0
# Percentage Identified 15 135 1.0
# Percentage Identified 6 144 1.0
# Percentage Identified 17 190 0.9894736842105263
# Percentage Identified 1 15 1.0
# Percentage Identified 15 193 1.0
# Percentage Identified 6 54 1.0
# Percentage Identified 7 58 1.0
# Percentage Identified 15 137 1.0
# Percentage Identified 11 90 1.0
# Percentage Identified 18 129 1.0
# Percentage Identified 9 99 1.0
# Percentage Identified 18 116 1.0
# Percentage Identified 11 114 1.0
# Percentage Identified 9 178 1.0
# Percentage Identified 15 111 1.0
# Percentage Identified 6 101 1.0
# Percentage Identified 11 151 1.0
# Percentage Identified 2 21 1.0
# Percentage Identified 16 92 1.0
# Percentage Identified 10 94 1.0
# Percentage Identified 11 116 1.0
# Percentage Identified 13 117 1.0
# Percentage Identified 8 104 1.0
# Percentage Identified 13 203 1.0
# Percentage Identified 20 34 1.0
# Percentage Identified 15 108 1.0
# Percentage Identified 6 59 1.0
# Percentage Identified 8 61 1.0
# Percentage Identified 15 141 1.0
# Percentage Identified 17 141 1.0
# Percentage Identified 15 100 1.0
# Percentage Identified 8 65 1.0
# Percentage Identified 14 115 1.0
# Percentage Identified 16 143 1.0
# Percentage Identified 18 204 1.0
# Percentage Identified 19 192 1.0
# Percentage Identified 10 90 1.0
# Percentage Identified 11 99 1.0
# Percentage Identified 13 74 1.0
# Percentage Identified 20 139 1.0
# Percentage Identified 19 117 1.0
# Percentage Identified 5 45 1.0
# Percentage Identified 19 143 1.0
# Percentage Identified 7 90 1.0
# Percentage Identified 19 141 1.0
# Percentage Identified 17 137 1.0
# Percentage Identified 11 84 1.0
# Percentage Identified 14 236 1.0
# Percentage Identified 12 97 1.0
# Percentage Identified 12 44 1.0
# Percentage Identified 1 1 1.0
# Percentage Identified 2 89 1.0
# Percentage Identified 6 113 1.0
# Percentage Identified 15 175 1.0
# Percentage Identified 9 69 1.0
# Percentage Identified 12 109 1.0
# Percentage Identified 10 74 1.0
# Percentage Identified 19 196 0.9948979591836735
# Percentage Identified 20 60 1.0
# Percentage Identified 19 120 1.0
# Percentage Identified 14 126 1.0
# Percentage Identified 18 143 1.0
# Percentage Identified 6 83 1.0
# Percentage Identified 4 11 1.0
# Percentage Identified 8 92 1.0
# Percentage Identified 13 114 1.0
# Percentage Identified 14 121 1.0
# Percentage Identified 9 121 1.0
# Percentage Identified 3 30 1.0
# Percentage Identified 15 143 1.0
# Percentage Identified 11 125 1.0
# Percentage Identified 13 82 1.0
# Percentage Identified 8 36 1.0
# Percentage Identified 9 111 1.0
# Percentage Identified 7 102 1.0
# Percentage Identified 8 160 1.0
# Percentage Identified 13 132 1.0
# Percentage Identified 12 101 1.0
# Percentage Identified 16 142 1.0
# Percentage Identified 6 50 1.0
# Percentage Identified 14 124 1.0
# Percentage Identified 15 104 1.0
# Percentage Identified 11 133 1.0
# Percentage Identified 19 106 1.0
# Percentage Identified 18 227 1.0
# Percentage Identified 20 206 1.0
# Percentage Identified 7 132 1.0
# Percentage Identified 8 122 1.0
# Percentage Identified 10 55 1.0
# Percentage Identified 11 106 1.0
# Percentage Identified 14 114 1.0
# Percentage Identified 19 227 1.0
# Percentage Identified 13 138 1.0
# Percentage Identified 19 73 1.0
# Percentage Identified 19 204 1.0
# Percentage Identified 17 154 1.0
# Percentage Identified 12 136 1.0
# Percentage Identified 4 73 1.0
# Percentage Identified 10 169 1.0
# Percentage Identified 20 207 1.0
# Percentage Identified 14 118 1.0
# Percentage Identified 11 86 1.0
# Percentage Identified 5 54 1.0
# Percentage Identified 13 119 1.0
# Percentage Identified 7 133 1.0
# Percentage Identified 18 181 1.0
# Percentage Identified 8 114 1.0
# Percentage Identified 18 159 1.0
# Percentage Identified 9 98 1.0
# Percentage Identified 15 162 1.0
# Percentage Identified 18 117 1.0
# Percentage Identified 12 116 1.0
# Percentage Identified 5 51 1.0
# Percentage Identified 18 168 1.0
# Percentage Identified 20 180 1.0
# Percentage Identified 12 67 1.0
# Percentage Identified 7 71 1.0
# Percentage Identified 11 98 1.0
# Percentage Identified 20 207 1.0
# Percentage Identified 9 119 1.0
# Percentage Identified 8 78 1.0
# Percentage Identified 6 84 1.0
# Percentage Identified 10 118 1.0
# Percentage Identified 9 150 1.0
# Percentage Identified 20 184 1.0
# Percentage Identified 20 159 1.0
# Percentage Identified 11 164 1.0
# Percentage Identified 9 114 1.0
# Percentage Identified 9 39 1.0
# Percentage Identified 11 60 0.9833333333333333
# Percentage Identified 23 166 0.8975903614457831
# Percentage Identified 12 143 0.951048951048951
# Percentage Identified 18 55 1.0
# Percentage Identified 22 183 0.9508196721311475
# Percentage Identified 9 128 1.0
# Percentage Identified 5 128 1.0
# Percentage Identified 4 47 1.0
# Percentage Identified 17 142 0.8943661971830986
# Percentage Identified 21 136 0.8014705882352942
# Percentage Identified 6 134 0.7761194029850746
# Percentage Identified 4 29 1.0
# Percentage Identified 1 48 1.0
# Percentage Identified 20 131 1.0
# Percentage Identified 1 69 1.0
# Percentage Identified 12 102 1.0
# Percentage Identified 10 140 1.0
# Percentage Identified 16 212 0.8301886792452831
# Percentage Identified 18 162 1.0
# Percentage Identified 13 94 1.0
# Percentage Identified 37 923 0.3076923076923077
# Percentage Identified 13 160 1.0
# Percentage Identified 3 57 1.0
# Percentage Identified 9 115 0.9739130434782609
# Percentage Identified 15 158 0.5632911392405063
# Percentage Identified 9 98 1.0
# Percentage Identified 9 50 1.0
# Percentage Identified 10 80 1.0
# Percentage Identified 16 145 1.0
# Percentage Identified 19 85 1.0
# Percentage Identified 15 79 1.0
# Percentage Identified 18 85 1.0
# Percentage Identified 18 106 1.0
# Percentage Identified 17 108 0.7962962962962963
# Percentage Identified 18 146 1.0
# Percentage Identified 13 27 1.0
# Percentage Identified 4 49 1.0
# Percentage Identified 12 81 1.0
# Percentage Identified 14 141 0.9929078014184397
# Percentage Identified 4 164 1.0
# Percentage Identified 2 25 1.0
# Percentage Identified 12 78 1.0
# Percentage Identified 155 1198 0.2020033388981636
# Percentage Identified 4 21 1.0
# Percentage Identified 20 162 0.49382716049382713
# Percentage Identified 14 137 0.5912408759124088
# Percentage Identified 112 1214 0.2701812191103789
# Percentage Identified 3 97 1.0
# Percentage Identified 9 49 0.9183673469387755
# Percentage Identified 85 697 0.20516499282639886
# Percentage Identified 14 144 0.6736111111111112
# Percentage Identified 70 759 0.10935441370223979
# Percentage Identified 41 346 0.4190751445086705
# Percentage Identified 1 39 1.0
# Percentage Identified 17 134 0.8880597014925373
# Percentage Identified 1 67 1.0
# Percentage Identified 18 103 0.5631067961165048
# Percentage Identified 11 98 0.5816326530612245
# Percentage Identified 5 25 1.0
# Percentage Identified 3 75 1.0
# Percentage Identified 21 267 0.3595505617977528
# Percentage Identified 19 112 1.0
# Percentage Identified 19 79 1.0
# Percentage Identified 11 22 1.0
# Percentage Identified 17 125 1.0
# Percentage Identified 16 99 1.0
# Percentage Identified 11 45 1.0
# Percentage Identified 71 23 1.0
# Percentage Identified 22 169 0.7633136094674556
# Percentage Identified 13 158 1.0
# Percentage Identified 13 65 0.9538461538461539
# Percentage Identified 8 162 0.9567901234567902
# Percentage Identified 14 135 1.0
# Percentage Identified 18 231 1.0
# Percentage Identified 9 126 0.9841269841269841
# Percentage Identified 11 139 1.0
# Percentage Identified 13 140 0.9785714285714285
# Percentage Identified 14 132 1.0
# Percentage Identified 18 67 1.0
# Percentage Identified 14 136 1.0
# Percentage Identified 13 88 1.0
# Percentage Identified 20 135 1.0
# Percentage Identified 13 90 1.0
# Percentage Identified 10 84 1.0
# Percentage Identified 10 107 1.0
# Percentage Identified 14 148 1.0
# Percentage Identified 4 50 1.0
# Percentage Identified 2 25 1.0
# Percentage Identified 9 121 1.0
# Percentage Identified 10 162 1.0
# Percentage Identified 6 29 1.0
# Percentage Identified 1 11 1.0
# Percentage Identified 16 151 1.0
# Percentage Identified 9 111 1.0
# Percentage Identified 20 122 1.0
# Percentage Identified 19 221 1.0
# Percentage Identified 1 19 1.0
# Percentage Identified 20 98 1.0
# Percentage Identified 11 163 1.0
# Percentage Identified 15 70 1.0
# Percentage Identified 10 94 1.0
# Percentage Identified 2 69 1.0
# Percentage Identified 18 199 1.0
# Percentage Identified 17 97 1.0
# Percentage Identified 13 177 1.0
# Percentage Identified 6 138 1.0
# Percentage Identified 5 104 1.0
# Percentage Identified 3 45 1.0
# Percentage Identified 17 167 1.0
# Percentage Identified 11 147 1.0
# Percentage Identified 14 85 1.0
# Percentage Identified 20 92 1.0
# Percentage Identified 20 161 1.0
# Percentage Identified 9 127 1.0
# Percentage Identified 10 106 1.0
# Percentage Identified 12 136 1.0
# Percentage Identified 14 61 1.0
# Percentage Identified 1 16 1.0
# Percentage Identified 6 64 1.0
# Percentage Identified 12 73 1.0
# Percentage Identified 4 52 1.0
# Percentage Identified 4 4 1.0
# Percentage Identified 13 143 1.0
# Percentage Identified 20 184 1.0
# Percentage Identified 12 99 1.0
# Percentage Identified 8 53 1.0
# Percentage Identified 5 25 1.0
# Percentage Identified 6 71 1.0
# Percentage Identified 11 155 1.0
# Percentage Identified 16 172 1.0
# Percentage Identified 3 50 1.0
# Percentage Identified 6 35 1.0
# Percentage Identified 4 97 1.0
# Percentage Identified 5 39 1.0
# Percentage Identified 17 154 1.0
# Percentage Identified 20 68 1.0
# Percentage Identified 12 113 1.0
# Percentage Identified 2 74 1.0
# Percentage Identified 12 146 1.0
# Percentage Identified 17 194 0.9742268041237113
# Percentage Identified 5 73 1.0
# Percentage Identified 19 179 1.0
# Percentage Identified 2 103 1.0
# Percentage Identified 10 102 1.0
# Percentage Identified 15 197 0.9949238578680203
# Percentage Identified 15 50 1.0
# Percentage Identified 18 79 1.0
# Percentage Identified 7 41 0.8536585365853658
# Percentage Identified 15 154 1.0
# Percentage Identified 14 116 1.0
# Percentage Identified 12 98 1.0
# Percentage Identified 19 136 0.8897058823529411
# Percentage Identified 13 120 0.9833333333333333
# Percentage Identified 11 161 0.937888198757764
# Percentage Identified 2 26 1.0
# Percentage Identified 13 82 0.7560975609756098
# Percentage Identified 11 149 1.0
# Percentage Identified 2 73 1.0
# Percentage Identified 14 144 1.0
# Percentage Identified 15 116 1.0
# Percentage Identified 11 53 1.0
# Percentage Identified 15 66 1.0
# Percentage Identified 15 182 1.0
# Percentage Identified 15 143 0.993006993006993
# Percentage Identified 13 92 1.0
# Percentage Identified 12 76 1.0
# Percentage Identified 20 126 1.0
# Percentage Identified 18 63 1.0
# Percentage Identified 14 119 1.0
# Percentage Identified 16 146 1.0
# Percentage Identified 10 127 1.0
# Percentage Identified 19 118 1.0
# Percentage Identified 20 146 0.9657534246575342
# Percentage Identified 30 249 0.26104417670682734
# Percentage Identified 17 153 1.0
# Percentage Identified 21 205 0.9512195121951219
# Percentage Identified 3 17 1.0
# Percentage Identified 11 93 1.0
# Percentage Identified 103 975 0.06564102564102564
# Percentage Identified 1 24 1.0
# Percentage Identified 74 599 0.0667779632721202
# Percentage Identified 16 246 0.8373983739837398
# Percentage Identified 19 165 0.896969696969697
# Percentage Identified 14 130 0.7307692307692307
# Percentage Identified 8 51 0.9803921568627451
# Percentage Identified 10 98 0.9591836734693877
# Percentage Identified 17 267 0.40074906367041196
# Percentage Identified 10 109 0.8165137614678899
# Percentage Identified 23 260 0.5884615384615385
# Percentage Identified 12 175 0.6342857142857142
# Percentage Identified 13 106 0.7830188679245284
# Percentage Identified 18 42 1.0
# Percentage Identified 58 589 0.300509337860781
# Percentage Identified 20 134 0.6567164179104478
# Percentage Identified 11 99 0.8686868686868687
# Percentage Identified 24 211 0.7630331753554502
# Percentage Identified 2 30 1.0
# Percentage Identified 64 390 0.2153846153846154
# Percentage Identified 21 295 0.7762711864406779
# Percentage Identified 2 6 1.0
# Percentage Identified 14 176 0.5454545454545454
# Percentage Identified 19 282 0.9326241134751773
# Percentage Identified 7 164 0.7439024390243902
# Percentage Identified 8 55 1.0
# Percentage Identified 17 204 0.7352941176470589
# Percentage Identified 5 105 1.0
# 704 78756

# %%
# Train and test on multiple datasets with mutation
num_outliers = []
for i in range(20):
    s_file = 'data/JDT.csv'
    cluster,cluster_tree,max_depth = cluster_driver(s_file)
    t_file = 'data/JDT_' + str(i) +'.csv'
    test_X,test_y = load_mutated_data(t_file,'defects')
    depth = max_depth
    predicted = cluster.predict(test_X,depth)
    cluster.certify_model(cluster_tree,test_y)
    total = 0
    for i in cluster_tree:
        if len(cluster_tree[i].test_points) == 0:
            continue
        total += len(cluster_tree[i].outlier_points)
    num_outliers.append(total/test_X.shape[0])

# %%
# Plot outliers detected at every iteration
plt.plot(num_outliers)
plt.title('Context Shift outlier detection plot for:' + s_file)
plt.xlabel('Number of Outliers')
plt.ylabel('Repeats')
plt.show()

# %%
x = np.array([[1,np.array([18,2,3,4])],[2,np.array([2,3,4,5])],[3,np.array([3,4,5,6])],[4,np.array([4,5,6,7])]])
y = np.array([1,1,1,1])

# %%
def distance(x,y):
    dist = (list(x[:,1]) - y)**2
    dist = np.sum(dist, axis=1)
    dist = np.sqrt(dist)
    print(dist)
    ind = np.unravel_index(np.argmin(dist, axis=None), dist.shape)
    min_distance = dist[np.argmin(dist, axis=None)]
    return ind[0],min_distance

# %%
x = np.random.rand(4500,118)
z = np.random.rand(4500,1)
x = np.array(list(zip(z,x)))
y = np.random.rand(1,118)

# %%
ind,dis = distance(x,y)

# %%
x[ind]

# %%
dis

# %%
x

# %%
model =  OneClassSVM(nu=0.8)

# %%
file = 'Data/KDD/modified/train.csv'
train_X, test_X, train_y, test_y = load_data(file,'defects')
model.fit(train_X)
# Out:
# (247010, 11)
# OneClassSVM(cache_size=200, coef0=0.0, degree=3, gamma='auto_deprecated',
#       kernel='rbf', max_iter=-1, nu=0.8, random_state=None, shrinking=True,
#       tol=0.001, verbose=False)

# %%
predicted = model.predict(test_X)

# %%
import collections, numpy
a = collections.Counter(predicted)

# %%
a
# Out:
# Counter({-1: 24701})
