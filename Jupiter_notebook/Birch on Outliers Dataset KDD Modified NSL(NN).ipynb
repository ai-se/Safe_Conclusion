# %%
import pandas as pd
import numpy as np
import collections
import seaborn as sns
import matplotlib.pyplot as plt
from graphviz import Digraph
import scipy.spatial.distance
from scipy.cluster.hierarchy import dendrogram
#Clustering birch
from freediscovery.cluster import birch_hierarchy_wrapper
from freediscovery.cluster import Birch,BirchSubcluster
#Sklearn
from sklearn.metrics.pairwise import pairwise_distances
from sklearn.model_selection import train_test_split
from sklearn import metrics
#Learners
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import OneClassSVM
#Distance measure
from scipy.spatial.distance import euclidean
from scipy import linalg, sparse

import warnings

import matplotlib.pyplot as plt

import pickle

# %%
warnings.filterwarnings("ignore")

# %%
def row_norms(X, squared=False):
    if sparse.issparse(X):
        if not isinstance(X, sparse.csr_matrix):
            X = sparse.csr_matrix(X)
        norms = csr_row_norms(X)
    else:
        norms = np.einsum('ij,ij->i', X, X)

    if not squared:
        np.sqrt(norms, norms)
    return norms

# %%
class bcluster(object):
    
    def __init__(self):
        self.parent = None
        self.parent_id = None
        self.depth = None
        self.size = None
        self.cluster_id = None
        self.data_points = []
        self.data_labels = []
        self.test_points = []
        self.test_labels = []
        self.predicted = []
        self.centroid = None
        self.classifier = None
        self.outlier_model = None
        self.cluster_obj = None
        self.outlier_points = []
        self.outlier_points_prediction = []
        self.score = []
        self.d1 = None
        self.d2 = None
        self.threshold = None
        self.retrain = False
    
    def set_parent(self,parent_node=None):
        if parent_node == None:
            self.parent = None
            self.parent_id = None
        else:
            self.parent = parent_node
            self.parent_id = parent_node.cluster_id
    
    def set_depth(self,depth):
        self.depth = depth
    
    def set_size(self,size):
        self.size = size
        
    def set_cluster_id(self,cluster_id):
        self.cluster_id = cluster_id
        
    def set_data_points(self,data_points):
        self.data_points = data_points
        
    def set_data_labels(self,data_labels):
        self.data_labels = data_labels
    
    def set_test_labels(self,test_labels):
        self.test_labels = test_labels
        
    def add_test_lables(self,test_labels):
        self.test_labels.append(test_labels)
        
    def reset_test_lables_bucket(self):
        self.test_labels = []
        
    def add_test_points(self,test_point):
        self.test_points.append(test_point)
        
    def reset_test_points_bucket(self):
        self.test_points = []
        
    def add_outlier_points_prediction(self,outlier_points_prediction):
        self.outlier_points_prediction.append(outlier_points_prediction)
        
    def reset_outlier_points_prediction_bucket(self):
        self.outlier_points_prediction = []
    
    def add_predicted(self,predicted):
        self.predicted.append(predicted)
    
    def set_centroid(self,centroid):
        self.centroid = centroid
        
    def set_classifier(self,classifier):
        self.classifier = classifier
        
    def set_outlier_model(self,outlier_model):
        self.outlier_model = outlier_model
        
    def set_cluster_obj(self,cluster_obj):
        self.cluster_obj = cluster_obj
        
    def add_outlier_points(self,outlier_points):
        self.outlier_points.append(outlier_points)
    
    def reset_outlier_bucket(self):
        self.outlier_points = []
        
    def set_score(self,score):
        self.score = score
        
    def add_d1(self,d1):
        self.d1 = d1
        
    def add_d2(self,d2):
        self.d2 = d2
        
    def calculate_threshold(self,outlier_threshold):
        self.threshold = max(self.d1,self.d2)*outlier_threshold
        
    def check_outlier(self,distance):
        if self.threshold < distance:
            result = True
        else:
            result = False
        return result
    
    def check_OCS_outlier(self,test_data):
        _result = self.outlier_model.predict([test_data])
        if _result == -1:
            result = True
            self.add_outlier_points_prediction(list(_result)[0])
        else:
            result = False
            self.add_outlier_points_prediction(list(_result)[0])
        return result
    
    def set_retarin():
        self.retrain = True

# %%
class birch(object):

    def __init__(self,threshold=0.5,branching_factor=40,n_clusters=None,outlier_threshold=0.7):
        self.threshold = threshold
        self.branching_factor = branching_factor
        self.n_clusters = n_clusters
        self.outlier_threshold = outlier_threshold
        self.Birch_clusterer = Birch(threshold=self.threshold, branching_factor=self.branching_factor,
                                     n_clusters=self.n_clusters,compute_sample_indices=True)
    # Fitting the model with train_X
    def fit(self,data,y):
        self.data = data
        self.y = y
        #self.data.drop(self.data.columns[len(self.data.columns)-1], axis=1, inplace=True)
        self.Birch_clusterer.fit(self.data)

    #Defines and builds the Cluster Feature Tree
    def get_cluster_tree(self):
        self.htree, n_clusters = birch_hierarchy_wrapper(self.Birch_clusterer)
        clusters = {}
        max_depth = 0
        for i in range(n_clusters):
            #print('cluster:', i)
            node = bcluster()
            sub_cluster = self.htree.flatten()[i]
            node.set_cluster_id(sub_cluster['cluster_id'])
            depth = sub_cluster.current_depth
            node.set_depth(depth)
            if depth > max_depth:
                max_depth = depth
            if i not in clusters.keys():
                clusters[i] = {}
            if sub_cluster.current_depth == 0:
                node.set_parent()
            else:
                node.set_parent(clusters[sub_cluster.parent['cluster_id']])
            cluster_size = sub_cluster['cluster_size']
            node.set_size(cluster_size)
            data_points = sub_cluster['document_id_accumulated']
            node.set_data_points(data_points)
            node.set_data_labels(self.y[sub_cluster['document_id_accumulated']])
            centroid = self.data.iloc[sub_cluster['document_id_accumulated'], :].mean(axis=0).values
            node.set_centroid(centroid)
            d1,d1_v = self.calculate_d1(centroid,data_points)
            d2 = self.calculate_d2(centroid,data_points,d1_v)
            node.add_d1(d1)
            node.add_d2(d2)
            node.calculate_threshold(self.outlier_threshold)
            clusters[i] = node
        return clusters,max_depth
    
    #Calculate the d1 distance(point farthest away from centroid)
    def calculate_d1(self,centroid,data_points):
        d1 = 0
        u = centroid
        d1_v = None
        for point in data_points:
            v = point
            distance = euclidean(u,v)
            if distance>d1:
                d1 = distance
                d1_v = v
        return d1,d1_v
    
    #Calculate the d2 distance(point farthest away from d1 and its distance from centroid)
    def calculate_d2(self,centroid,data_points,d1_v):
        d2_d1 = 0
        u = d1_v
        d2_v = None
        for point in data_points:
            v = point
            distance = euclidean(u,v)
            if distance>d2_d1:
                d2_d1 = distance
                d2_v = v
        d2 = euclidean(centroid,v)
        return d2
    
    # Display's the tree
    def show_clutser_tree(self):
        self.htree.display_tree()
        
    # Add classification model at each node and leaf
    def model_adder(self,cluster_tree):
        for cluster_id in cluster_tree:
            clf = DecisionTreeClassifier(criterion='entropy')
            sample_points = cluster_tree[cluster_id].data_points
            train_X_sub = self.data.iloc[sample_points,:]
            train_y_sub = self.y[sample_points]
            clf.fit(train_X_sub,train_y_sub)
            cluster_tree[cluster_id].set_classifier(clf)
        return cluster_tree
    
    def outlier_model_adder(self,cluster_tree,depth):
        for cluster_id in cluster_tree:
            #if depth != cluster_tree[cluster_id].depth:
            #    continue
            #print('building outlier',cluster_id,cluster_tree[cluster_id].depth,len(cluster_tree[cluster_id].data_points))
            _nu = ((cluster_tree[cluster_id].data_labels == -1).sum()/len(cluster_tree[cluster_id].data_labels))
            if _nu == 0:
                _nu = 0.01
            clf = OneClassSVM(kernel = 'sigmoid',gamma = 'scale',nu=0.4)
            sample_points = cluster_tree[cluster_id].data_points
            train_X_sub = self.data.iloc[sample_points,:]
            clf.fit(train_X_sub)
            cluster_tree[cluster_id].set_outlier_model(clf)
        return cluster_tree
        
    # Prediction Function with height based prediction with outlier detection
    def predict(self,test_X,depth,do_predict=True):
        predicted = []
        for test_instance in test_X.iterrows():
            test_sample = test_instance[1].values
            min_distance = float('inf')
            selected_cluster = None
            for cluster_id in cluster_tree:
                if cluster_tree[cluster_id].depth != depth:
                    continue
                u = cluster_tree[cluster_id].centroid
                v = np.asarray(test_sample,dtype='float64')
                distance = euclidean(u,v)
                if distance < min_distance:
                    min_distance = distance
                    selected_cluster = cluster_id
            cluster_tree[selected_cluster].add_test_points(test_instance[0])
            # Outlier identifier
            if cluster_tree[selected_cluster].check_outlier(min_distance):
                cluster_tree[selected_cluster].add_outlier_points(test_instance[0])
            if do_predict:
                _predicted_label = cluster_tree[selected_cluster].classifier.predict([test_sample])
                cluster_tree[selected_cluster].add_predicted(_predicted_label)
                predicted.append(_predicted_label)
        return predicted
    
    def distance(self,x,y):
        dist = (list(x[:,1]) - y)**2
        dist = np.sum(dist, axis=1)
        dist = np.sqrt(dist)
        ind = np.unravel_index(np.argmin(dist, axis=None), dist.shape)
        min_distance = dist[np.argmin(dist, axis=None)]
        return list(x[ind])[0],min_distance
    
    def distance_alternet(self,x,y,row_norm):
        reduced_distance = np.dot(np.matrix(y), np.matrix(x).T)
        reduced_distance *= -2
        reduced_distance += row_norm
        return np.array(np.argmin(reduced_distance, axis=1))[0][0]
    
    # New Predict
    def predict_new(self,test_X,test_y,depth,do_predict=True):
        predicted = []
        cluster_centroids = []
        cluster_centroids_ids = []
        for cluster_id in cluster_tree:
            if cluster_tree[cluster_id].depth != depth:
                continue
            cluster_tree[cluster_id].reset_outlier_bucket()
            cluster_tree[cluster_id].reset_test_lables_bucket()
            cluster_tree[cluster_id].reset_test_points_bucket()
            cluster_tree[cluster_id].reset_outlier_points_prediction_bucket()
            if cluster_tree[cluster_id].depth != depth:
                continue
            cluster_centroids_ids.append(cluster_id) # Change when using normal distance
            cluster_centroids.append(cluster_tree[cluster_id].centroid)
        cluster_centroids = np.array(cluster_centroids)
        row_norm = row_norms(cluster_centroids)
        for test_instance in test_X.iterrows():
            test_sample = np.array(test_instance[1].values)
            #selected_cluster,min_distance = self.distance_alternet(cluster_centroids,test_sample,row_norm)  # Change when using normal distance
            selected_cluster = cluster_centroids_ids[self.distance_alternet(cluster_centroids,test_sample,row_norm)]
            if cluster_tree[selected_cluster].check_OCS_outlier(test_sample):
                cluster_tree[selected_cluster].add_outlier_points(test_instance[0])
            cluster_tree[selected_cluster].add_test_points(test_instance[0])
            cluster_tree[selected_cluster].add_test_lables(test_y[test_instance[0]])
            if do_predict:
                _predicted_label = cluster_tree[selected_cluster].classifier.predict([test_sample])
                cluster_tree[selected_cluster].add_predicted(_predicted_label)
                predicted.append(_predicted_label)
        return predicted
    
    # Model certification creator
    def certify_model(self,cluster_tree,test_y):
        for cluster_id in cluster_tree:
            if len(cluster_tree[cluster_id].test_points) == 0:
                continue
            cluster_tree[cluster_id].set_test_labels(test_y[cluster_tree[cluster_id].test_points].values)
            precision = metrics.precision_score(cluster_tree[cluster_id].test_labels, 
                                                cluster_tree[cluster_id].predicted,average='weighted')
            recall = metrics.recall_score(cluster_tree[cluster_id].test_labels, 
                                          cluster_tree[cluster_id].predicted,average='weighted')
            f1_Score = metrics.f1_score(cluster_tree[cluster_id].test_labels, 
                                        cluster_tree[cluster_id].predicted,average='weighted')
            score = {'precision': precision,'recall': recall,'f1_Score': f1_Score}
            cluster_tree[cluster_id].set_score(score)
            
    # Model certification creator
    def recertify_model(self,cluster_tree):
        for cluster_id in cluster_tree:
            num_test_points = len(cluster_tree[cluster_id].test_points)
            num_outlier_points = len(cluster_tree[cluster_id].outlier_points)
            if num_outlier_points/num_test_points > 0.6:
                cluster_tree[cluster_id].set_retarin()
                
    def rebuild_models(self,cluster_tree):
        for cluster_id in cluster_tree:
            clf = DecisionTreeClassifier(criterion='entropy')
            sample_points = cluster_tree[cluster_id].data_points + cluster_tree[cluster_id].outlier_points  
            train_X_sub = self.data.iloc[sample_points,:]
            train_y_sub = self.y[sample_points]
            clf.fit(train_X_sub,train_y_sub)
            cluster_tree[cluster_id].set_classifier(clf)
        return cluster_tree

# %%
def load_data(path,target):
    df = pd.read_csv(path)
    print(df.shape)
    y = df[target]
    X = df.drop(labels = target, axis = 1)
    X = X.apply(pd.to_numeric)
    y_test = []
    for instance in y.values:
        if instance == 'normal':
            y_test.append(1)
        else:
            y_test.append(-1)
    y_test = np.array(y_test)
    return X,y_test

def load_mutated_data(path,target):
    df = pd.read_csv(path)
    y = df[target]
    X = df.drop(labels = target, axis = 1)
    X = X.apply(pd.to_numeric)
    y_test = []
    for instance in y.values:
        if instance == 'normal':
            y_test.append(1)
        else:
            y_test.append(-1)
    y_test = np.array(y_test)
    return X,y_test

# %%
# Cluster Driver
def cluster_driver(file,print_tree = True):
    train_X, train_y = load_data(file,'defects')
    cluster = birch(branching_factor=20)
    cluster.fit(train_X,train_y)
    cluster_tree,max_depth = cluster.get_cluster_tree()
    cluster_tree = cluster.model_adder(cluster_tree)
    cluster_tree = cluster.outlier_model_adder(cluster_tree,max_depth)
    if print_tree:
        cluster.show_clutser_tree()
    return cluster,cluster_tree,max_depth

# %%
# getting the cluster tree
file = 'Data/NSL-KDD/modified/Train/train.csv'
cluster,cluster_tree,max_depth = cluster_driver(file)
# Out:
# (18143, 120)
# [cluster_id=0] N_children: 2 N_samples: 18143
# > [cluster_id=1] N_children: 5 N_samples: 29
# > > [cluster_id=2] N_children: 0 N_samples: 4
# > > [cluster_id=3] N_children: 0 N_samples: 2
# > > [cluster_id=4] N_children: 0 N_samples: 1
# > > [cluster_id=5] N_children: 0 N_samples: 8
# > > [cluster_id=6] N_children: 0 N_samples: 14
# > [cluster_id=7] N_children: 20 N_samples: 18114
# > > [cluster_id=8] N_children: 5 N_samples: 63
# > > > [cluster_id=9] N_children: 0 N_samples: 7
# > > > [cluster_id=10] N_children: 0 N_samples: 14
# > > > [cluster_id=11] N_children: 0 N_samples: 17
# > > > [cluster_id=12] N_children: 0 N_samples: 15
# > > > [cluster_id=13] N_children: 0 N_samples: 10
# > > [cluster_id=14] N_children: 2 N_samples: 261
# > > > [cluster_id=15] N_children: 20 N_samples: 234
# > > > > [cluster_id=16] N_children: 0 N_samples: 20
# > > > > [cluster_id=17] N_children: 0 N_samples: 2
# > > > > [cluster_id=18] N_children: 0 N_samples: 10
# > > > > [cluster_id=19] N_children: 0 N_samples: 12
# > > > > [cluster_id=20] N_children: 0 N_samples: 9
# > > > > [cluster_id=21] N_children: 0 N_samples: 18
# > > > > [cluster_id=22] N_children: 0 N_samples: 2
# > > > > [cluster_id=23] N_children: 0 N_samples: 14
# > > > > [cluster_id=24] N_children: 0 N_samples: 17
# > > > > [cluster_id=25] N_children: 0 N_samples: 17
# > > > > [cluster_id=26] N_children: 0 N_samples: 10
# > > > > [cluster_id=27] N_children: 0 N_samples: 18
# > > > > [cluster_id=28] N_children: 0 N_samples: 10
# > > > > [cluster_id=29] N_children: 0 N_samples: 9
# > > > > [cluster_id=30] N_children: 0 N_samples: 19
# > > > > [cluster_id=31] N_children: 0 N_samples: 8
# > > > > [cluster_id=32] N_children: 0 N_samples: 9
# > > > > [cluster_id=33] N_children: 0 N_samples: 15
# > > > > [cluster_id=34] N_children: 0 N_samples: 12
# > > > > [cluster_id=35] N_children: 0 N_samples: 3
# > > > [cluster_id=36] N_children: 3 N_samples: 27
# > > > > [cluster_id=37] N_children: 0 N_samples: 1
# > > > > [cluster_id=38] N_children: 0 N_samples: 20
# > > > > [cluster_id=39] N_children: 0 N_samples: 6
# > > [cluster_id=40] N_children: 8 N_samples: 83
# > > > [cluster_id=41] N_children: 0 N_samples: 9
# > > > [cluster_id=42] N_children: 0 N_samples: 9
# > > > [cluster_id=43] N_children: 0 N_samples: 2
# > > > [cluster_id=44] N_children: 0 N_samples: 20
# > > > [cluster_id=45] N_children: 0 N_samples: 15
# > > > [cluster_id=46] N_children: 0 N_samples: 7
# > > > [cluster_id=47] N_children: 0 N_samples: 6
# > > > [cluster_id=48] N_children: 0 N_samples: 15
# > > [cluster_id=49] N_children: 8 N_samples: 1419
# > > > [cluster_id=50] N_children: 20 N_samples: 242
# > > > > [cluster_id=51] N_children: 0 N_samples: 14
# > > > > [cluster_id=52] N_children: 0 N_samples: 1
# > > > > [cluster_id=53] N_children: 0 N_samples: 9
# > > > > [cluster_id=54] N_children: 0 N_samples: 17
# > > > > [cluster_id=55] N_children: 0 N_samples: 14
# > > > > [cluster_id=56] N_children: 0 N_samples: 12
# > > > > [cluster_id=57] N_children: 0 N_samples: 18
# > > > > [cluster_id=58] N_children: 0 N_samples: 6
# > > > > [cluster_id=59] N_children: 0 N_samples: 19
# > > > > [cluster_id=60] N_children: 0 N_samples: 13
# > > > > [cluster_id=61] N_children: 0 N_samples: 18
# > > > > [cluster_id=62] N_children: 0 N_samples: 17
# > > > > [cluster_id=63] N_children: 0 N_samples: 9
# > > > > [cluster_id=64] N_children: 0 N_samples: 17
# > > > > [cluster_id=65] N_children: 0 N_samples: 6
# > > > > [cluster_id=66] N_children: 0 N_samples: 5
# > > > > [cluster_id=67] N_children: 0 N_samples: 15
# > > > > [cluster_id=68] N_children: 0 N_samples: 13
# > > > > [cluster_id=69] N_children: 0 N_samples: 4
# > > > > [cluster_id=70] N_children: 0 N_samples: 15
# > > > [cluster_id=71] N_children: 0 N_samples: 3
# > > > [cluster_id=72] N_children: 16 N_samples: 178
# > > > > [cluster_id=73] N_children: 0 N_samples: 11
# > > > > [cluster_id=74] N_children: 0 N_samples: 13
# > > > > [cluster_id=75] N_children: 0 N_samples: 8
# > > > > [cluster_id=76] N_children: 0 N_samples: 4
# > > > > [cluster_id=77] N_children: 0 N_samples: 11
# > > > > [cluster_id=78] N_children: 0 N_samples: 20
# > > > > [cluster_id=79] N_children: 0 N_samples: 16
# > > > > [cluster_id=80] N_children: 0 N_samples: 14
# > > > > [cluster_id=81] N_children: 0 N_samples: 15
# > > > > [cluster_id=82] N_children: 0 N_samples: 19
# > > > > [cluster_id=83] N_children: 0 N_samples: 16
# > > > > [cluster_id=84] N_children: 0 N_samples: 4
# > > > > [cluster_id=85] N_children: 0 N_samples: 10
# > > > > [cluster_id=86] N_children: 0 N_samples: 11
# > > > > [cluster_id=87] N_children: 0 N_samples: 5
# > > > > [cluster_id=88] N_children: 0 N_samples: 1
# > > > [cluster_id=89] N_children: 12 N_samples: 153
# > > > > [cluster_id=90] N_children: 0 N_samples: 13
# > > > > [cluster_id=91] N_children: 0 N_samples: 16
# > > > > [cluster_id=92] N_children: 0 N_samples: 19
# > > > > [cluster_id=93] N_children: 0 N_samples: 13
# > > > > [cluster_id=94] N_children: 0 N_samples: 13
# > > > > [cluster_id=95] N_children: 0 N_samples: 11
# > > > > [cluster_id=96] N_children: 0 N_samples: 13
# > > > > [cluster_id=97] N_children: 0 N_samples: 15
# > > > > [cluster_id=98] N_children: 0 N_samples: 11
# > > > > [cluster_id=99] N_children: 0 N_samples: 13
# > > > > [cluster_id=100] N_children: 0 N_samples: 8
# > > > > [cluster_id=101] N_children: 0 N_samples: 8
# > > > [cluster_id=102] N_children: 18 N_samples: 191
# > > > > [cluster_id=103] N_children: 0 N_samples: 9
# > > > > [cluster_id=104] N_children: 0 N_samples: 15
# > > > > [cluster_id=105] N_children: 0 N_samples: 9
# > > > > [cluster_id=106] N_children: 0 N_samples: 10
# > > > > [cluster_id=107] N_children: 0 N_samples: 2
# > > > > [cluster_id=108] N_children: 0 N_samples: 1
# > > > > [cluster_id=109] N_children: 0 N_samples: 12
# > > > > [cluster_id=110] N_children: 0 N_samples: 10
# > > > > [cluster_id=111] N_children: 0 N_samples: 4
# > > > > [cluster_id=112] N_children: 0 N_samples: 4
# > > > > [cluster_id=113] N_children: 0 N_samples: 15
# > > > > [cluster_id=114] N_children: 0 N_samples: 16
# > > > > [cluster_id=115] N_children: 0 N_samples: 10
# > > > > [cluster_id=116] N_children: 0 N_samples: 15
# > > > > [cluster_id=117] N_children: 0 N_samples: 14
# > > > > [cluster_id=118] N_children: 0 N_samples: 14
# > > > > [cluster_id=119] N_children: 0 N_samples: 12
# > > > > [cluster_id=120] N_children: 0 N_samples: 19
# > > > [cluster_id=121] N_children: 17 N_samples: 191
# > > > > [cluster_id=122] N_children: 0 N_samples: 19
# > > > > [cluster_id=123] N_children: 0 N_samples: 20
# > > > > [cluster_id=124] N_children: 0 N_samples: 13
# > > > > [cluster_id=125] N_children: 0 N_samples: 12
# > > > > [cluster_id=126] N_children: 0 N_samples: 19
# > > > > [cluster_id=127] N_children: 0 N_samples: 19
# > > > > [cluster_id=128] N_children: 0 N_samples: 15
# > > > > [cluster_id=129] N_children: 0 N_samples: 2
# > > > > [cluster_id=130] N_children: 0 N_samples: 10
# > > > > [cluster_id=131] N_children: 0 N_samples: 17
# > > > > [cluster_id=132] N_children: 0 N_samples: 13
# > > > > [cluster_id=133] N_children: 0 N_samples: 19
# > > > > [cluster_id=134] N_children: 0 N_samples: 4
# > > > > [cluster_id=135] N_children: 0 N_samples: 5
# > > > > [cluster_id=136] N_children: 0 N_samples: 1
# > > > > [cluster_id=137] N_children: 0 N_samples: 1
# > > > > [cluster_id=138] N_children: 0 N_samples: 2
# > > > [cluster_id=139] N_children: 19 N_samples: 257
# > > > > [cluster_id=140] N_children: 0 N_samples: 18
# > > > > [cluster_id=141] N_children: 0 N_samples: 12
# > > > > [cluster_id=142] N_children: 0 N_samples: 16
# > > > > [cluster_id=143] N_children: 0 N_samples: 12
# > > > > [cluster_id=144] N_children: 0 N_samples: 18
# > > > > [cluster_id=145] N_children: 0 N_samples: 9
# > > > > [cluster_id=146] N_children: 0 N_samples: 16
# > > > > [cluster_id=147] N_children: 0 N_samples: 19
# > > > > [cluster_id=148] N_children: 0 N_samples: 13
# > > > > [cluster_id=149] N_children: 0 N_samples: 11
# > > > > [cluster_id=150] N_children: 0 N_samples: 1
# > > > > [cluster_id=151] N_children: 0 N_samples: 19
# > > > > [cluster_id=152] N_children: 0 N_samples: 16
# > > > > [cluster_id=153] N_children: 0 N_samples: 20
# > > > > [cluster_id=154] N_children: 0 N_samples: 1
# > > > > [cluster_id=155] N_children: 0 N_samples: 20
# > > > > [cluster_id=156] N_children: 0 N_samples: 10
# > > > > [cluster_id=157] N_children: 0 N_samples: 13
# > > > > [cluster_id=158] N_children: 0 N_samples: 13
# > > > [cluster_id=159] N_children: 20 N_samples: 204
# > > > > [cluster_id=160] N_children: 0 N_samples: 8
# > > > > [cluster_id=161] N_children: 0 N_samples: 10
# > > > > [cluster_id=162] N_children: 0 N_samples: 6
# > > > > [cluster_id=163] N_children: 0 N_samples: 14
# > > > > [cluster_id=164] N_children: 0 N_samples: 5
# > > > > [cluster_id=165] N_children: 0 N_samples: 14
# > > > > [cluster_id=166] N_children: 0 N_samples: 11
# > > > > [cluster_id=167] N_children: 0 N_samples: 7
# > > > > [cluster_id=168] N_children: 0 N_samples: 8
# > > > > [cluster_id=169] N_children: 0 N_samples: 9
# > > > > [cluster_id=170] N_children: 0 N_samples: 16
# > > > > [cluster_id=171] N_children: 0 N_samples: 5
# > > > > [cluster_id=172] N_children: 0 N_samples: 10
# > > > > [cluster_id=173] N_children: 0 N_samples: 8
# > > > > [cluster_id=174] N_children: 0 N_samples: 19
# > > > > [cluster_id=175] N_children: 0 N_samples: 16
# > > > > [cluster_id=176] N_children: 0 N_samples: 11
# > > > > [cluster_id=177] N_children: 0 N_samples: 6
# > > > > [cluster_id=178] N_children: 0 N_samples: 7
# > > > > [cluster_id=179] N_children: 0 N_samples: 14
# > > [cluster_id=180] N_children: 7 N_samples: 79
# > > > [cluster_id=181] N_children: 0 N_samples: 17
# > > > [cluster_id=182] N_children: 0 N_samples: 4
# > > > [cluster_id=183] N_children: 0 N_samples: 13
# > > > [cluster_id=184] N_children: 0 N_samples: 10
# > > > [cluster_id=185] N_children: 0 N_samples: 9
# > > > [cluster_id=186] N_children: 0 N_samples: 7
# > > > [cluster_id=187] N_children: 0 N_samples: 19
# > > [cluster_id=188] N_children: 3 N_samples: 355
# > > > [cluster_id=189] N_children: 16 N_samples: 211
# > > > > [cluster_id=190] N_children: 0 N_samples: 17
# > > > > [cluster_id=191] N_children: 0 N_samples: 12
# > > > > [cluster_id=192] N_children: 0 N_samples: 13
# > > > > [cluster_id=193] N_children: 0 N_samples: 16
# > > > > [cluster_id=194] N_children: 0 N_samples: 13
# > > > > [cluster_id=195] N_children: 0 N_samples: 10
# > > > > [cluster_id=196] N_children: 0 N_samples: 16
# > > > > [cluster_id=197] N_children: 0 N_samples: 13
# > > > > [cluster_id=198] N_children: 0 N_samples: 9
# > > > > [cluster_id=199] N_children: 0 N_samples: 20
# > > > > [cluster_id=200] N_children: 0 N_samples: 11
# > > > > [cluster_id=201] N_children: 0 N_samples: 13
# > > > > [cluster_id=202] N_children: 0 N_samples: 14
# > > > > [cluster_id=203] N_children: 0 N_samples: 18
# > > > > [cluster_id=204] N_children: 0 N_samples: 3
# > > > > [cluster_id=205] N_children: 0 N_samples: 13
# > > > [cluster_id=206] N_children: 2 N_samples: 24
# > > > > [cluster_id=207] N_children: 0 N_samples: 19
# > > > > [cluster_id=208] N_children: 0 N_samples: 5
# > > > [cluster_id=209] N_children: 9 N_samples: 120
# > > > > [cluster_id=210] N_children: 0 N_samples: 4
# > > > > [cluster_id=211] N_children: 0 N_samples: 13
# > > > > [cluster_id=212] N_children: 0 N_samples: 16
# > > > > [cluster_id=213] N_children: 0 N_samples: 8
# > > > > [cluster_id=214] N_children: 0 N_samples: 17
# > > > > [cluster_id=215] N_children: 0 N_samples: 16
# > > > > [cluster_id=216] N_children: 0 N_samples: 9
# > > > > [cluster_id=217] N_children: 0 N_samples: 18
# > > > > [cluster_id=218] N_children: 0 N_samples: 19
# > > [cluster_id=219] N_children: 6 N_samples: 79
# > > > [cluster_id=220] N_children: 0 N_samples: 19
# > > > [cluster_id=221] N_children: 0 N_samples: 19
# > > > [cluster_id=222] N_children: 0 N_samples: 10
# > > > [cluster_id=223] N_children: 0 N_samples: 12
# > > > [cluster_id=224] N_children: 0 N_samples: 8
# > > > [cluster_id=225] N_children: 0 N_samples: 11
# > > [cluster_id=226] N_children: 16 N_samples: 2102
# > > > [cluster_id=227] N_children: 20 N_samples: 205
# > > > > [cluster_id=228] N_children: 0 N_samples: 15
# > > > > [cluster_id=229] N_children: 0 N_samples: 1
# > > > > [cluster_id=230] N_children: 0 N_samples: 17
# > > > > [cluster_id=231] N_children: 0 N_samples: 7
# > > > > [cluster_id=232] N_children: 0 N_samples: 3
# > > > > [cluster_id=233] N_children: 0 N_samples: 16
# > > > > [cluster_id=234] N_children: 0 N_samples: 18
# > > > > [cluster_id=235] N_children: 0 N_samples: 3
# > > > > [cluster_id=236] N_children: 0 N_samples: 12
# > > > > [cluster_id=237] N_children: 0 N_samples: 4
# > > > > [cluster_id=238] N_children: 0 N_samples: 13
# > > > > [cluster_id=239] N_children: 0 N_samples: 1
# > > > > [cluster_id=240] N_children: 0 N_samples: 10
# > > > > [cluster_id=241] N_children: 0 N_samples: 13
# > > > > [cluster_id=242] N_children: 0 N_samples: 14
# > > > > [cluster_id=243] N_children: 0 N_samples: 11
# > > > > [cluster_id=244] N_children: 0 N_samples: 10
# > > > > [cluster_id=245] N_children: 0 N_samples: 14
# > > > > [cluster_id=246] N_children: 0 N_samples: 12
# > > > > [cluster_id=247] N_children: 0 N_samples: 11
# > > > [cluster_id=248] N_children: 4 N_samples: 38
# > > > > [cluster_id=249] N_children: 0 N_samples: 4
# > > > > [cluster_id=250] N_children: 0 N_samples: 5
# > > > > [cluster_id=251] N_children: 0 N_samples: 15
# > > > > [cluster_id=252] N_children: 0 N_samples: 14
# > > > [cluster_id=253] N_children: 5 N_samples: 71
# > > > > [cluster_id=254] N_children: 0 N_samples: 10
# > > > > [cluster_id=255] N_children: 0 N_samples: 20
# > > > > [cluster_id=256] N_children: 0 N_samples: 10
# > > > > [cluster_id=257] N_children: 0 N_samples: 13
# > > > > [cluster_id=258] N_children: 0 N_samples: 18
# > > > [cluster_id=259] N_children: 10 N_samples: 105
# > > > > [cluster_id=260] N_children: 0 N_samples: 5
# > > > > [cluster_id=261] N_children: 0 N_samples: 19
# > > > > [cluster_id=262] N_children: 0 N_samples: 16
# > > > > [cluster_id=263] N_children: 0 N_samples: 1
# > > > > [cluster_id=264] N_children: 0 N_samples: 8
# > > > > [cluster_id=265] N_children: 0 N_samples: 13
# > > > > [cluster_id=266] N_children: 0 N_samples: 6
# > > > > [cluster_id=267] N_children: 0 N_samples: 9
# > > > > [cluster_id=268] N_children: 0 N_samples: 12
# > > > > [cluster_id=269] N_children: 0 N_samples: 16
# > > > [cluster_id=270] N_children: 11 N_samples: 114
# > > > > [cluster_id=271] N_children: 0 N_samples: 2
# > > > > [cluster_id=272] N_children: 0 N_samples: 1
# > > > > [cluster_id=273] N_children: 0 N_samples: 3
# > > > > [cluster_id=274] N_children: 0 N_samples: 10
# > > > > [cluster_id=275] N_children: 0 N_samples: 9
# > > > > [cluster_id=276] N_children: 0 N_samples: 19
# > > > > [cluster_id=277] N_children: 0 N_samples: 19
# > > > > [cluster_id=278] N_children: 0 N_samples: 15
# > > > > [cluster_id=279] N_children: 0 N_samples: 13
# > > > > [cluster_id=280] N_children: 0 N_samples: 17
# > > > > [cluster_id=281] N_children: 0 N_samples: 6
# > > > [cluster_id=282] N_children: 2 N_samples: 8
# > > > > [cluster_id=283] N_children: 0 N_samples: 6
# > > > > [cluster_id=284] N_children: 0 N_samples: 2
# > > > [cluster_id=285] N_children: 10 N_samples: 88
# > > > > [cluster_id=286] N_children: 0 N_samples: 17
# > > > > [cluster_id=287] N_children: 0 N_samples: 8
# > > > > [cluster_id=288] N_children: 0 N_samples: 3
# > > > > [cluster_id=289] N_children: 0 N_samples: 2
# > > > > [cluster_id=290] N_children: 0 N_samples: 13
# > > > > [cluster_id=291] N_children: 0 N_samples: 1
# > > > > [cluster_id=292] N_children: 0 N_samples: 18
# > > > > [cluster_id=293] N_children: 0 N_samples: 13
# > > > > [cluster_id=294] N_children: 0 N_samples: 5
# > > > > [cluster_id=295] N_children: 0 N_samples: 8
# > > > [cluster_id=296] N_children: 17 N_samples: 202
# > > > > [cluster_id=297] N_children: 0 N_samples: 8
# > > > > [cluster_id=298] N_children: 0 N_samples: 1
# > > > > [cluster_id=299] N_children: 0 N_samples: 18
# > > > > [cluster_id=300] N_children: 0 N_samples: 13
# > > > > [cluster_id=301] N_children: 0 N_samples: 14
# > > > > [cluster_id=302] N_children: 0 N_samples: 18
# > > > > [cluster_id=303] N_children: 0 N_samples: 19
# > > > > [cluster_id=304] N_children: 0 N_samples: 19
# > > > > [cluster_id=305] N_children: 0 N_samples: 8
# > > > > [cluster_id=306] N_children: 0 N_samples: 19
# > > > > [cluster_id=307] N_children: 0 N_samples: 14
# > > > > [cluster_id=308] N_children: 0 N_samples: 12
# > > > > [cluster_id=309] N_children: 0 N_samples: 11
# > > > > [cluster_id=310] N_children: 0 N_samples: 10
# > > > > [cluster_id=311] N_children: 0 N_samples: 2
# > > > > [cluster_id=312] N_children: 0 N_samples: 3
# > > > > [cluster_id=313] N_children: 0 N_samples: 13
# > > > [cluster_id=314] N_children: 13 N_samples: 144
# > > > > [cluster_id=315] N_children: 0 N_samples: 6
# > > > > [cluster_id=316] N_children: 0 N_samples: 10
# > > > > [cluster_id=317] N_children: 0 N_samples: 14
# > > > > [cluster_id=318] N_children: 0 N_samples: 8
# > > > > [cluster_id=319] N_children: 0 N_samples: 8
# > > > > [cluster_id=320] N_children: 0 N_samples: 8
# > > > > [cluster_id=321] N_children: 0 N_samples: 8
# > > > > [cluster_id=322] N_children: 0 N_samples: 14
# > > > > [cluster_id=323] N_children: 0 N_samples: 14
# > > > > [cluster_id=324] N_children: 0 N_samples: 15
# > > > > [cluster_id=325] N_children: 0 N_samples: 10
# > > > > [cluster_id=326] N_children: 0 N_samples: 18
# > > > > [cluster_id=327] N_children: 0 N_samples: 11
# > > > [cluster_id=328] N_children: 8 N_samples: 88
# > > > > [cluster_id=329] N_children: 0 N_samples: 12
# > > > > [cluster_id=330] N_children: 0 N_samples: 1
# > > > > [cluster_id=331] N_children: 0 N_samples: 18
# > > > > [cluster_id=332] N_children: 0 N_samples: 19
# > > > > [cluster_id=333] N_children: 0 N_samples: 10
# > > > > [cluster_id=334] N_children: 0 N_samples: 13
# > > > > [cluster_id=335] N_children: 0 N_samples: 11
# > > > > [cluster_id=336] N_children: 0 N_samples: 4
# > > > [cluster_id=337] N_children: 13 N_samples: 155
# > > > > [cluster_id=338] N_children: 0 N_samples: 11
# > > > > [cluster_id=339] N_children: 0 N_samples: 8
# > > > > [cluster_id=340] N_children: 0 N_samples: 9
# > > > > [cluster_id=341] N_children: 0 N_samples: 12
# > > > > [cluster_id=342] N_children: 0 N_samples: 1
# > > > > [cluster_id=343] N_children: 0 N_samples: 16
# > > > > [cluster_id=344] N_children: 0 N_samples: 14
# > > > > [cluster_id=345] N_children: 0 N_samples: 17
# > > > > [cluster_id=346] N_children: 0 N_samples: 10
# > > > > [cluster_id=347] N_children: 0 N_samples: 7
# > > > > [cluster_id=348] N_children: 0 N_samples: 16
# > > > > [cluster_id=349] N_children: 0 N_samples: 20
# > > > > [cluster_id=350] N_children: 0 N_samples: 14
# > > > [cluster_id=351] N_children: 15 N_samples: 221
# > > > > [cluster_id=352] N_children: 0 N_samples: 12
# > > > > [cluster_id=353] N_children: 0 N_samples: 19
# > > > > [cluster_id=354] N_children: 0 N_samples: 18
# > > > > [cluster_id=355] N_children: 0 N_samples: 8
# > > > > [cluster_id=356] N_children: 0 N_samples: 20
# > > > > [cluster_id=357] N_children: 0 N_samples: 19
# > > > > [cluster_id=358] N_children: 0 N_samples: 11
# > > > > [cluster_id=359] N_children: 0 N_samples: 14
# > > > > [cluster_id=360] N_children: 0 N_samples: 20
# > > > > [cluster_id=361] N_children: 0 N_samples: 9
# > > > > [cluster_id=362] N_children: 0 N_samples: 12
# > > > > [cluster_id=363] N_children: 0 N_samples: 19
# > > > > [cluster_id=364] N_children: 0 N_samples: 18
# > > > > [cluster_id=365] N_children: 0 N_samples: 10
# > > > > [cluster_id=366] N_children: 0 N_samples: 12
# > > > [cluster_id=367] N_children: 18 N_samples: 216
# > > > > [cluster_id=368] N_children: 0 N_samples: 20
# > > > > [cluster_id=369] N_children: 0 N_samples: 12
# > > > > [cluster_id=370] N_children: 0 N_samples: 9
# > > > > [cluster_id=371] N_children: 0 N_samples: 12
# > > > > [cluster_id=372] N_children: 0 N_samples: 15
# > > > > [cluster_id=373] N_children: 0 N_samples: 16
# > > > > [cluster_id=374] N_children: 0 N_samples: 5
# > > > > [cluster_id=375] N_children: 0 N_samples: 11
# > > > > [cluster_id=376] N_children: 0 N_samples: 19
# > > > > [cluster_id=377] N_children: 0 N_samples: 20
# > > > > [cluster_id=378] N_children: 0 N_samples: 12
# > > > > [cluster_id=379] N_children: 0 N_samples: 15
# > > > > [cluster_id=380] N_children: 0 N_samples: 7
# > > > > [cluster_id=381] N_children: 0 N_samples: 18
# > > > > [cluster_id=382] N_children: 0 N_samples: 14
# > > > > [cluster_id=383] N_children: 0 N_samples: 1
# > > > > [cluster_id=384] N_children: 0 N_samples: 3
# > > > > [cluster_id=385] N_children: 0 N_samples: 7
# > > > [cluster_id=386] N_children: 13 N_samples: 148
# > > > > [cluster_id=387] N_children: 0 N_samples: 5
# > > > > [cluster_id=388] N_children: 0 N_samples: 3
# > > > > [cluster_id=389] N_children: 0 N_samples: 18
# > > > > [cluster_id=390] N_children: 0 N_samples: 11
# > > > > [cluster_id=391] N_children: 0 N_samples: 12
# > > > > [cluster_id=392] N_children: 0 N_samples: 13
# > > > > [cluster_id=393] N_children: 0 N_samples: 15
# > > > > [cluster_id=394] N_children: 0 N_samples: 15
# > > > > [cluster_id=395] N_children: 0 N_samples: 15
# > > > > [cluster_id=396] N_children: 0 N_samples: 1
# > > > > [cluster_id=397] N_children: 0 N_samples: 10
# > > > > [cluster_id=398] N_children: 0 N_samples: 12
# > > > > [cluster_id=399] N_children: 0 N_samples: 18
# > > > [cluster_id=400] N_children: 11 N_samples: 147
# > > > > [cluster_id=401] N_children: 0 N_samples: 20
# > > > > [cluster_id=402] N_children: 0 N_samples: 12
# > > > > [cluster_id=403] N_children: 0 N_samples: 16
# > > > > [cluster_id=404] N_children: 0 N_samples: 3
# > > > > [cluster_id=405] N_children: 0 N_samples: 5
# > > > > [cluster_id=406] N_children: 0 N_samples: 4
# > > > > [cluster_id=407] N_children: 0 N_samples: 16
# > > > > [cluster_id=408] N_children: 0 N_samples: 12
# > > > > [cluster_id=409] N_children: 0 N_samples: 20
# > > > > [cluster_id=410] N_children: 0 N_samples: 20
# > > > > [cluster_id=411] N_children: 0 N_samples: 19
# > > > [cluster_id=412] N_children: 13 N_samples: 152
# > > > > [cluster_id=413] N_children: 0 N_samples: 19
# > > > > [cluster_id=414] N_children: 0 N_samples: 9
# > > > > [cluster_id=415] N_children: 0 N_samples: 14
# > > > > [cluster_id=416] N_children: 0 N_samples: 10
# > > > > [cluster_id=417] N_children: 0 N_samples: 20
# > > > > [cluster_id=418] N_children: 0 N_samples: 7
# > > > > [cluster_id=419] N_children: 0 N_samples: 11
# > > > > [cluster_id=420] N_children: 0 N_samples: 1
# > > > > [cluster_id=421] N_children: 0 N_samples: 17
# > > > > [cluster_id=422] N_children: 0 N_samples: 6
# > > > > [cluster_id=423] N_children: 0 N_samples: 17
# > > > > [cluster_id=424] N_children: 0 N_samples: 14
# > > > > [cluster_id=425] N_children: 0 N_samples: 7
# > > [cluster_id=426] N_children: 4 N_samples: 422
# > > > [cluster_id=427] N_children: 10 N_samples: 197
# > > > > [cluster_id=428] N_children: 0 N_samples: 9
# > > > > [cluster_id=429] N_children: 0 N_samples: 13
# > > > > [cluster_id=430] N_children: 0 N_samples: 11
# > > > > [cluster_id=431] N_children: 0 N_samples: 24
# > > > > [cluster_id=432] N_children: 0 N_samples: 30
# > > > > [cluster_id=433] N_children: 0 N_samples: 21
# > > > > [cluster_id=434] N_children: 0 N_samples: 24
# > > > > [cluster_id=435] N_children: 0 N_samples: 14
# > > > > [cluster_id=436] N_children: 0 N_samples: 32
# > > > > [cluster_id=437] N_children: 0 N_samples: 19
# > > > [cluster_id=438] N_children: 5 N_samples: 47
# > > > > [cluster_id=439] N_children: 0 N_samples: 5
# > > > > [cluster_id=440] N_children: 0 N_samples: 5
# > > > > [cluster_id=441] N_children: 0 N_samples: 11
# > > > > [cluster_id=442] N_children: 0 N_samples: 9
# > > > > [cluster_id=443] N_children: 0 N_samples: 17
# > > > [cluster_id=444] N_children: 5 N_samples: 69
# > > > > [cluster_id=445] N_children: 0 N_samples: 20
# > > > > [cluster_id=446] N_children: 0 N_samples: 19
# > > > > [cluster_id=447] N_children: 0 N_samples: 18
# > > > > [cluster_id=448] N_children: 0 N_samples: 10
# > > > > [cluster_id=449] N_children: 0 N_samples: 2
# > > > [cluster_id=450] N_children: 12 N_samples: 109
# > > > > [cluster_id=451] N_children: 0 N_samples: 7
# > > > > [cluster_id=452] N_children: 0 N_samples: 6
# > > > > [cluster_id=453] N_children: 0 N_samples: 15
# > > > > [cluster_id=454] N_children: 0 N_samples: 20
# > > > > [cluster_id=455] N_children: 0 N_samples: 3
# > > > > [cluster_id=456] N_children: 0 N_samples: 5
# > > > > [cluster_id=457] N_children: 0 N_samples: 3
# > > > > [cluster_id=458] N_children: 0 N_samples: 9
# > > > > [cluster_id=459] N_children: 0 N_samples: 14
# > > > > [cluster_id=460] N_children: 0 N_samples: 12
# > > > > [cluster_id=461] N_children: 0 N_samples: 13
# > > > > [cluster_id=462] N_children: 0 N_samples: 2
# > > [cluster_id=463] N_children: 7 N_samples: 947
# > > > [cluster_id=464] N_children: 14 N_samples: 180
# > > > > [cluster_id=465] N_children: 0 N_samples: 16
# > > > > [cluster_id=466] N_children: 0 N_samples: 13
# > > > > [cluster_id=467] N_children: 0 N_samples: 18
# > > > > [cluster_id=468] N_children: 0 N_samples: 10
# > > > > [cluster_id=469] N_children: 0 N_samples: 16
# > > > > [cluster_id=470] N_children: 0 N_samples: 14
# > > > > [cluster_id=471] N_children: 0 N_samples: 7
# > > > > [cluster_id=472] N_children: 0 N_samples: 14
# > > > > [cluster_id=473] N_children: 0 N_samples: 14
# > > > > [cluster_id=474] N_children: 0 N_samples: 14
# > > > > [cluster_id=475] N_children: 0 N_samples: 12
# > > > > [cluster_id=476] N_children: 0 N_samples: 11
# > > > > [cluster_id=477] N_children: 0 N_samples: 13
# > > > > [cluster_id=478] N_children: 0 N_samples: 8
# > > > [cluster_id=479] N_children: 10 N_samples: 120
# > > > > [cluster_id=480] N_children: 0 N_samples: 7
# > > > > [cluster_id=481] N_children: 0 N_samples: 16
# > > > > [cluster_id=482] N_children: 0 N_samples: 8
# > > > > [cluster_id=483] N_children: 0 N_samples: 15
# > > > > [cluster_id=484] N_children: 0 N_samples: 11
# > > > > [cluster_id=485] N_children: 0 N_samples: 19
# > > > > [cluster_id=486] N_children: 0 N_samples: 8
# > > > > [cluster_id=487] N_children: 0 N_samples: 13
# > > > > [cluster_id=488] N_children: 0 N_samples: 15
# > > > > [cluster_id=489] N_children: 0 N_samples: 8
# > > > [cluster_id=490] N_children: 5 N_samples: 57
# > > > > [cluster_id=491] N_children: 0 N_samples: 11
# > > > > [cluster_id=492] N_children: 0 N_samples: 2
# > > > > [cluster_id=493] N_children: 0 N_samples: 20
# > > > > [cluster_id=494] N_children: 0 N_samples: 5
# > > > > [cluster_id=495] N_children: 0 N_samples: 19
# > > > [cluster_id=496] N_children: 16 N_samples: 222
# > > > > [cluster_id=497] N_children: 0 N_samples: 12
# > > > > [cluster_id=498] N_children: 0 N_samples: 6
# > > > > [cluster_id=499] N_children: 0 N_samples: 20
# > > > > [cluster_id=500] N_children: 0 N_samples: 19
# > > > > [cluster_id=501] N_children: 0 N_samples: 18
# > > > > [cluster_id=502] N_children: 0 N_samples: 11
# > > > > [cluster_id=503] N_children: 0 N_samples: 20
# > > > > [cluster_id=504] N_children: 0 N_samples: 19
# > > > > [cluster_id=505] N_children: 0 N_samples: 13
# > > > > [cluster_id=506] N_children: 0 N_samples: 16
# > > > > [cluster_id=507] N_children: 0 N_samples: 13
# > > > > [cluster_id=508] N_children: 0 N_samples: 10
# > > > > [cluster_id=509] N_children: 0 N_samples: 16
# > > > > [cluster_id=510] N_children: 0 N_samples: 10
# > > > > [cluster_id=511] N_children: 0 N_samples: 10
# > > > > [cluster_id=512] N_children: 0 N_samples: 9
# > > > [cluster_id=513] N_children: 5 N_samples: 66
# > > > > [cluster_id=514] N_children: 0 N_samples: 3
# > > > > [cluster_id=515] N_children: 0 N_samples: 20
# > > > > [cluster_id=516] N_children: 0 N_samples: 19
# > > > > [cluster_id=517] N_children: 0 N_samples: 12
# > > > > [cluster_id=518] N_children: 0 N_samples: 12
# > > > [cluster_id=519] N_children: 9 N_samples: 108
# > > > > [cluster_id=520] N_children: 0 N_samples: 8
# > > > > [cluster_id=521] N_children: 0 N_samples: 19
# > > > > [cluster_id=522] N_children: 0 N_samples: 18
# > > > > [cluster_id=523] N_children: 0 N_samples: 8
# > > > > [cluster_id=524] N_children: 0 N_samples: 14
# > > > > [cluster_id=525] N_children: 0 N_samples: 11
# > > > > [cluster_id=526] N_children: 0 N_samples: 8
# > > > > [cluster_id=527] N_children: 0 N_samples: 17
# > > > > [cluster_id=528] N_children: 0 N_samples: 5
# > > > [cluster_id=529] N_children: 16 N_samples: 194
# > > > > [cluster_id=530] N_children: 0 N_samples: 7
# > > > > [cluster_id=531] N_children: 0 N_samples: 8
# > > > > [cluster_id=532] N_children: 0 N_samples: 7
# > > > > [cluster_id=533] N_children: 0 N_samples: 3
# > > > > [cluster_id=534] N_children: 0 N_samples: 20
# > > > > [cluster_id=535] N_children: 0 N_samples: 14
# > > > > [cluster_id=536] N_children: 0 N_samples: 15
# > > > > [cluster_id=537] N_children: 0 N_samples: 10
# > > > > [cluster_id=538] N_children: 0 N_samples: 16
# > > > > [cluster_id=539] N_children: 0 N_samples: 18
# > > > > [cluster_id=540] N_children: 0 N_samples: 8
# > > > > [cluster_id=541] N_children: 0 N_samples: 15
# > > > > [cluster_id=542] N_children: 0 N_samples: 16
# > > > > [cluster_id=543] N_children: 0 N_samples: 16
# > > > > [cluster_id=544] N_children: 0 N_samples: 13
# > > > > [cluster_id=545] N_children: 0 N_samples: 8
# > > [cluster_id=546] N_children: 15 N_samples: 1843
# > > > [cluster_id=547] N_children: 9 N_samples: 110
# > > > > [cluster_id=548] N_children: 0 N_samples: 8
# > > > > [cluster_id=549] N_children: 0 N_samples: 4
# > > > > [cluster_id=550] N_children: 0 N_samples: 20
# > > > > [cluster_id=551] N_children: 0 N_samples: 13
# > > > > [cluster_id=552] N_children: 0 N_samples: 20
# > > > > [cluster_id=553] N_children: 0 N_samples: 4
# > > > > [cluster_id=554] N_children: 0 N_samples: 14
# > > > > [cluster_id=555] N_children: 0 N_samples: 19
# > > > > [cluster_id=556] N_children: 0 N_samples: 8
# > > > [cluster_id=557] N_children: 15 N_samples: 176
# > > > > [cluster_id=558] N_children: 0 N_samples: 19
# > > > > [cluster_id=559] N_children: 0 N_samples: 9
# > > > > [cluster_id=560] N_children: 0 N_samples: 12
# > > > > [cluster_id=561] N_children: 0 N_samples: 4
# > > > > [cluster_id=562] N_children: 0 N_samples: 8
# > > > > [cluster_id=563] N_children: 0 N_samples: 12
# > > > > [cluster_id=564] N_children: 0 N_samples: 19
# > > > > [cluster_id=565] N_children: 0 N_samples: 16
# > > > > [cluster_id=566] N_children: 0 N_samples: 16
# > > > > [cluster_id=567] N_children: 0 N_samples: 10
# > > > > [cluster_id=568] N_children: 0 N_samples: 18
# > > > > [cluster_id=569] N_children: 0 N_samples: 9
# > > > > [cluster_id=570] N_children: 0 N_samples: 10
# > > > > [cluster_id=571] N_children: 0 N_samples: 1
# > > > > [cluster_id=572] N_children: 0 N_samples: 13
# > > > [cluster_id=573] N_children: 13 N_samples: 168
# > > > > [cluster_id=574] N_children: 0 N_samples: 19
# > > > > [cluster_id=575] N_children: 0 N_samples: 15
# > > > > [cluster_id=576] N_children: 0 N_samples: 16
# > > > > [cluster_id=577] N_children: 0 N_samples: 9
# > > > > [cluster_id=578] N_children: 0 N_samples: 6
# > > > > [cluster_id=579] N_children: 0 N_samples: 7
# > > > > [cluster_id=580] N_children: 0 N_samples: 17
# > > > > [cluster_id=581] N_children: 0 N_samples: 14
# > > > > [cluster_id=582] N_children: 0 N_samples: 16
# > > > > [cluster_id=583] N_children: 0 N_samples: 15
# > > > > [cluster_id=584] N_children: 0 N_samples: 15
# > > > > [cluster_id=585] N_children: 0 N_samples: 12
# > > > > [cluster_id=586] N_children: 0 N_samples: 7
# > > > [cluster_id=587] N_children: 7 N_samples: 103
# > > > > [cluster_id=588] N_children: 0 N_samples: 20
# > > > > [cluster_id=589] N_children: 0 N_samples: 17
# > > > > [cluster_id=590] N_children: 0 N_samples: 11
# > > > > [cluster_id=591] N_children: 0 N_samples: 14
# > > > > [cluster_id=592] N_children: 0 N_samples: 12
# > > > > [cluster_id=593] N_children: 0 N_samples: 19
# > > > > [cluster_id=594] N_children: 0 N_samples: 10
# > > > [cluster_id=595] N_children: 20 N_samples: 244
# > > > > [cluster_id=596] N_children: 0 N_samples: 12
# > > > > [cluster_id=597] N_children: 0 N_samples: 20
# > > > > [cluster_id=598] N_children: 0 N_samples: 10
# > > > > [cluster_id=599] N_children: 0 N_samples: 10
# > > > > [cluster_id=600] N_children: 0 N_samples: 13
# > > > > [cluster_id=601] N_children: 0 N_samples: 9
# > > > > [cluster_id=602] N_children: 0 N_samples: 20
# > > > > [cluster_id=603] N_children: 0 N_samples: 17
# > > > > [cluster_id=604] N_children: 0 N_samples: 3
# > > > > [cluster_id=605] N_children: 0 N_samples: 17
# > > > > [cluster_id=606] N_children: 0 N_samples: 5
# > > > > [cluster_id=607] N_children: 0 N_samples: 13
# > > > > [cluster_id=608] N_children: 0 N_samples: 7
# > > > > [cluster_id=609] N_children: 0 N_samples: 12
# > > > > [cluster_id=610] N_children: 0 N_samples: 12
# > > > > [cluster_id=611] N_children: 0 N_samples: 18
# > > > > [cluster_id=612] N_children: 0 N_samples: 13
# > > > > [cluster_id=613] N_children: 0 N_samples: 9
# > > > > [cluster_id=614] N_children: 0 N_samples: 10
# > > > > [cluster_id=615] N_children: 0 N_samples: 14
# > > > [cluster_id=616] N_children: 10 N_samples: 105
# > > > > [cluster_id=617] N_children: 0 N_samples: 15
# > > > > [cluster_id=618] N_children: 0 N_samples: 18
# > > > > [cluster_id=619] N_children: 0 N_samples: 6
# > > > > [cluster_id=620] N_children: 0 N_samples: 11
# > > > > [cluster_id=621] N_children: 0 N_samples: 9
# > > > > [cluster_id=622] N_children: 0 N_samples: 4
# > > > > [cluster_id=623] N_children: 0 N_samples: 11
# > > > > [cluster_id=624] N_children: 0 N_samples: 3
# > > > > [cluster_id=625] N_children: 0 N_samples: 10
# > > > > [cluster_id=626] N_children: 0 N_samples: 18
# > > > [cluster_id=627] N_children: 0 N_samples: 1
# > > > [cluster_id=628] N_children: 0 N_samples: 1
# > > > [cluster_id=629] N_children: 14 N_samples: 147
# > > > > [cluster_id=630] N_children: 0 N_samples: 14
# > > > > [cluster_id=631] N_children: 0 N_samples: 14
# > > > > [cluster_id=632] N_children: 0 N_samples: 2
# > > > > [cluster_id=633] N_children: 0 N_samples: 18
# > > > > [cluster_id=634] N_children: 0 N_samples: 16
# > > > > [cluster_id=635] N_children: 0 N_samples: 4
# > > > > [cluster_id=636] N_children: 0 N_samples: 12
# > > > > [cluster_id=637] N_children: 0 N_samples: 6
# > > > > [cluster_id=638] N_children: 0 N_samples: 9
# > > > > [cluster_id=639] N_children: 0 N_samples: 12
# > > > > [cluster_id=640] N_children: 0 N_samples: 6
# > > > > [cluster_id=641] N_children: 0 N_samples: 11
# > > > > [cluster_id=642] N_children: 0 N_samples: 19
# > > > > [cluster_id=643] N_children: 0 N_samples: 4
# > > > [cluster_id=644] N_children: 4 N_samples: 47
# > > > > [cluster_id=645] N_children: 0 N_samples: 12
# > > > > [cluster_id=646] N_children: 0 N_samples: 5
# > > > > [cluster_id=647] N_children: 0 N_samples: 11
# > > > > [cluster_id=648] N_children: 0 N_samples: 19
# > > > [cluster_id=649] N_children: 12 N_samples: 136
# > > > > [cluster_id=650] N_children: 0 N_samples: 9
# > > > > [cluster_id=651] N_children: 0 N_samples: 19
# > > > > [cluster_id=652] N_children: 0 N_samples: 10
# > > > > [cluster_id=653] N_children: 0 N_samples: 14
# > > > > [cluster_id=654] N_children: 0 N_samples: 14
# > > > > [cluster_id=655] N_children: 0 N_samples: 10
# > > > > [cluster_id=656] N_children: 0 N_samples: 7
# > > > > [cluster_id=657] N_children: 0 N_samples: 12
# > > > > [cluster_id=658] N_children: 0 N_samples: 13
# > > > > [cluster_id=659] N_children: 0 N_samples: 5
# > > > > [cluster_id=660] N_children: 0 N_samples: 16
# > > > > [cluster_id=661] N_children: 0 N_samples: 7
# > > > [cluster_id=662] N_children: 12 N_samples: 134
# > > > > [cluster_id=663] N_children: 0 N_samples: 13
# > > > > [cluster_id=664] N_children: 0 N_samples: 4
# > > > > [cluster_id=665] N_children: 0 N_samples: 18
# > > > > [cluster_id=666] N_children: 0 N_samples: 1
# > > > > [cluster_id=667] N_children: 0 N_samples: 7
# > > > > [cluster_id=668] N_children: 0 N_samples: 17
# > > > > [cluster_id=669] N_children: 0 N_samples: 20
# > > > > [cluster_id=670] N_children: 0 N_samples: 11
# > > > > [cluster_id=671] N_children: 0 N_samples: 5
# > > > > [cluster_id=672] N_children: 0 N_samples: 11
# > > > > [cluster_id=673] N_children: 0 N_samples: 17
# > > > > [cluster_id=674] N_children: 0 N_samples: 10
# > > > [cluster_id=675] N_children: 10 N_samples: 124
# > > > > [cluster_id=676] N_children: 0 N_samples: 12
# > > > > [cluster_id=677] N_children: 0 N_samples: 18
# > > > > [cluster_id=678] N_children: 0 N_samples: 13
# > > > > [cluster_id=679] N_children: 0 N_samples: 8
# > > > > [cluster_id=680] N_children: 0 N_samples: 13
# > > > > [cluster_id=681] N_children: 0 N_samples: 15
# > > > > [cluster_id=682] N_children: 0 N_samples: 12
# > > > > [cluster_id=683] N_children: 0 N_samples: 9
# > > > > [cluster_id=684] N_children: 0 N_samples: 11
# > > > > [cluster_id=685] N_children: 0 N_samples: 13
# > > > [cluster_id=686] N_children: 17 N_samples: 194
# > > > > [cluster_id=687] N_children: 0 N_samples: 17
# > > > > [cluster_id=688] N_children: 0 N_samples: 7
# > > > > [cluster_id=689] N_children: 0 N_samples: 3
# > > > > [cluster_id=690] N_children: 0 N_samples: 20
# > > > > [cluster_id=691] N_children: 0 N_samples: 13
# > > > > [cluster_id=692] N_children: 0 N_samples: 14
# > > > > [cluster_id=693] N_children: 0 N_samples: 19
# > > > > [cluster_id=694] N_children: 0 N_samples: 15
# > > > > [cluster_id=695] N_children: 0 N_samples: 6
# > > > > [cluster_id=696] N_children: 0 N_samples: 18
# > > > > [cluster_id=697] N_children: 0 N_samples: 3
# > > > > [cluster_id=698] N_children: 0 N_samples: 12
# > > > > [cluster_id=699] N_children: 0 N_samples: 18
# > > > > [cluster_id=700] N_children: 0 N_samples: 9
# > > > > [cluster_id=701] N_children: 0 N_samples: 10
# > > > > [cluster_id=702] N_children: 0 N_samples: 3
# > > > > [cluster_id=703] N_children: 0 N_samples: 7
# > > > [cluster_id=704] N_children: 14 N_samples: 153
# > > > > [cluster_id=705] N_children: 0 N_samples: 5
# > > > > [cluster_id=706] N_children: 0 N_samples: 20
# > > > > [cluster_id=707] N_children: 0 N_samples: 16
# > > > > [cluster_id=708] N_children: 0 N_samples: 8
# > > > > [cluster_id=709] N_children: 0 N_samples: 12
# > > > > [cluster_id=710] N_children: 0 N_samples: 14
# > > > > [cluster_id=711] N_children: 0 N_samples: 11
# > > > > [cluster_id=712] N_children: 0 N_samples: 11
# > > > > [cluster_id=713] N_children: 0 N_samples: 8
# > > > > [cluster_id=714] N_children: 0 N_samples: 14
# > > > > [cluster_id=715] N_children: 0 N_samples: 5
# > > > > [cluster_id=716] N_children: 0 N_samples: 11
# > > > > [cluster_id=717] N_children: 0 N_samples: 7
# > > > > [cluster_id=718] N_children: 0 N_samples: 11
# > > [cluster_id=719] N_children: 7 N_samples: 886
# > > > [cluster_id=720] N_children: 4 N_samples: 33
# > > > > [cluster_id=721] N_children: 0 N_samples: 3
# > > > > [cluster_id=722] N_children: 0 N_samples: 12
# > > > > [cluster_id=723] N_children: 0 N_samples: 6
# > > > > [cluster_id=724] N_children: 0 N_samples: 12
# > > > [cluster_id=725] N_children: 15 N_samples: 166
# > > > > [cluster_id=726] N_children: 0 N_samples: 7
# > > > > [cluster_id=727] N_children: 0 N_samples: 2
# > > > > [cluster_id=728] N_children: 0 N_samples: 5
# > > > > [cluster_id=729] N_children: 0 N_samples: 6
# > > > > [cluster_id=730] N_children: 0 N_samples: 18
# > > > > [cluster_id=731] N_children: 0 N_samples: 6
# > > > > [cluster_id=732] N_children: 0 N_samples: 18
# > > > > [cluster_id=733] N_children: 0 N_samples: 20
# > > > > [cluster_id=734] N_children: 0 N_samples: 17
# > > > > [cluster_id=735] N_children: 0 N_samples: 11
# > > > > [cluster_id=736] N_children: 0 N_samples: 9
# > > > > [cluster_id=737] N_children: 0 N_samples: 20
# > > > > [cluster_id=738] N_children: 0 N_samples: 8
# > > > > [cluster_id=739] N_children: 0 N_samples: 18
# > > > > [cluster_id=740] N_children: 0 N_samples: 1
# > > > [cluster_id=741] N_children: 12 N_samples: 132
# > > > > [cluster_id=742] N_children: 0 N_samples: 14
# > > > > [cluster_id=743] N_children: 0 N_samples: 2
# > > > > [cluster_id=744] N_children: 0 N_samples: 2
# > > > > [cluster_id=745] N_children: 0 N_samples: 19
# > > > > [cluster_id=746] N_children: 0 N_samples: 9
# > > > > [cluster_id=747] N_children: 0 N_samples: 14
# > > > > [cluster_id=748] N_children: 0 N_samples: 2
# > > > > [cluster_id=749] N_children: 0 N_samples: 11
# > > > > [cluster_id=750] N_children: 0 N_samples: 15
# > > > > [cluster_id=751] N_children: 0 N_samples: 18
# > > > > [cluster_id=752] N_children: 0 N_samples: 14
# > > > > [cluster_id=753] N_children: 0 N_samples: 12
# > > > [cluster_id=754] N_children: 9 N_samples: 120
# > > > > [cluster_id=755] N_children: 0 N_samples: 9
# > > > > [cluster_id=756] N_children: 0 N_samples: 14
# > > > > [cluster_id=757] N_children: 0 N_samples: 18
# > > > > [cluster_id=758] N_children: 0 N_samples: 19
# > > > > [cluster_id=759] N_children: 0 N_samples: 17
# > > > > [cluster_id=760] N_children: 0 N_samples: 20
# > > > > [cluster_id=761] N_children: 0 N_samples: 14
# > > > > [cluster_id=762] N_children: 0 N_samples: 4
# > > > > [cluster_id=763] N_children: 0 N_samples: 5
# > > > [cluster_id=764] N_children: 17 N_samples: 185
# > > > > [cluster_id=765] N_children: 0 N_samples: 1
# > > > > [cluster_id=766] N_children: 0 N_samples: 10
# > > > > [cluster_id=767] N_children: 0 N_samples: 8
# > > > > [cluster_id=768] N_children: 0 N_samples: 8
# > > > > [cluster_id=769] N_children: 0 N_samples: 11
# > > > > [cluster_id=770] N_children: 0 N_samples: 15
# > > > > [cluster_id=771] N_children: 0 N_samples: 16
# > > > > [cluster_id=772] N_children: 0 N_samples: 13
# > > > > [cluster_id=773] N_children: 0 N_samples: 3
# > > > > [cluster_id=774] N_children: 0 N_samples: 4
# > > > > [cluster_id=775] N_children: 0 N_samples: 17
# > > > > [cluster_id=776] N_children: 0 N_samples: 7
# > > > > [cluster_id=777] N_children: 0 N_samples: 13
# > > > > [cluster_id=778] N_children: 0 N_samples: 19
# > > > > [cluster_id=779] N_children: 0 N_samples: 19
# > > > > [cluster_id=780] N_children: 0 N_samples: 12
# > > > > [cluster_id=781] N_children: 0 N_samples: 9
# > > > [cluster_id=782] N_children: 15 N_samples: 159
# > > > > [cluster_id=783] N_children: 0 N_samples: 12
# > > > > [cluster_id=784] N_children: 0 N_samples: 6
# > > > > [cluster_id=785] N_children: 0 N_samples: 11
# > > > > [cluster_id=786] N_children: 0 N_samples: 1
# > > > > [cluster_id=787] N_children: 0 N_samples: 13
# > > > > [cluster_id=788] N_children: 0 N_samples: 16
# > > > > [cluster_id=789] N_children: 0 N_samples: 16
# > > > > [cluster_id=790] N_children: 0 N_samples: 11
# > > > > [cluster_id=791] N_children: 0 N_samples: 14
# > > > > [cluster_id=792] N_children: 0 N_samples: 14
# > > > > [cluster_id=793] N_children: 0 N_samples: 5
# > > > > [cluster_id=794] N_children: 0 N_samples: 1
# > > > > [cluster_id=795] N_children: 0 N_samples: 9
# > > > > [cluster_id=796] N_children: 0 N_samples: 20
# > > > > [cluster_id=797] N_children: 0 N_samples: 10
# > > > [cluster_id=798] N_children: 9 N_samples: 91
# > > > > [cluster_id=799] N_children: 0 N_samples: 11
# > > > > [cluster_id=800] N_children: 0 N_samples: 9
# > > > > [cluster_id=801] N_children: 0 N_samples: 11
# > > > > [cluster_id=802] N_children: 0 N_samples: 18
# > > > > [cluster_id=803] N_children: 0 N_samples: 1
# > > > > [cluster_id=804] N_children: 0 N_samples: 8
# > > > > [cluster_id=805] N_children: 0 N_samples: 16
# > > > > [cluster_id=806] N_children: 0 N_samples: 6
# > > > > [cluster_id=807] N_children: 0 N_samples: 11
# > > [cluster_id=808] N_children: 2 N_samples: 25
# > > > [cluster_id=809] N_children: 0 N_samples: 18
# > > > [cluster_id=810] N_children: 0 N_samples: 7
# > > [cluster_id=811] N_children: 5 N_samples: 724
# > > > [cluster_id=812] N_children: 19 N_samples: 178
# > > > > [cluster_id=813] N_children: 0 N_samples: 4
# > > > > [cluster_id=814] N_children: 0 N_samples: 6
# > > > > [cluster_id=815] N_children: 0 N_samples: 4
# > > > > [cluster_id=816] N_children: 0 N_samples: 7
# > > > > [cluster_id=817] N_children: 0 N_samples: 11
# > > > > [cluster_id=818] N_children: 0 N_samples: 6
# > > > > [cluster_id=819] N_children: 0 N_samples: 18
# > > > > [cluster_id=820] N_children: 0 N_samples: 15
# > > > > [cluster_id=821] N_children: 0 N_samples: 1
# > > > > [cluster_id=822] N_children: 0 N_samples: 15
# > > > > [cluster_id=823] N_children: 0 N_samples: 13
# > > > > [cluster_id=824] N_children: 0 N_samples: 5
# > > > > [cluster_id=825] N_children: 0 N_samples: 9
# > > > > [cluster_id=826] N_children: 0 N_samples: 4
# > > > > [cluster_id=827] N_children: 0 N_samples: 8
# > > > > [cluster_id=828] N_children: 0 N_samples: 18
# > > > > [cluster_id=829] N_children: 0 N_samples: 14
# > > > > [cluster_id=830] N_children: 0 N_samples: 4
# > > > > [cluster_id=831] N_children: 0 N_samples: 16
# > > > [cluster_id=832] N_children: 5 N_samples: 67
# > > > > [cluster_id=833] N_children: 0 N_samples: 18
# > > > > [cluster_id=834] N_children: 0 N_samples: 9
# > > > > [cluster_id=835] N_children: 0 N_samples: 15
# > > > > [cluster_id=836] N_children: 0 N_samples: 16
# > > > > [cluster_id=837] N_children: 0 N_samples: 9
# > > > [cluster_id=838] N_children: 9 N_samples: 75
# > > > > [cluster_id=839] N_children: 0 N_samples: 7
# > > > > [cluster_id=840] N_children: 0 N_samples: 4
# > > > > [cluster_id=841] N_children: 0 N_samples: 11
# > > > > [cluster_id=842] N_children: 0 N_samples: 5
# > > > > [cluster_id=843] N_children: 0 N_samples: 5
# > > > > [cluster_id=844] N_children: 0 N_samples: 2
# > > > > [cluster_id=845] N_children: 0 N_samples: 7
# > > > > [cluster_id=846] N_children: 0 N_samples: 18
# > > > > [cluster_id=847] N_children: 0 N_samples: 16
# > > > [cluster_id=848] N_children: 18 N_samples: 216
# > > > > [cluster_id=849] N_children: 0 N_samples: 2
# > > > > [cluster_id=850] N_children: 0 N_samples: 15
# > > > > [cluster_id=851] N_children: 0 N_samples: 10
# > > > > [cluster_id=852] N_children: 0 N_samples: 17
# > > > > [cluster_id=853] N_children: 0 N_samples: 18
# > > > > [cluster_id=854] N_children: 0 N_samples: 7
# > > > > [cluster_id=855] N_children: 0 N_samples: 5
# > > > > [cluster_id=856] N_children: 0 N_samples: 19
# > > > > [cluster_id=857] N_children: 0 N_samples: 15
# > > > > [cluster_id=858] N_children: 0 N_samples: 16
# > > > > [cluster_id=859] N_children: 0 N_samples: 14
# > > > > [cluster_id=860] N_children: 0 N_samples: 11
# > > > > [cluster_id=861] N_children: 0 N_samples: 12
# > > > > [cluster_id=862] N_children: 0 N_samples: 13
# > > > > [cluster_id=863] N_children: 0 N_samples: 13
# > > > > [cluster_id=864] N_children: 0 N_samples: 14
# > > > > [cluster_id=865] N_children: 0 N_samples: 9
# > > > > [cluster_id=866] N_children: 0 N_samples: 6
# > > > [cluster_id=867] N_children: 20 N_samples: 188
# > > > > [cluster_id=868] N_children: 0 N_samples: 11
# > > > > [cluster_id=869] N_children: 0 N_samples: 19
# > > > > [cluster_id=870] N_children: 0 N_samples: 8
# > > > > [cluster_id=871] N_children: 0 N_samples: 5
# > > > > [cluster_id=872] N_children: 0 N_samples: 3
# > > > > [cluster_id=873] N_children: 0 N_samples: 7
# > > > > [cluster_id=874] N_children: 0 N_samples: 3
# > > > > [cluster_id=875] N_children: 0 N_samples: 15
# > > > > [cluster_id=876] N_children: 0 N_samples: 6
# > > > > [cluster_id=877] N_children: 0 N_samples: 10
# > > > > [cluster_id=878] N_children: 0 N_samples: 3
# > > > > [cluster_id=879] N_children: 0 N_samples: 19
# > > > > [cluster_id=880] N_children: 0 N_samples: 23
# > > > > [cluster_id=881] N_children: 0 N_samples: 6
# > > > > [cluster_id=882] N_children: 0 N_samples: 10
# > > > > [cluster_id=883] N_children: 0 N_samples: 7
# > > > > [cluster_id=884] N_children: 0 N_samples: 21
# > > > > [cluster_id=885] N_children: 0 N_samples: 1
# > > > > [cluster_id=886] N_children: 0 N_samples: 7
# > > > > [cluster_id=887] N_children: 0 N_samples: 4
# > > [cluster_id=888] N_children: 8 N_samples: 847
# > > > [cluster_id=889] N_children: 14 N_samples: 152
# > > > > [cluster_id=890] N_children: 0 N_samples: 5
# > > > > [cluster_id=891] N_children: 0 N_samples: 20
# > > > > [cluster_id=892] N_children: 0 N_samples: 5
# > > > > [cluster_id=893] N_children: 0 N_samples: 16
# > > > > [cluster_id=894] N_children: 0 N_samples: 7
# > > > > [cluster_id=895] N_children: 0 N_samples: 8
# > > > > [cluster_id=896] N_children: 0 N_samples: 6
# > > > > [cluster_id=897] N_children: 0 N_samples: 13
# > > > > [cluster_id=898] N_children: 0 N_samples: 20
# > > > > [cluster_id=899] N_children: 0 N_samples: 9
# > > > > [cluster_id=900] N_children: 0 N_samples: 10
# > > > > [cluster_id=901] N_children: 0 N_samples: 12
# > > > > [cluster_id=902] N_children: 0 N_samples: 11
# > > > > [cluster_id=903] N_children: 0 N_samples: 10
# > > > [cluster_id=904] N_children: 4 N_samples: 50
# > > > > [cluster_id=905] N_children: 0 N_samples: 15
# > > > > [cluster_id=906] N_children: 0 N_samples: 8
# > > > > [cluster_id=907] N_children: 0 N_samples: 14
# > > > > [cluster_id=908] N_children: 0 N_samples: 13
# > > > [cluster_id=909] N_children: 7 N_samples: 86
# > > > > [cluster_id=910] N_children: 0 N_samples: 7
# > > > > [cluster_id=911] N_children: 0 N_samples: 8
# > > > > [cluster_id=912] N_children: 0 N_samples: 17
# > > > > [cluster_id=913] N_children: 0 N_samples: 4
# > > > > [cluster_id=914] N_children: 0 N_samples: 18
# > > > > [cluster_id=915] N_children: 0 N_samples: 18
# ...
# > > > > [cluster_id=1375] N_children: 0 N_samples: 5
# > > > > [cluster_id=1376] N_children: 0 N_samples: 1
# > > > > [cluster_id=1377] N_children: 0 N_samples: 20
# > > > > [cluster_id=1378] N_children: 0 N_samples: 18
# > > > > [cluster_id=1379] N_children: 0 N_samples: 20
# > > > > [cluster_id=1380] N_children: 0 N_samples: 15
# > > > > [cluster_id=1381] N_children: 0 N_samples: 12
# > > > > [cluster_id=1382] N_children: 0 N_samples: 17
# > > > > [cluster_id=1383] N_children: 0 N_samples: 18
# > > > > [cluster_id=1384] N_children: 0 N_samples: 17
# > > > > [cluster_id=1385] N_children: 0 N_samples: 12
# > > > > [cluster_id=1386] N_children: 0 N_samples: 11
# > > > > [cluster_id=1387] N_children: 0 N_samples: 12
# > > > > [cluster_id=1388] N_children: 0 N_samples: 17
# > > > [cluster_id=1389] N_children: 18 N_samples: 192
# > > > > [cluster_id=1390] N_children: 0 N_samples: 20
# > > > > [cluster_id=1391] N_children: 0 N_samples: 16
# > > > > [cluster_id=1392] N_children: 0 N_samples: 17
# > > > > [cluster_id=1393] N_children: 0 N_samples: 19
# > > > > [cluster_id=1394] N_children: 0 N_samples: 12
# > > > > [cluster_id=1395] N_children: 0 N_samples: 6
# > > > > [cluster_id=1396] N_children: 0 N_samples: 8
# > > > > [cluster_id=1397] N_children: 0 N_samples: 3
# > > > > [cluster_id=1398] N_children: 0 N_samples: 13
# > > > > [cluster_id=1399] N_children: 0 N_samples: 11
# > > > > [cluster_id=1400] N_children: 0 N_samples: 10
# > > > > [cluster_id=1401] N_children: 0 N_samples: 1
# > > > > [cluster_id=1402] N_children: 0 N_samples: 8
# > > > > [cluster_id=1403] N_children: 0 N_samples: 3
# > > > > [cluster_id=1404] N_children: 0 N_samples: 12
# > > > > [cluster_id=1405] N_children: 0 N_samples: 12
# > > > > [cluster_id=1406] N_children: 0 N_samples: 7
# > > > > [cluster_id=1407] N_children: 0 N_samples: 14
# > > > [cluster_id=1408] N_children: 3 N_samples: 31
# > > > > [cluster_id=1409] N_children: 0 N_samples: 2
# > > > > [cluster_id=1410] N_children: 0 N_samples: 15
# > > > > [cluster_id=1411] N_children: 0 N_samples: 14
# > > > [cluster_id=1412] N_children: 14 N_samples: 177
# > > > > [cluster_id=1413] N_children: 0 N_samples: 2
# > > > > [cluster_id=1414] N_children: 0 N_samples: 19
# > > > > [cluster_id=1415] N_children: 0 N_samples: 12
# > > > > [cluster_id=1416] N_children: 0 N_samples: 19
# > > > > [cluster_id=1417] N_children: 0 N_samples: 8
# > > > > [cluster_id=1418] N_children: 0 N_samples: 20
# > > > > [cluster_id=1419] N_children: 0 N_samples: 4
# > > > > [cluster_id=1420] N_children: 0 N_samples: 20
# > > > > [cluster_id=1421] N_children: 0 N_samples: 19
# > > > > [cluster_id=1422] N_children: 0 N_samples: 4
# > > > > [cluster_id=1423] N_children: 0 N_samples: 8
# > > > > [cluster_id=1424] N_children: 0 N_samples: 11
# > > > > [cluster_id=1425] N_children: 0 N_samples: 20
# > > > > [cluster_id=1426] N_children: 0 N_samples: 11
# > > > [cluster_id=1427] N_children: 19 N_samples: 230
# > > > > [cluster_id=1428] N_children: 0 N_samples: 18
# > > > > [cluster_id=1429] N_children: 0 N_samples: 12
# > > > > [cluster_id=1430] N_children: 0 N_samples: 4
# > > > > [cluster_id=1431] N_children: 0 N_samples: 15
# > > > > [cluster_id=1432] N_children: 0 N_samples: 5
# > > > > [cluster_id=1433] N_children: 0 N_samples: 12
# > > > > [cluster_id=1434] N_children: 0 N_samples: 13
# > > > > [cluster_id=1435] N_children: 0 N_samples: 17
# > > > > [cluster_id=1436] N_children: 0 N_samples: 14
# > > > > [cluster_id=1437] N_children: 0 N_samples: 9
# > > > > [cluster_id=1438] N_children: 0 N_samples: 4
# > > > > [cluster_id=1439] N_children: 0 N_samples: 20
# > > > > [cluster_id=1440] N_children: 0 N_samples: 7
# > > > > [cluster_id=1441] N_children: 0 N_samples: 20
# > > > > [cluster_id=1442] N_children: 0 N_samples: 12
# > > > > [cluster_id=1443] N_children: 0 N_samples: 11
# > > > > [cluster_id=1444] N_children: 0 N_samples: 19
# > > > > [cluster_id=1445] N_children: 0 N_samples: 9
# > > > > [cluster_id=1446] N_children: 0 N_samples: 9
# > > > [cluster_id=1447] N_children: 14 N_samples: 173
# > > > > [cluster_id=1448] N_children: 0 N_samples: 2
# > > > > [cluster_id=1449] N_children: 0 N_samples: 10
# > > > > [cluster_id=1450] N_children: 0 N_samples: 16
# > > > > [cluster_id=1451] N_children: 0 N_samples: 12
# > > > > [cluster_id=1452] N_children: 0 N_samples: 13
# > > > > [cluster_id=1453] N_children: 0 N_samples: 20
# > > > > [cluster_id=1454] N_children: 0 N_samples: 20
# > > > > [cluster_id=1455] N_children: 0 N_samples: 15
# > > > > [cluster_id=1456] N_children: 0 N_samples: 8
# > > > > [cluster_id=1457] N_children: 0 N_samples: 18
# > > > > [cluster_id=1458] N_children: 0 N_samples: 8
# > > > > [cluster_id=1459] N_children: 0 N_samples: 5
# > > > > [cluster_id=1460] N_children: 0 N_samples: 16
# > > > > [cluster_id=1461] N_children: 0 N_samples: 10
# > > > [cluster_id=1462] N_children: 18 N_samples: 220
# > > > > [cluster_id=1463] N_children: 0 N_samples: 14
# > > > > [cluster_id=1464] N_children: 0 N_samples: 19
# > > > > [cluster_id=1465] N_children: 0 N_samples: 6
# > > > > [cluster_id=1466] N_children: 0 N_samples: 18
# > > > > [cluster_id=1467] N_children: 0 N_samples: 12
# > > > > [cluster_id=1468] N_children: 0 N_samples: 6
# > > > > [cluster_id=1469] N_children: 0 N_samples: 11
# > > > > [cluster_id=1470] N_children: 0 N_samples: 6
# > > > > [cluster_id=1471] N_children: 0 N_samples: 7
# > > > > [cluster_id=1472] N_children: 0 N_samples: 12
# > > > > [cluster_id=1473] N_children: 0 N_samples: 17
# > > > > [cluster_id=1474] N_children: 0 N_samples: 5
# > > > > [cluster_id=1475] N_children: 0 N_samples: 16
# > > > > [cluster_id=1476] N_children: 0 N_samples: 13
# > > > > [cluster_id=1477] N_children: 0 N_samples: 19
# > > > > [cluster_id=1478] N_children: 0 N_samples: 15
# > > > > [cluster_id=1479] N_children: 0 N_samples: 8
# > > > > [cluster_id=1480] N_children: 0 N_samples: 16
# > > > [cluster_id=1481] N_children: 0 N_samples: 2
# > > > [cluster_id=1482] N_children: 14 N_samples: 194
# > > > > [cluster_id=1483] N_children: 0 N_samples: 17
# > > > > [cluster_id=1484] N_children: 0 N_samples: 20
# > > > > [cluster_id=1485] N_children: 0 N_samples: 13
# > > > > [cluster_id=1486] N_children: 0 N_samples: 19
# > > > > [cluster_id=1487] N_children: 0 N_samples: 19
# > > > > [cluster_id=1488] N_children: 0 N_samples: 9
# > > > > [cluster_id=1489] N_children: 0 N_samples: 10
# > > > > [cluster_id=1490] N_children: 0 N_samples: 17
# > > > > [cluster_id=1491] N_children: 0 N_samples: 11
# > > > > [cluster_id=1492] N_children: 0 N_samples: 10
# > > > > [cluster_id=1493] N_children: 0 N_samples: 13
# > > > > [cluster_id=1494] N_children: 0 N_samples: 13
# > > > > [cluster_id=1495] N_children: 0 N_samples: 9
# > > > > [cluster_id=1496] N_children: 0 N_samples: 14
# > > > [cluster_id=1497] N_children: 14 N_samples: 163
# > > > > [cluster_id=1498] N_children: 0 N_samples: 5
# > > > > [cluster_id=1499] N_children: 0 N_samples: 13
# > > > > [cluster_id=1500] N_children: 0 N_samples: 18
# > > > > [cluster_id=1501] N_children: 0 N_samples: 17
# > > > > [cluster_id=1502] N_children: 0 N_samples: 8
# > > > > [cluster_id=1503] N_children: 0 N_samples: 13
# > > > > [cluster_id=1504] N_children: 0 N_samples: 6
# > > > > [cluster_id=1505] N_children: 0 N_samples: 4
# > > > > [cluster_id=1506] N_children: 0 N_samples: 20
# > > > > [cluster_id=1507] N_children: 0 N_samples: 19
# > > > > [cluster_id=1508] N_children: 0 N_samples: 4
# > > > > [cluster_id=1509] N_children: 0 N_samples: 17
# > > > > [cluster_id=1510] N_children: 0 N_samples: 6
# > > > > [cluster_id=1511] N_children: 0 N_samples: 13
# > > > [cluster_id=1512] N_children: 12 N_samples: 161
# > > > > [cluster_id=1513] N_children: 0 N_samples: 15
# > > > > [cluster_id=1514] N_children: 0 N_samples: 11
# > > > > [cluster_id=1515] N_children: 0 N_samples: 3
# > > > > [cluster_id=1516] N_children: 0 N_samples: 18
# > > > > [cluster_id=1517] N_children: 0 N_samples: 16
# > > > > [cluster_id=1518] N_children: 0 N_samples: 17
# > > > > [cluster_id=1519] N_children: 0 N_samples: 8
# > > > > [cluster_id=1520] N_children: 0 N_samples: 17
# > > > > [cluster_id=1521] N_children: 0 N_samples: 18
# > > > > [cluster_id=1522] N_children: 0 N_samples: 21
# > > > > [cluster_id=1523] N_children: 0 N_samples: 14
# > > > > [cluster_id=1524] N_children: 0 N_samples: 3
# > > > [cluster_id=1525] N_children: 14 N_samples: 163
# > > > > [cluster_id=1526] N_children: 0 N_samples: 14
# > > > > [cluster_id=1527] N_children: 0 N_samples: 8
# > > > > [cluster_id=1528] N_children: 0 N_samples: 21
# > > > > [cluster_id=1529] N_children: 0 N_samples: 6
# > > > > [cluster_id=1530] N_children: 0 N_samples: 11
# > > > > [cluster_id=1531] N_children: 0 N_samples: 3
# > > > > [cluster_id=1532] N_children: 0 N_samples: 12
# > > > > [cluster_id=1533] N_children: 0 N_samples: 9
# > > > > [cluster_id=1534] N_children: 0 N_samples: 19
# > > > > [cluster_id=1535] N_children: 0 N_samples: 12
# > > > > [cluster_id=1536] N_children: 0 N_samples: 13
# > > > > [cluster_id=1537] N_children: 0 N_samples: 9
# > > > > [cluster_id=1538] N_children: 0 N_samples: 12
# > > > > [cluster_id=1539] N_children: 0 N_samples: 14
# > > > [cluster_id=1540] N_children: 20 N_samples: 254
# > > > > [cluster_id=1541] N_children: 0 N_samples: 6
# > > > > [cluster_id=1542] N_children: 0 N_samples: 19
# > > > > [cluster_id=1543] N_children: 0 N_samples: 1
# > > > > [cluster_id=1544] N_children: 0 N_samples: 17
# > > > > [cluster_id=1545] N_children: 0 N_samples: 11
# > > > > [cluster_id=1546] N_children: 0 N_samples: 18
# > > > > [cluster_id=1547] N_children: 0 N_samples: 8
# > > > > [cluster_id=1548] N_children: 0 N_samples: 7
# > > > > [cluster_id=1549] N_children: 0 N_samples: 18
# > > > > [cluster_id=1550] N_children: 0 N_samples: 19
# > > > > [cluster_id=1551] N_children: 0 N_samples: 17
# > > > > [cluster_id=1552] N_children: 0 N_samples: 13
# > > > > [cluster_id=1553] N_children: 0 N_samples: 16
# > > > > [cluster_id=1554] N_children: 0 N_samples: 15
# > > > > [cluster_id=1555] N_children: 0 N_samples: 13
# > > > > [cluster_id=1556] N_children: 0 N_samples: 3
# > > > > [cluster_id=1557] N_children: 0 N_samples: 13
# > > > > [cluster_id=1558] N_children: 0 N_samples: 18
# > > > > [cluster_id=1559] N_children: 0 N_samples: 6
# > > > > [cluster_id=1560] N_children: 0 N_samples: 16
# > > > [cluster_id=1561] N_children: 13 N_samples: 136
# > > > > [cluster_id=1562] N_children: 0 N_samples: 11
# > > > > [cluster_id=1563] N_children: 0 N_samples: 20
# > > > > [cluster_id=1564] N_children: 0 N_samples: 12
# > > > > [cluster_id=1565] N_children: 0 N_samples: 15
# > > > > [cluster_id=1566] N_children: 0 N_samples: 1
# > > > > [cluster_id=1567] N_children: 0 N_samples: 3
# > > > > [cluster_id=1568] N_children: 0 N_samples: 19
# > > > > [cluster_id=1569] N_children: 0 N_samples: 3
# > > > > [cluster_id=1570] N_children: 0 N_samples: 19
# > > > > [cluster_id=1571] N_children: 0 N_samples: 13
# > > > > [cluster_id=1572] N_children: 0 N_samples: 5
# > > > > [cluster_id=1573] N_children: 0 N_samples: 6
# > > > > [cluster_id=1574] N_children: 0 N_samples: 9
# > > > [cluster_id=1575] N_children: 8 N_samples: 104
# > > > > [cluster_id=1576] N_children: 0 N_samples: 9
# > > > > [cluster_id=1577] N_children: 0 N_samples: 12
# > > > > [cluster_id=1578] N_children: 0 N_samples: 20
# > > > > [cluster_id=1579] N_children: 0 N_samples: 10
# > > > > [cluster_id=1580] N_children: 0 N_samples: 7
# > > > > [cluster_id=1581] N_children: 0 N_samples: 18
# > > > > [cluster_id=1582] N_children: 0 N_samples: 14
# > > > > [cluster_id=1583] N_children: 0 N_samples: 14
# > > [cluster_id=1584] N_children: 9 N_samples: 973
# > > > [cluster_id=1585] N_children: 3 N_samples: 38
# > > > > [cluster_id=1586] N_children: 0 N_samples: 16
# > > > > [cluster_id=1587] N_children: 0 N_samples: 5
# > > > > [cluster_id=1588] N_children: 0 N_samples: 17
# > > > [cluster_id=1589] N_children: 0 N_samples: 17
# > > > [cluster_id=1590] N_children: 8 N_samples: 74
# > > > > [cluster_id=1591] N_children: 0 N_samples: 11
# > > > > [cluster_id=1592] N_children: 0 N_samples: 2
# > > > > [cluster_id=1593] N_children: 0 N_samples: 10
# > > > > [cluster_id=1594] N_children: 0 N_samples: 9
# > > > > [cluster_id=1595] N_children: 0 N_samples: 4
# > > > > [cluster_id=1596] N_children: 0 N_samples: 14
# > > > > [cluster_id=1597] N_children: 0 N_samples: 12
# > > > > [cluster_id=1598] N_children: 0 N_samples: 12
# > > > [cluster_id=1599] N_children: 10 N_samples: 141
# > > > > [cluster_id=1600] N_children: 0 N_samples: 17
# > > > > [cluster_id=1601] N_children: 0 N_samples: 6
# > > > > [cluster_id=1602] N_children: 0 N_samples: 7
# > > > > [cluster_id=1603] N_children: 0 N_samples: 19
# > > > > [cluster_id=1604] N_children: 0 N_samples: 19
# > > > > [cluster_id=1605] N_children: 0 N_samples: 16
# > > > > [cluster_id=1606] N_children: 0 N_samples: 11
# > > > > [cluster_id=1607] N_children: 0 N_samples: 14
# > > > > [cluster_id=1608] N_children: 0 N_samples: 16
# > > > > [cluster_id=1609] N_children: 0 N_samples: 16
# > > > [cluster_id=1610] N_children: 16 N_samples: 199
# > > > > [cluster_id=1611] N_children: 0 N_samples: 17
# > > > > [cluster_id=1612] N_children: 0 N_samples: 20
# > > > > [cluster_id=1613] N_children: 0 N_samples: 3
# > > > > [cluster_id=1614] N_children: 0 N_samples: 20
# > > > > [cluster_id=1615] N_children: 0 N_samples: 17
# > > > > [cluster_id=1616] N_children: 0 N_samples: 19
# > > > > [cluster_id=1617] N_children: 0 N_samples: 11
# > > > > [cluster_id=1618] N_children: 0 N_samples: 15
# > > > > [cluster_id=1619] N_children: 0 N_samples: 16
# > > > > [cluster_id=1620] N_children: 0 N_samples: 7
# > > > > [cluster_id=1621] N_children: 0 N_samples: 11
# > > > > [cluster_id=1622] N_children: 0 N_samples: 14
# > > > > [cluster_id=1623] N_children: 0 N_samples: 4
# > > > > [cluster_id=1624] N_children: 0 N_samples: 3
# > > > > [cluster_id=1625] N_children: 0 N_samples: 7
# > > > > [cluster_id=1626] N_children: 0 N_samples: 15
# > > > [cluster_id=1627] N_children: 6 N_samples: 79
# > > > > [cluster_id=1628] N_children: 0 N_samples: 20
# > > > > [cluster_id=1629] N_children: 0 N_samples: 6
# > > > > [cluster_id=1630] N_children: 0 N_samples: 20
# > > > > [cluster_id=1631] N_children: 0 N_samples: 11
# > > > > [cluster_id=1632] N_children: 0 N_samples: 18
# > > > > [cluster_id=1633] N_children: 0 N_samples: 4
# > > > [cluster_id=1634] N_children: 13 N_samples: 179
# > > > > [cluster_id=1635] N_children: 0 N_samples: 8
# > > > > [cluster_id=1636] N_children: 0 N_samples: 11
# > > > > [cluster_id=1637] N_children: 0 N_samples: 15
# > > > > [cluster_id=1638] N_children: 0 N_samples: 18
# > > > > [cluster_id=1639] N_children: 0 N_samples: 10
# > > > > [cluster_id=1640] N_children: 0 N_samples: 18
# > > > > [cluster_id=1641] N_children: 0 N_samples: 13
# > > > > [cluster_id=1642] N_children: 0 N_samples: 15
# > > > > [cluster_id=1643] N_children: 0 N_samples: 21
# > > > > [cluster_id=1644] N_children: 0 N_samples: 15
# > > > > [cluster_id=1645] N_children: 0 N_samples: 5
# > > > > [cluster_id=1646] N_children: 0 N_samples: 11
# > > > > [cluster_id=1647] N_children: 0 N_samples: 19
# > > > [cluster_id=1648] N_children: 12 N_samples: 130
# > > > > [cluster_id=1649] N_children: 0 N_samples: 7
# > > > > [cluster_id=1650] N_children: 0 N_samples: 17
# > > > > [cluster_id=1651] N_children: 0 N_samples: 18
# > > > > [cluster_id=1652] N_children: 0 N_samples: 3
# > > > > [cluster_id=1653] N_children: 0 N_samples: 11
# > > > > [cluster_id=1654] N_children: 0 N_samples: 11
# > > > > [cluster_id=1655] N_children: 0 N_samples: 11
# > > > > [cluster_id=1656] N_children: 0 N_samples: 4
# > > > > [cluster_id=1657] N_children: 0 N_samples: 10
# > > > > [cluster_id=1658] N_children: 0 N_samples: 15
# > > > > [cluster_id=1659] N_children: 0 N_samples: 7
# > > > > [cluster_id=1660] N_children: 0 N_samples: 16
# > > > [cluster_id=1661] N_children: 11 N_samples: 116
# > > > > [cluster_id=1662] N_children: 0 N_samples: 12
# > > > > [cluster_id=1663] N_children: 0 N_samples: 14
# > > > > [cluster_id=1664] N_children: 0 N_samples: 8
# > > > > [cluster_id=1665] N_children: 0 N_samples: 6
# > > > > [cluster_id=1666] N_children: 0 N_samples: 13
# > > > > [cluster_id=1667] N_children: 0 N_samples: 6
# > > > > [cluster_id=1668] N_children: 0 N_samples: 15
# > > > > [cluster_id=1669] N_children: 0 N_samples: 16
# > > > > [cluster_id=1670] N_children: 0 N_samples: 12
# > > > > [cluster_id=1671] N_children: 0 N_samples: 5
# > > > > [cluster_id=1672] N_children: 0 N_samples: 9

# %%
# Saving Model
cluster_tree_dict = {'cluster': cluster, 'cluster_tree': cluster_tree, 'max_depth': max_depth}
with open('Data/NSL-KDD/modified/birch_model.h5', 'wb') as config_dictionary_file:
    pickle.dump(cluster_tree, config_dictionary_file)

# %%
# Loading Test Data
file = 'Data/NSL-KDD/modified/Train/5_anomaly/A1.csv'
test_X,test_y = load_mutated_data(file,'defects')

# %%
# Loading Test Data
file = 'Data/NSL-KDD/modified/Train/Normal_Data/N1.csv'
test_X,test_y = load_mutated_data(file,'defects')

# %%
# Birch classifier score(mention depth)
print(max_depth)
depth = 0
predicted = cluster.predict_new(test_X,test_y,depth,True)
# Out:
# 2

# %%
# Check for outlies detected
total = 0
j = 0
for i in cluster_tree:
    if len(cluster_tree[i].test_points) == 0:
        continue
    print("Percentage Identified",len(cluster_tree[i].data_points),len(cluster_tree[i].test_points),len(cluster_tree[i].outlier_points)/len(cluster_tree[i].test_points))
    b = collections.Counter(cluster_tree[i].test_labels)
    j += 1
    total += len(cluster_tree[i].outlier_points)
print(j,total)
# Out:
# Percentage Identified 1815 552 0.48007246376811596
# 1 265

# %%
# Precison Recall on outliers
test_y_1 = []
predicted_1 = []
for i in cluster_tree:
    if len(cluster_tree[i].test_points) == 0:
        continue
    test_y_1.append(cluster_tree[i].test_labels)
    predicted_1.append(cluster_tree[i].outlier_points_prediction)
_test_y = [item for sublist in test_y_1 for item in sublist]
_predicted = [item for sublist in predicted_1 for item in sublist]
print(metrics.classification_report(_test_y, _predicted))
# Out:
#               precision    recall  f1-score   support
#
#           -1       1.00      0.48      0.65       552
#            1       0.00      0.00      0.00         0
#
#    micro avg       0.48      0.48      0.48       552
#    macro avg       0.50      0.24      0.32       552
# weighted avg       1.00      0.48      0.65       552

# %%
# Printing the Tree with data point distribution
tree = {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}}
for i in cluster_tree:
    a = collections.Counter(cluster_tree[i].data_labels)
    tree[str(cluster_tree[i].depth)][i] = a
    dpt_print = ''
    for j in range(cluster_tree[i].depth):
        dpt_print += '> '
    print(dpt_print, "Cluster_id:",i,a,cluster_tree[i].depth)
# Out:
#  Cluster_id: 0 Counter({1: 11658, -1: 6485}) 0
# >  Cluster_id: 1 Counter({1: 29}) 1
# > >  Cluster_id: 2 Counter({1: 4}) 2
# > >  Cluster_id: 3 Counter({1: 2}) 2
# > >  Cluster_id: 4 Counter({1: 1}) 2
# > >  Cluster_id: 5 Counter({1: 8}) 2
# > >  Cluster_id: 6 Counter({1: 14}) 2
# >  Cluster_id: 7 Counter({1: 11629, -1: 6485}) 1
# > >  Cluster_id: 8 Counter({1: 63}) 2
# > > >  Cluster_id: 9 Counter({1: 7}) 3
# > > >  Cluster_id: 10 Counter({1: 14}) 3
# > > >  Cluster_id: 11 Counter({1: 17}) 3
# > > >  Cluster_id: 12 Counter({1: 15}) 3
# > > >  Cluster_id: 13 Counter({1: 10}) 3
# > >  Cluster_id: 14 Counter({1: 261}) 2
# > > >  Cluster_id: 15 Counter({1: 234}) 3
# > > > >  Cluster_id: 16 Counter({1: 20}) 4
# > > > >  Cluster_id: 17 Counter({1: 2}) 4
# > > > >  Cluster_id: 18 Counter({1: 10}) 4
# > > > >  Cluster_id: 19 Counter({1: 12}) 4
# > > > >  Cluster_id: 20 Counter({1: 9}) 4
# > > > >  Cluster_id: 21 Counter({1: 18}) 4
# > > > >  Cluster_id: 22 Counter({1: 2}) 4
# > > > >  Cluster_id: 23 Counter({1: 14}) 4
# > > > >  Cluster_id: 24 Counter({1: 17}) 4
# > > > >  Cluster_id: 25 Counter({1: 17}) 4
# > > > >  Cluster_id: 26 Counter({1: 10}) 4
# > > > >  Cluster_id: 27 Counter({1: 18}) 4
# > > > >  Cluster_id: 28 Counter({1: 10}) 4
# > > > >  Cluster_id: 29 Counter({1: 9}) 4
# > > > >  Cluster_id: 30 Counter({1: 19}) 4
# > > > >  Cluster_id: 31 Counter({1: 8}) 4
# > > > >  Cluster_id: 32 Counter({1: 9}) 4
# > > > >  Cluster_id: 33 Counter({1: 15}) 4
# > > > >  Cluster_id: 34 Counter({1: 12}) 4
# > > > >  Cluster_id: 35 Counter({1: 3}) 4
# > > >  Cluster_id: 36 Counter({1: 27}) 3
# > > > >  Cluster_id: 37 Counter({1: 1}) 4
# > > > >  Cluster_id: 38 Counter({1: 20}) 4
# > > > >  Cluster_id: 39 Counter({1: 6}) 4
# > >  Cluster_id: 40 Counter({1: 83}) 2
# > > >  Cluster_id: 41 Counter({1: 9}) 3
# > > >  Cluster_id: 42 Counter({1: 9}) 3
# > > >  Cluster_id: 43 Counter({1: 2}) 3
# > > >  Cluster_id: 44 Counter({1: 20}) 3
# > > >  Cluster_id: 45 Counter({1: 15}) 3
# > > >  Cluster_id: 46 Counter({1: 7}) 3
# > > >  Cluster_id: 47 Counter({1: 6}) 3
# > > >  Cluster_id: 48 Counter({1: 15}) 3
# > >  Cluster_id: 49 Counter({1: 1419}) 2
# > > >  Cluster_id: 50 Counter({1: 242}) 3
# > > > >  Cluster_id: 51 Counter({1: 14}) 4
# > > > >  Cluster_id: 52 Counter({1: 1}) 4
# > > > >  Cluster_id: 53 Counter({1: 9}) 4
# > > > >  Cluster_id: 54 Counter({1: 17}) 4
# > > > >  Cluster_id: 55 Counter({1: 14}) 4
# > > > >  Cluster_id: 56 Counter({1: 12}) 4
# > > > >  Cluster_id: 57 Counter({1: 18}) 4
# > > > >  Cluster_id: 58 Counter({1: 6}) 4
# > > > >  Cluster_id: 59 Counter({1: 19}) 4
# > > > >  Cluster_id: 60 Counter({1: 13}) 4
# > > > >  Cluster_id: 61 Counter({1: 18}) 4
# > > > >  Cluster_id: 62 Counter({1: 17}) 4
# > > > >  Cluster_id: 63 Counter({1: 9}) 4
# > > > >  Cluster_id: 64 Counter({1: 17}) 4
# > > > >  Cluster_id: 65 Counter({1: 6}) 4
# > > > >  Cluster_id: 66 Counter({1: 5}) 4
# > > > >  Cluster_id: 67 Counter({1: 15}) 4
# > > > >  Cluster_id: 68 Counter({1: 13}) 4
# > > > >  Cluster_id: 69 Counter({1: 4}) 4
# > > > >  Cluster_id: 70 Counter({1: 15}) 4
# > > >  Cluster_id: 71 Counter({1: 3}) 3
# > > >  Cluster_id: 72 Counter({1: 178}) 3
# > > > >  Cluster_id: 73 Counter({1: 11}) 4
# > > > >  Cluster_id: 74 Counter({1: 13}) 4
# > > > >  Cluster_id: 75 Counter({1: 8}) 4
# > > > >  Cluster_id: 76 Counter({1: 4}) 4
# > > > >  Cluster_id: 77 Counter({1: 11}) 4
# > > > >  Cluster_id: 78 Counter({1: 20}) 4
# > > > >  Cluster_id: 79 Counter({1: 16}) 4
# > > > >  Cluster_id: 80 Counter({1: 14}) 4
# > > > >  Cluster_id: 81 Counter({1: 15}) 4
# > > > >  Cluster_id: 82 Counter({1: 19}) 4
# > > > >  Cluster_id: 83 Counter({1: 16}) 4
# > > > >  Cluster_id: 84 Counter({1: 4}) 4
# > > > >  Cluster_id: 85 Counter({1: 10}) 4
# > > > >  Cluster_id: 86 Counter({1: 11}) 4
# > > > >  Cluster_id: 87 Counter({1: 5}) 4
# > > > >  Cluster_id: 88 Counter({1: 1}) 4
# > > >  Cluster_id: 89 Counter({1: 153}) 3
# > > > >  Cluster_id: 90 Counter({1: 13}) 4
# > > > >  Cluster_id: 91 Counter({1: 16}) 4
# > > > >  Cluster_id: 92 Counter({1: 19}) 4
# > > > >  Cluster_id: 93 Counter({1: 13}) 4
# > > > >  Cluster_id: 94 Counter({1: 13}) 4
# > > > >  Cluster_id: 95 Counter({1: 11}) 4
# > > > >  Cluster_id: 96 Counter({1: 13}) 4
# > > > >  Cluster_id: 97 Counter({1: 15}) 4
# > > > >  Cluster_id: 98 Counter({1: 11}) 4
# > > > >  Cluster_id: 99 Counter({1: 13}) 4
# > > > >  Cluster_id: 100 Counter({1: 8}) 4
# > > > >  Cluster_id: 101 Counter({1: 8}) 4
# > > >  Cluster_id: 102 Counter({1: 191}) 3
# > > > >  Cluster_id: 103 Counter({1: 9}) 4
# > > > >  Cluster_id: 104 Counter({1: 15}) 4
# > > > >  Cluster_id: 105 Counter({1: 9}) 4
# > > > >  Cluster_id: 106 Counter({1: 10}) 4
# > > > >  Cluster_id: 107 Counter({1: 2}) 4
# > > > >  Cluster_id: 108 Counter({1: 1}) 4
# > > > >  Cluster_id: 109 Counter({1: 12}) 4
# > > > >  Cluster_id: 110 Counter({1: 10}) 4
# > > > >  Cluster_id: 111 Counter({1: 4}) 4
# > > > >  Cluster_id: 112 Counter({1: 4}) 4
# > > > >  Cluster_id: 113 Counter({1: 15}) 4
# > > > >  Cluster_id: 114 Counter({1: 16}) 4
# > > > >  Cluster_id: 115 Counter({1: 10}) 4
# > > > >  Cluster_id: 116 Counter({1: 15}) 4
# > > > >  Cluster_id: 117 Counter({1: 14}) 4
# > > > >  Cluster_id: 118 Counter({1: 14}) 4
# > > > >  Cluster_id: 119 Counter({1: 12}) 4
# > > > >  Cluster_id: 120 Counter({1: 19}) 4
# > > >  Cluster_id: 121 Counter({1: 191}) 3
# > > > >  Cluster_id: 122 Counter({1: 19}) 4
# > > > >  Cluster_id: 123 Counter({1: 20}) 4
# > > > >  Cluster_id: 124 Counter({1: 13}) 4
# > > > >  Cluster_id: 125 Counter({1: 12}) 4
# > > > >  Cluster_id: 126 Counter({1: 19}) 4
# > > > >  Cluster_id: 127 Counter({1: 19}) 4
# > > > >  Cluster_id: 128 Counter({1: 15}) 4
# > > > >  Cluster_id: 129 Counter({1: 2}) 4
# > > > >  Cluster_id: 130 Counter({1: 10}) 4
# > > > >  Cluster_id: 131 Counter({1: 17}) 4
# > > > >  Cluster_id: 132 Counter({1: 13}) 4
# > > > >  Cluster_id: 133 Counter({1: 19}) 4
# > > > >  Cluster_id: 134 Counter({1: 4}) 4
# > > > >  Cluster_id: 135 Counter({1: 5}) 4
# > > > >  Cluster_id: 136 Counter({1: 1}) 4
# > > > >  Cluster_id: 137 Counter({1: 1}) 4
# > > > >  Cluster_id: 138 Counter({1: 2}) 4
# > > >  Cluster_id: 139 Counter({1: 257}) 3
# > > > >  Cluster_id: 140 Counter({1: 18}) 4
# > > > >  Cluster_id: 141 Counter({1: 12}) 4
# > > > >  Cluster_id: 142 Counter({1: 16}) 4
# > > > >  Cluster_id: 143 Counter({1: 12}) 4
# > > > >  Cluster_id: 144 Counter({1: 18}) 4
# > > > >  Cluster_id: 145 Counter({1: 9}) 4
# > > > >  Cluster_id: 146 Counter({1: 16}) 4
# > > > >  Cluster_id: 147 Counter({1: 19}) 4
# > > > >  Cluster_id: 148 Counter({1: 13}) 4
# > > > >  Cluster_id: 149 Counter({1: 11}) 4
# > > > >  Cluster_id: 150 Counter({1: 1}) 4
# > > > >  Cluster_id: 151 Counter({1: 19}) 4
# > > > >  Cluster_id: 152 Counter({1: 16}) 4
# > > > >  Cluster_id: 153 Counter({1: 20}) 4
# > > > >  Cluster_id: 154 Counter({1: 1}) 4
# > > > >  Cluster_id: 155 Counter({1: 20}) 4
# > > > >  Cluster_id: 156 Counter({1: 10}) 4
# > > > >  Cluster_id: 157 Counter({1: 13}) 4
# > > > >  Cluster_id: 158 Counter({1: 13}) 4
# > > >  Cluster_id: 159 Counter({1: 204}) 3
# > > > >  Cluster_id: 160 Counter({1: 8}) 4
# > > > >  Cluster_id: 161 Counter({1: 10}) 4
# > > > >  Cluster_id: 162 Counter({1: 6}) 4
# > > > >  Cluster_id: 163 Counter({1: 14}) 4
# > > > >  Cluster_id: 164 Counter({1: 5}) 4
# > > > >  Cluster_id: 165 Counter({1: 14}) 4
# > > > >  Cluster_id: 166 Counter({1: 11}) 4
# > > > >  Cluster_id: 167 Counter({1: 7}) 4
# > > > >  Cluster_id: 168 Counter({1: 8}) 4
# > > > >  Cluster_id: 169 Counter({1: 9}) 4
# > > > >  Cluster_id: 170 Counter({1: 16}) 4
# > > > >  Cluster_id: 171 Counter({1: 5}) 4
# > > > >  Cluster_id: 172 Counter({1: 10}) 4
# > > > >  Cluster_id: 173 Counter({1: 8}) 4
# > > > >  Cluster_id: 174 Counter({1: 19}) 4
# > > > >  Cluster_id: 175 Counter({1: 16}) 4
# > > > >  Cluster_id: 176 Counter({1: 11}) 4
# > > > >  Cluster_id: 177 Counter({1: 6}) 4
# > > > >  Cluster_id: 178 Counter({1: 7}) 4
# > > > >  Cluster_id: 179 Counter({1: 14}) 4
# > >  Cluster_id: 180 Counter({1: 79}) 2
# > > >  Cluster_id: 181 Counter({1: 17}) 3
# > > >  Cluster_id: 182 Counter({1: 4}) 3
# > > >  Cluster_id: 183 Counter({1: 13}) 3
# > > >  Cluster_id: 184 Counter({1: 10}) 3
# > > >  Cluster_id: 185 Counter({1: 9}) 3
# > > >  Cluster_id: 186 Counter({1: 7}) 3
# > > >  Cluster_id: 187 Counter({1: 19}) 3
# > >  Cluster_id: 188 Counter({1: 355}) 2
# > > >  Cluster_id: 189 Counter({1: 211}) 3
# > > > >  Cluster_id: 190 Counter({1: 17}) 4
# > > > >  Cluster_id: 191 Counter({1: 12}) 4
# > > > >  Cluster_id: 192 Counter({1: 13}) 4
# > > > >  Cluster_id: 193 Counter({1: 16}) 4
# > > > >  Cluster_id: 194 Counter({1: 13}) 4
# > > > >  Cluster_id: 195 Counter({1: 10}) 4
# > > > >  Cluster_id: 196 Counter({1: 16}) 4
# > > > >  Cluster_id: 197 Counter({1: 13}) 4
# > > > >  Cluster_id: 198 Counter({1: 9}) 4
# > > > >  Cluster_id: 199 Counter({1: 20}) 4
# > > > >  Cluster_id: 200 Counter({1: 11}) 4
# > > > >  Cluster_id: 201 Counter({1: 13}) 4
# > > > >  Cluster_id: 202 Counter({1: 14}) 4
# > > > >  Cluster_id: 203 Counter({1: 18}) 4
# > > > >  Cluster_id: 204 Counter({1: 3}) 4
# > > > >  Cluster_id: 205 Counter({1: 13}) 4
# > > >  Cluster_id: 206 Counter({1: 24}) 3
# > > > >  Cluster_id: 207 Counter({1: 19}) 4
# > > > >  Cluster_id: 208 Counter({1: 5}) 4
# > > >  Cluster_id: 209 Counter({1: 120}) 3
# > > > >  Cluster_id: 210 Counter({1: 4}) 4
# > > > >  Cluster_id: 211 Counter({1: 13}) 4
# > > > >  Cluster_id: 212 Counter({1: 16}) 4
# > > > >  Cluster_id: 213 Counter({1: 8}) 4
# > > > >  Cluster_id: 214 Counter({1: 17}) 4
# > > > >  Cluster_id: 215 Counter({1: 16}) 4
# > > > >  Cluster_id: 216 Counter({1: 9}) 4
# > > > >  Cluster_id: 217 Counter({1: 18}) 4
# > > > >  Cluster_id: 218 Counter({1: 19}) 4
# > >  Cluster_id: 219 Counter({1: 79}) 2
# > > >  Cluster_id: 220 Counter({1: 19}) 3
# > > >  Cluster_id: 221 Counter({1: 19}) 3
# > > >  Cluster_id: 222 Counter({1: 10}) 3
# > > >  Cluster_id: 223 Counter({1: 12}) 3
# > > >  Cluster_id: 224 Counter({1: 8}) 3
# > > >  Cluster_id: 225 Counter({1: 11}) 3
# > >  Cluster_id: 226 Counter({1: 2102}) 2
# > > >  Cluster_id: 227 Counter({1: 205}) 3
# > > > >  Cluster_id: 228 Counter({1: 15}) 4
# > > > >  Cluster_id: 229 Counter({1: 1}) 4
# > > > >  Cluster_id: 230 Counter({1: 17}) 4
# > > > >  Cluster_id: 231 Counter({1: 7}) 4
# > > > >  Cluster_id: 232 Counter({1: 3}) 4
# > > > >  Cluster_id: 233 Counter({1: 16}) 4
# > > > >  Cluster_id: 234 Counter({1: 18}) 4
# > > > >  Cluster_id: 235 Counter({1: 3}) 4
# > > > >  Cluster_id: 236 Counter({1: 12}) 4
# > > > >  Cluster_id: 237 Counter({1: 4}) 4
# > > > >  Cluster_id: 238 Counter({1: 13}) 4
# > > > >  Cluster_id: 239 Counter({1: 1}) 4
# > > > >  Cluster_id: 240 Counter({1: 10}) 4
# > > > >  Cluster_id: 241 Counter({1: 13}) 4
# > > > >  Cluster_id: 242 Counter({1: 14}) 4
# > > > >  Cluster_id: 243 Counter({1: 11}) 4
# > > > >  Cluster_id: 244 Counter({1: 10}) 4
# > > > >  Cluster_id: 245 Counter({1: 14}) 4
# > > > >  Cluster_id: 246 Counter({1: 12}) 4
# > > > >  Cluster_id: 247 Counter({1: 11}) 4
# > > >  Cluster_id: 248 Counter({1: 38}) 3
# > > > >  Cluster_id: 249 Counter({1: 4}) 4
# > > > >  Cluster_id: 250 Counter({1: 5}) 4
# > > > >  Cluster_id: 251 Counter({1: 15}) 4
# > > > >  Cluster_id: 252 Counter({1: 14}) 4
# > > >  Cluster_id: 253 Counter({1: 71}) 3
# > > > >  Cluster_id: 254 Counter({1: 10}) 4
# > > > >  Cluster_id: 255 Counter({1: 20}) 4
# > > > >  Cluster_id: 256 Counter({1: 10}) 4
# > > > >  Cluster_id: 257 Counter({1: 13}) 4
# > > > >  Cluster_id: 258 Counter({1: 18}) 4
# > > >  Cluster_id: 259 Counter({1: 105}) 3
# > > > >  Cluster_id: 260 Counter({1: 5}) 4
# > > > >  Cluster_id: 261 Counter({1: 19}) 4
# > > > >  Cluster_id: 262 Counter({1: 16}) 4
# > > > >  Cluster_id: 263 Counter({1: 1}) 4
# > > > >  Cluster_id: 264 Counter({1: 8}) 4
# > > > >  Cluster_id: 265 Counter({1: 13}) 4
# > > > >  Cluster_id: 266 Counter({1: 6}) 4
# > > > >  Cluster_id: 267 Counter({1: 9}) 4
# > > > >  Cluster_id: 268 Counter({1: 12}) 4
# > > > >  Cluster_id: 269 Counter({1: 16}) 4
# > > >  Cluster_id: 270 Counter({1: 114}) 3
# > > > >  Cluster_id: 271 Counter({1: 2}) 4
# > > > >  Cluster_id: 272 Counter({1: 1}) 4
# > > > >  Cluster_id: 273 Counter({1: 3}) 4
# > > > >  Cluster_id: 274 Counter({1: 10}) 4
# > > > >  Cluster_id: 275 Counter({1: 9}) 4
# > > > >  Cluster_id: 276 Counter({1: 19}) 4
# > > > >  Cluster_id: 277 Counter({1: 19}) 4
# > > > >  Cluster_id: 278 Counter({1: 15}) 4
# > > > >  Cluster_id: 279 Counter({1: 13}) 4
# > > > >  Cluster_id: 280 Counter({1: 17}) 4
# > > > >  Cluster_id: 281 Counter({1: 6}) 4
# > > >  Cluster_id: 282 Counter({1: 8}) 3
# > > > >  Cluster_id: 283 Counter({1: 6}) 4
# > > > >  Cluster_id: 284 Counter({1: 2}) 4
# > > >  Cluster_id: 285 Counter({1: 88}) 3
# > > > >  Cluster_id: 286 Counter({1: 17}) 4
# > > > >  Cluster_id: 287 Counter({1: 8}) 4
# > > > >  Cluster_id: 288 Counter({1: 3}) 4
# > > > >  Cluster_id: 289 Counter({1: 2}) 4
# > > > >  Cluster_id: 290 Counter({1: 13}) 4
# > > > >  Cluster_id: 291 Counter({1: 1}) 4
# > > > >  Cluster_id: 292 Counter({1: 18}) 4
# > > > >  Cluster_id: 293 Counter({1: 13}) 4
# > > > >  Cluster_id: 294 Counter({1: 5}) 4
# > > > >  Cluster_id: 295 Counter({1: 8}) 4
# > > >  Cluster_id: 296 Counter({1: 202}) 3
# > > > >  Cluster_id: 297 Counter({1: 8}) 4
# > > > >  Cluster_id: 298 Counter({1: 1}) 4
# > > > >  Cluster_id: 299 Counter({1: 18}) 4
# > > > >  Cluster_id: 300 Counter({1: 13}) 4
# > > > >  Cluster_id: 301 Counter({1: 14}) 4
# > > > >  Cluster_id: 302 Counter({1: 18}) 4
# > > > >  Cluster_id: 303 Counter({1: 19}) 4
# > > > >  Cluster_id: 304 Counter({1: 19}) 4
# > > > >  Cluster_id: 305 Counter({1: 8}) 4
# > > > >  Cluster_id: 306 Counter({1: 19}) 4
# > > > >  Cluster_id: 307 Counter({1: 14}) 4
# > > > >  Cluster_id: 308 Counter({1: 12}) 4
# > > > >  Cluster_id: 309 Counter({1: 11}) 4
# > > > >  Cluster_id: 310 Counter({1: 10}) 4
# > > > >  Cluster_id: 311 Counter({1: 2}) 4
# > > > >  Cluster_id: 312 Counter({1: 3}) 4
# > > > >  Cluster_id: 313 Counter({1: 13}) 4
# > > >  Cluster_id: 314 Counter({1: 144}) 3
# > > > >  Cluster_id: 315 Counter({1: 6}) 4
# > > > >  Cluster_id: 316 Counter({1: 10}) 4
# > > > >  Cluster_id: 317 Counter({1: 14}) 4
# > > > >  Cluster_id: 318 Counter({1: 8}) 4
# > > > >  Cluster_id: 319 Counter({1: 8}) 4
# > > > >  Cluster_id: 320 Counter({1: 8}) 4
# > > > >  Cluster_id: 321 Counter({1: 8}) 4
# > > > >  Cluster_id: 322 Counter({1: 14}) 4
# > > > >  Cluster_id: 323 Counter({1: 14}) 4
# > > > >  Cluster_id: 324 Counter({1: 15}) 4
# > > > >  Cluster_id: 325 Counter({1: 10}) 4
# > > > >  Cluster_id: 326 Counter({1: 18}) 4
# > > > >  Cluster_id: 327 Counter({1: 11}) 4
# > > >  Cluster_id: 328 Counter({1: 88}) 3
# > > > >  Cluster_id: 329 Counter({1: 12}) 4
# > > > >  Cluster_id: 330 Counter({1: 1}) 4
# > > > >  Cluster_id: 331 Counter({1: 18}) 4
# > > > >  Cluster_id: 332 Counter({1: 19}) 4
# > > > >  Cluster_id: 333 Counter({1: 10}) 4
# > > > >  Cluster_id: 334 Counter({1: 13}) 4
# > > > >  Cluster_id: 335 Counter({1: 11}) 4
# > > > >  Cluster_id: 336 Counter({1: 4}) 4
# > > >  Cluster_id: 337 Counter({1: 155}) 3
# > > > >  Cluster_id: 338 Counter({1: 11}) 4
# > > > >  Cluster_id: 339 Counter({1: 8}) 4
# > > > >  Cluster_id: 340 Counter({1: 9}) 4
# > > > >  Cluster_id: 341 Counter({1: 12}) 4
# > > > >  Cluster_id: 342 Counter({1: 1}) 4
# > > > >  Cluster_id: 343 Counter({1: 16}) 4
# > > > >  Cluster_id: 344 Counter({1: 14}) 4
# > > > >  Cluster_id: 345 Counter({1: 17}) 4
# > > > >  Cluster_id: 346 Counter({1: 10}) 4
# > > > >  Cluster_id: 347 Counter({1: 7}) 4
# > > > >  Cluster_id: 348 Counter({1: 16}) 4
# > > > >  Cluster_id: 349 Counter({1: 20}) 4
# > > > >  Cluster_id: 350 Counter({1: 14}) 4
# > > >  Cluster_id: 351 Counter({1: 221}) 3
# > > > >  Cluster_id: 352 Counter({1: 12}) 4
# > > > >  Cluster_id: 353 Counter({1: 19}) 4
# > > > >  Cluster_id: 354 Counter({1: 18}) 4
# > > > >  Cluster_id: 355 Counter({1: 8}) 4
# > > > >  Cluster_id: 356 Counter({1: 20}) 4
# > > > >  Cluster_id: 357 Counter({1: 19}) 4
# > > > >  Cluster_id: 358 Counter({1: 11}) 4
# > > > >  Cluster_id: 359 Counter({1: 14}) 4
# > > > >  Cluster_id: 360 Counter({1: 20}) 4
# > > > >  Cluster_id: 361 Counter({1: 9}) 4
# > > > >  Cluster_id: 362 Counter({1: 12}) 4
# > > > >  Cluster_id: 363 Counter({1: 19}) 4
# > > > >  Cluster_id: 364 Counter({1: 18}) 4
# > > > >  Cluster_id: 365 Counter({1: 10}) 4
# > > > >  Cluster_id: 366 Counter({1: 12}) 4
# > > >  Cluster_id: 367 Counter({1: 216}) 3
# > > > >  Cluster_id: 368 Counter({1: 20}) 4
# > > > >  Cluster_id: 369 Counter({1: 12}) 4
# > > > >  Cluster_id: 370 Counter({1: 9}) 4
# > > > >  Cluster_id: 371 Counter({1: 12}) 4
# > > > >  Cluster_id: 372 Counter({1: 15}) 4
# > > > >  Cluster_id: 373 Counter({1: 16}) 4
# > > > >  Cluster_id: 374 Counter({1: 5}) 4
# > > > >  Cluster_id: 375 Counter({1: 11}) 4
# > > > >  Cluster_id: 376 Counter({1: 19}) 4
# > > > >  Cluster_id: 377 Counter({1: 20}) 4
# > > > >  Cluster_id: 378 Counter({1: 12}) 4
# > > > >  Cluster_id: 379 Counter({1: 15}) 4
# > > > >  Cluster_id: 380 Counter({1: 7}) 4
# > > > >  Cluster_id: 381 Counter({1: 18}) 4
# > > > >  Cluster_id: 382 Counter({1: 14}) 4
# > > > >  Cluster_id: 383 Counter({1: 1}) 4
# > > > >  Cluster_id: 384 Counter({1: 3}) 4
# > > > >  Cluster_id: 385 Counter({1: 7}) 4
# > > >  Cluster_id: 386 Counter({1: 148}) 3
# > > > >  Cluster_id: 387 Counter({1: 5}) 4
# > > > >  Cluster_id: 388 Counter({1: 3}) 4
# > > > >  Cluster_id: 389 Counter({1: 18}) 4
# > > > >  Cluster_id: 390 Counter({1: 11}) 4
# > > > >  Cluster_id: 391 Counter({1: 12}) 4
# > > > >  Cluster_id: 392 Counter({1: 13}) 4
# > > > >  Cluster_id: 393 Counter({1: 15}) 4
# > > > >  Cluster_id: 394 Counter({1: 15}) 4
# > > > >  Cluster_id: 395 Counter({1: 15}) 4
# > > > >  Cluster_id: 396 Counter({1: 1}) 4
# > > > >  Cluster_id: 397 Counter({1: 10}) 4
# > > > >  Cluster_id: 398 Counter({1: 12}) 4
# > > > >  Cluster_id: 399 Counter({1: 18}) 4
# > > >  Cluster_id: 400 Counter({1: 147}) 3
# > > > >  Cluster_id: 401 Counter({1: 20}) 4
# > > > >  Cluster_id: 402 Counter({1: 12}) 4
# > > > >  Cluster_id: 403 Counter({1: 16}) 4
# > > > >  Cluster_id: 404 Counter({1: 3}) 4
# > > > >  Cluster_id: 405 Counter({1: 5}) 4
# > > > >  Cluster_id: 406 Counter({1: 4}) 4
# > > > >  Cluster_id: 407 Counter({1: 16}) 4
# > > > >  Cluster_id: 408 Counter({1: 12}) 4
# > > > >  Cluster_id: 409 Counter({1: 20}) 4
# > > > >  Cluster_id: 410 Counter({1: 20}) 4
# > > > >  Cluster_id: 411 Counter({1: 19}) 4
# > > >  Cluster_id: 412 Counter({1: 152}) 3
# > > > >  Cluster_id: 413 Counter({1: 19}) 4
# > > > >  Cluster_id: 414 Counter({1: 9}) 4
# > > > >  Cluster_id: 415 Counter({1: 14}) 4
# > > > >  Cluster_id: 416 Counter({1: 10}) 4
# > > > >  Cluster_id: 417 Counter({1: 20}) 4
# > > > >  Cluster_id: 418 Counter({1: 7}) 4
# > > > >  Cluster_id: 419 Counter({1: 11}) 4
# > > > >  Cluster_id: 420 Counter({1: 1}) 4
# > > > >  Cluster_id: 421 Counter({1: 17}) 4
# > > > >  Cluster_id: 422 Counter({1: 6}) 4
# > > > >  Cluster_id: 423 Counter({1: 17}) 4
# > > > >  Cluster_id: 424 Counter({1: 14}) 4
# > > > >  Cluster_id: 425 Counter({1: 7}) 4
# > >  Cluster_id: 426 Counter({1: 422}) 2
# > > >  Cluster_id: 427 Counter({1: 197}) 3
# > > > >  Cluster_id: 428 Counter({1: 9}) 4
# > > > >  Cluster_id: 429 Counter({1: 13}) 4
# > > > >  Cluster_id: 430 Counter({1: 11}) 4
# > > > >  Cluster_id: 431 Counter({1: 24}) 4
# > > > >  Cluster_id: 432 Counter({1: 30}) 4
# > > > >  Cluster_id: 433 Counter({1: 21}) 4
# > > > >  Cluster_id: 434 Counter({1: 24}) 4
# > > > >  Cluster_id: 435 Counter({1: 14}) 4
# > > > >  Cluster_id: 436 Counter({1: 32}) 4
# > > > >  Cluster_id: 437 Counter({1: 19}) 4
# > > >  Cluster_id: 438 Counter({1: 47}) 3
# > > > >  Cluster_id: 439 Counter({1: 5}) 4
# > > > >  Cluster_id: 440 Counter({1: 5}) 4
# > > > >  Cluster_id: 441 Counter({1: 11}) 4
# > > > >  Cluster_id: 442 Counter({1: 9}) 4
# > > > >  Cluster_id: 443 Counter({1: 17}) 4
# > > >  Cluster_id: 444 Counter({1: 69}) 3
# > > > >  Cluster_id: 445 Counter({1: 20}) 4
# > > > >  Cluster_id: 446 Counter({1: 19}) 4
# > > > >  Cluster_id: 447 Counter({1: 18}) 4
# > > > >  Cluster_id: 448 Counter({1: 10}) 4
# > > > >  Cluster_id: 449 Counter({1: 2}) 4
# > > >  Cluster_id: 450 Counter({1: 109}) 3
# > > > >  Cluster_id: 451 Counter({1: 7}) 4
# > > > >  Cluster_id: 452 Counter({1: 6}) 4
# > > > >  Cluster_id: 453 Counter({1: 15}) 4
# > > > >  Cluster_id: 454 Counter({1: 20}) 4
# > > > >  Cluster_id: 455 Counter({1: 3}) 4
# > > > >  Cluster_id: 456 Counter({1: 5}) 4
# > > > >  Cluster_id: 457 Counter({1: 3}) 4
# > > > >  Cluster_id: 458 Counter({1: 9}) 4
# > > > >  Cluster_id: 459 Counter({1: 14}) 4
# > > > >  Cluster_id: 460 Counter({1: 12}) 4
# > > > >  Cluster_id: 461 Counter({1: 13}) 4
# > > > >  Cluster_id: 462 Counter({1: 2}) 4
# > >  Cluster_id: 463 Counter({1: 947}) 2
# > > >  Cluster_id: 464 Counter({1: 180}) 3
# > > > >  Cluster_id: 465 Counter({1: 16}) 4
# > > > >  Cluster_id: 466 Counter({1: 13}) 4
# > > > >  Cluster_id: 467 Counter({1: 18}) 4
# > > > >  Cluster_id: 468 Counter({1: 10}) 4
# > > > >  Cluster_id: 469 Counter({1: 16}) 4
# > > > >  Cluster_id: 470 Counter({1: 14}) 4
# > > > >  Cluster_id: 471 Counter({1: 7}) 4
# > > > >  Cluster_id: 472 Counter({1: 14}) 4
# > > > >  Cluster_id: 473 Counter({1: 14}) 4
# > > > >  Cluster_id: 474 Counter({1: 14}) 4
# > > > >  Cluster_id: 475 Counter({1: 12}) 4
# > > > >  Cluster_id: 476 Counter({1: 11}) 4
# > > > >  Cluster_id: 477 Counter({1: 13}) 4
# > > > >  Cluster_id: 478 Counter({1: 8}) 4
# > > >  Cluster_id: 479 Counter({1: 120}) 3
# > > > >  Cluster_id: 480 Counter({1: 7}) 4
# > > > >  Cluster_id: 481 Counter({1: 16}) 4
# > > > >  Cluster_id: 482 Counter({1: 8}) 4
# > > > >  Cluster_id: 483 Counter({1: 15}) 4
# > > > >  Cluster_id: 484 Counter({1: 11}) 4
# > > > >  Cluster_id: 485 Counter({1: 19}) 4
# > > > >  Cluster_id: 486 Counter({1: 8}) 4
# > > > >  Cluster_id: 487 Counter({1: 13}) 4
# > > > >  Cluster_id: 488 Counter({1: 15}) 4
# > > > >  Cluster_id: 489 Counter({1: 8}) 4
# > > >  Cluster_id: 490 Counter({1: 57}) 3
# > > > >  Cluster_id: 491 Counter({1: 11}) 4
# > > > >  Cluster_id: 492 Counter({1: 2}) 4
# > > > >  Cluster_id: 493 Counter({1: 20}) 4
# > > > >  Cluster_id: 494 Counter({1: 5}) 4
# > > > >  Cluster_id: 495 Counter({1: 19}) 4
# > > >  Cluster_id: 496 Counter({1: 222}) 3
# > > > >  Cluster_id: 497 Counter({1: 12}) 4
# > > > >  Cluster_id: 498 Counter({1: 6}) 4
# > > > >  Cluster_id: 499 Counter({1: 20}) 4
# > > > >  Cluster_id: 500 Counter({1: 19}) 4
# > > > >  Cluster_id: 501 Counter({1: 18}) 4
# > > > >  Cluster_id: 502 Counter({1: 11}) 4
# > > > >  Cluster_id: 503 Counter({1: 20}) 4
# > > > >  Cluster_id: 504 Counter({1: 19}) 4
# > > > >  Cluster_id: 505 Counter({1: 13}) 4
# > > > >  Cluster_id: 506 Counter({1: 16}) 4
# > > > >  Cluster_id: 507 Counter({1: 13}) 4
# > > > >  Cluster_id: 508 Counter({1: 10}) 4
# > > > >  Cluster_id: 509 Counter({1: 16}) 4
# > > > >  Cluster_id: 510 Counter({1: 10}) 4
# > > > >  Cluster_id: 511 Counter({1: 10}) 4
# > > > >  Cluster_id: 512 Counter({1: 9}) 4
# > > >  Cluster_id: 513 Counter({1: 66}) 3
# > > > >  Cluster_id: 514 Counter({1: 3}) 4
# > > > >  Cluster_id: 515 Counter({1: 20}) 4
# > > > >  Cluster_id: 516 Counter({1: 19}) 4
# > > > >  Cluster_id: 517 Counter({1: 12}) 4
# > > > >  Cluster_id: 518 Counter({1: 12}) 4
# > > >  Cluster_id: 519 Counter({1: 108}) 3
# > > > >  Cluster_id: 520 Counter({1: 8}) 4
# > > > >  Cluster_id: 521 Counter({1: 19}) 4
# > > > >  Cluster_id: 522 Counter({1: 18}) 4
# > > > >  Cluster_id: 523 Counter({1: 8}) 4
# > > > >  Cluster_id: 524 Counter({1: 14}) 4
# > > > >  Cluster_id: 525 Counter({1: 11}) 4
# > > > >  Cluster_id: 526 Counter({1: 8}) 4
# > > > >  Cluster_id: 527 Counter({1: 17}) 4
# > > > >  Cluster_id: 528 Counter({1: 5}) 4
# > > >  Cluster_id: 529 Counter({1: 194}) 3
# > > > >  Cluster_id: 530 Counter({1: 7}) 4
# > > > >  Cluster_id: 531 Counter({1: 8}) 4
# > > > >  Cluster_id: 532 Counter({1: 7}) 4
# > > > >  Cluster_id: 533 Counter({1: 3}) 4
# > > > >  Cluster_id: 534 Counter({1: 20}) 4
# > > > >  Cluster_id: 535 Counter({1: 14}) 4
# > > > >  Cluster_id: 536 Counter({1: 15}) 4
# > > > >  Cluster_id: 537 Counter({1: 10}) 4
# > > > >  Cluster_id: 538 Counter({1: 16}) 4
# > > > >  Cluster_id: 539 Counter({1: 18}) 4
# > > > >  Cluster_id: 540 Counter({1: 8}) 4
# > > > >  Cluster_id: 541 Counter({1: 15}) 4
# > > > >  Cluster_id: 542 Counter({1: 16}) 4
# > > > >  Cluster_id: 543 Counter({1: 16}) 4
# > > > >  Cluster_id: 544 Counter({1: 13}) 4
# > > > >  Cluster_id: 545 Counter({1: 8}) 4
# > >  Cluster_id: 546 Counter({1: 1843}) 2
# > > >  Cluster_id: 547 Counter({1: 110}) 3
# > > > >  Cluster_id: 548 Counter({1: 8}) 4
# > > > >  Cluster_id: 549 Counter({1: 4}) 4
# > > > >  Cluster_id: 550 Counter({1: 20}) 4
# > > > >  Cluster_id: 551 Counter({1: 13}) 4
# > > > >  Cluster_id: 552 Counter({1: 20}) 4
# > > > >  Cluster_id: 553 Counter({1: 4}) 4
# > > > >  Cluster_id: 554 Counter({1: 14}) 4
# > > > >  Cluster_id: 555 Counter({1: 19}) 4
# > > > >  Cluster_id: 556 Counter({1: 8}) 4
# > > >  Cluster_id: 557 Counter({1: 176}) 3
# > > > >  Cluster_id: 558 Counter({1: 19}) 4
# > > > >  Cluster_id: 559 Counter({1: 9}) 4
# > > > >  Cluster_id: 560 Counter({1: 12}) 4
# > > > >  Cluster_id: 561 Counter({1: 4}) 4
# > > > >  Cluster_id: 562 Counter({1: 8}) 4
# > > > >  Cluster_id: 563 Counter({1: 12}) 4
# > > > >  Cluster_id: 564 Counter({1: 19}) 4
# > > > >  Cluster_id: 565 Counter({1: 16}) 4
# > > > >  Cluster_id: 566 Counter({1: 16}) 4
# > > > >  Cluster_id: 567 Counter({1: 10}) 4
# > > > >  Cluster_id: 568 Counter({1: 18}) 4
# > > > >  Cluster_id: 569 Counter({1: 9}) 4
# > > > >  Cluster_id: 570 Counter({1: 10}) 4
# > > > >  Cluster_id: 571 Counter({1: 1}) 4
# > > > >  Cluster_id: 572 Counter({1: 13}) 4
# > > >  Cluster_id: 573 Counter({1: 168}) 3
# > > > >  Cluster_id: 574 Counter({1: 19}) 4
# > > > >  Cluster_id: 575 Counter({1: 15}) 4
# > > > >  Cluster_id: 576 Counter({1: 16}) 4
# > > > >  Cluster_id: 577 Counter({1: 9}) 4
# > > > >  Cluster_id: 578 Counter({1: 6}) 4
# > > > >  Cluster_id: 579 Counter({1: 7}) 4
# > > > >  Cluster_id: 580 Counter({1: 17}) 4
# > > > >  Cluster_id: 581 Counter({1: 14}) 4
# > > > >  Cluster_id: 582 Counter({1: 16}) 4
# > > > >  Cluster_id: 583 Counter({1: 15}) 4
# > > > >  Cluster_id: 584 Counter({1: 15}) 4
# > > > >  Cluster_id: 585 Counter({1: 12}) 4
# > > > >  Cluster_id: 586 Counter({1: 7}) 4
# > > >  Cluster_id: 587 Counter({1: 103}) 3
# > > > >  Cluster_id: 588 Counter({1: 20}) 4
# > > > >  Cluster_id: 589 Counter({1: 17}) 4
# > > > >  Cluster_id: 590 Counter({1: 11}) 4
# > > > >  Cluster_id: 591 Counter({1: 14}) 4
# > > > >  Cluster_id: 592 Counter({1: 12}) 4
# > > > >  Cluster_id: 593 Counter({1: 19}) 4
# > > > >  Cluster_id: 594 Counter({1: 10}) 4
# > > >  Cluster_id: 595 Counter({1: 244}) 3
# > > > >  Cluster_id: 596 Counter({1: 12}) 4
# > > > >  Cluster_id: 597 Counter({1: 20}) 4
# > > > >  Cluster_id: 598 Counter({1: 10}) 4
# > > > >  Cluster_id: 599 Counter({1: 10}) 4
# > > > >  Cluster_id: 600 Counter({1: 13}) 4
# > > > >  Cluster_id: 601 Counter({1: 9}) 4
# > > > >  Cluster_id: 602 Counter({1: 20}) 4
# > > > >  Cluster_id: 603 Counter({1: 17}) 4
# > > > >  Cluster_id: 604 Counter({1: 3}) 4
# > > > >  Cluster_id: 605 Counter({1: 17}) 4
# > > > >  Cluster_id: 606 Counter({1: 5}) 4
# > > > >  Cluster_id: 607 Counter({1: 13}) 4
# > > > >  Cluster_id: 608 Counter({1: 7}) 4
# > > > >  Cluster_id: 609 Counter({1: 12}) 4
# > > > >  Cluster_id: 610 Counter({1: 12}) 4
# > > > >  Cluster_id: 611 Counter({1: 18}) 4
# > > > >  Cluster_id: 612 Counter({1: 13}) 4
# > > > >  Cluster_id: 613 Counter({1: 9}) 4
# > > > >  Cluster_id: 614 Counter({1: 10}) 4
# > > > >  Cluster_id: 615 Counter({1: 14}) 4
# > > >  Cluster_id: 616 Counter({1: 105}) 3
# > > > >  Cluster_id: 617 Counter({1: 15}) 4
# > > > >  Cluster_id: 618 Counter({1: 18}) 4
# > > > >  Cluster_id: 619 Counter({1: 6}) 4
# > > > >  Cluster_id: 620 Counter({1: 11}) 4
# > > > >  Cluster_id: 621 Counter({1: 9}) 4
# > > > >  Cluster_id: 622 Counter({1: 4}) 4
# > > > >  Cluster_id: 623 Counter({1: 11}) 4
# > > > >  Cluster_id: 624 Counter({1: 3}) 4
# > > > >  Cluster_id: 625 Counter({1: 10}) 4
# > > > >  Cluster_id: 626 Counter({1: 18}) 4
# > > >  Cluster_id: 627 Counter({1: 1}) 3
# > > >  Cluster_id: 628 Counter({1: 1}) 3
# > > >  Cluster_id: 629 Counter({1: 147}) 3
# > > > >  Cluster_id: 630 Counter({1: 14}) 4
# > > > >  Cluster_id: 631 Counter({1: 14}) 4
# > > > >  Cluster_id: 632 Counter({1: 2}) 4
# > > > >  Cluster_id: 633 Counter({1: 18}) 4
# > > > >  Cluster_id: 634 Counter({1: 16}) 4
# > > > >  Cluster_id: 635 Counter({1: 4}) 4
# > > > >  Cluster_id: 636 Counter({1: 12}) 4
# > > > >  Cluster_id: 637 Counter({1: 6}) 4
# > > > >  Cluster_id: 638 Counter({1: 9}) 4
# > > > >  Cluster_id: 639 Counter({1: 12}) 4
# > > > >  Cluster_id: 640 Counter({1: 6}) 4
# > > > >  Cluster_id: 641 Counter({1: 11}) 4
# > > > >  Cluster_id: 642 Counter({1: 19}) 4
# > > > >  Cluster_id: 643 Counter({1: 4}) 4
# > > >  Cluster_id: 644 Counter({1: 47}) 3
# > > > >  Cluster_id: 645 Counter({1: 12}) 4
# > > > >  Cluster_id: 646 Counter({1: 5}) 4
# > > > >  Cluster_id: 647 Counter({1: 11}) 4
# > > > >  Cluster_id: 648 Counter({1: 19}) 4
# > > >  Cluster_id: 649 Counter({1: 136}) 3
# > > > >  Cluster_id: 650 Counter({1: 9}) 4
# > > > >  Cluster_id: 651 Counter({1: 19}) 4
# > > > >  Cluster_id: 652 Counter({1: 10}) 4
# > > > >  Cluster_id: 653 Counter({1: 14}) 4
# > > > >  Cluster_id: 654 Counter({1: 14}) 4
# > > > >  Cluster_id: 655 Counter({1: 10}) 4
# > > > >  Cluster_id: 656 Counter({1: 7}) 4
# > > > >  Cluster_id: 657 Counter({1: 12}) 4
# > > > >  Cluster_id: 658 Counter({1: 13}) 4
# > > > >  Cluster_id: 659 Counter({1: 5}) 4
# > > > >  Cluster_id: 660 Counter({1: 16}) 4
# > > > >  Cluster_id: 661 Counter({1: 7}) 4
# > > >  Cluster_id: 662 Counter({1: 134}) 3
# > > > >  Cluster_id: 663 Counter({1: 13}) 4
# > > > >  Cluster_id: 664 Counter({1: 4}) 4
# > > > >  Cluster_id: 665 Counter({1: 18}) 4
# > > > >  Cluster_id: 666 Counter({1: 1}) 4
# > > > >  Cluster_id: 667 Counter({1: 7}) 4
# > > > >  Cluster_id: 668 Counter({1: 17}) 4
# > > > >  Cluster_id: 669 Counter({1: 20}) 4
# > > > >  Cluster_id: 670 Counter({1: 11}) 4
# > > > >  Cluster_id: 671 Counter({1: 5}) 4
# > > > >  Cluster_id: 672 Counter({1: 11}) 4
# > > > >  Cluster_id: 673 Counter({1: 17}) 4
# > > > >  Cluster_id: 674 Counter({1: 10}) 4
# > > >  Cluster_id: 675 Counter({1: 124}) 3
# > > > >  Cluster_id: 676 Counter({1: 12}) 4
# > > > >  Cluster_id: 677 Counter({1: 18}) 4
# > > > >  Cluster_id: 678 Counter({1: 13}) 4
# > > > >  Cluster_id: 679 Counter({1: 8}) 4
# > > > >  Cluster_id: 680 Counter({1: 13}) 4
# > > > >  Cluster_id: 681 Counter({1: 15}) 4
# > > > >  Cluster_id: 682 Counter({1: 12}) 4
# > > > >  Cluster_id: 683 Counter({1: 9}) 4
# > > > >  Cluster_id: 684 Counter({1: 11}) 4
# > > > >  Cluster_id: 685 Counter({1: 13}) 4
# > > >  Cluster_id: 686 Counter({1: 194}) 3
# > > > >  Cluster_id: 687 Counter({1: 17}) 4
# > > > >  Cluster_id: 688 Counter({1: 7}) 4
# > > > >  Cluster_id: 689 Counter({1: 3}) 4
# > > > >  Cluster_id: 690 Counter({1: 20}) 4
# > > > >  Cluster_id: 691 Counter({1: 13}) 4
# > > > >  Cluster_id: 692 Counter({1: 14}) 4
# > > > >  Cluster_id: 693 Counter({1: 19}) 4
# > > > >  Cluster_id: 694 Counter({1: 15}) 4
# > > > >  Cluster_id: 695 Counter({1: 6}) 4
# > > > >  Cluster_id: 696 Counter({1: 18}) 4
# > > > >  Cluster_id: 697 Counter({1: 3}) 4
# > > > >  Cluster_id: 698 Counter({1: 12}) 4
# > > > >  Cluster_id: 699 Counter({1: 18}) 4
# > > > >  Cluster_id: 700 Counter({1: 9}) 4
# > > > >  Cluster_id: 701 Counter({1: 10}) 4
# > > > >  Cluster_id: 702 Counter({1: 3}) 4
# > > > >  Cluster_id: 703 Counter({1: 7}) 4
# > > >  Cluster_id: 704 Counter({1: 153}) 3
# > > > >  Cluster_id: 705 Counter({1: 5}) 4
# > > > >  Cluster_id: 706 Counter({1: 20}) 4
# > > > >  Cluster_id: 707 Counter({1: 16}) 4
# > > > >  Cluster_id: 708 Counter({1: 8}) 4
# > > > >  Cluster_id: 709 Counter({1: 12}) 4
# > > > >  Cluster_id: 710 Counter({1: 14}) 4
# > > > >  Cluster_id: 711 Counter({1: 11}) 4
# > > > >  Cluster_id: 712 Counter({1: 11}) 4
# > > > >  Cluster_id: 713 Counter({1: 8}) 4
# > > > >  Cluster_id: 714 Counter({1: 14}) 4
# > > > >  Cluster_id: 715 Counter({1: 5}) 4
# > > > >  Cluster_id: 716 Counter({1: 11}) 4
# > > > >  Cluster_id: 717 Counter({1: 7}) 4
# > > > >  Cluster_id: 718 Counter({1: 11}) 4
# > >  Cluster_id: 719 Counter({1: 886}) 2
# > > >  Cluster_id: 720 Counter({1: 33}) 3
# > > > >  Cluster_id: 721 Counter({1: 3}) 4
# > > > >  Cluster_id: 722 Counter({1: 12}) 4
# > > > >  Cluster_id: 723 Counter({1: 6}) 4
# > > > >  Cluster_id: 724 Counter({1: 12}) 4
# > > >  Cluster_id: 725 Counter({1: 166}) 3
# > > > >  Cluster_id: 726 Counter({1: 7}) 4
# > > > >  Cluster_id: 727 Counter({1: 2}) 4
# > > > >  Cluster_id: 728 Counter({1: 5}) 4
# > > > >  Cluster_id: 729 Counter({1: 6}) 4
# > > > >  Cluster_id: 730 Counter({1: 18}) 4
# > > > >  Cluster_id: 731 Counter({1: 6}) 4
# > > > >  Cluster_id: 732 Counter({1: 18}) 4
# > > > >  Cluster_id: 733 Counter({1: 20}) 4
# > > > >  Cluster_id: 734 Counter({1: 17}) 4
# > > > >  Cluster_id: 735 Counter({1: 11}) 4
# > > > >  Cluster_id: 736 Counter({1: 9}) 4
# > > > >  Cluster_id: 737 Counter({1: 20}) 4
# > > > >  Cluster_id: 738 Counter({1: 8}) 4
# > > > >  Cluster_id: 739 Counter({1: 18}) 4
# > > > >  Cluster_id: 740 Counter({1: 1}) 4
# > > >  Cluster_id: 741 Counter({1: 132}) 3
# > > > >  Cluster_id: 742 Counter({1: 14}) 4
# > > > >  Cluster_id: 743 Counter({1: 2}) 4
# > > > >  Cluster_id: 744 Counter({1: 2}) 4
# > > > >  Cluster_id: 745 Counter({1: 19}) 4
# > > > >  Cluster_id: 746 Counter({1: 9}) 4
# > > > >  Cluster_id: 747 Counter({1: 14}) 4
# > > > >  Cluster_id: 748 Counter({1: 2}) 4
# > > > >  Cluster_id: 749 Counter({1: 11}) 4
# > > > >  Cluster_id: 750 Counter({1: 15}) 4
# > > > >  Cluster_id: 751 Counter({1: 18}) 4
# > > > >  Cluster_id: 752 Counter({1: 14}) 4
# > > > >  Cluster_id: 753 Counter({1: 12}) 4
# > > >  Cluster_id: 754 Counter({1: 120}) 3
# > > > >  Cluster_id: 755 Counter({1: 9}) 4
# > > > >  Cluster_id: 756 Counter({1: 14}) 4
# > > > >  Cluster_id: 757 Counter({1: 18}) 4
# > > > >  Cluster_id: 758 Counter({1: 19}) 4
# > > > >  Cluster_id: 759 Counter({1: 17}) 4
# > > > >  Cluster_id: 760 Counter({1: 20}) 4
# > > > >  Cluster_id: 761 Counter({1: 14}) 4
# > > > >  Cluster_id: 762 Counter({1: 4}) 4
# > > > >  Cluster_id: 763 Counter({1: 5}) 4
# > > >  Cluster_id: 764 Counter({1: 185}) 3
# > > > >  Cluster_id: 765 Counter({1: 1}) 4
# > > > >  Cluster_id: 766 Counter({1: 10}) 4
# > > > >  Cluster_id: 767 Counter({1: 8}) 4
# > > > >  Cluster_id: 768 Counter({1: 8}) 4
# > > > >  Cluster_id: 769 Counter({1: 11}) 4
# > > > >  Cluster_id: 770 Counter({1: 15}) 4
# > > > >  Cluster_id: 771 Counter({1: 16}) 4
# > > > >  Cluster_id: 772 Counter({1: 13}) 4
# > > > >  Cluster_id: 773 Counter({1: 3}) 4
# > > > >  Cluster_id: 774 Counter({1: 4}) 4
# > > > >  Cluster_id: 775 Counter({1: 17}) 4
# > > > >  Cluster_id: 776 Counter({1: 7}) 4
# > > > >  Cluster_id: 777 Counter({1: 13}) 4
# > > > >  Cluster_id: 778 Counter({1: 19}) 4
# > > > >  Cluster_id: 779 Counter({1: 19}) 4
# > > > >  Cluster_id: 780 Counter({1: 12}) 4
# > > > >  Cluster_id: 781 Counter({1: 9}) 4
# > > >  Cluster_id: 782 Counter({1: 159}) 3
# > > > >  Cluster_id: 783 Counter({1: 12}) 4
# > > > >  Cluster_id: 784 Counter({1: 6}) 4
# > > > >  Cluster_id: 785 Counter({1: 11}) 4
# > > > >  Cluster_id: 786 Counter({1: 1}) 4
# > > > >  Cluster_id: 787 Counter({1: 13}) 4
# > > > >  Cluster_id: 788 Counter({1: 16}) 4
# > > > >  Cluster_id: 789 Counter({1: 16}) 4
# > > > >  Cluster_id: 790 Counter({1: 11}) 4
# > > > >  Cluster_id: 791 Counter({1: 14}) 4
# > > > >  Cluster_id: 792 Counter({1: 14}) 4
# > > > >  Cluster_id: 793 Counter({1: 5}) 4
# > > > >  Cluster_id: 794 Counter({1: 1}) 4
# > > > >  Cluster_id: 795 Counter({1: 9}) 4
# > > > >  Cluster_id: 796 Counter({1: 20}) 4
# > > > >  Cluster_id: 797 Counter({1: 10}) 4
# > > >  Cluster_id: 798 Counter({1: 91}) 3
# > > > >  Cluster_id: 799 Counter({1: 11}) 4
# > > > >  Cluster_id: 800 Counter({1: 9}) 4
# > > > >  Cluster_id: 801 Counter({1: 11}) 4
# > > > >  Cluster_id: 802 Counter({1: 18}) 4
# > > > >  Cluster_id: 803 Counter({1: 1}) 4
# > > > >  Cluster_id: 804 Counter({1: 8}) 4
# > > > >  Cluster_id: 805 Counter({1: 16}) 4
# > > > >  Cluster_id: 806 Counter({1: 6}) 4
# > > > >  Cluster_id: 807 Counter({1: 11}) 4
# > >  Cluster_id: 808 Counter({1: 25}) 2
# > > >  Cluster_id: 809 Counter({1: 18}) 3
# > > >  Cluster_id: 810 Counter({1: 7}) 3
# > >  Cluster_id: 811 Counter({1: 724}) 2
# > > >  Cluster_id: 812 Counter({1: 178}) 3
# > > > >  Cluster_id: 813 Counter({1: 4}) 4
# > > > >  Cluster_id: 814 Counter({1: 6}) 4
# > > > >  Cluster_id: 815 Counter({1: 4}) 4
# > > > >  Cluster_id: 816 Counter({1: 7}) 4
# > > > >  Cluster_id: 817 Counter({1: 11}) 4
# > > > >  Cluster_id: 818 Counter({1: 6}) 4
# > > > >  Cluster_id: 819 Counter({1: 18}) 4
# > > > >  Cluster_id: 820 Counter({1: 15}) 4
# > > > >  Cluster_id: 821 Counter({1: 1}) 4
# > > > >  Cluster_id: 822 Counter({1: 15}) 4
# > > > >  Cluster_id: 823 Counter({1: 13}) 4
# > > > >  Cluster_id: 824 Counter({1: 5}) 4
# > > > >  Cluster_id: 825 Counter({1: 9}) 4
# > > > >  Cluster_id: 826 Counter({1: 4}) 4
# > > > >  Cluster_id: 827 Counter({1: 8}) 4
# > > > >  Cluster_id: 828 Counter({1: 18}) 4
# > > > >  Cluster_id: 829 Counter({1: 14}) 4
# > > > >  Cluster_id: 830 Counter({1: 4}) 4
# > > > >  Cluster_id: 831 Counter({1: 16}) 4
# > > >  Cluster_id: 832 Counter({1: 67}) 3
# > > > >  Cluster_id: 833 Counter({1: 18}) 4
# > > > >  Cluster_id: 834 Counter({1: 9}) 4
# > > > >  Cluster_id: 835 Counter({1: 15}) 4
# > > > >  Cluster_id: 836 Counter({1: 16}) 4
# > > > >  Cluster_id: 837 Counter({1: 9}) 4
# > > >  Cluster_id: 838 Counter({1: 75}) 3
# > > > >  Cluster_id: 839 Counter({1: 7}) 4
# > > > >  Cluster_id: 840 Counter({1: 4}) 4
# > > > >  Cluster_id: 841 Counter({1: 11}) 4
# > > > >  Cluster_id: 842 Counter({1: 5}) 4
# > > > >  Cluster_id: 843 Counter({1: 5}) 4
# > > > >  Cluster_id: 844 Counter({1: 2}) 4
# > > > >  Cluster_id: 845 Counter({1: 7}) 4
# > > > >  Cluster_id: 846 Counter({1: 18}) 4
# > > > >  Cluster_id: 847 Counter({1: 16}) 4
# > > >  Cluster_id: 848 Counter({1: 216}) 3
# > > > >  Cluster_id: 849 Counter({1: 2}) 4
# > > > >  Cluster_id: 850 Counter({1: 15}) 4
# > > > >  Cluster_id: 851 Counter({1: 10}) 4
# > > > >  Cluster_id: 852 Counter({1: 17}) 4
# > > > >  Cluster_id: 853 Counter({1: 18}) 4
# > > > >  Cluster_id: 854 Counter({1: 7}) 4
# > > > >  Cluster_id: 855 Counter({1: 5}) 4
# > > > >  Cluster_id: 856 Counter({1: 19}) 4
# > > > >  Cluster_id: 857 Counter({1: 15}) 4
# > > > >  Cluster_id: 858 Counter({1: 16}) 4
# > > > >  Cluster_id: 859 Counter({1: 14}) 4
# > > > >  Cluster_id: 860 Counter({1: 11}) 4
# > > > >  Cluster_id: 861 Counter({1: 12}) 4
# > > > >  Cluster_id: 862 Counter({1: 13}) 4
# > > > >  Cluster_id: 863 Counter({1: 13}) 4
# > > > >  Cluster_id: 864 Counter({1: 14}) 4
# > > > >  Cluster_id: 865 Counter({1: 9}) 4
# > > > >  Cluster_id: 866 Counter({1: 6}) 4
# > > >  Cluster_id: 867 Counter({1: 188}) 3
# > > > >  Cluster_id: 868 Counter({1: 11}) 4
# > > > >  Cluster_id: 869 Counter({1: 19}) 4
# > > > >  Cluster_id: 870 Counter({1: 8}) 4
# > > > >  Cluster_id: 871 Counter({1: 5}) 4
# > > > >  Cluster_id: 872 Counter({1: 3}) 4
# > > > >  Cluster_id: 873 Counter({1: 7}) 4
# > > > >  Cluster_id: 874 Counter({1: 3}) 4
# > > > >  Cluster_id: 875 Counter({1: 15}) 4
# > > > >  Cluster_id: 876 Counter({1: 6}) 4
# > > > >  Cluster_id: 877 Counter({1: 10}) 4
# > > > >  Cluster_id: 878 Counter({1: 3}) 4
# > > > >  Cluster_id: 879 Counter({1: 19}) 4
# > > > >  Cluster_id: 880 Counter({1: 23}) 4
# > > > >  Cluster_id: 881 Counter({1: 6}) 4
# > > > >  Cluster_id: 882 Counter({1: 10}) 4
# > > > >  Cluster_id: 883 Counter({1: 7}) 4
# > > > >  Cluster_id: 884 Counter({1: 21}) 4
# > > > >  Cluster_id: 885 Counter({1: 1}) 4
# > > > >  Cluster_id: 886 Counter({1: 7}) 4
# > > > >  Cluster_id: 887 Counter({1: 4}) 4
# > >  Cluster_id: 888 Counter({1: 719, -1: 128}) 2
# > > >  Cluster_id: 889 Counter({1: 120, -1: 32}) 3
# > > > >  Cluster_id: 890 Counter({1: 5}) 4
# > > > >  Cluster_id: 891 Counter({1: 13, -1: 7}) 4
# > > > >  Cluster_id: 892 Counter({1: 5}) 4
# > > > >  Cluster_id: 893 Counter({1: 14, -1: 2}) 4
# > > > >  Cluster_id: 894 Counter({1: 7}) 4
# > > > >  Cluster_id: 895 Counter({1: 8}) 4
# > > > >  Cluster_id: 896 Counter({1: 6}) 4
# > > > >  Cluster_id: 897 Counter({1: 13}) 4
# > > > >  Cluster_id: 898 Counter({1: 17, -1: 3}) 4
# > > > >  Cluster_id: 899 Counter({1: 9}) 4
# > > > >  Cluster_id: 900 Counter({1: 10}) 4
# > > > >  Cluster_id: 901 Counter({1: 11, -1: 1}) 4
# > > > >  Cluster_id: 902 Counter({-1: 9, 1: 2}) 4
# > > > >  Cluster_id: 903 Counter({-1: 10}) 4
# > > >  Cluster_id: 904 Counter({1: 50}) 3
# > > > >  Cluster_id: 905 Counter({1: 15}) 4
# > > > >  Cluster_id: 906 Counter({1: 8}) 4
# > > > >  Cluster_id: 907 Counter({1: 14}) 4
# > > > >  Cluster_id: 908 Counter({1: 13}) 4
# > > >  Cluster_id: 909 Counter({1: 86}) 3
# > > > >  Cluster_id: 910 Counter({1: 7}) 4
# > > > >  Cluster_id: 911 Counter({1: 8}) 4
# > > > >  Cluster_id: 912 Counter({1: 17}) 4
# > > > >  Cluster_id: 913 Counter({1: 4}) 4
# > > > >  Cluster_id: 914 Counter({1: 18}) 4
# > > > >  Cluster_id: 915 Counter({1: 18}) 4
# > > > >  Cluster_id: 916 Counter({1: 14}) 4
# > > >  Cluster_id: 917 Counter({1: 175, -1: 23}) 3
# > > > >  Cluster_id: 918 Counter({1: 19}) 4
# > > > >  Cluster_id: 919 Counter({1: 13}) 4
# > > > >  Cluster_id: 920 Counter({1: 12}) 4
# > > > >  Cluster_id: 921 Counter({1: 5}) 4
# > > > >  Cluster_id: 922 Counter({1: 3, -1: 2}) 4
# > > > >  Cluster_id: 923 Counter({1: 9, -1: 2}) 4
# > > > >  Cluster_id: 924 Counter({1: 8}) 4
# > > > >  Cluster_id: 925 Counter({1: 11, -1: 8}) 4
# > > > >  Cluster_id: 926 Counter({1: 17}) 4
# > > > >  Cluster_id: 927 Counter({1: 17}) 4
# > > > >  Cluster_id: 928 Counter({1: 4}) 4
# > > > >  Cluster_id: 929 Counter({1: 2}) 4
# > > > >  Cluster_id: 930 Counter({1: 19}) 4
# > > > >  Cluster_id: 931 Counter({1: 6, -1: 6}) 4
# > > > >  Cluster_id: 932 Counter({1: 14}) 4
# > > > >  Cluster_id: 933 Counter({1: 7, -1: 1}) 4
# > > > >  Cluster_id: 934 Counter({1: 9, -1: 1}) 4
# > > > >  Cluster_id: 935 Counter({-1: 3}) 4
# > > >  Cluster_id: 936 Counter({1: 81, -1: 6}) 3
# > > > >  Cluster_id: 937 Counter({1: 14}) 4
# > > > >  Cluster_id: 938 Counter({1: 16}) 4
# > > > >  Cluster_id: 939 Counter({1: 14}) 4
# > > > >  Cluster_id: 940 Counter({1: 5}) 4
# > > > >  Cluster_id: 941 Counter({1: 5}) 4
# > > > >  Cluster_id: 942 Counter({1: 5}) 4
# > > > >  Cluster_id: 943 Counter({1: 15, -1: 1}) 4
# > > > >  Cluster_id: 944 Counter({1: 7, -1: 5}) 4
# > > >  Cluster_id: 945 Counter({1: 62}) 3
# > > > >  Cluster_id: 946 Counter({1: 1}) 4
# > > > >  Cluster_id: 947 Counter({1: 5}) 4
# > > > >  Cluster_id: 948 Counter({1: 9}) 4
# > > > >  Cluster_id: 949 Counter({1: 9}) 4
# > > > >  Cluster_id: 950 Counter({1: 26}) 4
# > > > >  Cluster_id: 951 Counter({1: 12}) 4
# > > >  Cluster_id: 952 Counter({1: 124}) 3
# > > > >  Cluster_id: 953 Counter({1: 18}) 4
# > > > >  Cluster_id: 954 Counter({1: 13}) 4
# > > > >  Cluster_id: 955 Counter({1: 16}) 4
# > > > >  Cluster_id: 956 Counter({1: 2}) 4
# > > > >  Cluster_id: 957 Counter({1: 20}) 4
# > > > >  Cluster_id: 958 Counter({1: 12}) 4
# > > > >  Cluster_id: 959 Counter({1: 18}) 4
# > > > >  Cluster_id: 960 Counter({1: 3}) 4
# > > > >  Cluster_id: 961 Counter({1: 5}) 4
# > > > >  Cluster_id: 962 Counter({1: 17}) 4
# > > >  Cluster_id: 963 Counter({-1: 67, 1: 21}) 3
# > > > >  Cluster_id: 964 Counter({1: 3}) 4
# > > > >  Cluster_id: 965 Counter({1: 17, -1: 2}) 4
# > > > >  Cluster_id: 966 Counter({1: 1, -1: 1}) 4
# > > > >  Cluster_id: 967 Counter({-1: 18}) 4
# > > > >  Cluster_id: 968 Counter({-1: 9}) 4
# > > > >  Cluster_id: 969 Counter({-1: 14}) 4
# > > > >  Cluster_id: 970 Counter({-1: 10}) 4
# > > > >  Cluster_id: 971 Counter({-1: 13}) 4
# > >  Cluster_id: 972 Counter({1: 1197, -1: 715}) 2
# > > >  Cluster_id: 973 Counter({1: 151}) 3
# > > > >  Cluster_id: 974 Counter({1: 5}) 4
# > > > >  Cluster_id: 975 Counter({1: 16}) 4
# > > > >  Cluster_id: 976 Counter({1: 17}) 4
# > > > >  Cluster_id: 977 Counter({1: 20}) 4
# > > > >  Cluster_id: 978 Counter({1: 4}) 4
# > > > >  Cluster_id: 979 Counter({1: 17}) 4
# > > > >  Cluster_id: 980 Counter({1: 16}) 4
# > > > >  Cluster_id: 981 Counter({1: 19}) 4
# > > > >  Cluster_id: 982 Counter({1: 16}) 4
# > > > >  Cluster_id: 983 Counter({1: 16}) 4
# > > > >  Cluster_id: 984 Counter({1: 5}) 4
# > > >  Cluster_id: 985 Counter({1: 18}) 3
# > > >  Cluster_id: 986 Counter({1: 29, -1: 4}) 3
# > > > >  Cluster_id: 987 Counter({1: 12}) 4
# > > > >  Cluster_id: 988 Counter({1: 7}) 4
# > > > >  Cluster_id: 989 Counter({1: 6, -1: 1}) 4
# > > > >  Cluster_id: 990 Counter({1: 4, -1: 3}) 4
# > > >  Cluster_id: 991 Counter({1: 5}) 3
# > > >  Cluster_id: 992 Counter({1: 14}) 3
# > > >  Cluster_id: 993 Counter({1: 17}) 3
# > > >  Cluster_id: 994 Counter({1: 239}) 3
# > > > >  Cluster_id: 995 Counter({1: 14}) 4
# > > > >  Cluster_id: 996 Counter({1: 21}) 4
# > > > >  Cluster_id: 997 Counter({1: 11}) 4
# > > > >  Cluster_id: 998 Counter({1: 6}) 4
# > > > >  Cluster_id: 999 Counter({1: 14}) 4
# > > > >  Cluster_id: 1000 Counter({1: 18}) 4
# > > > >  Cluster_id: 1001 Counter({1: 17}) 4
# > > > >  Cluster_id: 1002 Counter({1: 8}) 4
# > > > >  Cluster_id: 1003 Counter({1: 17}) 4
# > > > >  Cluster_id: 1004 Counter({1: 18}) 4
# > > > >  Cluster_id: 1005 Counter({1: 1}) 4
# > > > >  Cluster_id: 1006 Counter({1: 16}) 4
# > > > >  Cluster_id: 1007 Counter({1: 18}) 4
# > > > >  Cluster_id: 1008 Counter({1: 17}) 4
# > > > >  Cluster_id: 1009 Counter({1: 2}) 4
# > > > >  Cluster_id: 1010 Counter({1: 15}) 4
# > > > >  Cluster_id: 1011 Counter({1: 7}) 4
# > > > >  Cluster_id: 1012 Counter({1: 9}) 4
# > > > >  Cluster_id: 1013 Counter({1: 10}) 4
# > > >  Cluster_id: 1014 Counter({1: 149, -1: 11}) 3
# > > > >  Cluster_id: 1015 Counter({1: 13}) 4
# > > > >  Cluster_id: 1016 Counter({1: 17}) 4
# > > > >  Cluster_id: 1017 Counter({1: 17}) 4
# > > > >  Cluster_id: 1018 Counter({1: 19}) 4
# > > > >  Cluster_id: 1019 Counter({1: 6}) 4
# > > > >  Cluster_id: 1020 Counter({1: 17}) 4
# > > > >  Cluster_id: 1021 Counter({1: 7}) 4
# > > > >  Cluster_id: 1022 Counter({1: 10}) 4
# > > > >  Cluster_id: 1023 Counter({1: 16}) 4
# > > > >  Cluster_id: 1024 Counter({1: 20}) 4
# > > > >  Cluster_id: 1025 Counter({-1: 11, 1: 7}) 4
# > > >  Cluster_id: 1026 Counter({1: 44}) 3
# > > > >  Cluster_id: 1027 Counter({1: 16}) 4
# > > > >  Cluster_id: 1028 Counter({1: 3}) 4
# > > > >  Cluster_id: 1029 Counter({1: 8}) 4
# > > > >  Cluster_id: 1030 Counter({1: 17}) 4
# > > >  Cluster_id: 1031 Counter({1: 202}) 3
# > > > >  Cluster_id: 1032 Counter({1: 19}) 4
# > > > >  Cluster_id: 1033 Counter({1: 15}) 4
# > > > >  Cluster_id: 1034 Counter({1: 16}) 4
# > > > >  Cluster_id: 1035 Counter({1: 15}) 4
# > > > >  Cluster_id: 1036 Counter({1: 9}) 4
# > > > >  Cluster_id: 1037 Counter({1: 17}) 4
# > > > >  Cluster_id: 1038 Counter({1: 17}) 4
# > > > >  Cluster_id: 1039 Counter({1: 14}) 4
# > > > >  Cluster_id: 1040 Counter({1: 11}) 4
# > > > >  Cluster_id: 1041 Counter({1: 20}) 4
# > > > >  Cluster_id: 1042 Counter({1: 4}) 4
# > > > >  Cluster_id: 1043 Counter({1: 6}) 4
# > > > >  Cluster_id: 1044 Counter({1: 6}) 4
# > > > >  Cluster_id: 1045 Counter({1: 2}) 4
# > > > >  Cluster_id: 1046 Counter({1: 10}) 4
# > > > >  Cluster_id: 1047 Counter({1: 9}) 4
# > > > >  Cluster_id: 1048 Counter({1: 6}) 4
# > > > >  Cluster_id: 1049 Counter({1: 6}) 4
# > > >  Cluster_id: 1050 Counter({1: 107, -1: 3}) 3
# > > > >  Cluster_id: 1051 Counter({1: 9}) 4
# > > > >  Cluster_id: 1052 Counter({1: 8}) 4
# > > > >  Cluster_id: 1053 Counter({1: 5, -1: 3}) 4
# > > > >  Cluster_id: 1054 Counter({1: 19}) 4
# > > > >  Cluster_id: 1055 Counter({1: 9}) 4
# > > > >  Cluster_id: 1056 Counter({1: 3}) 4
# > > > >  Cluster_id: 1057 Counter({1: 11}) 4
# > > > >  Cluster_id: 1058 Counter({1: 11}) 4
# > > > >  Cluster_id: 1059 Counter({1: 12}) 4
# > > > >  Cluster_id: 1060 Counter({1: 10}) 4
# > > > >  Cluster_id: 1061 Counter({1: 10}) 4
# > > >  Cluster_id: 1062 Counter({1: 198}) 3
# > > > >  Cluster_id: 1063 Counter({1: 17}) 4
# > > > >  Cluster_id: 1064 Counter({1: 12}) 4
# > > > >  Cluster_id: 1065 Counter({1: 18}) 4
# > > > >  Cluster_id: 1066 Counter({1: 16}) 4
# > > > >  Cluster_id: 1067 Counter({1: 18}) 4
# > > > >  Cluster_id: 1068 Counter({1: 9}) 4
# > > > >  Cluster_id: 1069 Counter({1: 13}) 4
# > > > >  Cluster_id: 1070 Counter({1: 4}) 4
# > > > >  Cluster_id: 1071 Counter({1: 5}) 4
# > > > >  Cluster_id: 1072 Counter({1: 20}) 4
# > > > >  Cluster_id: 1073 Counter({1: 8}) 4
# > > > >  Cluster_id: 1074 Counter({1: 4}) 4
# > > > >  Cluster_id: 1075 Counter({1: 13}) 4
# > > > >  Cluster_id: 1076 Counter({1: 17}) 4
# > > > >  Cluster_id: 1077 Counter({1: 8}) 4
# > > > >  Cluster_id: 1078 Counter({1: 4}) 4
# > > > >  Cluster_id: 1079 Counter({1: 12}) 4
# > > >  Cluster_id: 1080 Counter({1: 24, -1: 19}) 3
# > > > >  Cluster_id: 1081 Counter({1: 13}) 4
# > > > >  Cluster_id: 1082 Counter({1: 9}) 4
# > > > >  Cluster_id: 1083 Counter({1: 2, -1: 1}) 4
# > > > >  Cluster_id: 1084 Counter({-1: 18}) 4
# > > >  Cluster_id: 1085 Counter({-1: 161}) 3
# > > > >  Cluster_id: 1086 Counter({-1: 2}) 4
# > > > >  Cluster_id: 1087 Counter({-1: 1}) 4
# > > > >  Cluster_id: 1088 Counter({-1: 19}) 4
# > > > >  Cluster_id: 1089 Counter({-1: 20}) 4
# > > > >  Cluster_id: 1090 Counter({-1: 11}) 4
# > > > >  Cluster_id: 1091 Counter({-1: 10}) 4
# > > > >  Cluster_id: 1092 Counter({-1: 2}) 4
# > > > >  Cluster_id: 1093 Counter({-1: 8}) 4
# > > > >  Cluster_id: 1094 Counter({-1: 17}) 4
# > > > >  Cluster_id: 1095 Counter({-1: 11}) 4
# > > > >  Cluster_id: 1096 Counter({-1: 9}) 4
# > > > >  Cluster_id: 1097 Counter({-1: 15}) 4
# > > > >  Cluster_id: 1098 Counter({-1: 19}) 4
# ...
# > > > >  Cluster_id: 1325 Counter({-1: 19}) 4
# > > > >  Cluster_id: 1326 Counter({-1: 21}) 4
# > > > >  Cluster_id: 1327 Counter({-1: 12}) 4
# > > > >  Cluster_id: 1328 Counter({-1: 16}) 4
# > > >  Cluster_id: 1329 Counter({-1: 208, 1: 12}) 3
# > > > >  Cluster_id: 1330 Counter({-1: 15, 1: 2}) 4
# > > > >  Cluster_id: 1331 Counter({-1: 7, 1: 1}) 4
# > > > >  Cluster_id: 1332 Counter({-1: 8}) 4
# > > > >  Cluster_id: 1333 Counter({-1: 9}) 4
# > > > >  Cluster_id: 1334 Counter({-1: 15, 1: 2}) 4
# > > > >  Cluster_id: 1335 Counter({-1: 19}) 4
# > > > >  Cluster_id: 1336 Counter({-1: 10}) 4
# > > > >  Cluster_id: 1337 Counter({-1: 16}) 4
# > > > >  Cluster_id: 1338 Counter({-1: 10}) 4
# > > > >  Cluster_id: 1339 Counter({-1: 16}) 4
# > > > >  Cluster_id: 1340 Counter({-1: 21}) 4
# > > > >  Cluster_id: 1341 Counter({-1: 7, 1: 6}) 4
# > > > >  Cluster_id: 1342 Counter({-1: 16}) 4
# > > > >  Cluster_id: 1343 Counter({-1: 14}) 4
# > > > >  Cluster_id: 1344 Counter({-1: 9, 1: 1}) 4
# > > > >  Cluster_id: 1345 Counter({-1: 16}) 4
# > > >  Cluster_id: 1346 Counter({-1: 68, 1: 2}) 3
# > > > >  Cluster_id: 1347 Counter({1: 1, -1: 1}) 4
# > > > >  Cluster_id: 1348 Counter({-1: 13, 1: 1}) 4
# > > > >  Cluster_id: 1349 Counter({-1: 6}) 4
# > > > >  Cluster_id: 1350 Counter({-1: 16}) 4
# > > > >  Cluster_id: 1351 Counter({-1: 16}) 4
# > > > >  Cluster_id: 1352 Counter({-1: 8}) 4
# > > > >  Cluster_id: 1353 Counter({-1: 8}) 4
# > > >  Cluster_id: 1354 Counter({-1: 103, 1: 2}) 3
# > > > >  Cluster_id: 1355 Counter({-1: 17, 1: 1}) 4
# > > > >  Cluster_id: 1356 Counter({-1: 10}) 4
# > > > >  Cluster_id: 1357 Counter({-1: 10}) 4
# > > > >  Cluster_id: 1358 Counter({-1: 12}) 4
# > > > >  Cluster_id: 1359 Counter({-1: 20}) 4
# > > > >  Cluster_id: 1360 Counter({-1: 13, 1: 1}) 4
# > > > >  Cluster_id: 1361 Counter({-1: 6}) 4
# > > > >  Cluster_id: 1362 Counter({-1: 15}) 4
# > >  Cluster_id: 1363 Counter({-1: 2501}) 2
# > > >  Cluster_id: 1364 Counter({-1: 74}) 3
# > > > >  Cluster_id: 1365 Counter({-1: 7}) 4
# > > > >  Cluster_id: 1366 Counter({-1: 7}) 4
# > > > >  Cluster_id: 1367 Counter({-1: 19}) 4
# > > > >  Cluster_id: 1368 Counter({-1: 20}) 4
# > > > >  Cluster_id: 1369 Counter({-1: 18}) 4
# > > > >  Cluster_id: 1370 Counter({-1: 3}) 4
# > > >  Cluster_id: 1371 Counter({-1: 12}) 3
# > > >  Cluster_id: 1372 Counter({-1: 2}) 3
# > > >  Cluster_id: 1373 Counter({-1: 213}) 3
# > > > >  Cluster_id: 1374 Counter({-1: 18}) 4
# > > > >  Cluster_id: 1375 Counter({-1: 5}) 4
# > > > >  Cluster_id: 1376 Counter({-1: 1}) 4
# > > > >  Cluster_id: 1377 Counter({-1: 20}) 4
# > > > >  Cluster_id: 1378 Counter({-1: 18}) 4
# > > > >  Cluster_id: 1379 Counter({-1: 20}) 4
# > > > >  Cluster_id: 1380 Counter({-1: 15}) 4
# > > > >  Cluster_id: 1381 Counter({-1: 12}) 4
# > > > >  Cluster_id: 1382 Counter({-1: 17}) 4
# > > > >  Cluster_id: 1383 Counter({-1: 18}) 4
# > > > >  Cluster_id: 1384 Counter({-1: 17}) 4
# > > > >  Cluster_id: 1385 Counter({-1: 12}) 4
# > > > >  Cluster_id: 1386 Counter({-1: 11}) 4
# > > > >  Cluster_id: 1387 Counter({-1: 12}) 4
# > > > >  Cluster_id: 1388 Counter({-1: 17}) 4
# > > >  Cluster_id: 1389 Counter({-1: 192}) 3
# > > > >  Cluster_id: 1390 Counter({-1: 20}) 4
# > > > >  Cluster_id: 1391 Counter({-1: 16}) 4
# > > > >  Cluster_id: 1392 Counter({-1: 17}) 4
# > > > >  Cluster_id: 1393 Counter({-1: 19}) 4
# > > > >  Cluster_id: 1394 Counter({-1: 12}) 4
# > > > >  Cluster_id: 1395 Counter({-1: 6}) 4
# > > > >  Cluster_id: 1396 Counter({-1: 8}) 4
# > > > >  Cluster_id: 1397 Counter({-1: 3}) 4
# > > > >  Cluster_id: 1398 Counter({-1: 13}) 4
# > > > >  Cluster_id: 1399 Counter({-1: 11}) 4
# > > > >  Cluster_id: 1400 Counter({-1: 10}) 4
# > > > >  Cluster_id: 1401 Counter({-1: 1}) 4
# > > > >  Cluster_id: 1402 Counter({-1: 8}) 4
# > > > >  Cluster_id: 1403 Counter({-1: 3}) 4
# > > > >  Cluster_id: 1404 Counter({-1: 12}) 4
# > > > >  Cluster_id: 1405 Counter({-1: 12}) 4
# > > > >  Cluster_id: 1406 Counter({-1: 7}) 4
# > > > >  Cluster_id: 1407 Counter({-1: 14}) 4
# > > >  Cluster_id: 1408 Counter({-1: 31}) 3
# > > > >  Cluster_id: 1409 Counter({-1: 2}) 4
# > > > >  Cluster_id: 1410 Counter({-1: 15}) 4
# > > > >  Cluster_id: 1411 Counter({-1: 14}) 4
# > > >  Cluster_id: 1412 Counter({-1: 177}) 3
# > > > >  Cluster_id: 1413 Counter({-1: 2}) 4
# > > > >  Cluster_id: 1414 Counter({-1: 19}) 4
# > > > >  Cluster_id: 1415 Counter({-1: 12}) 4
# > > > >  Cluster_id: 1416 Counter({-1: 19}) 4
# > > > >  Cluster_id: 1417 Counter({-1: 8}) 4
# > > > >  Cluster_id: 1418 Counter({-1: 20}) 4
# > > > >  Cluster_id: 1419 Counter({-1: 4}) 4
# > > > >  Cluster_id: 1420 Counter({-1: 20}) 4
# > > > >  Cluster_id: 1421 Counter({-1: 19}) 4
# > > > >  Cluster_id: 1422 Counter({-1: 4}) 4
# > > > >  Cluster_id: 1423 Counter({-1: 8}) 4
# > > > >  Cluster_id: 1424 Counter({-1: 11}) 4
# > > > >  Cluster_id: 1425 Counter({-1: 20}) 4
# > > > >  Cluster_id: 1426 Counter({-1: 11}) 4
# > > >  Cluster_id: 1427 Counter({-1: 230}) 3
# > > > >  Cluster_id: 1428 Counter({-1: 18}) 4
# > > > >  Cluster_id: 1429 Counter({-1: 12}) 4
# > > > >  Cluster_id: 1430 Counter({-1: 4}) 4
# > > > >  Cluster_id: 1431 Counter({-1: 15}) 4
# > > > >  Cluster_id: 1432 Counter({-1: 5}) 4
# > > > >  Cluster_id: 1433 Counter({-1: 12}) 4
# > > > >  Cluster_id: 1434 Counter({-1: 13}) 4
# > > > >  Cluster_id: 1435 Counter({-1: 17}) 4
# > > > >  Cluster_id: 1436 Counter({-1: 14}) 4
# > > > >  Cluster_id: 1437 Counter({-1: 9}) 4
# > > > >  Cluster_id: 1438 Counter({-1: 4}) 4
# > > > >  Cluster_id: 1439 Counter({-1: 20}) 4
# > > > >  Cluster_id: 1440 Counter({-1: 7}) 4
# > > > >  Cluster_id: 1441 Counter({-1: 20}) 4
# > > > >  Cluster_id: 1442 Counter({-1: 12}) 4
# > > > >  Cluster_id: 1443 Counter({-1: 11}) 4
# > > > >  Cluster_id: 1444 Counter({-1: 19}) 4
# > > > >  Cluster_id: 1445 Counter({-1: 9}) 4
# > > > >  Cluster_id: 1446 Counter({-1: 9}) 4
# > > >  Cluster_id: 1447 Counter({-1: 173}) 3
# > > > >  Cluster_id: 1448 Counter({-1: 2}) 4
# > > > >  Cluster_id: 1449 Counter({-1: 10}) 4
# > > > >  Cluster_id: 1450 Counter({-1: 16}) 4
# > > > >  Cluster_id: 1451 Counter({-1: 12}) 4
# > > > >  Cluster_id: 1452 Counter({-1: 13}) 4
# > > > >  Cluster_id: 1453 Counter({-1: 20}) 4
# > > > >  Cluster_id: 1454 Counter({-1: 20}) 4
# > > > >  Cluster_id: 1455 Counter({-1: 15}) 4
# > > > >  Cluster_id: 1456 Counter({-1: 8}) 4
# > > > >  Cluster_id: 1457 Counter({-1: 18}) 4
# > > > >  Cluster_id: 1458 Counter({-1: 8}) 4
# > > > >  Cluster_id: 1459 Counter({-1: 5}) 4
# > > > >  Cluster_id: 1460 Counter({-1: 16}) 4
# > > > >  Cluster_id: 1461 Counter({-1: 10}) 4
# > > >  Cluster_id: 1462 Counter({-1: 220}) 3
# > > > >  Cluster_id: 1463 Counter({-1: 14}) 4
# > > > >  Cluster_id: 1464 Counter({-1: 19}) 4
# > > > >  Cluster_id: 1465 Counter({-1: 6}) 4
# > > > >  Cluster_id: 1466 Counter({-1: 18}) 4
# > > > >  Cluster_id: 1467 Counter({-1: 12}) 4
# > > > >  Cluster_id: 1468 Counter({-1: 6}) 4
# > > > >  Cluster_id: 1469 Counter({-1: 11}) 4
# > > > >  Cluster_id: 1470 Counter({-1: 6}) 4
# > > > >  Cluster_id: 1471 Counter({-1: 7}) 4
# > > > >  Cluster_id: 1472 Counter({-1: 12}) 4
# > > > >  Cluster_id: 1473 Counter({-1: 17}) 4
# > > > >  Cluster_id: 1474 Counter({-1: 5}) 4
# > > > >  Cluster_id: 1475 Counter({-1: 16}) 4
# > > > >  Cluster_id: 1476 Counter({-1: 13}) 4
# > > > >  Cluster_id: 1477 Counter({-1: 19}) 4
# > > > >  Cluster_id: 1478 Counter({-1: 15}) 4
# > > > >  Cluster_id: 1479 Counter({-1: 8}) 4
# > > > >  Cluster_id: 1480 Counter({-1: 16}) 4
# > > >  Cluster_id: 1481 Counter({-1: 2}) 3
# > > >  Cluster_id: 1482 Counter({-1: 194}) 3
# > > > >  Cluster_id: 1483 Counter({-1: 17}) 4
# > > > >  Cluster_id: 1484 Counter({-1: 20}) 4
# > > > >  Cluster_id: 1485 Counter({-1: 13}) 4
# > > > >  Cluster_id: 1486 Counter({-1: 19}) 4
# > > > >  Cluster_id: 1487 Counter({-1: 19}) 4
# > > > >  Cluster_id: 1488 Counter({-1: 9}) 4
# > > > >  Cluster_id: 1489 Counter({-1: 10}) 4
# > > > >  Cluster_id: 1490 Counter({-1: 17}) 4
# > > > >  Cluster_id: 1491 Counter({-1: 11}) 4
# > > > >  Cluster_id: 1492 Counter({-1: 10}) 4
# > > > >  Cluster_id: 1493 Counter({-1: 13}) 4
# > > > >  Cluster_id: 1494 Counter({-1: 13}) 4
# > > > >  Cluster_id: 1495 Counter({-1: 9}) 4
# > > > >  Cluster_id: 1496 Counter({-1: 14}) 4
# > > >  Cluster_id: 1497 Counter({-1: 163}) 3
# > > > >  Cluster_id: 1498 Counter({-1: 5}) 4
# > > > >  Cluster_id: 1499 Counter({-1: 13}) 4
# > > > >  Cluster_id: 1500 Counter({-1: 18}) 4
# > > > >  Cluster_id: 1501 Counter({-1: 17}) 4
# > > > >  Cluster_id: 1502 Counter({-1: 8}) 4
# > > > >  Cluster_id: 1503 Counter({-1: 13}) 4
# > > > >  Cluster_id: 1504 Counter({-1: 6}) 4
# > > > >  Cluster_id: 1505 Counter({-1: 4}) 4
# > > > >  Cluster_id: 1506 Counter({-1: 20}) 4
# > > > >  Cluster_id: 1507 Counter({-1: 19}) 4
# > > > >  Cluster_id: 1508 Counter({-1: 4}) 4
# > > > >  Cluster_id: 1509 Counter({-1: 17}) 4
# > > > >  Cluster_id: 1510 Counter({-1: 6}) 4
# > > > >  Cluster_id: 1511 Counter({-1: 13}) 4
# > > >  Cluster_id: 1512 Counter({-1: 161}) 3
# > > > >  Cluster_id: 1513 Counter({-1: 15}) 4
# > > > >  Cluster_id: 1514 Counter({-1: 11}) 4
# > > > >  Cluster_id: 1515 Counter({-1: 3}) 4
# > > > >  Cluster_id: 1516 Counter({-1: 18}) 4
# > > > >  Cluster_id: 1517 Counter({-1: 16}) 4
# > > > >  Cluster_id: 1518 Counter({-1: 17}) 4
# > > > >  Cluster_id: 1519 Counter({-1: 8}) 4
# > > > >  Cluster_id: 1520 Counter({-1: 17}) 4
# > > > >  Cluster_id: 1521 Counter({-1: 18}) 4
# > > > >  Cluster_id: 1522 Counter({-1: 21}) 4
# > > > >  Cluster_id: 1523 Counter({-1: 14}) 4
# > > > >  Cluster_id: 1524 Counter({-1: 3}) 4
# > > >  Cluster_id: 1525 Counter({-1: 163}) 3
# > > > >  Cluster_id: 1526 Counter({-1: 14}) 4
# > > > >  Cluster_id: 1527 Counter({-1: 8}) 4
# > > > >  Cluster_id: 1528 Counter({-1: 21}) 4
# > > > >  Cluster_id: 1529 Counter({-1: 6}) 4
# > > > >  Cluster_id: 1530 Counter({-1: 11}) 4
# > > > >  Cluster_id: 1531 Counter({-1: 3}) 4
# > > > >  Cluster_id: 1532 Counter({-1: 12}) 4
# > > > >  Cluster_id: 1533 Counter({-1: 9}) 4
# > > > >  Cluster_id: 1534 Counter({-1: 19}) 4
# > > > >  Cluster_id: 1535 Counter({-1: 12}) 4
# > > > >  Cluster_id: 1536 Counter({-1: 13}) 4
# > > > >  Cluster_id: 1537 Counter({-1: 9}) 4
# > > > >  Cluster_id: 1538 Counter({-1: 12}) 4
# > > > >  Cluster_id: 1539 Counter({-1: 14}) 4
# > > >  Cluster_id: 1540 Counter({-1: 254}) 3
# > > > >  Cluster_id: 1541 Counter({-1: 6}) 4
# > > > >  Cluster_id: 1542 Counter({-1: 19}) 4
# > > > >  Cluster_id: 1543 Counter({-1: 1}) 4
# > > > >  Cluster_id: 1544 Counter({-1: 17}) 4
# > > > >  Cluster_id: 1545 Counter({-1: 11}) 4
# > > > >  Cluster_id: 1546 Counter({-1: 18}) 4
# > > > >  Cluster_id: 1547 Counter({-1: 8}) 4
# > > > >  Cluster_id: 1548 Counter({-1: 7}) 4
# > > > >  Cluster_id: 1549 Counter({-1: 18}) 4
# > > > >  Cluster_id: 1550 Counter({-1: 19}) 4
# > > > >  Cluster_id: 1551 Counter({-1: 17}) 4
# > > > >  Cluster_id: 1552 Counter({-1: 13}) 4
# > > > >  Cluster_id: 1553 Counter({-1: 16}) 4
# > > > >  Cluster_id: 1554 Counter({-1: 15}) 4
# > > > >  Cluster_id: 1555 Counter({-1: 13}) 4
# > > > >  Cluster_id: 1556 Counter({-1: 3}) 4
# > > > >  Cluster_id: 1557 Counter({-1: 13}) 4
# > > > >  Cluster_id: 1558 Counter({-1: 18}) 4
# > > > >  Cluster_id: 1559 Counter({-1: 6}) 4
# > > > >  Cluster_id: 1560 Counter({-1: 16}) 4
# > > >  Cluster_id: 1561 Counter({-1: 136}) 3
# > > > >  Cluster_id: 1562 Counter({-1: 11}) 4
# > > > >  Cluster_id: 1563 Counter({-1: 20}) 4
# > > > >  Cluster_id: 1564 Counter({-1: 12}) 4
# > > > >  Cluster_id: 1565 Counter({-1: 15}) 4
# > > > >  Cluster_id: 1566 Counter({-1: 1}) 4
# > > > >  Cluster_id: 1567 Counter({-1: 3}) 4
# > > > >  Cluster_id: 1568 Counter({-1: 19}) 4
# > > > >  Cluster_id: 1569 Counter({-1: 3}) 4
# > > > >  Cluster_id: 1570 Counter({-1: 19}) 4
# > > > >  Cluster_id: 1571 Counter({-1: 13}) 4
# > > > >  Cluster_id: 1572 Counter({-1: 5}) 4
# > > > >  Cluster_id: 1573 Counter({-1: 6}) 4
# > > > >  Cluster_id: 1574 Counter({-1: 9}) 4
# > > >  Cluster_id: 1575 Counter({-1: 104}) 3
# > > > >  Cluster_id: 1576 Counter({-1: 9}) 4
# > > > >  Cluster_id: 1577 Counter({-1: 12}) 4
# > > > >  Cluster_id: 1578 Counter({-1: 20}) 4
# > > > >  Cluster_id: 1579 Counter({-1: 10}) 4
# > > > >  Cluster_id: 1580 Counter({-1: 7}) 4
# > > > >  Cluster_id: 1581 Counter({-1: 18}) 4
# > > > >  Cluster_id: 1582 Counter({-1: 14}) 4
# > > > >  Cluster_id: 1583 Counter({-1: 14}) 4
# > >  Cluster_id: 1584 Counter({-1: 966, 1: 7}) 2
# > > >  Cluster_id: 1585 Counter({-1: 36, 1: 2}) 3
# > > > >  Cluster_id: 1586 Counter({-1: 14, 1: 2}) 4
# > > > >  Cluster_id: 1587 Counter({-1: 5}) 4
# > > > >  Cluster_id: 1588 Counter({-1: 17}) 4
# > > >  Cluster_id: 1589 Counter({-1: 17}) 3
# > > >  Cluster_id: 1590 Counter({-1: 74}) 3
# > > > >  Cluster_id: 1591 Counter({-1: 11}) 4
# > > > >  Cluster_id: 1592 Counter({-1: 2}) 4
# > > > >  Cluster_id: 1593 Counter({-1: 10}) 4
# > > > >  Cluster_id: 1594 Counter({-1: 9}) 4
# > > > >  Cluster_id: 1595 Counter({-1: 4}) 4
# > > > >  Cluster_id: 1596 Counter({-1: 14}) 4
# > > > >  Cluster_id: 1597 Counter({-1: 12}) 4
# > > > >  Cluster_id: 1598 Counter({-1: 12}) 4
# > > >  Cluster_id: 1599 Counter({-1: 138, 1: 3}) 3
# > > > >  Cluster_id: 1600 Counter({-1: 15, 1: 2}) 4
# > > > >  Cluster_id: 1601 Counter({-1: 6}) 4
# > > > >  Cluster_id: 1602 Counter({-1: 7}) 4
# > > > >  Cluster_id: 1603 Counter({-1: 19}) 4
# > > > >  Cluster_id: 1604 Counter({-1: 19}) 4
# > > > >  Cluster_id: 1605 Counter({-1: 16}) 4
# > > > >  Cluster_id: 1606 Counter({-1: 11}) 4
# > > > >  Cluster_id: 1607 Counter({-1: 14}) 4
# > > > >  Cluster_id: 1608 Counter({-1: 16}) 4
# > > > >  Cluster_id: 1609 Counter({-1: 15, 1: 1}) 4
# > > >  Cluster_id: 1610 Counter({-1: 197, 1: 2}) 3
# > > > >  Cluster_id: 1611 Counter({-1: 15, 1: 2}) 4
# > > > >  Cluster_id: 1612 Counter({-1: 20}) 4
# > > > >  Cluster_id: 1613 Counter({-1: 3}) 4
# > > > >  Cluster_id: 1614 Counter({-1: 20}) 4
# > > > >  Cluster_id: 1615 Counter({-1: 17}) 4
# > > > >  Cluster_id: 1616 Counter({-1: 19}) 4
# > > > >  Cluster_id: 1617 Counter({-1: 11}) 4
# > > > >  Cluster_id: 1618 Counter({-1: 15}) 4
# > > > >  Cluster_id: 1619 Counter({-1: 16}) 4
# > > > >  Cluster_id: 1620 Counter({-1: 7}) 4
# > > > >  Cluster_id: 1621 Counter({-1: 11}) 4
# > > > >  Cluster_id: 1622 Counter({-1: 14}) 4
# > > > >  Cluster_id: 1623 Counter({-1: 4}) 4
# > > > >  Cluster_id: 1624 Counter({-1: 3}) 4
# > > > >  Cluster_id: 1625 Counter({-1: 7}) 4
# > > > >  Cluster_id: 1626 Counter({-1: 15}) 4
# > > >  Cluster_id: 1627 Counter({-1: 79}) 3
# > > > >  Cluster_id: 1628 Counter({-1: 20}) 4
# > > > >  Cluster_id: 1629 Counter({-1: 6}) 4
# > > > >  Cluster_id: 1630 Counter({-1: 20}) 4
# > > > >  Cluster_id: 1631 Counter({-1: 11}) 4
# > > > >  Cluster_id: 1632 Counter({-1: 18}) 4
# > > > >  Cluster_id: 1633 Counter({-1: 4}) 4
# > > >  Cluster_id: 1634 Counter({-1: 179}) 3
# > > > >  Cluster_id: 1635 Counter({-1: 8}) 4
# > > > >  Cluster_id: 1636 Counter({-1: 11}) 4
# > > > >  Cluster_id: 1637 Counter({-1: 15}) 4
# > > > >  Cluster_id: 1638 Counter({-1: 18}) 4
# > > > >  Cluster_id: 1639 Counter({-1: 10}) 4
# > > > >  Cluster_id: 1640 Counter({-1: 18}) 4
# > > > >  Cluster_id: 1641 Counter({-1: 13}) 4
# > > > >  Cluster_id: 1642 Counter({-1: 15}) 4
# > > > >  Cluster_id: 1643 Counter({-1: 21}) 4
# > > > >  Cluster_id: 1644 Counter({-1: 15}) 4
# > > > >  Cluster_id: 1645 Counter({-1: 5}) 4
# > > > >  Cluster_id: 1646 Counter({-1: 11}) 4
# > > > >  Cluster_id: 1647 Counter({-1: 19}) 4
# > > >  Cluster_id: 1648 Counter({-1: 130}) 3
# > > > >  Cluster_id: 1649 Counter({-1: 7}) 4
# > > > >  Cluster_id: 1650 Counter({-1: 17}) 4
# > > > >  Cluster_id: 1651 Counter({-1: 18}) 4
# > > > >  Cluster_id: 1652 Counter({-1: 3}) 4
# > > > >  Cluster_id: 1653 Counter({-1: 11}) 4
# > > > >  Cluster_id: 1654 Counter({-1: 11}) 4
# > > > >  Cluster_id: 1655 Counter({-1: 11}) 4
# > > > >  Cluster_id: 1656 Counter({-1: 4}) 4
# > > > >  Cluster_id: 1657 Counter({-1: 10}) 4
# > > > >  Cluster_id: 1658 Counter({-1: 15}) 4
# > > > >  Cluster_id: 1659 Counter({-1: 7}) 4
# > > > >  Cluster_id: 1660 Counter({-1: 16}) 4
# > > >  Cluster_id: 1661 Counter({-1: 116}) 3
# > > > >  Cluster_id: 1662 Counter({-1: 12}) 4
# > > > >  Cluster_id: 1663 Counter({-1: 14}) 4
# > > > >  Cluster_id: 1664 Counter({-1: 8}) 4
# > > > >  Cluster_id: 1665 Counter({-1: 6}) 4
# > > > >  Cluster_id: 1666 Counter({-1: 13}) 4
# > > > >  Cluster_id: 1667 Counter({-1: 6}) 4
# > > > >  Cluster_id: 1668 Counter({-1: 15}) 4
# > > > >  Cluster_id: 1669 Counter({-1: 16}) 4
# > > > >  Cluster_id: 1670 Counter({-1: 12}) 4
# > > > >  Cluster_id: 1671 Counter({-1: 5}) 4
# > > > >  Cluster_id: 1672 Counter({-1: 9}) 4

# %%
for depth in tree:
    dpt_print = ''
    for j in range(int(depth)):
        dpt_print += '> '
    for cluster in tree[depth]:
        print(dpt_print, "Cluster_id: ",cluster, 'labels: ', tree[depth][cluster])

# %%
file = 'Data/NSL-KDD/modified/Train/5_anomaly/A3.csv'
test_X,test_y = load_mutated_data(file,'defects')
predicted = cluster_tree[14].classifier.predict(test_X)
print(metrics.classification_report(test_y, predicted))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00       530
#            1       0.00      0.00      0.00         0
#
#    micro avg       0.00      0.00      0.00       530
#    macro avg       0.00      0.00      0.00       530
# weighted avg       0.00      0.00      0.00       530

# %%
file = 'Data/NSL-KDD/modified/Train/Normal_Data/N3.csv'
test_X,test_y = load_mutated_data(file,'defects')
predicted = cluster_tree[14].classifier.predict(test_X)
print(metrics.classification_report(test_y, predicted))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00       649
#            1       0.64      1.00      0.78      1166
#
#    micro avg       0.64      0.64      0.64      1815
#    macro avg       0.32      0.50      0.39      1815
# weighted avg       0.41      0.64      0.50      1815

# %%
a = [1,2,3,5]
b = [4,8,2,3]

# %%
a.append(b)

# %%
flat_list = [item for sublist in a for item in sublist]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-8728781dabdc> in <module>
# ----> 1 flat_list = [item for sublist in a for item in sublist]
#
# <ipython-input-83-8728781dabdc> in <listcomp>(.0)
# ----> 1 flat_list = [item for sublist in a for item in sublist]
#
# TypeError: 'int' object is not iterable

# %%
a
