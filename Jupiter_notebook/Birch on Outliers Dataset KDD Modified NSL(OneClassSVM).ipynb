# %%
import pandas as pd
import numpy as np
import collections
import seaborn as sns
import matplotlib.pyplot as plt
from graphviz import Digraph
import scipy.spatial.distance
from scipy.cluster.hierarchy import dendrogram
#Clustering birch
from freediscovery.cluster import birch_hierarchy_wrapper
from freediscovery.cluster import Birch,BirchSubcluster
#Sklearn
from sklearn.metrics.pairwise import pairwise_distances
from sklearn.model_selection import train_test_split
from sklearn import metrics
#Learners
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import OneClassSVM
#Distance measure
from scipy.spatial.distance import euclidean
from scipy import linalg, sparse

import warnings

import matplotlib.pyplot as plt

import pickle

# %%
warnings.filterwarnings("ignore")

# %%
def row_norms(X, squared=False):
    if sparse.issparse(X):
        if not isinstance(X, sparse.csr_matrix):
            X = sparse.csr_matrix(X)
        norms = csr_row_norms(X)
    else:
        norms = np.einsum('ij,ij->i', X, X)

    if not squared:
        np.sqrt(norms, norms)
    return norms

# %%
class bcluster(object):
    
    def __init__(self):
        self.parent = None
        self.parent_id = None
        self.depth = None
        self.size = None
        self.cluster_id = None
        self.data_points = []
        self.data_labels = []
        self.test_points = []
        self.test_labels = []
        self.predicted = []
        self.centroid = None
        self.classifier = None
        self.outlier_model = None
        self.cluster_obj = None
        self.outlier_points = []
        self.outlier_points_prediction = []
        self.score = []
        self.d1 = None
        self.d2 = None
        self.threshold = None
    
    def set_parent(self,parent_node=None):
        if parent_node == None:
            self.parent = None
            self.parent_id = None
        else:
            self.parent = parent_node
            self.parent_id = parent_node.cluster_id
    
    def set_depth(self,depth):
        self.depth = depth
    
    def set_size(self,size):
        self.size = size
        
    def set_cluster_id(self,cluster_id):
        self.cluster_id = cluster_id
        
    def set_data_points(self,data_points):
        self.data_points = data_points
        
    def set_data_labels(self,data_labels):
        self.data_labels = data_labels
    
    def set_test_labels(self,test_labels):
        self.test_labels = test_labels
        
    def add_test_lables(self,test_labels):
        self.test_labels.append(test_labels)
        
    def reset_test_lables_bucket(self):
        self.test_labels = []
        
    def add_test_points(self,test_point):
        self.test_points.append(test_point)
        
    def reset_test_points_bucket(self):
        self.test_points = []
        
    def add_outlier_points_prediction(self,outlier_points_prediction):
        self.outlier_points_prediction.append(outlier_points_prediction)
        
    def reset_outlier_points_prediction_bucket(self):
        self.outlier_points_prediction = []
    
    def add_predicted(self,predicted):
        self.predicted.append(predicted)
    
    def set_centroid(self,centroid):
        self.centroid = centroid
        
    def set_classifier(self,classifier):
        self.classifier = classifier
        
    def set_outlier_model(self,outlier_model):
        self.outlier_model = outlier_model
        
    def set_cluster_obj(self,cluster_obj):
        self.cluster_obj = cluster_obj
        
    def add_outlier_points(self,outlier_points):
        self.outlier_points.append(outlier_points)
    
    def reset_outlier_bucket(self):
        self.outlier_points = []
        
    def set_score(self,score):
        self.score = score
        
    def add_d1(self,d1):
        self.d1 = d1
        
    def add_d2(self,d2):
        self.d2 = d2
        
    def calculate_threshold(self,outlier_threshold):
        self.threshold = max(self.d1,self.d2)*outlier_threshold
        
    def check_outlier(self,distance):
        if self.threshold < distance:
            result = True
        else:
            result = False
        return result
    
    def check_OCS_outlier(self,test_data):
        _result = self.outlier_model.predict([test_data])
        if _result == -1:
            result = True
            self.add_outlier_points_prediction(list(_result)[0])
        else:
            result = False
            self.add_outlier_points_prediction(list(_result)[0])
        return result

# %%
class birch(object):

    def __init__(self,threshold=0.3,branching_factor=40,n_clusters=None,outlier_threshold=0.7):
        self.threshold = threshold
        self.branching_factor = branching_factor
        self.n_clusters = n_clusters
        self.outlier_threshold = outlier_threshold
        self.Birch_clusterer = Birch(threshold=self.threshold, branching_factor=self.branching_factor,
                                     n_clusters=self.n_clusters,compute_sample_indices=True)
    # Fitting the model with train_X
    def fit(self,data,y):
        self.data = data
        self.y = y
        #self.data.drop(self.data.columns[len(self.data.columns)-1], axis=1, inplace=True)
        self.Birch_clusterer.fit(self.data)

    #Defines and builds the Cluster Feature Tree
    def get_cluster_tree(self):
        self.htree, n_clusters = birch_hierarchy_wrapper(self.Birch_clusterer)
        clusters = {}
        max_depth = 0
        for i in range(n_clusters):
            #print('cluster:', i)
            node = bcluster()
            sub_cluster = self.htree.flatten()[i]
            node.set_cluster_id(sub_cluster['cluster_id'])
            depth = sub_cluster.current_depth
            node.set_depth(depth)
            if depth > max_depth:
                max_depth = depth
            if i not in clusters.keys():
                clusters[i] = {}
            if sub_cluster.current_depth == 0:
                node.set_parent()
            else:
                node.set_parent(clusters[sub_cluster.parent['cluster_id']])
            cluster_size = sub_cluster['cluster_size']
            node.set_size(cluster_size)
            data_points = sub_cluster['document_id_accumulated']
            node.set_data_points(data_points)
            node.set_data_labels(self.y[sub_cluster['document_id_accumulated']])
            centroid = self.data.iloc[sub_cluster['document_id_accumulated'], :].mean(axis=0).values
            node.set_centroid(centroid)
            d1,d1_v = self.calculate_d1(centroid,data_points)
            d2 = self.calculate_d2(centroid,data_points,d1_v)
            node.add_d1(d1)
            node.add_d2(d2)
            node.calculate_threshold(self.outlier_threshold)
            clusters[i] = node
        return clusters,max_depth
    
    #Calculate the d1 distance(point farthest away from centroid)
    def calculate_d1(self,centroid,data_points):
        d1 = 0
        u = centroid
        d1_v = None
        for point in data_points:
            v = point
            distance = euclidean(u,v)
            if distance>d1:
                d1 = distance
                d1_v = v
        return d1,d1_v
    
    #Calculate the d2 distance(point farthest away from d1 and its distance from centroid)
    def calculate_d2(self,centroid,data_points,d1_v):
        d2_d1 = 0
        u = d1_v
        d2_v = None
        for point in data_points:
            v = point
            distance = euclidean(u,v)
            if distance>d2_d1:
                d2_d1 = distance
                d2_v = v
        d2 = euclidean(centroid,v)
        return d2
    
    # Display's the tree
    def show_clutser_tree(self):
        self.htree.display_tree()
        
    # Add classification model at each node and leaf
    def model_adder(self,cluster_tree):
        for cluster_id in cluster_tree:
            clf = DecisionTreeClassifier(criterion='entropy')
            sample_points = cluster_tree[cluster_id].data_points
            train_X_sub = self.data.iloc[sample_points,:]
            train_y_sub = self.y.iloc[sample_points]
            clf.fit(train_X_sub,train_y_sub)
            cluster_tree[cluster_id].set_classifier(clf)
        return cluster_tree
    
    def outlier_model_adder(self,cluster_tree,depth):
        for cluster_id in cluster_tree:
            #if depth != cluster_tree[cluster_id].depth:
            #    continue
            #print('building outlier',cluster_id,cluster_tree[cluster_id].depth,len(cluster_tree[cluster_id].data_points))
            _nu = ((cluster_tree[cluster_id].data_labels == -1).sum()/len(cluster_tree[cluster_id].data_labels))
            if _nu == 0:
                _nu = 0.01
            clf = OneClassSVM(kernel = 'sigmoid',gamma = 'scale',nu=0.4)
            sample_points = cluster_tree[cluster_id].data_points
            train_X_sub = self.data.iloc[sample_points,:]
            clf.fit(train_X_sub)
            cluster_tree[cluster_id].set_outlier_model(clf)
        return cluster_tree
        
    # Prediction Function with height based prediction with outlier detection
    def predict(self,test_X,depth,do_predict=True):
        predicted = []
        for test_instance in test_X.iterrows():
            test_sample = test_instance[1].values
            min_distance = float('inf')
            selected_cluster = None
            for cluster_id in cluster_tree:
                if cluster_tree[cluster_id].depth != depth:
                    continue
                u = cluster_tree[cluster_id].centroid
                v = np.asarray(test_sample,dtype='float64')
                distance = euclidean(u,v)
                if distance < min_distance:
                    min_distance = distance
                    selected_cluster = cluster_id
            cluster_tree[selected_cluster].add_test_points(test_instance[0])
            # Outlier identifier
            if cluster_tree[selected_cluster].check_outlier(min_distance):
                cluster_tree[selected_cluster].add_outlier_points(test_instance[0])
            if do_predict:
                _predicted_label = cluster_tree[selected_cluster].classifier.predict([test_sample])
                cluster_tree[selected_cluster].add_predicted(_predicted_label)
                predicted.append(_predicted_label)
        return predicted
    
    def distance(self,x,y):
        dist = (list(x[:,1]) - y)**2
        dist = np.sum(dist, axis=1)
        dist = np.sqrt(dist)
        ind = np.unravel_index(np.argmin(dist, axis=None), dist.shape)
        min_distance = dist[np.argmin(dist, axis=None)]
        return list(x[ind])[0],min_distance
    
    def distance_alternet(self,x,y,row_norm):
        reduced_distance = np.dot(np.matrix(y), np.matrix(x).T)
        reduced_distance *= -2
        reduced_distance += row_norm
        return np.array(np.argmin(reduced_distance, axis=1))[0][0]
    
    # New Predict
    def predict_new(self,test_X,test_y,depth,do_predict=True):
        predicted = []
        cluster_centroids = []
        cluster_centroids_ids = []
        for cluster_id in cluster_tree:
            cluster_tree[cluster_id].reset_outlier_bucket()
            cluster_tree[cluster_id].reset_test_lables_bucket()
            cluster_tree[cluster_id].reset_test_points_bucket()
            cluster_tree[cluster_id].reset_outlier_points_prediction_bucket()
            if cluster_tree[cluster_id].depth != depth:
                continue
            cluster_centroids_ids.append(cluster_id) # Change when using normal distance
            cluster_centroids.append(cluster_tree[cluster_id].centroid)
        cluster_centroids = np.array(cluster_centroids)
        row_norm = row_norms(cluster_centroids)
        for test_instance in test_X.iterrows():
            test_sample = np.array(test_instance[1].values)
            #selected_cluster,min_distance = self.distance_alternet(cluster_centroids,test_sample,row_norm)  # Change when using normal distance
            selected_cluster = cluster_centroids_ids[self.distance_alternet(cluster_centroids,test_sample,row_norm)]
            if cluster_tree[selected_cluster].check_OCS_outlier(test_sample):
                cluster_tree[selected_cluster].add_outlier_points(test_instance[0])
            cluster_tree[selected_cluster].add_test_points(test_instance[0])
            cluster_tree[selected_cluster].add_test_lables(test_y[test_instance[0]])
            if do_predict:
                _predicted_label = cluster_tree[selected_cluster].classifier.predict([test_sample])
                cluster_tree[selected_cluster].add_predicted(_predicted_label)
                predicted.append(_predicted_label)
        return predicted
    
    # Model certification creator
    def certify_model(self,cluster_tree,test_y):
        for cluster_id in cluster_tree:
            if len(cluster_tree[cluster_id].test_points) == 0:
                continue
            cluster_tree[cluster_id].set_test_labels(test_y[cluster_tree[cluster_id].test_points].values)
            precision = metrics.precision_score(cluster_tree[cluster_id].test_labels, 
                                                cluster_tree[cluster_id].predicted,average='weighted')
            recall = metrics.recall_score(cluster_tree[cluster_id].test_labels, 
                                          cluster_tree[cluster_id].predicted,average='weighted')
            f1_Score = metrics.f1_score(cluster_tree[cluster_id].test_labels, 
                                        cluster_tree[cluster_id].predicted,average='weighted')
            score = {'precision': precision,'recall': recall,'f1_Score': f1_Score}
            cluster_tree[cluster_id].set_score(score)

# %%
def load_data(path,target):
    df = pd.read_csv(path)
    print(df.shape)
    y = df[target]
    X = df.drop(labels = target, axis = 1)
    X = X.apply(pd.to_numeric)
    y_test = []
    for instance in y.values:
        if instance == 'normal':
            y_test.append(1)
        else:
            y_test.append(-1)
    y_test = np.array(y_test)
    return X,y_test

def load_mutated_data(path,target):
    df = pd.read_csv(path)
    y = df[target]
    X = df.drop(labels = target, axis = 1)
    X = X.apply(pd.to_numeric)
    y_test = []
    for instance in y.values:
        if instance == 'normal':
            y_test.append(1)
        else:
            y_test.append(-1)
    y_test = np.array(y_test)
    return X,y_test

# %%
# Cluster Driver
def cluster_driver(file,print_tree = True):
    train_X, train_y = load_data(file,'defects')
    cluster = birch(branching_factor=20)
    cluster.fit(train_X,train_y)
    cluster_tree,max_depth = cluster.get_cluster_tree()
    #cluster_tree = cluster.model_adder(cluster_tree)
    cluster_tree = cluster.outlier_model_adder(cluster_tree,max_depth)
    if print_tree:
        cluster.show_clutser_tree()
    return cluster,cluster_tree,max_depth

# %%
# getting the cluster tree
file = 'Data/NSL-KDD/modified/train.csv'
cluster,cluster_tree,max_depth = cluster_driver(file)
# Out:
# (25192, 21)
# [cluster_id=0] N_children: 3 N_samples: 25192
# > [cluster_id=1] N_children: 13 N_samples: 175
# > > [cluster_id=2] N_children: 0 N_samples: 15
# > > [cluster_id=3] N_children: 0 N_samples: 17
# > > [cluster_id=4] N_children: 0 N_samples: 18
# > > [cluster_id=5] N_children: 0 N_samples: 20
# > > [cluster_id=6] N_children: 0 N_samples: 15
# > > [cluster_id=7] N_children: 0 N_samples: 15
# > > [cluster_id=8] N_children: 0 N_samples: 6
# > > [cluster_id=9] N_children: 0 N_samples: 2
# > > [cluster_id=10] N_children: 0 N_samples: 19
# > > [cluster_id=11] N_children: 0 N_samples: 1
# > > [cluster_id=12] N_children: 0 N_samples: 20
# > > [cluster_id=13] N_children: 0 N_samples: 18
# > > [cluster_id=14] N_children: 0 N_samples: 9
# > [cluster_id=15] N_children: 20 N_samples: 24952
# > > [cluster_id=16] N_children: 10 N_samples: 146
# > > > [cluster_id=17] N_children: 0 N_samples: 18
# > > > [cluster_id=18] N_children: 0 N_samples: 16
# > > > [cluster_id=19] N_children: 0 N_samples: 1
# > > > [cluster_id=20] N_children: 0 N_samples: 19
# > > > [cluster_id=21] N_children: 0 N_samples: 19
# > > > [cluster_id=22] N_children: 0 N_samples: 12
# > > > [cluster_id=23] N_children: 0 N_samples: 20
# > > > [cluster_id=24] N_children: 0 N_samples: 14
# > > > [cluster_id=25] N_children: 0 N_samples: 20
# > > > [cluster_id=26] N_children: 0 N_samples: 7
# > > [cluster_id=27] N_children: 4 N_samples: 302
# > > > [cluster_id=28] N_children: 19 N_samples: 251
# > > > > [cluster_id=29] N_children: 0 N_samples: 18
# > > > > [cluster_id=30] N_children: 0 N_samples: 16
# > > > > [cluster_id=31] N_children: 0 N_samples: 8
# > > > > [cluster_id=32] N_children: 0 N_samples: 15
# > > > > [cluster_id=33] N_children: 0 N_samples: 8
# > > > > [cluster_id=34] N_children: 0 N_samples: 7
# > > > > [cluster_id=35] N_children: 0 N_samples: 11
# > > > > [cluster_id=36] N_children: 0 N_samples: 22
# > > > > [cluster_id=37] N_children: 0 N_samples: 7
# > > > > [cluster_id=38] N_children: 0 N_samples: 19
# > > > > [cluster_id=39] N_children: 0 N_samples: 11
# > > > > [cluster_id=40] N_children: 0 N_samples: 3
# > > > > [cluster_id=41] N_children: 0 N_samples: 16
# > > > > [cluster_id=42] N_children: 0 N_samples: 16
# > > > > [cluster_id=43] N_children: 0 N_samples: 14
# > > > > [cluster_id=44] N_children: 0 N_samples: 5
# > > > > [cluster_id=45] N_children: 0 N_samples: 16
# > > > > [cluster_id=46] N_children: 0 N_samples: 14
# > > > > [cluster_id=47] N_children: 0 N_samples: 25
# > > > [cluster_id=48] N_children: 0 N_samples: 2
# > > > [cluster_id=49] N_children: 6 N_samples: 26
# > > > > [cluster_id=50] N_children: 0 N_samples: 1
# > > > > [cluster_id=51] N_children: 0 N_samples: 1
# > > > > [cluster_id=52] N_children: 0 N_samples: 1
# > > > > [cluster_id=53] N_children: 0 N_samples: 7
# > > > > [cluster_id=54] N_children: 0 N_samples: 1
# > > > > [cluster_id=55] N_children: 0 N_samples: 15
# > > > [cluster_id=56] N_children: 2 N_samples: 23
# > > > > [cluster_id=57] N_children: 0 N_samples: 18
# > > > > [cluster_id=58] N_children: 0 N_samples: 5
# > > [cluster_id=59] N_children: 9 N_samples: 1065
# > > > [cluster_id=60] N_children: 8 N_samples: 105
# > > > > [cluster_id=61] N_children: 0 N_samples: 12
# > > > > [cluster_id=62] N_children: 0 N_samples: 19
# > > > > [cluster_id=63] N_children: 0 N_samples: 17
# > > > > [cluster_id=64] N_children: 0 N_samples: 8
# > > > > [cluster_id=65] N_children: 0 N_samples: 8
# > > > > [cluster_id=66] N_children: 0 N_samples: 9
# > > > > [cluster_id=67] N_children: 0 N_samples: 20
# > > > > [cluster_id=68] N_children: 0 N_samples: 12
# > > > [cluster_id=69] N_children: 20 N_samples: 264
# > > > > [cluster_id=70] N_children: 0 N_samples: 11
# > > > > [cluster_id=71] N_children: 0 N_samples: 18
# > > > > [cluster_id=72] N_children: 0 N_samples: 9
# > > > > [cluster_id=73] N_children: 0 N_samples: 15
# > > > > [cluster_id=74] N_children: 0 N_samples: 13
# > > > > [cluster_id=75] N_children: 0 N_samples: 8
# > > > > [cluster_id=76] N_children: 0 N_samples: 19
# > > > > [cluster_id=77] N_children: 0 N_samples: 20
# > > > > [cluster_id=78] N_children: 0 N_samples: 12
# > > > > [cluster_id=79] N_children: 0 N_samples: 20
# > > > > [cluster_id=80] N_children: 0 N_samples: 10
# > > > > [cluster_id=81] N_children: 0 N_samples: 6
# > > > > [cluster_id=82] N_children: 0 N_samples: 2
# > > > > [cluster_id=83] N_children: 0 N_samples: 17
# > > > > [cluster_id=84] N_children: 0 N_samples: 18
# > > > > [cluster_id=85] N_children: 0 N_samples: 8
# > > > > [cluster_id=86] N_children: 0 N_samples: 18
# > > > > [cluster_id=87] N_children: 0 N_samples: 17
# > > > > [cluster_id=88] N_children: 0 N_samples: 11
# > > > > [cluster_id=89] N_children: 0 N_samples: 12
# > > > [cluster_id=90] N_children: 0 N_samples: 10
# > > > [cluster_id=91] N_children: 13 N_samples: 157
# > > > > [cluster_id=92] N_children: 0 N_samples: 12
# > > > > [cluster_id=93] N_children: 0 N_samples: 8
# > > > > [cluster_id=94] N_children: 0 N_samples: 16
# > > > > [cluster_id=95] N_children: 0 N_samples: 19
# > > > > [cluster_id=96] N_children: 0 N_samples: 12
# > > > > [cluster_id=97] N_children: 0 N_samples: 3
# > > > > [cluster_id=98] N_children: 0 N_samples: 7
# > > > > [cluster_id=99] N_children: 0 N_samples: 9
# > > > > [cluster_id=100] N_children: 0 N_samples: 16
# > > > > [cluster_id=101] N_children: 0 N_samples: 14
# > > > > [cluster_id=102] N_children: 0 N_samples: 15
# > > > > [cluster_id=103] N_children: 0 N_samples: 11
# > > > > [cluster_id=104] N_children: 0 N_samples: 15
# > > > [cluster_id=105] N_children: 17 N_samples: 178
# > > > > [cluster_id=106] N_children: 0 N_samples: 1
# > > > > [cluster_id=107] N_children: 0 N_samples: 16
# > > > > [cluster_id=108] N_children: 0 N_samples: 9
# > > > > [cluster_id=109] N_children: 0 N_samples: 9
# > > > > [cluster_id=110] N_children: 0 N_samples: 14
# > > > > [cluster_id=111] N_children: 0 N_samples: 9
# > > > > [cluster_id=112] N_children: 0 N_samples: 13
# > > > > [cluster_id=113] N_children: 0 N_samples: 1
# > > > > [cluster_id=114] N_children: 0 N_samples: 12
# > > > > [cluster_id=115] N_children: 0 N_samples: 16
# > > > > [cluster_id=116] N_children: 0 N_samples: 18
# > > > > [cluster_id=117] N_children: 0 N_samples: 10
# > > > > [cluster_id=118] N_children: 0 N_samples: 2
# > > > > [cluster_id=119] N_children: 0 N_samples: 14
# > > > > [cluster_id=120] N_children: 0 N_samples: 10
# > > > > [cluster_id=121] N_children: 0 N_samples: 10
# > > > > [cluster_id=122] N_children: 0 N_samples: 14
# > > > [cluster_id=123] N_children: 16 N_samples: 198
# > > > > [cluster_id=124] N_children: 0 N_samples: 20
# > > > > [cluster_id=125] N_children: 0 N_samples: 19
# > > > > [cluster_id=126] N_children: 0 N_samples: 20
# > > > > [cluster_id=127] N_children: 0 N_samples: 1
# > > > > [cluster_id=128] N_children: 0 N_samples: 4
# > > > > [cluster_id=129] N_children: 0 N_samples: 19
# > > > > [cluster_id=130] N_children: 0 N_samples: 9
# > > > > [cluster_id=131] N_children: 0 N_samples: 18
# > > > > [cluster_id=132] N_children: 0 N_samples: 7
# > > > > [cluster_id=133] N_children: 0 N_samples: 13
# > > > > [cluster_id=134] N_children: 0 N_samples: 11
# > > > > [cluster_id=135] N_children: 0 N_samples: 17
# > > > > [cluster_id=136] N_children: 0 N_samples: 9
# > > > > [cluster_id=137] N_children: 0 N_samples: 12
# > > > > [cluster_id=138] N_children: 0 N_samples: 10
# > > > > [cluster_id=139] N_children: 0 N_samples: 9
# > > > [cluster_id=140] N_children: 0 N_samples: 17
# > > > [cluster_id=141] N_children: 7 N_samples: 70
# > > > > [cluster_id=142] N_children: 0 N_samples: 19
# > > > > [cluster_id=143] N_children: 0 N_samples: 6
# > > > > [cluster_id=144] N_children: 0 N_samples: 4
# > > > > [cluster_id=145] N_children: 0 N_samples: 13
# > > > > [cluster_id=146] N_children: 0 N_samples: 14
# > > > > [cluster_id=147] N_children: 0 N_samples: 7
# > > > > [cluster_id=148] N_children: 0 N_samples: 7
# > > > [cluster_id=149] N_children: 5 N_samples: 66
# > > > > [cluster_id=150] N_children: 0 N_samples: 7
# > > > > [cluster_id=151] N_children: 0 N_samples: 18
# > > > > [cluster_id=152] N_children: 0 N_samples: 6
# > > > > [cluster_id=153] N_children: 0 N_samples: 18
# > > > > [cluster_id=154] N_children: 0 N_samples: 17
# > > [cluster_id=155] N_children: 2 N_samples: 237
# > > > [cluster_id=156] N_children: 14 N_samples: 190
# > > > > [cluster_id=157] N_children: 0 N_samples: 14
# > > > > [cluster_id=158] N_children: 0 N_samples: 20
# > > > > [cluster_id=159] N_children: 0 N_samples: 10
# > > > > [cluster_id=160] N_children: 0 N_samples: 12
# > > > > [cluster_id=161] N_children: 0 N_samples: 12
# > > > > [cluster_id=162] N_children: 0 N_samples: 19
# > > > > [cluster_id=163] N_children: 0 N_samples: 3
# > > > > [cluster_id=164] N_children: 0 N_samples: 12
# > > > > [cluster_id=165] N_children: 0 N_samples: 8
# > > > > [cluster_id=166] N_children: 0 N_samples: 15
# > > > > [cluster_id=167] N_children: 0 N_samples: 18
# > > > > [cluster_id=168] N_children: 0 N_samples: 17
# > > > > [cluster_id=169] N_children: 0 N_samples: 13
# > > > > [cluster_id=170] N_children: 0 N_samples: 17
# > > > [cluster_id=171] N_children: 6 N_samples: 47
# > > > > [cluster_id=172] N_children: 0 N_samples: 2
# > > > > [cluster_id=173] N_children: 0 N_samples: 9
# > > > > [cluster_id=174] N_children: 0 N_samples: 5
# > > > > [cluster_id=175] N_children: 0 N_samples: 18
# > > > > [cluster_id=176] N_children: 0 N_samples: 2
# > > > > [cluster_id=177] N_children: 0 N_samples: 11
# > > [cluster_id=178] N_children: 19 N_samples: 2577
# > > > [cluster_id=179] N_children: 5 N_samples: 36
# > > > > [cluster_id=180] N_children: 0 N_samples: 5
# > > > > [cluster_id=181] N_children: 0 N_samples: 4
# > > > > [cluster_id=182] N_children: 0 N_samples: 4
# > > > > [cluster_id=183] N_children: 0 N_samples: 7
# > > > > [cluster_id=184] N_children: 0 N_samples: 16
# > > > [cluster_id=185] N_children: 15 N_samples: 203
# > > > > [cluster_id=186] N_children: 0 N_samples: 18
# > > > > [cluster_id=187] N_children: 0 N_samples: 17
# > > > > [cluster_id=188] N_children: 0 N_samples: 18
# > > > > [cluster_id=189] N_children: 0 N_samples: 12
# > > > > [cluster_id=190] N_children: 0 N_samples: 10
# > > > > [cluster_id=191] N_children: 0 N_samples: 15
# > > > > [cluster_id=192] N_children: 0 N_samples: 12
# > > > > [cluster_id=193] N_children: 0 N_samples: 18
# > > > > [cluster_id=194] N_children: 0 N_samples: 20
# > > > > [cluster_id=195] N_children: 0 N_samples: 4
# > > > > [cluster_id=196] N_children: 0 N_samples: 16
# > > > > [cluster_id=197] N_children: 0 N_samples: 14
# > > > > [cluster_id=198] N_children: 0 N_samples: 12
# > > > > [cluster_id=199] N_children: 0 N_samples: 4
# > > > > [cluster_id=200] N_children: 0 N_samples: 13
# > > > [cluster_id=201] N_children: 0 N_samples: 1
# > > > [cluster_id=202] N_children: 18 N_samples: 239
# > > > > [cluster_id=203] N_children: 0 N_samples: 4
# > > > > [cluster_id=204] N_children: 0 N_samples: 10
# > > > > [cluster_id=205] N_children: 0 N_samples: 18
# > > > > [cluster_id=206] N_children: 0 N_samples: 16
# > > > > [cluster_id=207] N_children: 0 N_samples: 15
# > > > > [cluster_id=208] N_children: 0 N_samples: 13
# > > > > [cluster_id=209] N_children: 0 N_samples: 17
# > > > > [cluster_id=210] N_children: 0 N_samples: 18
# > > > > [cluster_id=211] N_children: 0 N_samples: 11
# > > > > [cluster_id=212] N_children: 0 N_samples: 16
# > > > > [cluster_id=213] N_children: 0 N_samples: 8
# > > > > [cluster_id=214] N_children: 0 N_samples: 14
# > > > > [cluster_id=215] N_children: 0 N_samples: 7
# > > > > [cluster_id=216] N_children: 0 N_samples: 14
# > > > > [cluster_id=217] N_children: 0 N_samples: 18
# > > > > [cluster_id=218] N_children: 0 N_samples: 19
# > > > > [cluster_id=219] N_children: 0 N_samples: 14
# > > > > [cluster_id=220] N_children: 0 N_samples: 7
# > > > [cluster_id=221] N_children: 13 N_samples: 172
# > > > > [cluster_id=222] N_children: 0 N_samples: 16
# > > > > [cluster_id=223] N_children: 0 N_samples: 11
# > > > > [cluster_id=224] N_children: 0 N_samples: 13
# > > > > [cluster_id=225] N_children: 0 N_samples: 16
# > > > > [cluster_id=226] N_children: 0 N_samples: 8
# > > > > [cluster_id=227] N_children: 0 N_samples: 10
# > > > > [cluster_id=228] N_children: 0 N_samples: 20
# > > > > [cluster_id=229] N_children: 0 N_samples: 18
# > > > > [cluster_id=230] N_children: 0 N_samples: 19
# > > > > [cluster_id=231] N_children: 0 N_samples: 13
# > > > > [cluster_id=232] N_children: 0 N_samples: 9
# > > > > [cluster_id=233] N_children: 0 N_samples: 5
# > > > > [cluster_id=234] N_children: 0 N_samples: 14
# > > > [cluster_id=235] N_children: 8 N_samples: 70
# > > > > [cluster_id=236] N_children: 0 N_samples: 6
# > > > > [cluster_id=237] N_children: 0 N_samples: 3
# > > > > [cluster_id=238] N_children: 0 N_samples: 5
# > > > > [cluster_id=239] N_children: 0 N_samples: 8
# > > > > [cluster_id=240] N_children: 0 N_samples: 4
# > > > > [cluster_id=241] N_children: 0 N_samples: 17
# > > > > [cluster_id=242] N_children: 0 N_samples: 9
# > > > > [cluster_id=243] N_children: 0 N_samples: 18
# > > > [cluster_id=244] N_children: 13 N_samples: 174
# > > > > [cluster_id=245] N_children: 0 N_samples: 18
# > > > > [cluster_id=246] N_children: 0 N_samples: 10
# > > > > [cluster_id=247] N_children: 0 N_samples: 20
# > > > > [cluster_id=248] N_children: 0 N_samples: 14
# > > > > [cluster_id=249] N_children: 0 N_samples: 20
# > > > > [cluster_id=250] N_children: 0 N_samples: 12
# > > > > [cluster_id=251] N_children: 0 N_samples: 14
# > > > > [cluster_id=252] N_children: 0 N_samples: 14
# > > > > [cluster_id=253] N_children: 0 N_samples: 2
# > > > > [cluster_id=254] N_children: 0 N_samples: 9
# > > > > [cluster_id=255] N_children: 0 N_samples: 16
# > > > > [cluster_id=256] N_children: 0 N_samples: 12
# > > > > [cluster_id=257] N_children: 0 N_samples: 13
# > > > [cluster_id=258] N_children: 18 N_samples: 239
# > > > > [cluster_id=259] N_children: 0 N_samples: 6
# > > > > [cluster_id=260] N_children: 0 N_samples: 7
# > > > > [cluster_id=261] N_children: 0 N_samples: 11
# > > > > [cluster_id=262] N_children: 0 N_samples: 19
# > > > > [cluster_id=263] N_children: 0 N_samples: 18
# > > > > [cluster_id=264] N_children: 0 N_samples: 7
# > > > > [cluster_id=265] N_children: 0 N_samples: 15
# > > > > [cluster_id=266] N_children: 0 N_samples: 18
# > > > > [cluster_id=267] N_children: 0 N_samples: 2
# > > > > [cluster_id=268] N_children: 0 N_samples: 20
# > > > > [cluster_id=269] N_children: 0 N_samples: 19
# > > > > [cluster_id=270] N_children: 0 N_samples: 10
# > > > > [cluster_id=271] N_children: 0 N_samples: 17
# > > > > [cluster_id=272] N_children: 0 N_samples: 12
# > > > > [cluster_id=273] N_children: 0 N_samples: 17
# > > > > [cluster_id=274] N_children: 0 N_samples: 7
# > > > > [cluster_id=275] N_children: 0 N_samples: 15
# > > > > [cluster_id=276] N_children: 0 N_samples: 19
# > > > [cluster_id=277] N_children: 17 N_samples: 209
# > > > > [cluster_id=278] N_children: 0 N_samples: 3
# > > > > [cluster_id=279] N_children: 0 N_samples: 20
# > > > > [cluster_id=280] N_children: 0 N_samples: 14
# > > > > [cluster_id=281] N_children: 0 N_samples: 14
# > > > > [cluster_id=282] N_children: 0 N_samples: 7
# > > > > [cluster_id=283] N_children: 0 N_samples: 16
# > > > > [cluster_id=284] N_children: 0 N_samples: 14
# > > > > [cluster_id=285] N_children: 0 N_samples: 13
# > > > > [cluster_id=286] N_children: 0 N_samples: 13
# > > > > [cluster_id=287] N_children: 0 N_samples: 10
# > > > > [cluster_id=288] N_children: 0 N_samples: 11
# > > > > [cluster_id=289] N_children: 0 N_samples: 16
# > > > > [cluster_id=290] N_children: 0 N_samples: 10
# > > > > [cluster_id=291] N_children: 0 N_samples: 1
# > > > > [cluster_id=292] N_children: 0 N_samples: 19
# > > > > [cluster_id=293] N_children: 0 N_samples: 12
# > > > > [cluster_id=294] N_children: 0 N_samples: 16
# > > > [cluster_id=295] N_children: 0 N_samples: 1
# > > > [cluster_id=296] N_children: 11 N_samples: 126
# > > > > [cluster_id=297] N_children: 0 N_samples: 13
# > > > > [cluster_id=298] N_children: 0 N_samples: 11
# > > > > [cluster_id=299] N_children: 0 N_samples: 3
# > > > > [cluster_id=300] N_children: 0 N_samples: 4
# > > > > [cluster_id=301] N_children: 0 N_samples: 6
# > > > > [cluster_id=302] N_children: 0 N_samples: 19
# > > > > [cluster_id=303] N_children: 0 N_samples: 18
# > > > > [cluster_id=304] N_children: 0 N_samples: 9
# > > > > [cluster_id=305] N_children: 0 N_samples: 9
# > > > > [cluster_id=306] N_children: 0 N_samples: 17
# > > > > [cluster_id=307] N_children: 0 N_samples: 17
# > > > [cluster_id=308] N_children: 11 N_samples: 154
# > > > > [cluster_id=309] N_children: 0 N_samples: 10
# > > > > [cluster_id=310] N_children: 0 N_samples: 14
# > > > > [cluster_id=311] N_children: 0 N_samples: 10
# > > > > [cluster_id=312] N_children: 0 N_samples: 14
# > > > > [cluster_id=313] N_children: 0 N_samples: 13
# > > > > [cluster_id=314] N_children: 0 N_samples: 15
# > > > > [cluster_id=315] N_children: 0 N_samples: 6
# > > > > [cluster_id=316] N_children: 0 N_samples: 18
# > > > > [cluster_id=317] N_children: 0 N_samples: 20
# > > > > [cluster_id=318] N_children: 0 N_samples: 19
# > > > > [cluster_id=319] N_children: 0 N_samples: 15
# > > > [cluster_id=320] N_children: 18 N_samples: 232
# > > > > [cluster_id=321] N_children: 0 N_samples: 7
# > > > > [cluster_id=322] N_children: 0 N_samples: 12
# > > > > [cluster_id=323] N_children: 0 N_samples: 18
# > > > > [cluster_id=324] N_children: 0 N_samples: 20
# > > > > [cluster_id=325] N_children: 0 N_samples: 9
# > > > > [cluster_id=326] N_children: 0 N_samples: 13
# > > > > [cluster_id=327] N_children: 0 N_samples: 15
# > > > > [cluster_id=328] N_children: 0 N_samples: 19
# > > > > [cluster_id=329] N_children: 0 N_samples: 17
# > > > > [cluster_id=330] N_children: 0 N_samples: 19
# > > > > [cluster_id=331] N_children: 0 N_samples: 14
# > > > > [cluster_id=332] N_children: 0 N_samples: 11
# > > > > [cluster_id=333] N_children: 0 N_samples: 20
# > > > > [cluster_id=334] N_children: 0 N_samples: 8
# > > > > [cluster_id=335] N_children: 0 N_samples: 2
# > > > > [cluster_id=336] N_children: 0 N_samples: 14
# > > > > [cluster_id=337] N_children: 0 N_samples: 12
# > > > > [cluster_id=338] N_children: 0 N_samples: 2
# > > > [cluster_id=339] N_children: 2 N_samples: 17
# > > > > [cluster_id=340] N_children: 0 N_samples: 15
# > > > > [cluster_id=341] N_children: 0 N_samples: 2
# > > > [cluster_id=342] N_children: 14 N_samples: 155
# > > > > [cluster_id=343] N_children: 0 N_samples: 6
# > > > > [cluster_id=344] N_children: 0 N_samples: 14
# > > > > [cluster_id=345] N_children: 0 N_samples: 10
# > > > > [cluster_id=346] N_children: 0 N_samples: 10
# > > > > [cluster_id=347] N_children: 0 N_samples: 10
# > > > > [cluster_id=348] N_children: 0 N_samples: 15
# > > > > [cluster_id=349] N_children: 0 N_samples: 7
# > > > > [cluster_id=350] N_children: 0 N_samples: 14
# > > > > [cluster_id=351] N_children: 0 N_samples: 6
# > > > > [cluster_id=352] N_children: 0 N_samples: 11
# > > > > [cluster_id=353] N_children: 0 N_samples: 8
# > > > > [cluster_id=354] N_children: 0 N_samples: 15
# > > > > [cluster_id=355] N_children: 0 N_samples: 14
# > > > > [cluster_id=356] N_children: 0 N_samples: 15
# > > > [cluster_id=357] N_children: 12 N_samples: 165
# > > > > [cluster_id=358] N_children: 0 N_samples: 11
# > > > > [cluster_id=359] N_children: 0 N_samples: 19
# > > > > [cluster_id=360] N_children: 0 N_samples: 8
# > > > > [cluster_id=361] N_children: 0 N_samples: 14
# > > > > [cluster_id=362] N_children: 0 N_samples: 20
# > > > > [cluster_id=363] N_children: 0 N_samples: 15
# > > > > [cluster_id=364] N_children: 0 N_samples: 14
# > > > > [cluster_id=365] N_children: 0 N_samples: 8
# > > > > [cluster_id=366] N_children: 0 N_samples: 15
# > > > > [cluster_id=367] N_children: 0 N_samples: 13
# > > > > [cluster_id=368] N_children: 0 N_samples: 13
# > > > > [cluster_id=369] N_children: 0 N_samples: 15
# > > > [cluster_id=370] N_children: 0 N_samples: 6
# > > > [cluster_id=371] N_children: 11 N_samples: 171
# > > > > [cluster_id=372] N_children: 0 N_samples: 18
# > > > > [cluster_id=373] N_children: 0 N_samples: 20
# > > > > [cluster_id=374] N_children: 0 N_samples: 18
# > > > > [cluster_id=375] N_children: 0 N_samples: 12
# > > > > [cluster_id=376] N_children: 0 N_samples: 12
# > > > > [cluster_id=377] N_children: 0 N_samples: 20
# > > > > [cluster_id=378] N_children: 0 N_samples: 15
# > > > > [cluster_id=379] N_children: 0 N_samples: 17
# > > > > [cluster_id=380] N_children: 0 N_samples: 14
# > > > > [cluster_id=381] N_children: 0 N_samples: 10
# > > > > [cluster_id=382] N_children: 0 N_samples: 15
# > > > [cluster_id=383] N_children: 19 N_samples: 207
# > > > > [cluster_id=384] N_children: 0 N_samples: 8
# > > > > [cluster_id=385] N_children: 0 N_samples: 1
# > > > > [cluster_id=386] N_children: 0 N_samples: 11
# > > > > [cluster_id=387] N_children: 0 N_samples: 10
# > > > > [cluster_id=388] N_children: 0 N_samples: 19
# > > > > [cluster_id=389] N_children: 0 N_samples: 3
# > > > > [cluster_id=390] N_children: 0 N_samples: 19
# > > > > [cluster_id=391] N_children: 0 N_samples: 17
# > > > > [cluster_id=392] N_children: 0 N_samples: 8
# > > > > [cluster_id=393] N_children: 0 N_samples: 1
# > > > > [cluster_id=394] N_children: 0 N_samples: 14
# > > > > [cluster_id=395] N_children: 0 N_samples: 8
# > > > > [cluster_id=396] N_children: 0 N_samples: 14
# > > > > [cluster_id=397] N_children: 0 N_samples: 15
# > > > > [cluster_id=398] N_children: 0 N_samples: 5
# > > > > [cluster_id=399] N_children: 0 N_samples: 7
# > > > > [cluster_id=400] N_children: 0 N_samples: 20
# > > > > [cluster_id=401] N_children: 0 N_samples: 20
# > > > > [cluster_id=402] N_children: 0 N_samples: 7
# > > [cluster_id=403] N_children: 14 N_samples: 1692
# > > > [cluster_id=404] N_children: 0 N_samples: 8
# > > > [cluster_id=405] N_children: 11 N_samples: 113
# > > > > [cluster_id=406] N_children: 0 N_samples: 12
# > > > > [cluster_id=407] N_children: 0 N_samples: 13
# > > > > [cluster_id=408] N_children: 0 N_samples: 17
# > > > > [cluster_id=409] N_children: 0 N_samples: 7
# > > > > [cluster_id=410] N_children: 0 N_samples: 9
# > > > > [cluster_id=411] N_children: 0 N_samples: 6
# > > > > [cluster_id=412] N_children: 0 N_samples: 10
# > > > > [cluster_id=413] N_children: 0 N_samples: 13
# > > > > [cluster_id=414] N_children: 0 N_samples: 6
# > > > > [cluster_id=415] N_children: 0 N_samples: 4
# > > > > [cluster_id=416] N_children: 0 N_samples: 16
# > > > [cluster_id=417] N_children: 5 N_samples: 54
# > > > > [cluster_id=418] N_children: 0 N_samples: 10
# > > > > [cluster_id=419] N_children: 0 N_samples: 18
# > > > > [cluster_id=420] N_children: 0 N_samples: 2
# > > > > [cluster_id=421] N_children: 0 N_samples: 15
# > > > > [cluster_id=422] N_children: 0 N_samples: 9
# > > > [cluster_id=423] N_children: 10 N_samples: 129
# > > > > [cluster_id=424] N_children: 0 N_samples: 10
# > > > > [cluster_id=425] N_children: 0 N_samples: 15
# > > > > [cluster_id=426] N_children: 0 N_samples: 1
# > > > > [cluster_id=427] N_children: 0 N_samples: 6
# > > > > [cluster_id=428] N_children: 0 N_samples: 20
# > > > > [cluster_id=429] N_children: 0 N_samples: 3
# > > > > [cluster_id=430] N_children: 0 N_samples: 20
# > > > > [cluster_id=431] N_children: 0 N_samples: 18
# > > > > [cluster_id=432] N_children: 0 N_samples: 20
# > > > > [cluster_id=433] N_children: 0 N_samples: 16
# > > > [cluster_id=434] N_children: 0 N_samples: 1
# > > > [cluster_id=435] N_children: 11 N_samples: 146
# > > > > [cluster_id=436] N_children: 0 N_samples: 16
# > > > > [cluster_id=437] N_children: 0 N_samples: 19
# > > > > [cluster_id=438] N_children: 0 N_samples: 5
# > > > > [cluster_id=439] N_children: 0 N_samples: 20
# > > > > [cluster_id=440] N_children: 0 N_samples: 14
# > > > > [cluster_id=441] N_children: 0 N_samples: 20
# > > > > [cluster_id=442] N_children: 0 N_samples: 12
# > > > > [cluster_id=443] N_children: 0 N_samples: 15
# > > > > [cluster_id=444] N_children: 0 N_samples: 14
# > > > > [cluster_id=445] N_children: 0 N_samples: 10
# > > > > [cluster_id=446] N_children: 0 N_samples: 1
# > > > [cluster_id=447] N_children: 0 N_samples: 4
# > > > [cluster_id=448] N_children: 19 N_samples: 238
# > > > > [cluster_id=449] N_children: 0 N_samples: 17
# > > > > [cluster_id=450] N_children: 0 N_samples: 11
# > > > > [cluster_id=451] N_children: 0 N_samples: 1
# > > > > [cluster_id=452] N_children: 0 N_samples: 12
# > > > > [cluster_id=453] N_children: 0 N_samples: 8
# > > > > [cluster_id=454] N_children: 0 N_samples: 8
# > > > > [cluster_id=455] N_children: 0 N_samples: 16
# > > > > [cluster_id=456] N_children: 0 N_samples: 12
# > > > > [cluster_id=457] N_children: 0 N_samples: 5
# > > > > [cluster_id=458] N_children: 0 N_samples: 18
# > > > > [cluster_id=459] N_children: 0 N_samples: 19
# > > > > [cluster_id=460] N_children: 0 N_samples: 16
# > > > > [cluster_id=461] N_children: 0 N_samples: 20
# > > > > [cluster_id=462] N_children: 0 N_samples: 20
# > > > > [cluster_id=463] N_children: 0 N_samples: 3
# > > > > [cluster_id=464] N_children: 0 N_samples: 15
# > > > > [cluster_id=465] N_children: 0 N_samples: 6
# > > > > [cluster_id=466] N_children: 0 N_samples: 14
# > > > > [cluster_id=467] N_children: 0 N_samples: 17
# > > > [cluster_id=468] N_children: 12 N_samples: 142
# > > > > [cluster_id=469] N_children: 0 N_samples: 7
# > > > > [cluster_id=470] N_children: 0 N_samples: 7
# > > > > [cluster_id=471] N_children: 0 N_samples: 18
# > > > > [cluster_id=472] N_children: 0 N_samples: 13
# > > > > [cluster_id=473] N_children: 0 N_samples: 12
# > > > > [cluster_id=474] N_children: 0 N_samples: 10
# > > > > [cluster_id=475] N_children: 0 N_samples: 15
# > > > > [cluster_id=476] N_children: 0 N_samples: 14
# > > > > [cluster_id=477] N_children: 0 N_samples: 2
# > > > > [cluster_id=478] N_children: 0 N_samples: 20
# > > > > [cluster_id=479] N_children: 0 N_samples: 16
# > > > > [cluster_id=480] N_children: 0 N_samples: 8
# > > > [cluster_id=481] N_children: 14 N_samples: 137
# > > > > [cluster_id=482] N_children: 0 N_samples: 17
# > > > > [cluster_id=483] N_children: 0 N_samples: 10
# > > > > [cluster_id=484] N_children: 0 N_samples: 9
# > > > > [cluster_id=485] N_children: 0 N_samples: 8
# > > > > [cluster_id=486] N_children: 0 N_samples: 14
# > > > > [cluster_id=487] N_children: 0 N_samples: 9
# > > > > [cluster_id=488] N_children: 0 N_samples: 2
# > > > > [cluster_id=489] N_children: 0 N_samples: 2
# > > > > [cluster_id=490] N_children: 0 N_samples: 19
# > > > > [cluster_id=491] N_children: 0 N_samples: 3
# > > > > [cluster_id=492] N_children: 0 N_samples: 3
# > > > > [cluster_id=493] N_children: 0 N_samples: 20
# > > > > [cluster_id=494] N_children: 0 N_samples: 18
# > > > > [cluster_id=495] N_children: 0 N_samples: 3
# > > > [cluster_id=496] N_children: 9 N_samples: 103
# > > > > [cluster_id=497] N_children: 0 N_samples: 6
# > > > > [cluster_id=498] N_children: 0 N_samples: 13
# > > > > [cluster_id=499] N_children: 0 N_samples: 9
# > > > > [cluster_id=500] N_children: 0 N_samples: 10
# > > > > [cluster_id=501] N_children: 0 N_samples: 11
# > > > > [cluster_id=502] N_children: 0 N_samples: 15
# > > > > [cluster_id=503] N_children: 0 N_samples: 13
# > > > > [cluster_id=504] N_children: 0 N_samples: 17
# > > > > [cluster_id=505] N_children: 0 N_samples: 9
# > > > [cluster_id=506] N_children: 15 N_samples: 189
# > > > > [cluster_id=507] N_children: 0 N_samples: 15
# > > > > [cluster_id=508] N_children: 0 N_samples: 4
# > > > > [cluster_id=509] N_children: 0 N_samples: 11
# > > > > [cluster_id=510] N_children: 0 N_samples: 11
# > > > > [cluster_id=511] N_children: 0 N_samples: 13
# > > > > [cluster_id=512] N_children: 0 N_samples: 20
# > > > > [cluster_id=513] N_children: 0 N_samples: 16
# > > > > [cluster_id=514] N_children: 0 N_samples: 12
# > > > > [cluster_id=515] N_children: 0 N_samples: 13
# > > > > [cluster_id=516] N_children: 0 N_samples: 6
# > > > > [cluster_id=517] N_children: 0 N_samples: 11
# > > > > [cluster_id=518] N_children: 0 N_samples: 11
# > > > > [cluster_id=519] N_children: 0 N_samples: 13
# > > > > [cluster_id=520] N_children: 0 N_samples: 16
# > > > > [cluster_id=521] N_children: 0 N_samples: 17
# > > > [cluster_id=522] N_children: 20 N_samples: 274
# > > > > [cluster_id=523] N_children: 0 N_samples: 5
# > > > > [cluster_id=524] N_children: 0 N_samples: 19
# > > > > [cluster_id=525] N_children: 0 N_samples: 16
# > > > > [cluster_id=526] N_children: 0 N_samples: 13
# > > > > [cluster_id=527] N_children: 0 N_samples: 10
# > > > > [cluster_id=528] N_children: 0 N_samples: 15
# > > > > [cluster_id=529] N_children: 0 N_samples: 8
# > > > > [cluster_id=530] N_children: 0 N_samples: 15
# > > > > [cluster_id=531] N_children: 0 N_samples: 19
# > > > > [cluster_id=532] N_children: 0 N_samples: 13
# > > > > [cluster_id=533] N_children: 0 N_samples: 17
# > > > > [cluster_id=534] N_children: 0 N_samples: 19
# > > > > [cluster_id=535] N_children: 0 N_samples: 15
# > > > > [cluster_id=536] N_children: 0 N_samples: 8
# > > > > [cluster_id=537] N_children: 0 N_samples: 19
# > > > > [cluster_id=538] N_children: 0 N_samples: 3
# > > > > [cluster_id=539] N_children: 0 N_samples: 11
# > > > > [cluster_id=540] N_children: 0 N_samples: 16
# > > > > [cluster_id=541] N_children: 0 N_samples: 18
# > > > > [cluster_id=542] N_children: 0 N_samples: 15
# > > > [cluster_id=543] N_children: 12 N_samples: 154
# > > > > [cluster_id=544] N_children: 0 N_samples: 14
# > > > > [cluster_id=545] N_children: 0 N_samples: 15
# > > > > [cluster_id=546] N_children: 0 N_samples: 2
# > > > > [cluster_id=547] N_children: 0 N_samples: 13
# > > > > [cluster_id=548] N_children: 0 N_samples: 15
# > > > > [cluster_id=549] N_children: 0 N_samples: 9
# > > > > [cluster_id=550] N_children: 0 N_samples: 19
# > > > > [cluster_id=551] N_children: 0 N_samples: 13
# > > > > [cluster_id=552] N_children: 0 N_samples: 11
# > > > > [cluster_id=553] N_children: 0 N_samples: 20
# > > > > [cluster_id=554] N_children: 0 N_samples: 11
# > > > > [cluster_id=555] N_children: 0 N_samples: 12
# > > [cluster_id=556] N_children: 7 N_samples: 1553
# > > > [cluster_id=557] N_children: 13 N_samples: 296
# > > > > [cluster_id=558] N_children: 0 N_samples: 16
# > > > > [cluster_id=559] N_children: 0 N_samples: 17
# > > > > [cluster_id=560] N_children: 0 N_samples: 13
# > > > > [cluster_id=561] N_children: 0 N_samples: 13
# > > > > [cluster_id=562] N_children: 0 N_samples: 8
# > > > > [cluster_id=563] N_children: 0 N_samples: 13
# > > > > [cluster_id=564] N_children: 0 N_samples: 3
# > > > > [cluster_id=565] N_children: 0 N_samples: 4
# > > > > [cluster_id=566] N_children: 0 N_samples: 16
# > > > > [cluster_id=567] N_children: 0 N_samples: 11
# > > > > [cluster_id=568] N_children: 0 N_samples: 11
# > > > > [cluster_id=569] N_children: 0 N_samples: 157
# > > > > [cluster_id=570] N_children: 0 N_samples: 14
# > > > [cluster_id=571] N_children: 16 N_samples: 158
# > > > > [cluster_id=572] N_children: 0 N_samples: 1
# > > > > [cluster_id=573] N_children: 0 N_samples: 10
# > > > > [cluster_id=574] N_children: 0 N_samples: 5
# > > > > [cluster_id=575] N_children: 0 N_samples: 6
# > > > > [cluster_id=576] N_children: 0 N_samples: 11
# > > > > [cluster_id=577] N_children: 0 N_samples: 1
# > > > > [cluster_id=578] N_children: 0 N_samples: 1
# > > > > [cluster_id=579] N_children: 0 N_samples: 13
# > > > > [cluster_id=580] N_children: 0 N_samples: 15
# > > > > [cluster_id=581] N_children: 0 N_samples: 14
# > > > > [cluster_id=582] N_children: 0 N_samples: 13
# > > > > [cluster_id=583] N_children: 0 N_samples: 13
# > > > > [cluster_id=584] N_children: 0 N_samples: 11
# > > > > [cluster_id=585] N_children: 0 N_samples: 5
# > > > > [cluster_id=586] N_children: 0 N_samples: 21
# > > > > [cluster_id=587] N_children: 0 N_samples: 18
# > > > [cluster_id=588] N_children: 14 N_samples: 203
# > > > > [cluster_id=589] N_children: 0 N_samples: 16
# > > > > [cluster_id=590] N_children: 0 N_samples: 10
# > > > > [cluster_id=591] N_children: 0 N_samples: 17
# > > > > [cluster_id=592] N_children: 0 N_samples: 19
# > > > > [cluster_id=593] N_children: 0 N_samples: 17
# > > > > [cluster_id=594] N_children: 0 N_samples: 11
# > > > > [cluster_id=595] N_children: 0 N_samples: 16
# > > > > [cluster_id=596] N_children: 0 N_samples: 22
# > > > > [cluster_id=597] N_children: 0 N_samples: 17
# > > > > [cluster_id=598] N_children: 0 N_samples: 18
# > > > > [cluster_id=599] N_children: 0 N_samples: 12
# > > > > [cluster_id=600] N_children: 0 N_samples: 8
# > > > > [cluster_id=601] N_children: 0 N_samples: 7
# > > > > [cluster_id=602] N_children: 0 N_samples: 13
# > > > [cluster_id=603] N_children: 14 N_samples: 201
# > > > > [cluster_id=604] N_children: 0 N_samples: 10
# > > > > [cluster_id=605] N_children: 0 N_samples: 15
# > > > > [cluster_id=606] N_children: 0 N_samples: 12
# > > > > [cluster_id=607] N_children: 0 N_samples: 21
# > > > > [cluster_id=608] N_children: 0 N_samples: 18
# > > > > [cluster_id=609] N_children: 0 N_samples: 17
# > > > > [cluster_id=610] N_children: 0 N_samples: 14
# > > > > [cluster_id=611] N_children: 0 N_samples: 20
# > > > > [cluster_id=612] N_children: 0 N_samples: 16
# > > > > [cluster_id=613] N_children: 0 N_samples: 14
# > > > > [cluster_id=614] N_children: 0 N_samples: 10
# > > > > [cluster_id=615] N_children: 0 N_samples: 11
# > > > > [cluster_id=616] N_children: 0 N_samples: 11
# > > > > [cluster_id=617] N_children: 0 N_samples: 12
# > > > [cluster_id=618] N_children: 18 N_samples: 222
# > > > > [cluster_id=619] N_children: 0 N_samples: 2
# > > > > [cluster_id=620] N_children: 0 N_samples: 23
# > > > > [cluster_id=621] N_children: 0 N_samples: 22
# > > > > [cluster_id=622] N_children: 0 N_samples: 10
# > > > > [cluster_id=623] N_children: 0 N_samples: 5
# > > > > [cluster_id=624] N_children: 0 N_samples: 10
# > > > > [cluster_id=625] N_children: 0 N_samples: 5
# > > > > [cluster_id=626] N_children: 0 N_samples: 22
# > > > > [cluster_id=627] N_children: 0 N_samples: 2
# > > > > [cluster_id=628] N_children: 0 N_samples: 16
# > > > > [cluster_id=629] N_children: 0 N_samples: 3
# > > > > [cluster_id=630] N_children: 0 N_samples: 3
# > > > > [cluster_id=631] N_children: 0 N_samples: 19
# > > > > [cluster_id=632] N_children: 0 N_samples: 10
# > > > > [cluster_id=633] N_children: 0 N_samples: 3
# > > > > [cluster_id=634] N_children: 0 N_samples: 33
# > > > > [cluster_id=635] N_children: 0 N_samples: 24
# > > > > [cluster_id=636] N_children: 0 N_samples: 10
# > > > [cluster_id=637] N_children: 15 N_samples: 196
# > > > > [cluster_id=638] N_children: 0 N_samples: 18
# > > > > [cluster_id=639] N_children: 0 N_samples: 19
# > > > > [cluster_id=640] N_children: 0 N_samples: 4
# > > > > [cluster_id=641] N_children: 0 N_samples: 13
# > > > > [cluster_id=642] N_children: 0 N_samples: 18
# > > > > [cluster_id=643] N_children: 0 N_samples: 4
# > > > > [cluster_id=644] N_children: 0 N_samples: 17
# > > > > [cluster_id=645] N_children: 0 N_samples: 12
# > > > > [cluster_id=646] N_children: 0 N_samples: 20
# > > > > [cluster_id=647] N_children: 0 N_samples: 9
# > > > > [cluster_id=648] N_children: 0 N_samples: 10
# > > > > [cluster_id=649] N_children: 0 N_samples: 21
# > > > > [cluster_id=650] N_children: 0 N_samples: 13
# > > > > [cluster_id=651] N_children: 0 N_samples: 10
# > > > > [cluster_id=652] N_children: 0 N_samples: 8
# > > > [cluster_id=653] N_children: 20 N_samples: 277
# > > > > [cluster_id=654] N_children: 0 N_samples: 9
# > > > > [cluster_id=655] N_children: 0 N_samples: 9
# > > > > [cluster_id=656] N_children: 0 N_samples: 19
# > > > > [cluster_id=657] N_children: 0 N_samples: 2
# > > > > [cluster_id=658] N_children: 0 N_samples: 16
# > > > > [cluster_id=659] N_children: 0 N_samples: 10
# > > > > [cluster_id=660] N_children: 0 N_samples: 26
# > > > > [cluster_id=661] N_children: 0 N_samples: 11
# > > > > [cluster_id=662] N_children: 0 N_samples: 7
# > > > > [cluster_id=663] N_children: 0 N_samples: 17
# > > > > [cluster_id=664] N_children: 0 N_samples: 17
# > > > > [cluster_id=665] N_children: 0 N_samples: 10
# > > > > [cluster_id=666] N_children: 0 N_samples: 11
# > > > > [cluster_id=667] N_children: 0 N_samples: 6
# > > > > [cluster_id=668] N_children: 0 N_samples: 9
# > > > > [cluster_id=669] N_children: 0 N_samples: 19
# > > > > [cluster_id=670] N_children: 0 N_samples: 22
# > > > > [cluster_id=671] N_children: 0 N_samples: 12
# > > > > [cluster_id=672] N_children: 0 N_samples: 14
# > > > > [cluster_id=673] N_children: 0 N_samples: 31
# > > [cluster_id=674] N_children: 5 N_samples: 782
# > > > [cluster_id=675] N_children: 18 N_samples: 209
# > > > > [cluster_id=676] N_children: 0 N_samples: 8
# > > > > [cluster_id=677] N_children: 0 N_samples: 8
# > > > > [cluster_id=678] N_children: 0 N_samples: 6
# > > > > [cluster_id=679] N_children: 0 N_samples: 16
# > > > > [cluster_id=680] N_children: 0 N_samples: 17
# > > > > [cluster_id=681] N_children: 0 N_samples: 16
# > > > > [cluster_id=682] N_children: 0 N_samples: 20
# > > > > [cluster_id=683] N_children: 0 N_samples: 8
# > > > > [cluster_id=684] N_children: 0 N_samples: 4
# > > > > [cluster_id=685] N_children: 0 N_samples: 7
# > > > > [cluster_id=686] N_children: 0 N_samples: 18
# > > > > [cluster_id=687] N_children: 0 N_samples: 10
# > > > > [cluster_id=688] N_children: 0 N_samples: 14
# > > > > [cluster_id=689] N_children: 0 N_samples: 13
# > > > > [cluster_id=690] N_children: 0 N_samples: 12
# > > > > [cluster_id=691] N_children: 0 N_samples: 10
# > > > > [cluster_id=692] N_children: 0 N_samples: 17
# > > > > [cluster_id=693] N_children: 0 N_samples: 5
# > > > [cluster_id=694] N_children: 17 N_samples: 179
# > > > > [cluster_id=695] N_children: 0 N_samples: 10
# > > > > [cluster_id=696] N_children: 0 N_samples: 3
# > > > > [cluster_id=697] N_children: 0 N_samples: 18
# > > > > [cluster_id=698] N_children: 0 N_samples: 6
# > > > > [cluster_id=699] N_children: 0 N_samples: 8
# > > > > [cluster_id=700] N_children: 0 N_samples: 8
# > > > > [cluster_id=701] N_children: 0 N_samples: 16
# > > > > [cluster_id=702] N_children: 0 N_samples: 3
# > > > > [cluster_id=703] N_children: 0 N_samples: 12
# > > > > [cluster_id=704] N_children: 0 N_samples: 13
# > > > > [cluster_id=705] N_children: 0 N_samples: 11
# > > > > [cluster_id=706] N_children: 0 N_samples: 15
# > > > > [cluster_id=707] N_children: 0 N_samples: 18
# > > > > [cluster_id=708] N_children: 0 N_samples: 7
# > > > > [cluster_id=709] N_children: 0 N_samples: 16
# > > > > [cluster_id=710] N_children: 0 N_samples: 3
# > > > > [cluster_id=711] N_children: 0 N_samples: 12
# > > > [cluster_id=712] N_children: 16 N_samples: 196
# > > > > [cluster_id=713] N_children: 0 N_samples: 16
# > > > > [cluster_id=714] N_children: 0 N_samples: 11
# > > > > [cluster_id=715] N_children: 0 N_samples: 16
# > > > > [cluster_id=716] N_children: 0 N_samples: 16
# > > > > [cluster_id=717] N_children: 0 N_samples: 12
# > > > > [cluster_id=718] N_children: 0 N_samples: 16
# > > > > [cluster_id=719] N_children: 0 N_samples: 17
# > > > > [cluster_id=720] N_children: 0 N_samples: 7
# > > > > [cluster_id=721] N_children: 0 N_samples: 6
# > > > > [cluster_id=722] N_children: 0 N_samples: 17
# > > > > [cluster_id=723] N_children: 0 N_samples: 14
# > > > > [cluster_id=724] N_children: 0 N_samples: 4
# > > > > [cluster_id=725] N_children: 0 N_samples: 8
# > > > > [cluster_id=726] N_children: 0 N_samples: 14
# > > > > [cluster_id=727] N_children: 0 N_samples: 16
# > > > > [cluster_id=728] N_children: 0 N_samples: 6
# > > > [cluster_id=729] N_children: 11 N_samples: 142
# > > > > [cluster_id=730] N_children: 0 N_samples: 7
# > > > > [cluster_id=731] N_children: 0 N_samples: 12
# > > > > [cluster_id=732] N_children: 0 N_samples: 11
# > > > > [cluster_id=733] N_children: 0 N_samples: 11
# > > > > [cluster_id=734] N_children: 0 N_samples: 19
# > > > > [cluster_id=735] N_children: 0 N_samples: 11
# > > > > [cluster_id=736] N_children: 0 N_samples: 9
# > > > > [cluster_id=737] N_children: 0 N_samples: 10
# > > > > [cluster_id=738] N_children: 0 N_samples: 20
# > > > > [cluster_id=739] N_children: 0 N_samples: 19
# > > > > [cluster_id=740] N_children: 0 N_samples: 13
# > > > [cluster_id=741] N_children: 5 N_samples: 56
# > > > > [cluster_id=742] N_children: 0 N_samples: 15
# > > > > [cluster_id=743] N_children: 0 N_samples: 20
# > > > > [cluster_id=744] N_children: 0 N_samples: 1
# > > > > [cluster_id=745] N_children: 0 N_samples: 16
# > > > > [cluster_id=746] N_children: 0 N_samples: 4
# > > [cluster_id=747] N_children: 9 N_samples: 1327
# > > > [cluster_id=748] N_children: 5 N_samples: 62
# > > > > [cluster_id=749] N_children: 0 N_samples: 14
# > > > > [cluster_id=750] N_children: 0 N_samples: 8
# > > > > [cluster_id=751] N_children: 0 N_samples: 11
# > > > > [cluster_id=752] N_children: 0 N_samples: 20
# > > > > [cluster_id=753] N_children: 0 N_samples: 9
# > > > [cluster_id=754] N_children: 9 N_samples: 119
# > > > > [cluster_id=755] N_children: 0 N_samples: 14
# > > > > [cluster_id=756] N_children: 0 N_samples: 7
# > > > > [cluster_id=757] N_children: 0 N_samples: 15
# > > > > [cluster_id=758] N_children: 0 N_samples: 7
# > > > > [cluster_id=759] N_children: 0 N_samples: 13
# > > > > [cluster_id=760] N_children: 0 N_samples: 12
# > > > > [cluster_id=761] N_children: 0 N_samples: 20
# > > > > [cluster_id=762] N_children: 0 N_samples: 16
# > > > > [cluster_id=763] N_children: 0 N_samples: 15
# > > > [cluster_id=764] N_children: 17 N_samples: 208
# > > > > [cluster_id=765] N_children: 0 N_samples: 13
# > > > > [cluster_id=766] N_children: 0 N_samples: 15
# > > > > [cluster_id=767] N_children: 0 N_samples: 2
# > > > > [cluster_id=768] N_children: 0 N_samples: 11
# > > > > [cluster_id=769] N_children: 0 N_samples: 13
# > > > > [cluster_id=770] N_children: 0 N_samples: 11
# > > > > [cluster_id=771] N_children: 0 N_samples: 17
# > > > > [cluster_id=772] N_children: 0 N_samples: 11
# > > > > [cluster_id=773] N_children: 0 N_samples: 12
# > > > > [cluster_id=774] N_children: 0 N_samples: 4
# > > > > [cluster_id=775] N_children: 0 N_samples: 12
# > > > > [cluster_id=776] N_children: 0 N_samples: 14
# > > > > [cluster_id=777] N_children: 0 N_samples: 10
# > > > > [cluster_id=778] N_children: 0 N_samples: 13
# > > > > [cluster_id=779] N_children: 0 N_samples: 13
# > > > > [cluster_id=780] N_children: 0 N_samples: 18
# > > > > [cluster_id=781] N_children: 0 N_samples: 19
# > > > [cluster_id=782] N_children: 17 N_samples: 237
# > > > > [cluster_id=783] N_children: 0 N_samples: 19
# > > > > [cluster_id=784] N_children: 0 N_samples: 18
# > > > > [cluster_id=785] N_children: 0 N_samples: 12
# > > > > [cluster_id=786] N_children: 0 N_samples: 17
# > > > > [cluster_id=787] N_children: 0 N_samples: 18
# > > > > [cluster_id=788] N_children: 0 N_samples: 17
# > > > > [cluster_id=789] N_children: 0 N_samples: 10
# > > > > [cluster_id=790] N_children: 0 N_samples: 10
# > > > > [cluster_id=791] N_children: 0 N_samples: 15
# > > > > [cluster_id=792] N_children: 0 N_samples: 14
# > > > > [cluster_id=793] N_children: 0 N_samples: 19
# > > > > [cluster_id=794] N_children: 0 N_samples: 18
# > > > > [cluster_id=795] N_children: 0 N_samples: 6
# > > > > [cluster_id=796] N_children: 0 N_samples: 10
# > > > > [cluster_id=797] N_children: 0 N_samples: 10
# > > > > [cluster_id=798] N_children: 0 N_samples: 13
# > > > > [cluster_id=799] N_children: 0 N_samples: 11
# > > > [cluster_id=800] N_children: 2 N_samples: 33
# > > > > [cluster_id=801] N_children: 0 N_samples: 18
# > > > > [cluster_id=802] N_children: 0 N_samples: 15
# > > > [cluster_id=803] N_children: 10 N_samples: 142
# > > > > [cluster_id=804] N_children: 0 N_samples: 14
# > > > > [cluster_id=805] N_children: 0 N_samples: 14
# > > > > [cluster_id=806] N_children: 0 N_samples: 19
# > > > > [cluster_id=807] N_children: 0 N_samples: 11
# > > > > [cluster_id=808] N_children: 0 N_samples: 15
# > > > > [cluster_id=809] N_children: 0 N_samples: 17
# > > > > [cluster_id=810] N_children: 0 N_samples: 20
# > > > > [cluster_id=811] N_children: 0 N_samples: 12
# > > > > [cluster_id=812] N_children: 0 N_samples: 8
# > > > > [cluster_id=813] N_children: 0 N_samples: 12
# > > > [cluster_id=814] N_children: 6 N_samples: 59
# > > > > [cluster_id=815] N_children: 0 N_samples: 13
# > > > > [cluster_id=816] N_children: 0 N_samples: 20
# > > > > [cluster_id=817] N_children: 0 N_samples: 1
# > > > > [cluster_id=818] N_children: 0 N_samples: 3
# > > > > [cluster_id=819] N_children: 0 N_samples: 19
# > > > > [cluster_id=820] N_children: 0 N_samples: 3
# > > > [cluster_id=821] N_children: 19 N_samples: 281
# > > > > [cluster_id=822] N_children: 0 N_samples: 8
# > > > > [cluster_id=823] N_children: 0 N_samples: 21
# > > > > [cluster_id=824] N_children: 0 N_samples: 12
# > > > > [cluster_id=825] N_children: 0 N_samples: 14
# > > > > [cluster_id=826] N_children: 0 N_samples: 18
# > > > > [cluster_id=827] N_children: 0 N_samples: 19
# > > > > [cluster_id=828] N_children: 0 N_samples: 19
# > > > > [cluster_id=829] N_children: 0 N_samples: 11
# > > > > [cluster_id=830] N_children: 0 N_samples: 14
# > > > > [cluster_id=831] N_children: 0 N_samples: 28
# > > > > [cluster_id=832] N_children: 0 N_samples: 1
# > > > > [cluster_id=833] N_children: 0 N_samples: 19
# > > > > [cluster_id=834] N_children: 0 N_samples: 7
# > > > > [cluster_id=835] N_children: 0 N_samples: 20
# > > > > [cluster_id=836] N_children: 0 N_samples: 10
# > > > > [cluster_id=837] N_children: 0 N_samples: 20
# > > > > [cluster_id=838] N_children: 0 N_samples: 19
# > > > > [cluster_id=839] N_children: 0 N_samples: 9
# > > > > [cluster_id=840] N_children: 0 N_samples: 12
# > > > [cluster_id=841] N_children: 16 N_samples: 186
# > > > > [cluster_id=842] N_children: 0 N_samples: 13
# > > > > [cluster_id=843] N_children: 0 N_samples: 13
# > > > > [cluster_id=844] N_children: 0 N_samples: 15
# > > > > [cluster_id=845] N_children: 0 N_samples: 4
# > > > > [cluster_id=846] N_children: 0 N_samples: 3
# > > > > [cluster_id=847] N_children: 0 N_samples: 17
# > > > > [cluster_id=848] N_children: 0 N_samples: 19
# > > > > [cluster_id=849] N_children: 0 N_samples: 12
# > > > > [cluster_id=850] N_children: 0 N_samples: 13
# > > > > [cluster_id=851] N_children: 0 N_samples: 20
# > > > > [cluster_id=852] N_children: 0 N_samples: 2
# > > > > [cluster_id=853] N_children: 0 N_samples: 9
# > > > > [cluster_id=854] N_children: 0 N_samples: 11
# > > > > [cluster_id=855] N_children: 0 N_samples: 11
# > > > > [cluster_id=856] N_children: 0 N_samples: 11
# > > > > [cluster_id=857] N_children: 0 N_samples: 13
# > > [cluster_id=858] N_children: 16 N_samples: 2327
# > > > [cluster_id=859] N_children: 13 N_samples: 153
# > > > > [cluster_id=860] N_children: 0 N_samples: 7
# > > > > [cluster_id=861] N_children: 0 N_samples: 17
# > > > > [cluster_id=862] N_children: 0 N_samples: 12
# > > > > [cluster_id=863] N_children: 0 N_samples: 19
# > > > > [cluster_id=864] N_children: 0 N_samples: 12
# > > > > [cluster_id=865] N_children: 0 N_samples: 10
# > > > > [cluster_id=866] N_children: 0 N_samples: 16
# > > > > [cluster_id=867] N_children: 0 N_samples: 5
# > > > > [cluster_id=868] N_children: 0 N_samples: 7
# > > > > [cluster_id=869] N_children: 0 N_samples: 14
# > > > > [cluster_id=870] N_children: 0 N_samples: 6
# > > > > [cluster_id=871] N_children: 0 N_samples: 9
# > > > > [cluster_id=872] N_children: 0 N_samples: 19
# > > > [cluster_id=873] N_children: 11 N_samples: 133
# > > > > [cluster_id=874] N_children: 0 N_samples: 16
# > > > > [cluster_id=875] N_children: 0 N_samples: 1
# > > > > [cluster_id=876] N_children: 0 N_samples: 14
# > > > > [cluster_id=877] N_children: 0 N_samples: 17
# > > > > [cluster_id=878] N_children: 0 N_samples: 18
# > > > > [cluster_id=879] N_children: 0 N_samples: 4
# > > > > [cluster_id=880] N_children: 0 N_samples: 11
# > > > > [cluster_id=881] N_children: 0 N_samples: 13
# > > > > [cluster_id=882] N_children: 0 N_samples: 17
# > > > > [cluster_id=883] N_children: 0 N_samples: 11
# > > > > [cluster_id=884] N_children: 0 N_samples: 11
# > > > [cluster_id=885] N_children: 13 N_samples: 177
# > > > > [cluster_id=886] N_children: 0 N_samples: 14
# > > > > [cluster_id=887] N_children: 0 N_samples: 15
# > > > > [cluster_id=888] N_children: 0 N_samples: 14
# > > > > [cluster_id=889] N_children: 0 N_samples: 14
# > > > > [cluster_id=890] N_children: 0 N_samples: 19
# > > > > [cluster_id=891] N_children: 0 N_samples: 10
# > > > > [cluster_id=892] N_children: 0 N_samples: 9
# > > > > [cluster_id=893] N_children: 0 N_samples: 17
# > > > > [cluster_id=894] N_children: 0 N_samples: 17
# > > > > [cluster_id=895] N_children: 0 N_samples: 19
# > > > > [cluster_id=896] N_children: 0 N_samples: 12
# > > > > [cluster_id=897] N_children: 0 N_samples: 6
# > > > > [cluster_id=898] N_children: 0 N_samples: 11
# > > > [cluster_id=899] N_children: 15 N_samples: 149
# > > > > [cluster_id=900] N_children: 0 N_samples: 4
# > > > > [cluster_id=901] N_children: 0 N_samples: 5
# > > > > [cluster_id=902] N_children: 0 N_samples: 11
# > > > > [cluster_id=903] N_children: 0 N_samples: 17
# > > > > [cluster_id=904] N_children: 0 N_samples: 6
# > > > > [cluster_id=905] N_children: 0 N_samples: 16
# > > > > [cluster_id=906] N_children: 0 N_samples: 11
# > > > > [cluster_id=907] N_children: 0 N_samples: 4
# > > > > [cluster_id=908] N_children: 0 N_samples: 15
# > > > > [cluster_id=909] N_children: 0 N_samples: 17
# > > > > [cluster_id=910] N_children: 0 N_samples: 7
# > > > > [cluster_id=911] N_children: 0 N_samples: 3
# > > > > [cluster_id=912] N_children: 0 N_samples: 11
# > > > > [cluster_id=913] N_children: 0 N_samples: 11
# ...
# > > > > [cluster_id=1914] N_children: 0 N_samples: 5
# > > > > [cluster_id=1915] N_children: 0 N_samples: 15
# > > > > [cluster_id=1916] N_children: 0 N_samples: 17
# > > > > [cluster_id=1917] N_children: 0 N_samples: 8
# > > > > [cluster_id=1918] N_children: 0 N_samples: 20
# > > > > [cluster_id=1919] N_children: 0 N_samples: 7
# > > > > [cluster_id=1920] N_children: 0 N_samples: 7
# > > > > [cluster_id=1921] N_children: 0 N_samples: 3
# > > > > [cluster_id=1922] N_children: 0 N_samples: 13
# > > > [cluster_id=1923] N_children: 7 N_samples: 51
# > > > > [cluster_id=1924] N_children: 0 N_samples: 5
# > > > > [cluster_id=1925] N_children: 0 N_samples: 5
# > > > > [cluster_id=1926] N_children: 0 N_samples: 10
# > > > > [cluster_id=1927] N_children: 0 N_samples: 16
# > > > > [cluster_id=1928] N_children: 0 N_samples: 7
# > > > > [cluster_id=1929] N_children: 0 N_samples: 1
# > > > > [cluster_id=1930] N_children: 0 N_samples: 7
# > > > [cluster_id=1931] N_children: 0 N_samples: 16
# > > > [cluster_id=1932] N_children: 9 N_samples: 109
# > > > > [cluster_id=1933] N_children: 0 N_samples: 4
# > > > > [cluster_id=1934] N_children: 0 N_samples: 25
# > > > > [cluster_id=1935] N_children: 0 N_samples: 4
# > > > > [cluster_id=1936] N_children: 0 N_samples: 18
# > > > > [cluster_id=1937] N_children: 0 N_samples: 16
# > > > > [cluster_id=1938] N_children: 0 N_samples: 2
# > > > > [cluster_id=1939] N_children: 0 N_samples: 14
# > > > > [cluster_id=1940] N_children: 0 N_samples: 6
# > > > > [cluster_id=1941] N_children: 0 N_samples: 20
# > > > [cluster_id=1942] N_children: 7 N_samples: 81
# > > > > [cluster_id=1943] N_children: 0 N_samples: 14
# > > > > [cluster_id=1944] N_children: 0 N_samples: 15
# > > > > [cluster_id=1945] N_children: 0 N_samples: 2
# > > > > [cluster_id=1946] N_children: 0 N_samples: 8
# > > > > [cluster_id=1947] N_children: 0 N_samples: 29
# > > > > [cluster_id=1948] N_children: 0 N_samples: 5
# > > > > [cluster_id=1949] N_children: 0 N_samples: 8
# > > > [cluster_id=1950] N_children: 13 N_samples: 179
# > > > > [cluster_id=1951] N_children: 0 N_samples: 12
# > > > > [cluster_id=1952] N_children: 0 N_samples: 17
# > > > > [cluster_id=1953] N_children: 0 N_samples: 18
# > > > > [cluster_id=1954] N_children: 0 N_samples: 23
# > > > > [cluster_id=1955] N_children: 0 N_samples: 6
# > > > > [cluster_id=1956] N_children: 0 N_samples: 14
# > > > > [cluster_id=1957] N_children: 0 N_samples: 13
# > > > > [cluster_id=1958] N_children: 0 N_samples: 7
# > > > > [cluster_id=1959] N_children: 0 N_samples: 7
# > > > > [cluster_id=1960] N_children: 0 N_samples: 14
# > > > > [cluster_id=1961] N_children: 0 N_samples: 14
# > > > > [cluster_id=1962] N_children: 0 N_samples: 19
# > > > > [cluster_id=1963] N_children: 0 N_samples: 15
# > > > [cluster_id=1964] N_children: 2 N_samples: 22
# > > > > [cluster_id=1965] N_children: 0 N_samples: 8
# > > > > [cluster_id=1966] N_children: 0 N_samples: 14
# > > > [cluster_id=1967] N_children: 10 N_samples: 93
# > > > > [cluster_id=1968] N_children: 0 N_samples: 3
# > > > > [cluster_id=1969] N_children: 0 N_samples: 12
# > > > > [cluster_id=1970] N_children: 0 N_samples: 2
# > > > > [cluster_id=1971] N_children: 0 N_samples: 18
# > > > > [cluster_id=1972] N_children: 0 N_samples: 14
# > > > > [cluster_id=1973] N_children: 0 N_samples: 20
# > > > > [cluster_id=1974] N_children: 0 N_samples: 11
# > > > > [cluster_id=1975] N_children: 0 N_samples: 1
# > > > > [cluster_id=1976] N_children: 0 N_samples: 4
# > > > > [cluster_id=1977] N_children: 0 N_samples: 8
# > > > [cluster_id=1978] N_children: 16 N_samples: 199
# > > > > [cluster_id=1979] N_children: 0 N_samples: 7
# > > > > [cluster_id=1980] N_children: 0 N_samples: 12
# > > > > [cluster_id=1981] N_children: 0 N_samples: 12
# > > > > [cluster_id=1982] N_children: 0 N_samples: 19
# > > > > [cluster_id=1983] N_children: 0 N_samples: 6
# > > > > [cluster_id=1984] N_children: 0 N_samples: 12
# > > > > [cluster_id=1985] N_children: 0 N_samples: 16
# > > > > [cluster_id=1986] N_children: 0 N_samples: 20
# > > > > [cluster_id=1987] N_children: 0 N_samples: 17
# > > > > [cluster_id=1988] N_children: 0 N_samples: 9
# > > > > [cluster_id=1989] N_children: 0 N_samples: 4
# > > > > [cluster_id=1990] N_children: 0 N_samples: 13
# > > > > [cluster_id=1991] N_children: 0 N_samples: 19
# > > > > [cluster_id=1992] N_children: 0 N_samples: 20
# > > > > [cluster_id=1993] N_children: 0 N_samples: 9
# > > > > [cluster_id=1994] N_children: 0 N_samples: 4
# > > > [cluster_id=1995] N_children: 0 N_samples: 7
# > > > [cluster_id=1996] N_children: 9 N_samples: 207
# > > > > [cluster_id=1997] N_children: 0 N_samples: 12
# > > > > [cluster_id=1998] N_children: 0 N_samples: 7
# > > > > [cluster_id=1999] N_children: 0 N_samples: 13
# > > > > [cluster_id=2000] N_children: 0 N_samples: 5
# > > > > [cluster_id=2001] N_children: 0 N_samples: 9
# > > > > [cluster_id=2002] N_children: 0 N_samples: 17
# > > > > [cluster_id=2003] N_children: 0 N_samples: 4
# > > > > [cluster_id=2004] N_children: 0 N_samples: 132
# > > > > [cluster_id=2005] N_children: 0 N_samples: 8
# > > [cluster_id=2006] N_children: 16 N_samples: 2091
# > > > [cluster_id=2007] N_children: 13 N_samples: 149
# > > > > [cluster_id=2008] N_children: 0 N_samples: 1
# > > > > [cluster_id=2009] N_children: 0 N_samples: 18
# > > > > [cluster_id=2010] N_children: 0 N_samples: 8
# > > > > [cluster_id=2011] N_children: 0 N_samples: 11
# > > > > [cluster_id=2012] N_children: 0 N_samples: 2
# > > > > [cluster_id=2013] N_children: 0 N_samples: 23
# > > > > [cluster_id=2014] N_children: 0 N_samples: 13
# > > > > [cluster_id=2015] N_children: 0 N_samples: 16
# > > > > [cluster_id=2016] N_children: 0 N_samples: 17
# > > > > [cluster_id=2017] N_children: 0 N_samples: 13
# > > > > [cluster_id=2018] N_children: 0 N_samples: 11
# > > > > [cluster_id=2019] N_children: 0 N_samples: 13
# > > > > [cluster_id=2020] N_children: 0 N_samples: 3
# > > > [cluster_id=2021] N_children: 17 N_samples: 248
# > > > > [cluster_id=2022] N_children: 0 N_samples: 13
# > > > > [cluster_id=2023] N_children: 0 N_samples: 14
# > > > > [cluster_id=2024] N_children: 0 N_samples: 21
# > > > > [cluster_id=2025] N_children: 0 N_samples: 17
# > > > > [cluster_id=2026] N_children: 0 N_samples: 10
# > > > > [cluster_id=2027] N_children: 0 N_samples: 21
# > > > > [cluster_id=2028] N_children: 0 N_samples: 13
# > > > > [cluster_id=2029] N_children: 0 N_samples: 17
# > > > > [cluster_id=2030] N_children: 0 N_samples: 20
# > > > > [cluster_id=2031] N_children: 0 N_samples: 18
# > > > > [cluster_id=2032] N_children: 0 N_samples: 21
# > > > > [cluster_id=2033] N_children: 0 N_samples: 9
# > > > > [cluster_id=2034] N_children: 0 N_samples: 20
# > > > > [cluster_id=2035] N_children: 0 N_samples: 12
# > > > > [cluster_id=2036] N_children: 0 N_samples: 4
# > > > > [cluster_id=2037] N_children: 0 N_samples: 10
# > > > > [cluster_id=2038] N_children: 0 N_samples: 8
# > > > [cluster_id=2039] N_children: 3 N_samples: 33
# > > > > [cluster_id=2040] N_children: 0 N_samples: 15
# > > > > [cluster_id=2041] N_children: 0 N_samples: 10
# > > > > [cluster_id=2042] N_children: 0 N_samples: 8
# > > > [cluster_id=2043] N_children: 13 N_samples: 181
# > > > > [cluster_id=2044] N_children: 0 N_samples: 10
# > > > > [cluster_id=2045] N_children: 0 N_samples: 19
# > > > > [cluster_id=2046] N_children: 0 N_samples: 2
# > > > > [cluster_id=2047] N_children: 0 N_samples: 18
# > > > > [cluster_id=2048] N_children: 0 N_samples: 20
# > > > > [cluster_id=2049] N_children: 0 N_samples: 16
# > > > > [cluster_id=2050] N_children: 0 N_samples: 9
# > > > > [cluster_id=2051] N_children: 0 N_samples: 13
# > > > > [cluster_id=2052] N_children: 0 N_samples: 19
# > > > > [cluster_id=2053] N_children: 0 N_samples: 12
# > > > > [cluster_id=2054] N_children: 0 N_samples: 16
# > > > > [cluster_id=2055] N_children: 0 N_samples: 12
# > > > > [cluster_id=2056] N_children: 0 N_samples: 15
# > > > [cluster_id=2057] N_children: 0 N_samples: 3
# > > > [cluster_id=2058] N_children: 0 N_samples: 9
# > > > [cluster_id=2059] N_children: 9 N_samples: 127
# > > > > [cluster_id=2060] N_children: 0 N_samples: 21
# > > > > [cluster_id=2061] N_children: 0 N_samples: 8
# > > > > [cluster_id=2062] N_children: 0 N_samples: 19
# > > > > [cluster_id=2063] N_children: 0 N_samples: 14
# > > > > [cluster_id=2064] N_children: 0 N_samples: 18
# > > > > [cluster_id=2065] N_children: 0 N_samples: 11
# > > > > [cluster_id=2066] N_children: 0 N_samples: 20
# > > > > [cluster_id=2067] N_children: 0 N_samples: 13
# > > > > [cluster_id=2068] N_children: 0 N_samples: 3
# > > > [cluster_id=2069] N_children: 18 N_samples: 257
# > > > > [cluster_id=2070] N_children: 0 N_samples: 18
# > > > > [cluster_id=2071] N_children: 0 N_samples: 19
# > > > > [cluster_id=2072] N_children: 0 N_samples: 21
# > > > > [cluster_id=2073] N_children: 0 N_samples: 16
# > > > > [cluster_id=2074] N_children: 0 N_samples: 12
# > > > > [cluster_id=2075] N_children: 0 N_samples: 20
# > > > > [cluster_id=2076] N_children: 0 N_samples: 21
# > > > > [cluster_id=2077] N_children: 0 N_samples: 12
# > > > > [cluster_id=2078] N_children: 0 N_samples: 18
# > > > > [cluster_id=2079] N_children: 0 N_samples: 11
# > > > > [cluster_id=2080] N_children: 0 N_samples: 14
# > > > > [cluster_id=2081] N_children: 0 N_samples: 5
# > > > > [cluster_id=2082] N_children: 0 N_samples: 19
# > > > > [cluster_id=2083] N_children: 0 N_samples: 9
# > > > > [cluster_id=2084] N_children: 0 N_samples: 14
# > > > > [cluster_id=2085] N_children: 0 N_samples: 13
# > > > > [cluster_id=2086] N_children: 0 N_samples: 6
# > > > > [cluster_id=2087] N_children: 0 N_samples: 9
# > > > [cluster_id=2088] N_children: 15 N_samples: 180
# > > > > [cluster_id=2089] N_children: 0 N_samples: 11
# > > > > [cluster_id=2090] N_children: 0 N_samples: 9
# > > > > [cluster_id=2091] N_children: 0 N_samples: 15
# > > > > [cluster_id=2092] N_children: 0 N_samples: 10
# > > > > [cluster_id=2093] N_children: 0 N_samples: 11
# > > > > [cluster_id=2094] N_children: 0 N_samples: 18
# > > > > [cluster_id=2095] N_children: 0 N_samples: 15
# > > > > [cluster_id=2096] N_children: 0 N_samples: 13
# > > > > [cluster_id=2097] N_children: 0 N_samples: 7
# > > > > [cluster_id=2098] N_children: 0 N_samples: 18
# > > > > [cluster_id=2099] N_children: 0 N_samples: 22
# > > > > [cluster_id=2100] N_children: 0 N_samples: 1
# > > > > [cluster_id=2101] N_children: 0 N_samples: 10
# > > > > [cluster_id=2102] N_children: 0 N_samples: 5
# > > > > [cluster_id=2103] N_children: 0 N_samples: 15
# > > > [cluster_id=2104] N_children: 9 N_samples: 112
# > > > > [cluster_id=2105] N_children: 0 N_samples: 12
# > > > > [cluster_id=2106] N_children: 0 N_samples: 21
# > > > > [cluster_id=2107] N_children: 0 N_samples: 5
# > > > > [cluster_id=2108] N_children: 0 N_samples: 1
# > > > > [cluster_id=2109] N_children: 0 N_samples: 23
# > > > > [cluster_id=2110] N_children: 0 N_samples: 1
# > > > > [cluster_id=2111] N_children: 0 N_samples: 19
# > > > > [cluster_id=2112] N_children: 0 N_samples: 12
# > > > > [cluster_id=2113] N_children: 0 N_samples: 18
# > > > [cluster_id=2114] N_children: 11 N_samples: 131
# > > > > [cluster_id=2115] N_children: 0 N_samples: 5
# > > > > [cluster_id=2116] N_children: 0 N_samples: 18
# > > > > [cluster_id=2117] N_children: 0 N_samples: 19
# > > > > [cluster_id=2118] N_children: 0 N_samples: 9
# > > > > [cluster_id=2119] N_children: 0 N_samples: 9
# > > > > [cluster_id=2120] N_children: 0 N_samples: 13
# > > > > [cluster_id=2121] N_children: 0 N_samples: 8
# > > > > [cluster_id=2122] N_children: 0 N_samples: 14
# > > > > [cluster_id=2123] N_children: 0 N_samples: 16
# > > > > [cluster_id=2124] N_children: 0 N_samples: 7
# > > > > [cluster_id=2125] N_children: 0 N_samples: 13
# > > > [cluster_id=2126] N_children: 8 N_samples: 95
# > > > > [cluster_id=2127] N_children: 0 N_samples: 2
# > > > > [cluster_id=2128] N_children: 0 N_samples: 19
# > > > > [cluster_id=2129] N_children: 0 N_samples: 5
# > > > > [cluster_id=2130] N_children: 0 N_samples: 16
# > > > > [cluster_id=2131] N_children: 0 N_samples: 16
# > > > > [cluster_id=2132] N_children: 0 N_samples: 10
# > > > > [cluster_id=2133] N_children: 0 N_samples: 19
# > > > > [cluster_id=2134] N_children: 0 N_samples: 8
# > > > [cluster_id=2135] N_children: 17 N_samples: 228
# > > > > [cluster_id=2136] N_children: 0 N_samples: 15
# > > > > [cluster_id=2137] N_children: 0 N_samples: 13
# > > > > [cluster_id=2138] N_children: 0 N_samples: 19
# > > > > [cluster_id=2139] N_children: 0 N_samples: 14
# > > > > [cluster_id=2140] N_children: 0 N_samples: 7
# > > > > [cluster_id=2141] N_children: 0 N_samples: 14
# > > > > [cluster_id=2142] N_children: 0 N_samples: 9
# > > > > [cluster_id=2143] N_children: 0 N_samples: 17
# > > > > [cluster_id=2144] N_children: 0 N_samples: 16
# > > > > [cluster_id=2145] N_children: 0 N_samples: 15
# > > > > [cluster_id=2146] N_children: 0 N_samples: 14
# > > > > [cluster_id=2147] N_children: 0 N_samples: 15
# > > > > [cluster_id=2148] N_children: 0 N_samples: 3
# > > > > [cluster_id=2149] N_children: 0 N_samples: 17
# > > > > [cluster_id=2150] N_children: 0 N_samples: 18
# > > > > [cluster_id=2151] N_children: 0 N_samples: 7
# > > > > [cluster_id=2152] N_children: 0 N_samples: 15
# > > > [cluster_id=2153] N_children: 12 N_samples: 153
# > > > > [cluster_id=2154] N_children: 0 N_samples: 11
# > > > > [cluster_id=2155] N_children: 0 N_samples: 16
# > > > > [cluster_id=2156] N_children: 0 N_samples: 10
# > > > > [cluster_id=2157] N_children: 0 N_samples: 12
# > > > > [cluster_id=2158] N_children: 0 N_samples: 7
# > > > > [cluster_id=2159] N_children: 0 N_samples: 20
# > > > > [cluster_id=2160] N_children: 0 N_samples: 12
# > > > > [cluster_id=2161] N_children: 0 N_samples: 13
# > > > > [cluster_id=2162] N_children: 0 N_samples: 20
# > > > > [cluster_id=2163] N_children: 0 N_samples: 14
# > > > > [cluster_id=2164] N_children: 0 N_samples: 8
# > > > > [cluster_id=2165] N_children: 0 N_samples: 10
# > > > [cluster_id=2166] N_children: 14 N_samples: 152
# > > > > [cluster_id=2167] N_children: 0 N_samples: 5
# > > > > [cluster_id=2168] N_children: 0 N_samples: 3
# > > > > [cluster_id=2169] N_children: 0 N_samples: 2
# > > > > [cluster_id=2170] N_children: 0 N_samples: 19
# > > > > [cluster_id=2171] N_children: 0 N_samples: 21
# > > > > [cluster_id=2172] N_children: 0 N_samples: 14
# > > > > [cluster_id=2173] N_children: 0 N_samples: 20
# > > > > [cluster_id=2174] N_children: 0 N_samples: 1
# > > > > [cluster_id=2175] N_children: 0 N_samples: 13
# > > > > [cluster_id=2176] N_children: 0 N_samples: 1
# > > > > [cluster_id=2177] N_children: 0 N_samples: 16
# > > > > [cluster_id=2178] N_children: 0 N_samples: 17
# > > > > [cluster_id=2179] N_children: 0 N_samples: 1
# > > > > [cluster_id=2180] N_children: 0 N_samples: 19
# > > > [cluster_id=2181] N_children: 3 N_samples: 33
# > > > > [cluster_id=2182] N_children: 0 N_samples: 17
# > > > > [cluster_id=2183] N_children: 0 N_samples: 1
# > > > > [cluster_id=2184] N_children: 0 N_samples: 15
# > > [cluster_id=2185] N_children: 20 N_samples: 214
# > > > [cluster_id=2186] N_children: 0 N_samples: 18
# > > > [cluster_id=2187] N_children: 0 N_samples: 5
# > > > [cluster_id=2188] N_children: 0 N_samples: 16
# > > > [cluster_id=2189] N_children: 0 N_samples: 10
# > > > [cluster_id=2190] N_children: 0 N_samples: 14
# > > > [cluster_id=2191] N_children: 0 N_samples: 15
# > > > [cluster_id=2192] N_children: 0 N_samples: 2
# > > > [cluster_id=2193] N_children: 0 N_samples: 8
# > > > [cluster_id=2194] N_children: 0 N_samples: 20
# > > > [cluster_id=2195] N_children: 0 N_samples: 15
# > > > [cluster_id=2196] N_children: 0 N_samples: 11
# > > > [cluster_id=2197] N_children: 0 N_samples: 15
# > > > [cluster_id=2198] N_children: 0 N_samples: 9
# > > > [cluster_id=2199] N_children: 0 N_samples: 16
# > > > [cluster_id=2200] N_children: 0 N_samples: 10
# > > > [cluster_id=2201] N_children: 0 N_samples: 7
# > > > [cluster_id=2202] N_children: 0 N_samples: 1
# > > > [cluster_id=2203] N_children: 0 N_samples: 8
# > > > [cluster_id=2204] N_children: 0 N_samples: 4
# > > > [cluster_id=2205] N_children: 0 N_samples: 10
# > [cluster_id=2206] N_children: 6 N_samples: 65
# > > [cluster_id=2207] N_children: 0 N_samples: 10
# > > [cluster_id=2208] N_children: 0 N_samples: 13
# > > [cluster_id=2209] N_children: 0 N_samples: 17
# > > [cluster_id=2210] N_children: 0 N_samples: 6
# > > [cluster_id=2211] N_children: 0 N_samples: 1
# > > [cluster_id=2212] N_children: 0 N_samples: 18

# %%
# Saving Model
cluster_tree_dict = {'cluster': cluster, 'cluster_tree': cluster_tree, 'max_depth': max_depth}
with open('Data/NSL-KDD/modified/birch_model.h5', 'wb') as config_dictionary_file:
    pickle.dump(cluster_tree, config_dictionary_file)

# %%
# Loading Test Data
file = 'Data/NSL-KDD/modified/test.csv'
test_X,test_y = load_mutated_data(file,'defects')

# %%
# Birch classifier score(mention depth)
print(max_depth)
depth = 1
predicted = cluster.predict_new(test_X,test_y,depth,False)

# %%
# Check for outlies detected
total = 0
j = 0
for i in cluster_tree:
    if len(cluster_tree[i].test_points) == 0:
        continue
    print("Percentage Identified",len(cluster_tree[i].data_points),len(cluster_tree[i].test_points),len(cluster_tree[i].outlier_points)/len(cluster_tree[i].test_points))
    b = collections.Counter(cluster_tree[i].test_labels)
    j += 1
    total += len(cluster_tree[i].outlier_points)
print(j,total)

# %%
# Precison Recall on outliers
test_y_1 = []
predicted_1 = []
for i in cluster_tree:
    if len(cluster_tree[i].test_points) == 0:
        continue
    test_y_1.append(cluster_tree[i].test_labels)
    predicted_1.append(cluster_tree[i].outlier_points_prediction)
_test_y = [item for sublist in test_y_1 for item in sublist]
_predicted = [item for sublist in predicted_1 for item in sublist]
print(metrics.classification_report(_test_y, _predicted))

# %%
# Printing the Tree with data point distribution
tree = {'0': {}, '1': {}, '2': {}, '3': {}, '4': {}}
for i in cluster_tree:
    a = collections.Counter(cluster_tree[i].data_labels)
    tree[str(cluster_tree[i].depth)][i] = a
    dpt_print = ''
    for j in range(cluster_tree[i].depth):
        dpt_print += '> '
    print(dpt_print, "Cluster_id:",i,a,cluster_tree[i].depth)

# %%
for depth in tree:
    dpt_print = ''
    for j in range(int(depth)):
        dpt_print += '> '
    for cluster in tree[depth]:
        print(dpt_print, "Cluster_id: ",cluster, 'labels: ', tree[depth][cluster])

# %%
predicted = cluster_tree[0].outlier_model.predict(test_X)

# %%
print(metrics.classification_report(test_y, _predicted))
