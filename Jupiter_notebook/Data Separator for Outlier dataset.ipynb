# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

# %%
data_path = 'Data/KDD/kddcup10_dummied_normalized.csv'
df = pd.read_csv(data_path)
print(df.shape)
# Out:
# (494021, 118)

# %%
data_path = 'Data/KDD/kddcup10.csv'
df = pd.read_csv(data_path)
# create dummy variables(use only once to modify the dataset)
def create_data_pca(df,target):
    df_change = df[['protocol_type', 'service','flag']]
    df = df.drop(labels = ['protocol_type', 'service','flag'], axis = 1)
    df_change = pd.get_dummies(df_change, prefix=['protocol_type', 'service','flag'])
    df = df.merge(df_change,left_index=True, right_index=True)
    y = df[target].values
    X = df.drop(labels = target, axis = 1)
    pca = PCA(n_components=10)
    X = pca.fit_transform(X)
    df = pd.DataFrame(X)
    df['defects'] = y
    df.to_csv('Data/KDD/kddcup10_dummied.csv', index = False)
    return df
df = create_data_pca(df,'defects')

# %%
data_path = 'Data/KDD/kddcup10.csv'
df = pd.read_csv(data_path)
# create dummy variables(use only once to modify the dataset)
def create_data(df,target):
    df_change = df[['protocol_type', 'service','flag']]
    df = df.drop(labels = ['protocol_type', 'service','flag'], axis = 1)
    df_change = pd.get_dummies(df_change, prefix=['protocol_type', 'service','flag'])
    df = df.merge(df_change,left_index=True, right_index=True)
    df.to_csv('Data/KDD/kddcup10_dummied.csv', index = False)
    return df
df = create_data(df,'defects')

# %%
data_path = 'Data/KDD/kddcup10.csv'
df = pd.read_csv(data_path)
# create dummy variables(use only once to modify the dataset)
def create_data_normalized(df,target):
    df_change = df[['protocol_type', 'service','flag']]
    df = df.drop(labels = ['protocol_type', 'service','flag'], axis = 1)
    df_change = pd.get_dummies(df_change, prefix=['protocol_type', 'service','flag'])
    df = df.merge(df_change,left_index=True, right_index=True)
    columns = df.columns
    y = df[target]
    X = df.drop(labels = target, axis = 1)
    min_max_scaler = preprocessing.StandardScaler()
    np_scaled = min_max_scaler.fit_transform(X)
    data = pd.DataFrame(np_scaled, columns = columns[:-1])
    df = data.assign(defects = y.values.tolist())
    df.to_csv('Data/KDD/kddcup10_dummied_normalized.csv', index = False)
    return df
df = create_data_normalized(df,'defects')

# %%
targets = df.defects.unique()

# %%
# Get class wise dataset
targets = df.defects.unique()
for target in targets:
    sub_data_path = 'Data/KDD/modified/kddcup10_' + target.split('.')[0] + '.csv'
    sub_df = df[df['defects'] == target].reset_index(drop = True)
    sub_df.to_csv(sub_data_path, index = False)

# %%
# Create training set with 2 classes
class1_path = 'Data/KDD/modified/kddcup10_normal.csv'
df_class1 = pd.read_csv(class1_path)
class2_path = 'Data/KDD/modified/kddcup10_neptune.csv'
df_class2 = pd.read_csv(class2_path)
train_df = pd.concat([df_class1, df_class2], ignore_index=True)
train_df_path = 'Data/KDD/modified/train.csv'
train_df.to_csv(train_df_path, index = False)

# %%
# Create training set with 1 classes
class1_path = 'Data/KDD/modified/kddcup10_normal.csv'
df_class1 = pd.read_csv(class1_path)
train_df = df_class1
train_df_path = 'Data/KDD/modified/train.csv'
train_df.to_csv(train_df_path, index = False)

# %%
# Create training set with all classes
target = 'defects'
y = df[target]
X = df.drop(labels = target, axis = 1)
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.50, random_state=42)
train_df = train_X
train_df[target] = train_y
train_df_path = 'Data/KDD/modified/train.csv'
train_df.to_csv(train_df_path, index = False)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
# Create Test Dataset
test_df = pd.DataFrame([])
for target in targets:
    sub_data_path = 'Data/KDD/modified/kddcup10_' + target.split('.')[0] + '.csv'
    if target.split('.')[0] not in ['normal']: #'neptune','smurf'
        sub_df = df[df['defects'] == target].reset_index(drop = True)
        test_df = pd.concat([test_df,sub_df], ignore_index=True)
test_df_path = 'Data/KDD/modified/test.csv'
test_df.to_csv(test_df_path, index = False)

# %%
train_df.groupby('defects').count()
# Out:
#                        0       1       2       3       4       5       6  \
# defects
# back.               1106    1106    1106    1106    1106    1106    1106
# buffer_overflow.      15      15      15      15      15      15      15
# ftp_write.             6       6       6       6       6       6       6
# guess_passwd.         29      29      29      29      29      29      29
# imap.                  8       8       8       8       8       8       8
# ipsweep.             629     629     629     629     629     629     629
# land.                 11      11      11      11      11      11      11
# loadmodule.            6       6       6       6       6       6       6
# multihop.              5       5       5       5       5       5       5
# neptune.           53680   53680   53680   53680   53680   53680   53680
# nmap.                121     121     121     121     121     121     121
# normal.            48628   48628   48628   48628   48628   48628   48628
# perl.                  1       1       1       1       1       1       1
# phf.                   3       3       3       3       3       3       3
# pod.                 146     146     146     146     146     146     146
# portsweep.           523     523     523     523     523     523     523
# rootkit.               6       6       6       6       6       6       6
# satan.               827     827     827     827     827     827     827
# smurf.            140247  140247  140247  140247  140247  140247  140247
# spy.                   2       2       2       2       2       2       2
# teardrop.            492     492     492     492     492     492     492
# warezclient.         509     509     509     509     509     509     509
# warezmaster.          10      10      10      10      10      10      10
#
#                        7       8       9
# defects
# back.               1106    1106    1106
# buffer_overflow.      15      15      15
# ftp_write.             6       6       6
# guess_passwd.         29      29      29
# imap.                  8       8       8
# ipsweep.             629     629     629
# land.                 11      11      11
# loadmodule.            6       6       6
# multihop.              5       5       5
# neptune.           53680   53680   53680
# nmap.                121     121     121
# normal.            48628   48628   48628
# perl.                  1       1       1
# phf.                   3       3       3
# pod.                 146     146     146
# portsweep.           523     523     523
# rootkit.               6       6       6
# satan.               827     827     827
# smurf.            140247  140247  140247
# spy.                   2       2       2
# teardrop.            492     492     492
# warezclient.         509     509     509
# warezmaster.          10      10      10

# %%
train_df.shape
# Out:
# (247010, 11)
